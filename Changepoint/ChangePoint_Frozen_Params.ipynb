# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-06-26 23:55:53.932611: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-26 23:55:54.016602: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-26 23:55:54.348080: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-26 23:55:54.350088: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 23:55:55.948694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)
# Out:
# 2023-06-26 23:55:58.910617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-06-26 23:55:58.910651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: c3101.swan.hcc.unl.edu
# 2023-06-26 23:55:58.910658: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: c3101.swan.hcc.unl.edu
# 2023-06-26 23:55:58.910770: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 525.116.4
# 2023-06-26 23:55:58.910789: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 525.116.4
# 2023-06-26 23:55:58.910794: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 525.116.4

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_heavy_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_heavy_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 5.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.90, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [46.937980677625916, 1101.1872203979399] [3.3562604792193174, 60.42440648700525]
# Smiles Weight Mean and Std Dev
# 0.5242301707761243 0.26061248578420004
# Smiles Weight CI
# 0.08194234181201711 0.9497537575933586
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.96316343 49.01572435] [ 3.18270728 66.36424479] [1.07409103 1.35393786]
# (Manually) Weighted RMSE Train
# [ 3.35626048 60.42440649]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [30.447581854097628, 669.5030597857238] [2.5083379620160198, 61.138933678386955]
# Smiles Weight Mean and Std Dev
# 0.5114947240717628 0.23448113764559636
# Smiles Weight CI
# 0.10694744563616758 0.9242359473131447
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.7451908 52.0165154] [ 2.58357607 64.20185222] [0.94112805 1.234259  ]
# (Manually) Weighted RMSE Train
# [ 2.50833796 61.13893368]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [22.16811324613526, 491.8382866908945] [2.292163120509621, 54.55410264140515]
# Smiles Weight Mean and Std Dev
# 0.49789489560904243 0.20912497905849503
# Smiles Weight CI
# 0.13154080597236892 0.9016426580027295
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.41595842 49.60399667] [ 2.68014691 59.78198265] [1.10935143 1.2051848 ]
# (Manually) Weighted RMSE Train
# [ 2.29216312 54.55410264]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [14.358270974049706, 376.71044837755704] [2.1217147363461915, 51.76621071192193]
# Smiles Weight Mean and Std Dev
# 0.4903293457994375 0.18177924881050533
# Smiles Weight CI
# 0.19408231330679915 0.8122290722462779
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.29580612 47.47125523] [ 2.6267072  57.77231615] [1.14413285 1.21699576]
# (Manually) Weighted RMSE Train
# [ 2.12171474 51.76621071]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [10.466738628528145, 255.49288590880445] [1.8687907668026198, 46.92054222754786]
# Smiles Weight Mean and Std Dev
# 0.5178749613013995 0.16687069462064344
# Smiles Weight CI
# 0.21673489989291495 0.8197475816478708
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87531202 40.16348883] [ 2.80388021 62.60126796] [1.49515397 1.55866111]
# (Manually) Weighted RMSE Train
# [ 1.86879077 46.92054223]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [7.179017125460425, 155.45799675706633] [1.0550173168201094, 31.10489160720638]
# Smiles Weight Mean and Std Dev
# 0.6194722043982366 0.1272005647529101
# Smiles Weight CI
# 0.3812794640113913 0.8494226980089976
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32843667 29.38516693] [ 2.57921612 58.25017257] [1.9415424  1.98229851]
# (Manually) Weighted RMSE Train
# [ 1.05501732 31.10489161]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.924481897437849, 111.59658323140876] [0.6753228281600221, 20.363018373764543]
# Smiles Weight Mean and Std Dev
# 0.6673401018601083 0.10656681791553742
# Smiles Weight CI
# 0.45999928175911786 0.8649772508731424
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.99004285 19.88580419] [ 2.48201299 59.12254755] [2.50697531 2.97310317]
# (Manually) Weighted RMSE Train
# [ 0.67532283 20.36301837]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.3404920144560273, 80.76474275132284] [0.43357233200957745, 9.076275364160235]
# Smiles Weight Mean and Std Dev
# 0.7098339216395556 0.08880958483961982
# Smiles Weight CI
# 0.5080619580873663 0.8594677187566736
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.73047129 14.56482381] [ 2.46023079 53.0890055 ] [3.36800478 3.64501529]
# (Manually) Weighted RMSE Train
# [0.43357233 9.07627536]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.291174771249692, 55.601571970722475] [0.2374066971397822, 6.598582955169302]
# Smiles Weight Mean and Std Dev
# 0.7028182420929541 0.08442283689185928
# Smiles Weight CI
# 0.5413412465638613 0.8310947834638975
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.54024875 12.39691017] [ 2.48628079 51.94298924] [4.60210373 4.18999481]
# (Manually) Weighted RMSE Train
# [0.2374067  6.59858296]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.9602285218975803, 42.340624698820285] [0.19265783100554612, 4.9573426158181055]
# Smiles Weight Mean and Std Dev
# 0.6902146940369601 0.0786154267539834
# Smiles Weight CI
# 0.5314042254339606 0.8265917309144813
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48346209 11.43280959] [ 2.48572755 52.01134312] [5.14151488 4.54930546]
# (Manually) Weighted RMSE Train
# [0.19265783 4.95734262]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.5353965519461392, 36.30991392397061] [0.15384467682870562, 4.129507297277674]
# Smiles Weight Mean and Std Dev
# 0.6899373080823628 0.07279946661192692
# Smiles Weight CI
# 0.5387532318095063 0.8135161573651591
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.43817903 9.40646684] [ 2.48090679 51.63407474] [5.66185654 5.48921031]
# (Manually) Weighted RMSE Train
# [0.15384468 4.1295073 ]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.317442019154423, 29.98732665039368] [0.1515223748439454, 3.640578939294487]
# Smiles Weight Mean and Std Dev
# 0.6806936702926492 0.07298858459402983
# Smiles Weight CI
# 0.5367237073619173 0.7995050160852712
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.45122878 9.4508581 ] [ 2.46781494 52.03550234] [5.46909922 5.50590241]
# (Manually) Weighted RMSE Train
# [0.15152237 3.64057894]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9979144942648592] [1.1900832480792114, 25.946719750619273] [0.1502325511842021, 3.5443952380059387]
# Smiles Weight Mean and Std Dev
# 0.6781116789946986 0.06621272398998387
# Smiles Weight CI
# 0.5494955383781204 0.8049365270148532
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.43396284 8.95771218] [ 2.50269664 52.3051523 ] [5.76707587 5.83911955]
# (Manually) Weighted RMSE Train
# [0.15023255 3.54439524]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9947862356621481] [1.132074242878803, 23.450669729107286] [0.15719776126338775, 3.43254566363846]
# Smiles Weight Mean and Std Dev
# 0.6693787853325287 0.062726419798007
# Smiles Weight CI
# 0.5398251192198622 0.7713287772689001
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.43335351 9.49211727] [ 2.50732245 52.40513479] [5.78585934 5.52091102]
# (Manually) Weighted RMSE Train
# [0.15719776 3.43254566]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9958289885297185] [1.0346317705042773, 22.009115186744893] [0.15563473440362496, 3.277465831192753]
# Smiles Weight Mean and Std Dev
# 0.6640274803553922 0.06389005562189093
# Smiles Weight CI
# 0.5349551509593877 0.7735300435018998
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.42510873 9.35528685] [ 2.51101239 52.17003511] [5.90675334 5.57652972]
# (Manually) Weighted RMSE Train
# [0.15563473 3.27746583]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9822732012513035, 0.9916579770594369] [0.9991151029538445, 23.01455869066953] [0.15381194820728555, 3.345428915113728]
# Smiles Weight Mean and Std Dev
# 0.6669152994149149 0.07218336212125571
# Smiles Weight CI
# 0.5153585006464682 0.798751514614948
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.41032912 9.11106592] [ 2.5171554  52.30517299] [6.13447913 5.74084014]
# (Manually) Weighted RMSE Train
# [0.15381195 3.34542892]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9906152241918665] [0.888053348087106, 20.60486209356808] [0.15222253797705257, 3.271457926623429]
# Smiles Weight Mean and Std Dev
# 0.6681554063660163 0.0685047202604522
# Smiles Weight CI
# 0.5294685745749592 0.7851480165688701
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39594384 9.09735184] [ 2.53038366 52.34605463] [6.39076396 5.75398814]
# (Manually) Weighted RMSE Train
# [0.15222254 3.27145793]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9603753910323254, 0.986444212721585] [0.8113717843841558, 18.24910198606829] [0.15521959626344276, 3.3756739332118175]
# Smiles Weight Mean and Std Dev
# 0.6648283105962559 0.05804434294465841
# Smiles Weight CI
# 0.5427933462343619 0.7590063955917982
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39869313 8.92534055] [ 2.52871358 52.18151733] [6.342506   5.84644552]
# (Manually) Weighted RMSE Train
# [0.1552196  3.37567393]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.9854014598540146] [0.7828400357756597, 19.043381991309122] [0.1551708177825103, 3.211999709000699]
# Smiles Weight Mean and Std Dev
# 0.6661175786967725 0.06098116173045831
# Smiles Weight CI
# 0.5450733576539697 0.7795604064655522
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39305666 8.88739658] [ 2.53164108 52.28123265] [6.44090619 5.88262627]
# (Manually) Weighted RMSE Train
# [0.15517082 3.21199971]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9833159541188738] [0.77369246583034, 18.068400881604102] [0.15785307539135776, 3.229182626393387]
# Smiles Weight Mean and Std Dev
# 0.6624958590662411 0.06032290834801435
# Smiles Weight CI
# 0.5232003573565439 0.7660392004626473
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39292701 8.82342871] [ 2.529423   52.20226072] [6.43738636 5.91632374]
# (Manually) Weighted RMSE Train
# [0.15785308 3.22918263]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9416058394160584, 0.9822732012513035] [0.840512873975723, 18.49848551108973] [0.1593108413845679, 3.193879420103016]
# Smiles Weight Mean and Std Dev
# 0.6605938839951958 0.06702977922498597
# Smiles Weight CI
# 0.5175090899587306 0.7794203476327766
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39808036 8.84493305] [ 2.53158623 52.28552031] [6.35948544 5.91135286]
# (Manually) Weighted RMSE Train
# [0.15931084 3.19387942]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9781021897810219] [0.7769907456729291, 16.731647262400703] [0.15923892712490081, 3.17272697811494]
# Smiles Weight Mean and Std Dev
# 0.6637832262513397 0.061810627194118534
# Smiles Weight CI
# 0.522462546679148 0.7613618844346952
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.38755119 8.78137271] [ 2.53575066 52.36792068] [6.54300837 5.96352329]
# (Manually) Weighted RMSE Train
# [0.15923893 3.17272698]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9687174139728885] [0.6870471650877047, 15.251130331656578] [0.15902249749367303, 3.157571883260924]
# Smiles Weight Mean and Std Dev
# 0.6639813515368753 0.05759551775321366
# Smiles Weight CI
# 0.5390451556979777 0.7619541583886766
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.38485153 8.70672525] [ 2.54626255 52.40433483] [6.61622042 6.0188341 ]
# (Manually) Weighted RMSE Train
# [0.1590225  3.15757188]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.9708029197080292] [0.75338693430504, 16.51508527217827] [0.16081575523991937, 3.1690650025253406]
# Smiles Weight Mean and Std Dev
# 0.6592333059489822 0.06254552042470454
# Smiles Weight CI
# 0.5217976133505512 0.7686260058885939
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39094106 8.70047528] [ 2.53525094 52.36526872] [6.48499537 6.0186676 ]
# (Manually) Weighted RMSE Train
# [0.16081576 3.169065  ]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9624608967674662] [0.7340709505269459, 15.28766394756168] [0.1621145088992535, 3.1433592581697645]
# Smiles Weight Mean and Std Dev
# 0.6604298827608495 0.05638905313316691
# Smiles Weight CI
# 0.5436399181852671 0.7606746467429703
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.38836298 8.63911005] [ 2.53878471 52.48359207] [6.53714388 6.07511558]
# (Manually) Weighted RMSE Train
# [0.16211451 3.14335926]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.8779979144942649, 0.9572471324296142] [0.7299465579715007, 15.17142219749115] [0.16470159299389348, 3.096813624704382]
# Smiles Weight Mean and Std Dev
# 0.6520587320745258 0.059956263829377666
# Smiles Weight CI
# 0.5244508248598045 0.7483352245029806
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.40641738 8.74608415] [ 2.53871236 52.49246352] [6.24656449 6.00182466]
# (Manually) Weighted RMSE Train
# [0.16470159 3.09681362]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.8779979144942649, 0.9551616266944735] [0.740910603004628, 15.594452681683386] [0.16684470692664785, 3.1019187300984563]
# Smiles Weight Mean and Std Dev
# 0.6503577877708586 0.061454149486379187
# Smiles Weight CI
# 0.523738556894517 0.755686385345133
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.4082043  8.80194953] [ 2.53908456 52.41208267] [6.22013184 5.95459932]
# (Manually) Weighted RMSE Train
# [0.16684471 3.10191873]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.8696558915537018, 0.9551616266944735] [0.704455543800708, 15.166574097060806] [0.16444640941721034, 3.0650475287036465]
# Smiles Weight Mean and Std Dev
# 0.6553258839807317 0.0585567495613025
# Smiles Weight CI
# 0.5256240218601431 0.749855427100887
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39628144 8.77475805] [ 2.5422049  52.56125292] [6.41515012 5.99005154]
# (Manually) Weighted RMSE Train
# [0.16444641 3.06504753]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.8779979144942649, 0.9572471324296142] [0.7387202877583571, 16.195666632653083] [0.16419324397807586, 3.058865596679247]
# Smiles Weight Mean and Std Dev
# 0.658302693960331 0.06042460307148266
# Smiles Weight CI
# 0.5298439375832228 0.7514887548690757
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.38756314 8.67546839] [ 2.54721393 52.71304444] [6.57238433 6.07610357]
# (Manually) Weighted RMSE Train
# [0.16419324 3.0588656 ]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.8571428571428571, 0.9395203336809176] [0.6600901407145044, 14.147879678333291] [0.16528945302982892, 3.0431095766597984]
# Smiles Weight Mean and Std Dev
# 0.65592301649125 0.05488430840323978
# Smiles Weight CI
# 0.5566611515518801 0.7465382918429141
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39039426 8.65895848] [ 2.54795553 52.71357757] [6.52662144 6.08775035]
# (Manually) Weighted RMSE Train
# [0.16528945 3.04310958]
#
#
# done for fold0
# train_width[0.704455543800708, 15.166574097060806]
# smiles_weight0.6553258839807317
# rmse_train[0.08713263407072652, 0.0710230481291085]
# smiles_weight_ci[0.5256240218601431, 0.749855427100887]
# CPU times: user 9min 1s, sys: 5min 41s, total: 14min 42s
# Wall time: 4min 40s

# %%
with open("..//Data/returned_stuff.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
# returned_stuff2 = get_results(2, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-2], threshold = 0.75)

# %%
len(returned_stuff)
# Out:
# 9

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.50, epochs = 100)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.7612095933263816, 0.7664233576642335] [0.6860854375986064, 14.429102916754175] [0.31277075623588413, 10.318347173573349]
# Smiles Weight Mean and Std Dev
# 0.64354052601607 0.05730147545171646
# Smiles Weight CI
# 0.527371399647989 0.739285882163423
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.51431164 14.01585116] [ 2.45016993 50.60609023] [4.76397918 3.61063268]
# (Manually) Weighted RMSE Train
# [ 0.31277076 10.31834717]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.762252346193952, 0.7851929092805006] [0.6344329498602391, 14.180362059724136] [0.3057410805779108, 9.794109615363599]
# Smiles Weight Mean and Std Dev
# 0.6247462812316935 0.05941646246174281
# Smiles Weight CI
# 0.48667676724038417 0.7300737002264908
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.58433707 14.78092455] [ 2.35061707 48.38209746] [4.0227074  3.27327951]
# (Manually) Weighted RMSE Train
# [0.30574108 9.79410962]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.7768508863399375, 0.7851929092805006] [0.6105536616893867, 13.881309706026729] [0.29631786361961165, 9.389309080997455]
# Smiles Weight Mean and Std Dev
# 0.6164723384297395 0.056908972165699866
# Smiles Weight CI
# 0.5122819458626056 0.7331615057024238
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.63581944 15.25563686] [ 2.25888757 46.25665565] [3.55271861 3.03210256]
# (Manually) Weighted RMSE Train
# [0.29631786 9.38930908]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.7685088633993743, 0.7883211678832117] [0.6058679977249183, 13.440981253633332] [0.28741325244946164, 9.006284646788599]
# Smiles Weight Mean and Std Dev
# 0.596046750430018 0.05963652413517987
# Smiles Weight CI
# 0.4713517151226339 0.6998126492401651
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.69703344 16.09914744] [ 2.15927819 43.95117104] [3.09781147 2.73003097]
# (Manually) Weighted RMSE Train
# [0.28741325 9.00628465]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.7768508863399375] [0.6221257494346402, 13.525963713113565] [0.2829449101046203, 8.716595163888577]
# Smiles Weight Mean and Std Dev
# 0.5724822987544711 0.06422650601219751
# Smiles Weight CI
# 0.44037566602841394 0.6755137806012695
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.76199561 17.09237519] [ 2.05276276 41.42899529] [2.69392989 2.42382904]
# (Manually) Weighted RMSE Train
# [0.28294491 8.71659516]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.7205422314911366] [0.5892412167465241, 11.79501076997205] [0.2725395917669684, 8.383838820958102]
# Smiles Weight Mean and Std Dev
# 0.5452946961252738 0.054701098230919384
# Smiles Weight CI
# 0.43894357258332767 0.6597545438354031
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83767645 18.42935141] [ 1.97480451 39.18669471] [2.35747885 2.1263198 ]
# (Manually) Weighted RMSE Train
# [0.27253959 8.38383882]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.7820646506777894, 0.7090719499478624] [0.5751354921383299, 11.50141403040889] [0.26455271060539226, 8.271656779667458]
# Smiles Weight Mean and Std Dev
# 0.5273038817875265 0.06295876090985837
# Smiles Weight CI
# 0.3934472566869175 0.6507164574487242
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89142546 19.42260617] [ 1.90955507 37.14258305] [2.14213656 1.91233775]
# (Manually) Weighted RMSE Train
# [0.26455271 8.27165678]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.7685088633993743, 0.6788321167883211] [0.5762812129804267, 11.522222699188886] [0.2674206792071726, 8.257853955050287]
# Smiles Weight Mean and Std Dev
# 0.5104418070153031 0.05562964130061499
# Smiles Weight CI
# 0.3990097728415519 0.6203577373858509
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.93173996 20.2265277 ] [ 1.84814696 35.56529899] [1.98354373 1.75834921]
# (Manually) Weighted RMSE Train
# [0.26742068 8.25785396]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.7737226277372263, 0.6465067778936392] [0.5499262794589327, 10.653637267651868] [0.26386155175829734, 8.101216224103473]
# Smiles Weight Mean and Std Dev
# 0.4929261720542742 0.05422223619023154
# Smiles Weight CI
# 0.39251253952128845 0.5994878391377039
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97463927 21.17259343] [ 1.78001103 34.13004471] [1.82632805 1.61199169]
# (Manually) Weighted RMSE Train
# [0.26386155 8.10121622]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.7851929092805006, 0.6861313868613139] [0.550942921749145, 11.032766626519045] [0.2540991753555806, 7.7276188404180415]
# Smiles Weight Mean and Std Dev
# 0.47974961161649393 0.05467178365698468
# Smiles Weight CI
# 0.3676753183855691 0.5908560199666891
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.03261088 22.11429982] [ 1.72436989 33.35679867] [1.66991257 1.50838141]
# (Manually) Weighted RMSE Train
# [0.25409918 7.72761884]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.7664233576642335, 0.6371220020855057] [0.5420535978655681, 10.6176322469932] [0.26512778305463275, 7.800254136487994]
# Smiles Weight Mean and Std Dev
# 0.4815556543807778 0.05988719917262168
# Smiles Weight CI
# 0.36886449958645146 0.6041662108088132
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.03072766 22.31913923] [ 1.6998214  32.91608281] [1.64914698 1.47479177]
# (Manually) Weighted RMSE Train
# [0.26512778 7.80025414]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.7445255474452555, 0.616266944734098] [0.4978209586013949, 9.828368567363732] [0.2609892495424262, 7.6683884287841595]
# Smiles Weight Mean and Std Dev
# 0.47383026792880023 0.05249171879265915
# Smiles Weight CI
# 0.37000326336568395 0.5891151545121305
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.04677141 22.92747173] [ 1.6814612  31.94112264] [1.60633085 1.39313759]
# (Manually) Weighted RMSE Train
# [0.26098925 7.66838843]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.7518248175182481, 0.6193952033368092] [0.5075517491836827, 10.01296171740477] [0.25598820804033795, 7.52222588059638]
# Smiles Weight Mean and Std Dev
# 0.4684027853494372 0.05520287538251632
# Smiles Weight CI
# 0.3706446443096099 0.5672572203601135
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05856609 23.48463591] [ 1.66771038 31.26925775] [1.57544286 1.33147722]
# (Manually) Weighted RMSE Train
# [0.25598821 7.52222588]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.7778936392075079, 0.6089676746611054] [0.5058299042526989, 10.01775805404886] [0.25059651952531836, 7.380994383924906]
# Smiles Weight Mean and Std Dev
# 0.4589341248538476 0.05369916274749378
# Smiles Weight CI
# 0.35936724749661686 0.5720280716461827
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08354761 23.88560586] [ 1.63544416 30.71563732] [1.50934223 1.28594759]
# (Manually) Weighted RMSE Train
# [0.25059652 7.38099438]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.7403545359749739, 0.5860271115745568] [0.46606658691334013, 8.830357041616214] [0.24941641638433626, 7.272995895456196]
# Smiles Weight Mean and Std Dev
# 0.4573801201853554 0.05296137745233599
# Smiles Weight CI
# 0.3622555074279142 0.5601445289233679
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09084899 24.281528  ] [ 1.62518223 30.43096414] [1.48983246 1.25325573]
# (Manually) Weighted RMSE Train
# [0.24941642 7.2729959 ]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.7539103232533889, 0.5787278415015641] [0.46246997102630133, 8.60795774754579] [0.2417131695304676, 7.015264368361623]
# Smiles Weight Mean and Std Dev
# 0.44771180417393813 0.051749003053351665
# Smiles Weight CI
# 0.3444883107506585 0.5533180560066981
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13614352 25.05648529] [ 1.59188396 30.03858409] [1.40112929 1.1988347 ]
# (Manually) Weighted RMSE Train
# [0.24171317 7.01526437]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.7455683003128258, 0.5808133472367049] [0.4525792169801588, 8.557983953522955] [0.2394909106550754, 7.009751813483596]
# Smiles Weight Mean and Std Dev
# 0.4521586254480631 0.0532800274050045
# Smiles Weight CI
# 0.34449399177961443 0.5603333594496106
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.12821845 25.13348236] [ 1.60479872 29.93761339] [1.42241843 1.19114466]
# (Manually) Weighted RMSE Train
# [0.23949091 7.00975181]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.7413972888425443, 0.5818561001042752] [0.4695571187050716, 8.763777355203318] [0.24031281822669076, 6.993417093216664]
# Smiles Weight Mean and Std Dev
# 0.4538804689007448 0.05606699285044216
# Smiles Weight CI
# 0.3640006239953456 0.5775698747807527
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1267792  25.42024582] [ 1.59955058 29.50016849] [1.41957766 1.16049895]
# (Manually) Weighted RMSE Train
# [0.24031282 6.99341709]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.7403545359749739, 0.5808133472367049] [0.4244355691754199, 8.301596503949384] [0.22950058902786075, 6.75102843439565]
# Smiles Weight Mean and Std Dev
# 0.4392405577345322 0.04978893533726581
# Smiles Weight CI
# 0.3436629722567032 0.5317500268519672
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18075628 26.46626641] [ 1.55970106 28.58480435] [1.32093395 1.08004672]
# (Manually) Weighted RMSE Train
# [0.22950059 6.75102843]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.7413972888425443, 0.5630865484880083] [0.4327717816731562, 8.098725549198527] [0.22680869761229144, 6.667816668956454]
# Smiles Weight Mean and Std Dev
# 0.4369663802049622 0.05261337793616042
# Smiles Weight CI
# 0.34026712655007724 0.543398593522668
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19058472 26.86068385] [ 1.55366829 28.21930415] [1.30496239 1.05058026]
# (Manually) Weighted RMSE Train
# [0.2268087  6.66781667]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.7476538060479666, 0.5599582898852972] [0.4485177413413999, 8.008359317354167] [0.22910264279395487, 6.5934482687437015]
# Smiles Weight Mean and Std Dev
# 0.4361143059993325 0.057359281492855824
# Smiles Weight CI
# 0.31975811807455756 0.5466055153105192
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20255436 27.11561982] [ 1.53492468 27.97170052] [1.27638694 1.0315715 ]
# (Manually) Weighted RMSE Train
# [0.22910264 6.59344827]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.7549530761209593, 0.5547445255474452] [0.4363016290070965, 7.7406677312698084] [0.2254301398475802, 6.503475862503076]
# Smiles Weight Mean and Std Dev
# 0.43591563690655816 0.05575353819991815
# Smiles Weight CI
# 0.33045778775061196 0.5460936193645868
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20308363 27.22279424] [ 1.53962192 27.99753913] [1.27972976 1.02845942]
# (Manually) Weighted RMSE Train
# [0.22543014 6.50347586]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.7466110531803962, 0.5422314911366006] [0.4226027034926857, 7.2263419220225416] [0.2188620641337095, 6.312265188641014]
# Smiles Weight Mean and Std Dev
# 0.42277772539319136 0.0511995310101311
# Smiles Weight CI
# 0.3283402964047133 0.5231678414739845
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23355136 28.01575046] [ 1.51572613 27.43694971] [1.22874991 0.97934017]
# (Manually) Weighted RMSE Train
# [0.21886206 6.31226519]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.7382690302398331, 0.5547445255474452] [0.4106704816097662, 7.378589605803545] [0.21539453949534093, 6.25841207587971]
# Smiles Weight Mean and Std Dev
# 0.4232095267341311 0.05499549444271429
# Smiles Weight CI
# 0.32636214400304453 0.539295274345313
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23473122 28.2812223 ] [ 1.51906252 27.22981594] [1.23027789 0.96282316]
# (Manually) Weighted RMSE Train
# [0.21539454 6.25841208]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.7549530761209593, 0.5453597497393118] [0.41940765834010235, 7.330380018118979] [0.2126380284633742, 6.1988536728933665]
# Smiles Weight Mean and Std Dev
# 0.42088497800101615 0.055452121450347315
# Smiles Weight CI
# 0.3119900164260832 0.5385038062541908
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24608055 28.64927283] [ 1.5159769  26.94556138] [1.21659623 0.94053212]
# (Manually) Weighted RMSE Train
# [0.21263803 6.19885367]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.7413972888425443, 0.5380604796663191] [0.40853787106029127, 7.1625732294500235] [0.21275839616722764, 6.2140723908913085]
# Smiles Weight Mean and Std Dev
# 0.4216924301767503 0.05381651293422913
# Smiles Weight CI
# 0.31588364245998984 0.5159659690107059
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23257267 28.65689264] [ 1.53348931 26.91315663] [1.24413704 0.93915125]
# (Manually) Weighted RMSE Train
# [0.2127584  6.21407239]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.7205422314911366, 0.5140771637122002] [0.38776860869114127, 6.645524506298885] [0.20827777189060948, 6.076253803944875]
# Smiles Weight Mean and Std Dev
# 0.4077400035398554 0.048598725784147624
# Smiles Weight CI
# 0.32911368986299855 0.5130600748344565
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26971835 29.48785988] [ 1.50849583 26.31871746] [1.18805546 0.89252722]
# (Manually) Weighted RMSE Train
# [0.20827777 6.0762538 ]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.7194994786235662, 0.5213764337851929] [0.3853173388812769, 6.785188381301658] [0.20951148062634772, 6.073367149571115]
# Smiles Weight Mean and Std Dev
# 0.41165376545943616 0.04853908675390258
# Smiles Weight CI
# 0.3358371868588506 0.5063609491868013
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25737733 29.53717746] [ 1.52106708 26.24716169] [1.20971409 0.88861442]
# (Manually) Weighted RMSE Train
# [0.20951148 6.07336715]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.7236704900938478, 0.5130344108446299] [0.4133267296455524, 6.820304477927608] [0.21333697712332778, 6.094600843937409]
# Smiles Weight Mean and Std Dev
# 0.41405092440146146 0.05224434835562882
# Smiles Weight CI
# 0.3122625659120543 0.5259013886360538
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23681766 29.4881008 ] [ 1.53480579 26.21870453] [1.24093133 0.88912829]
# (Manually) Weighted RMSE Train
# [0.21333698 6.09460084]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.7257559958289885, 0.5286757038581856] [0.40598702547855625, 6.878781743179353] [0.21051859682857102, 5.989890776373865]
# Smiles Weight Mean and Std Dev
# 0.40624497821773964 0.05408003916034027
# Smiles Weight CI
# 0.30561024220681726 0.518998404522739
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25950507 30.13113754] [ 1.52024328 25.64017555] [1.20701641 0.85095279]
# (Manually) Weighted RMSE Train
# [0.2105186  5.98989078]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.7236704900938478, 0.516162669447341] [0.4102168171248154, 6.758335205791906] [0.20852327135824053, 5.935484436404373]
# Smiles Weight Mean and Std Dev
# 0.40104725419741866 0.0517044837670033
# Smiles Weight CI
# 0.30068595835394085 0.5079005532705836
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28008852 30.4018069 ] [ 1.51028846 25.36706916] [1.17983127 0.83439347]
# (Manually) Weighted RMSE Train
# [0.20852327 5.93548444]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.7059436913451512, 0.5078206465067779] [0.4211447130617026, 6.720214238942168] [0.21152433063117954, 5.914953976170629]
# Smiles Weight Mean and Std Dev
# 0.4042782774551984 0.053068165197935876
# Smiles Weight CI
# 0.31009220899927364 0.5118607830958467
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26458185 30.36821226] [ 1.52186296 25.47941139] [1.20345153 0.83901585]
# (Manually) Weighted RMSE Train
# [0.21152433 5.91495398]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.7049009384775808, 0.5255474452554745] [0.40906736756433815, 6.648681105303519] [0.21104139250212273, 5.900007902667998]
# Smiles Weight Mean and Std Dev
# 0.4063106906121111 0.055812746378903176
# Smiles Weight CI
# 0.3084540078947244 0.5145280769611812
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26483191 30.56108659] [ 1.51827317 25.35294816] [1.20037545 0.82958268]
# (Manually) Weighted RMSE Train
# [0.21104139 5.9000079 ]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.7059436913451512, 0.5036496350364964] [0.41699725306443985, 6.432452135010915] [0.20914999106848242, 5.842318532610952]
# Smiles Weight Mean and Std Dev
# 0.4004630454885785 0.05302154074245476
# Smiles Weight CI
# 0.30859793943611113 0.5205072777776073
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27824426 31.01628259] [ 1.51355422 24.98849279] [1.18408842 0.80565725]
# (Manually) Weighted RMSE Train
# [0.20914999 5.84231853]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.6986444212721585, 0.49635036496350365] [0.3917353124801583, 6.29986145350382] [0.2063037746015556, 5.8145500855478485]
# Smiles Weight Mean and Std Dev
# 0.398136598955287 0.05494209357769978
# Smiles Weight CI
# 0.3023313351940578 0.5091258882101606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29701014 31.30116093] [ 1.498665   24.70394645] [1.1554767  0.78923419]
# (Manually) Weighted RMSE Train
# [0.20630377 5.81455009]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.6903023983315955, 0.5036496350364964] [0.3971085145570254, 6.363432426588362] [0.20609567979924615, 5.778634723469097]
# Smiles Weight Mean and Std Dev
# 0.39802721004970404 0.04929000199585842
# Smiles Weight CI
# 0.30820174027853825 0.5093006163748747
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29720625 31.55789374] [ 1.49677938 24.37516675] [1.15384842 0.77239524]
# (Manually) Weighted RMSE Train
# [0.20609568 5.77863472]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.7007299270072993, 0.4859228362877998] [0.3941807009191692, 6.12886385042348] [0.2038469675923278, 5.701276812293415]
# Smiles Weight Mean and Std Dev
# 0.39490261181122005 0.05384393305967623
# Smiles Weight CI
# 0.31051409327388285 0.5181909372830001
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31968114 32.03683824] [ 1.48174122 24.01872393] [1.12280246 0.74972205]
# (Manually) Weighted RMSE Train
# [0.20384697 5.70127681]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.4681960375391032] [0.39414825936440445, 6.019116587382665] [0.20939840851530137, 5.738072484070634]
# Smiles Weight Mean and Std Dev
# 0.4054100232138712 0.050772104336516466
# Smiles Weight CI
# 0.29665365287912004 0.5042882283089685
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27888652 31.66478096] [ 1.50434509 24.31197157] [1.17629286 0.76779219]
# (Manually) Weighted RMSE Train
# [0.20939841 5.73807248]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.6579770594369134, 0.44004171011470283] [0.34374896884873546, 5.438150482443638] [0.20600271909529572, 5.678540177800155]
# Smiles Weight Mean and Std Dev
# 0.4005626693232768 0.04369372330035777
# Smiles Weight CI
# 0.33323969373690054 0.49837848965772774
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.30021363 32.10566446] [ 1.48745858 23.91464226] [1.14401091 0.74487299]
# (Manually) Weighted RMSE Train
# [0.20600272 5.67854018]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.47340980187695514] [0.3873051737212194, 5.834754696907056] [0.20477379562329662, 5.632954150586019]
# Smiles Weight Mean and Std Dev
# 0.39610607080064375 0.05457613288575961
# Smiles Weight CI
# 0.3061969338537929 0.5049554052003589
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31510684 32.43776833] [ 1.47772995 23.64322372] [1.12365772 0.72887948]
# (Manually) Weighted RMSE Train
# [0.2047738  5.63295415]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.6777893639207507, 0.4608967674661105] [0.39048235213507315, 5.702156836064161] [0.2050379085605433, 5.5996855348829015]
# Smiles Weight Mean and Std Dev
# 0.39698764115800517 0.05207584603289175
# Smiles Weight CI
# 0.30528849737358127 0.506638529350377
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31214392 32.62900469] [ 1.47532522 23.49622216] [1.12436235 0.72010233]
# (Manually) Weighted RMSE Train
# [0.20503791 5.59968553]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.6454640250260688, 0.4254431699687174] [0.32967546030690964, 5.106953615923238] [0.20426672313236355, 5.5865198091820245]
# Smiles Weight Mean and Std Dev
# 0.3978136385898956 0.04291460396932911
# Smiles Weight CI
# 0.32310312066854835 0.48496424868063054
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32059685 32.79455527] [ 1.4676281  23.28527089] [1.11133697 0.71003466]
# (Manually) Weighted RMSE Train
# [0.20426672 5.58651981]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.6694473409801877, 0.44629822732012514] [0.3564900527751309, 5.42641165574419] [0.20035119472883384, 5.515382702742515]
# Smiles Weight Mean and Std Dev
# 0.39065895315300503 0.046011657450467223
# Smiles Weight CI
# 0.29445448923856093 0.4828332944319913
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35237137 33.38321361] [ 1.44943352 22.78795451] [1.07177181 0.68261716]
# (Manually) Weighted RMSE Train
# [0.20035119 5.5153827 ]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.6892596454640251, 0.4754953076120959] [0.389133514640794, 5.746907175066966] [0.20451389860778924, 5.550301803666208]
# Smiles Weight Mean and Std Dev
# 0.40348587549717013 0.05622588314763712
# Smiles Weight CI
# 0.3025964505440809 0.5310894090046884
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31802296 32.91591943] [ 1.47061668 23.29703011] [1.11577471 0.70777394]
# (Manually) Weighted RMSE Train
# [0.2045139 5.5503018]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.6923879040667362, 0.49739311783107404] [0.39671613333547473, 6.003557583646704] [0.2055827766669596, 5.537219873395128]
# Smiles Weight Mean and Std Dev
# 0.40730873590984484 0.05951385924282141
# Smiles Weight CI
# 0.3016646533715841 0.5372415184855802
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31295387 33.02679965] [ 1.47441815 23.20287781] [1.12297788 0.70254696]
# (Manually) Weighted RMSE Train
# [0.20558278 5.53721987]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.662148070907195, 0.4369134515119917] [0.35648477965856945, 5.2916543880717555] [0.2006928641079138, 5.488955523513674]
# Smiles Weight Mean and Std Dev
# 0.395904772231164 0.05008597488000119
# Smiles Weight CI
# 0.3017842726751813 0.5035527716565106
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36076157 33.69634806] [ 1.44130164 22.6255458 ] [1.05918749 0.67145394]
# (Manually) Weighted RMSE Train
# [0.20069286 5.48895552]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.6475495307612096, 0.43795620437956206] [0.3375245906535813, 5.2165442191202525] [0.20277275351946694, 5.486251404551146]
# Smiles Weight Mean and Std Dev
# 0.402941582059124 0.049936213675780536
# Smiles Weight CI
# 0.31046253525902384 0.5016814789909381
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34292013 33.60846186] [ 1.44928296 22.74138399] [1.07920265 0.67665649]
# (Manually) Weighted RMSE Train
# [0.20277275 5.4862514 ]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.6454640250260688, 0.443169968717414] [0.3384220332278798, 5.195612427684411] [0.2041861350370296, 5.469544540588164]
# Smiles Weight Mean and Std Dev
# 0.4069915171539851 0.05157025047997973
# Smiles Weight CI
# 0.315951494723117 0.5135394333597589
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33715432 33.59770293] [ 1.45361043 22.80192346] [1.0870925  0.67867507]
# (Manually) Weighted RMSE Train
# [0.20418614 5.46954454]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.6579770594369134, 0.4483837330552659] [0.3630281328251533, 5.317433792124963] [0.20364191187661848, 5.443064690972363]
# Smiles Weight Mean and Std Dev
# 0.40427084043591904 0.05241974305159982
# Smiles Weight CI
# 0.307234807960529 0.5240489744971871
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34749752 33.90028802] [ 1.4440916  22.49135964] [1.07168405 0.6634563 ]
# (Manually) Weighted RMSE Train
# [0.20364191 5.44306469]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.6725755995828988, 0.4692387904066736] [0.38072509999177545, 5.461023056870485] [0.2040840682967874, 5.427511801090061]
# Smiles Weight Mean and Std Dev
# 0.4044557569432076 0.0565958233819413
# Smiles Weight CI
# 0.3182253452608216 0.5446005395343061
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34845756 34.09936777] [ 1.44366176 22.37872797] [1.07060229 0.65627985]
# (Manually) Weighted RMSE Train
# [0.20408407 5.4275118 ]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.6465067778936392, 0.44421272158498437] [0.34596022463739556, 5.239601682640228] [0.20256721985226184, 5.406618900882819]
# Smiles Weight Mean and Std Dev
# 0.40410685683196124 0.05286970823070368
# Smiles Weight CI
# 0.30286269750340433 0.5166014445830296
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35729592 34.23022496] [ 1.43678135 22.20947958] [1.0585616  0.64882657]
# (Manually) Weighted RMSE Train
# [0.20256722 5.4066189 ]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.6319082377476538, 0.4556830031282586] [0.33479440696535573, 5.340642807004923] [0.20118979615385563, 5.379211701819683]
# Smiles Weight Mean and Std Dev
# 0.4019902428823786 0.05250722274657911
# Smiles Weight CI
# 0.3184392194294634 0.5204432727983905
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37259156 34.54199469] [ 1.42523195 21.91882586] [1.0383511  0.63455588]
# (Manually) Weighted RMSE Train
# [0.2011898 5.3792117]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.6277372262773723, 0.45359749739311783] [0.34043376674946935, 5.254248179999922] [0.20579593451107545, 5.408014929285367]
# Smiles Weight Mean and Std Dev
# 0.412533702221377 0.05436069696049026
# Smiles Weight CI
# 0.3124476004634005 0.5175988757559657
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34529833 34.18903864] [ 1.44412089 22.34448156] [1.07345772 0.65355688]
# (Manually) Weighted RMSE Train
# [0.20579593 5.40801493]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.6193952033368092, 0.45151199165797706] [0.32577787030083266, 5.187440857324905] [0.20108856436597733, 5.334956171259825]
# Smiles Weight Mean and Std Dev
# 0.3984021706484016 0.047814922711749655
# Smiles Weight CI
# 0.3081466326740558 0.5056211682335369
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39000327 34.98406495] [ 1.41345694 21.4899433 ] [1.01687311 0.61427805]
# (Manually) Weighted RMSE Train
# [0.20108856 5.33495617]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.583941605839416, 0.42961418143899893] [0.3014291208084512, 4.8409193823370655] [0.2043028539789327, 5.320215471942103]
# Smiles Weight Mean and Std Dev
# 0.40625249205029546 0.0442292739810966
# Smiles Weight CI
# 0.32433519949780565 0.5079958906845309
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3719843 34.8686701] [ 1.42423297 21.61532656] [1.03808256 0.61990682]
# (Manually) Weighted RMSE Train
# [0.20430285 5.32021547]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.6506777893639207, 0.44421272158498437] [0.3541870853778251, 5.236808054281529] [0.2056456411190524, 5.321159787519812]
# Smiles Weight Mean and Std Dev
# 0.4102370535478554 0.054478808482604765
# Smiles Weight CI
# 0.3130598950489549 0.5161677256382888
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36234415 34.82673947] [ 1.43235971 21.67955594] [1.05139344 0.62249743]
# (Manually) Weighted RMSE Train
# [0.20564564 5.32115979]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.6193952033368092, 0.4118873826903024] [0.3212965385579266, 4.814001929739622] [0.20143071885072866, 5.276705834449734]
# Smiles Weight Mean and Std Dev
# 0.399166117501575 0.048609227182797414
# Smiles Weight CI
# 0.3145621634293913 0.5184786801179048
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39818608 35.49407276] [ 1.40912392 21.02262364] [1.00782288 0.59228547]
# (Manually) Weighted RMSE Train
# [0.20143072 5.27670583]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.6204379562043796, 0.4264859228362878] [0.3349242218749419, 4.979774200859035] [0.20336414102596673, 5.279371199483045]
# Smiles Weight Mean and Std Dev
# 0.4053558524870967 0.05190410923347177
# Smiles Weight CI
# 0.3094148493166139 0.5254494876641689
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3796293  35.36733941] [ 1.42016088 21.22770596] [1.02937861 0.60020647]
# (Manually) Weighted RMSE Train
# [0.20336414 5.2793712 ]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.6225234619395204, 0.41605839416058393] [0.3229620075017984, 4.788666681698376] [0.20212506095855248, 5.254937758152864]
# Smiles Weight Mean and Std Dev
# 0.40390253078205113 0.05087373908443511
# Smiles Weight CI
# 0.31477382163898576 0.5127120660899194
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39584188 35.65469308] [ 1.40785973 20.95389416] [1.00860975 0.58768965]
# (Manually) Weighted RMSE Train
# [0.20212506 5.25493776]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.4369134515119917] [0.30049470797605093, 4.788873765193313] [0.20504780326712632, 5.270852538761143]
# Smiles Weight Mean and Std Dev
# 0.41489356702046176 0.049792050779695694
# Smiles Weight CI
# 0.3364296830832542 0.5261273757211705
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3701336 35.3427432] [ 1.42852077 21.36889969] [1.04261422 0.60461916]
# (Manually) Weighted RMSE Train
# [0.2050478  5.27085254]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.6068821689259646, 0.4410844629822732] [0.3156993690253709, 4.9023365626050985] [0.2026452047349099, 5.242635057356703]
# Smiles Weight Mean and Std Dev
# 0.40984198257282584 0.05234900857707149
# Smiles Weight CI
# 0.32275798614091744 0.520577477218681
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38815223 35.65188281] [ 1.41395809 21.03306477] [1.01859008 0.58995663]
# (Manually) Weighted RMSE Train
# [0.2026452  5.24263506]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.6058394160583942, 0.443169968717414] [0.3124506209962699, 5.04662042983339] [0.19972734441441167, 5.168964100535185]
# Smiles Weight Mean and Std Dev
# 0.4037255698344604 0.05368052545724415
# Smiles Weight CI
# 0.31454060325093874 0.5166454212094994
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41769262 36.13463837] [ 1.39432599 20.49392393] [0.98351784 0.56715453]
# (Manually) Weighted RMSE Train
# [0.19972734 5.1689641 ]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.4358706986444213] [0.3009872464186663, 4.908194353153945] [0.19975794436355496, 5.172142122752635]
# Smiles Weight Mean and Std Dev
# 0.4044564351654803 0.05020754585971229
# Smiles Weight CI
# 0.31668280965973133 0.5111934876494252
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4136061  36.11122437] [ 1.39721766 20.47969821] [0.98840665 0.56712833]
# (Manually) Weighted RMSE Train
# [0.19975794 5.17214212]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.6183524504692388, 0.44004171011470283] [0.31516514394725387, 4.9575583387306095] [0.20007490648479478, 5.181895998443905]
# Smiles Weight Mean and Std Dev
# 0.4068502787739864 0.05348479088664605
# Smiles Weight CI
# 0.31616544874120117 0.5217260391835515
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41095087 36.11748202] [ 1.40027719 20.57699888] [0.99243511 0.56972407]
# (Manually) Weighted RMSE Train
# [0.20007491 5.181896  ]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.6016684045881127, 0.443169968717414] [0.301603247980268, 4.900094444308903] [0.19896770949237796, 5.1439333210818186]
# Smiles Weight Mean and Std Dev
# 0.40478925011543787 0.05113324806289855
# Smiles Weight CI
# 0.31492807845192694 0.5061732895383942
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42392512 36.39301145] [ 1.39099635 20.25449972] [0.97687465 0.55654915]
# (Manually) Weighted RMSE Train
# [0.19896771 5.14393332]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.5776850886339937, 0.4337851929092805] [0.28977303912460334, 4.740388101582141] [0.19973219985553758, 5.141949809020302]
# Smiles Weight Mean and Std Dev
# 0.40690904157491636 0.0480741363406603
# Smiles Weight CI
# 0.3272820418509525 0.522227371143063
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42228737 36.42038899] [ 1.39399798 20.29054596] [0.98010993 0.55712052]
# (Manually) Weighted RMSE Train
# [0.1997322  5.14194981]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.5954118873826904, 0.4369134515119917] [0.2932708137776014, 4.7890839551155295] [0.1994061210649424, 5.125660721137661]
# Smiles Weight Mean and Std Dev
# 0.4051416346072419 0.04947494976424912
# Smiles Weight CI
# 0.321252349869372 0.503255811586421
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42839201 36.66603092] [ 1.39013338 20.0379734 ] [0.9732156  0.54649966]
# (Manually) Weighted RMSE Train
# [0.19940612 5.12566072]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.583941605839416, 0.41605839416058393] [0.283787360511665, 4.649272953835517] [0.19873872034719525, 5.111429766105109]
# Smiles Weight Mean and Std Dev
# 0.4027630746185492 0.047499424635706604
# Smiles Weight CI
# 0.31892999695923563 0.4956221841088416
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.43669332 36.79000843] [ 1.38369398 19.88129755] [0.96311019 0.54039937]
# (Manually) Weighted RMSE Train
# [0.19873872 5.11142977]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.5808133472367049, 0.4421272158498436] [0.29401776832699955, 4.9343167815476905] [0.20066333489742852, 5.12555756875635]
# Smiles Weight Mean and Std Dev
# 0.40997092417448777 0.051489010437164154
# Smiles Weight CI
# 0.3224158964518697 0.5325024976766214
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41965591 36.58626027] [ 1.39196755 20.18206512] [0.98049643 0.55162963]
# (Manually) Weighted RMSE Train
# [0.20066333 5.12555757]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.602711157455683, 0.45255474452554745] [0.29819028157343597, 5.072878362672413] [0.19947149178549484, 5.096111931087738]
# Smiles Weight Mean and Std Dev
# 0.4067012887715811 0.05334207703308924
# Smiles Weight CI
# 0.3050239955772025 0.512731995460111
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.43805245 36.86601157] [ 1.37998821 19.86013887] [0.95962301 0.53871135]
# (Manually) Weighted RMSE Train
# [0.19947149 5.09611193]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.5776850886339937, 0.43899895724713245] [0.2839755780757524, 4.889807925304958] [0.1991442761873734, 5.086809631683917]
# Smiles Weight Mean and Std Dev
# 0.4062643545429528 0.04862667714642904
# Smiles Weight CI
# 0.31204412180063057 0.5140139668801009
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44596357 37.0088443 ] [ 1.37412719 19.69890376] [0.95031937 0.53227557]
# (Manually) Weighted RMSE Train
# [0.19914428 5.08680963]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.5922836287799792, 0.4629822732012513] [0.3043219350411624, 5.1515864800057045] [0.20087637099766473, 5.115810425162077]
# Smiles Weight Mean and Std Dev
# 0.4139962974070992 0.0523615371475039
# Smiles Weight CI
# 0.32392894046916215 0.5346544317017934
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42987218 36.79296817] [ 1.3858897  20.03136463] [0.96924027 0.54443459]
# (Manually) Weighted RMSE Train
# [0.20087637 5.11581043]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.5724713242961418, 0.4358706986444213] [0.2763942355524276, 4.919262428885246] [0.19779898317269806, 5.04764664949626]
# Smiles Weight Mean and Std Dev
# 0.40346773962911037 0.04842500847426509
# Smiles Weight CI
# 0.3120061064791613 0.498852044369926
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46868316 37.36926294] [ 1.35776193 19.27875825] [0.92447573 0.51589881]
# (Manually) Weighted RMSE Train
# [0.19779898 5.04764665]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.5974973931178311, 0.44525547445255476] [0.2843849146603497, 4.9640782495811235] [0.19741436796155323, 5.048884840142542]
# Smiles Weight Mean and Std Dev
# 0.4053490929028668 0.051632900973983396
# Smiles Weight CI
# 0.312696481263668 0.5076241578677825
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46880426 37.40165834] [ 1.35863395 19.31289256] [0.9249932  0.51636461]
# (Manually) Weighted RMSE Train
# [0.19741437 5.04888484]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.5735140771637122, 0.45255474452554745] [0.27616026292743123, 5.002463470453162] [0.19812985822838722, 5.04774971165833]
# Smiles Weight Mean and Std Dev
# 0.4089419521761961 0.048050486457459095
# Smiles Weight CI
# 0.31696339990205996 0.5140642116702836
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4594931  37.33095892] [ 1.36322426 19.37854115] [0.93403954 0.51910108]
# (Manually) Weighted RMSE Train
# [0.19812986 5.04774971]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.4546402502606882] [0.2942954528802877, 5.147708129394482] [0.1989669780548784, 5.06800994230054]
# Smiles Weight Mean and Std Dev
# 0.4131392409885029 0.05332261786852247
# Smiles Weight CI
# 0.3189777629556789 0.5247491033472789
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45615896 37.26965709] [ 1.3660203  19.54342314] [0.93809834 0.52437894]
# (Manually) Weighted RMSE Train
# [0.19896698 5.06800994]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.5808133472367049, 0.44525547445255476] [0.27873568724122283, 4.999300988251521] [0.19636031085355954, 5.009907991028049]
# Smiles Weight Mean and Std Dev
# 0.4032401753245209 0.05091335430680702
# Smiles Weight CI
# 0.3108865905218322 0.5197682483403568
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.49089081 37.72463923] [ 1.33899042 18.88863276] [0.89811434 0.50069751]
# (Manually) Weighted RMSE Train
# [0.19636031 5.00990799]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.46506777893639206] [0.2856633723439607, 5.300497200816772] [0.19805878611667424, 5.041681211332899]
# Smiles Weight Mean and Std Dev
# 0.412054599044309 0.053950404906154104
# Smiles Weight CI
# 0.3237176370677542 0.5381327622959566
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46836057 37.50707264] [ 1.35615202 19.28069562] [0.92358243 0.51405493]
# (Manually) Weighted RMSE Train
# [0.19805879 5.04168121]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.5735140771637122, 0.4337851929092805] [0.27071661421311, 4.974304187308999] [0.1971201044839582, 5.025474582827391]
# Smiles Weight Mean and Std Dev
# 0.40760834385568695 0.049413388514513615
# Smiles Weight CI
# 0.3176647342415989 0.5027843590091345
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48486966 37.81122727] [ 1.34367701 18.92112909] [0.90491243 0.50041034]
# (Manually) Weighted RMSE Train
# [0.1971201  5.02547458]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.5724713242961418, 0.44525547445255476] [0.27227388053809426, 4.976965736065721] [0.19729469816624717, 5.031161122887292]
# Smiles Weight Mean and Std Dev
# 0.40963180392056797 0.05198485501441575
# Smiles Weight CI
# 0.30047924383606495 0.5144165535949924
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48229634 37.83948213] [ 1.34369818 18.93567909] [0.90649767 0.5004212 ]
# (Manually) Weighted RMSE Train
# [0.1972947  5.03116112]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.5922836287799792, 0.4619395203336809] [0.2921559234928543, 5.210865384138904] [0.19766459383578605, 5.015639982001312]
# Smiles Weight Mean and Std Dev
# 0.4084502666868729 0.05431088793737435
# Smiles Weight CI
# 0.30555426584723233 0.5370311463571543
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48851339 38.02631966] [ 1.33959153 18.71638162] [0.89995263 0.49219545]
# (Manually) Weighted RMSE Train
# [0.19766459 5.01563998]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.5495307612095933, 0.42127215849843586] [0.2607716106687016, 4.758977444441997] [0.19876148842723754, 5.016700651033584]
# Smiles Weight Mean and Std Dev
# 0.4141386294154753 0.04715150006160637
# Smiles Weight CI
# 0.33089289088124196 0.5117590899457933
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47808039 37.91211625] [ 1.3468614  18.91899841] [0.91122338 0.49902248]
# (Manually) Weighted RMSE Train
# [0.19876149 5.01670065]
#
#
# done for fold1
# train_width[0.28977303912460334, 4.740388101582141]
# smiles_weight0.40690904157491636
# rmse_train[0.10582896235111018, 0.11914886644597733]
# smiles_weight_ci[0.3272820418509525, 0.522227371143063]
# CPU times: user 25min 40s, sys: 15min 24s, total: 41min 4s
# Wall time: 13min 39s

# %%
with open("..//Data/returned_stuff1.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
returned_stuff
# Out:
# [0.08713263407072652, 0.0710230481291085]

# %%
returned_stuff_1_unr = np.array(returned_stuff[2])
returned_stuff_2_unr = np.array(returned_stuff1[2])

# %%
returned_stuff_1_unr
# Out:
# array([0.08713263, 0.07102305])

# %%
# returned_stuff

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()
