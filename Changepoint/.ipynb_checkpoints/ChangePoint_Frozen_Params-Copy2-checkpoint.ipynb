# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-06-27 02:12:52.764128: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-27 02:12:52.767290: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 02:12:52.806363: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 02:12:52.807419: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 02:12:53.521202: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)
# Out:
# 2023-06-27 02:12:54.494812: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-06-27 02:12:54.494851: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: c3101.swan.hcc.unl.edu
# 2023-06-27 02:12:54.494863: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: c3101.swan.hcc.unl.edu
# 2023-06-27 02:12:54.494995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 525.116.4
# 2023-06-27 02:12:54.495025: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 525.116.4
# 2023-06-27 02:12:54.495035: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 525.116.4

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_heavy_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_heavy_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 5.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,14), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [122.16503885664171, 2856.5159207278816] [5.248573306443645, 120.50663269624019]
# Smiles Weight Mean and Std Dev
# 0.562760663266822 0.2556458594641061
# Smiles Weight CI
# 0.11994985869873667 0.9372733677339112
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 4.60340172 81.4328909 ] [ 3.7035178  94.69310529] [0.80451762 1.1628361 ]
# (Manually) Weighted RMSE Train
# [  5.24857331 120.5066327 ]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [63.824938893545166, 1512.0347741710143] [4.004335900923587, 58.380878703156604]
# Smiles Weight Mean and Std Dev
# 0.6004691962471302 0.19673029683539614
# Smiles Weight CI
# 0.1982191265756391 0.8986028763736423
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 3.67175571 73.82747312] [ 3.09347269 48.22098839] [0.84250504 0.65315778]
# (Manually) Weighted RMSE Train
# [ 4.0043359 58.3808787]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [36.355407996453884, 846.1939051349597] [2.3919932254928202, 51.056200722676614]
# Smiles Weight Mean and Std Dev
# 0.6191424495707334 0.15110581266274437
# Smiles Weight CI
# 0.32178445197455524 0.8903329017310596
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 3.15141887 57.74883662] [ 2.03016411 52.37301346] [0.64420637 0.90691028]
# (Manually) Weighted RMSE Train
# [ 2.39199323 51.05620072]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [21.17226253617854, 488.22356930988315] [1.6144022770857698, 52.81669600311187]
# Smiles Weight Mean and Std Dev
# 0.6584955021454882 0.11623485729580162
# Smiles Weight CI
# 0.4550733996642375 0.8722358701973324
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.35547804 70.94377124] [ 1.82870245 53.93975978] [0.77636149 0.76031706]
# (Manually) Weighted RMSE Train
# [ 1.61440228 52.816696  ]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [12.941723325559757, 303.07235259540795] [1.5451223196703243, 40.43333750089715]
# Smiles Weight Mean and Std Dev
# 0.7093835224618884 0.08915770135096317
# Smiles Weight CI
# 0.5085737541431193 0.8700823685228122
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73365396 51.37027897] [ 2.55259095 57.22850093] [1.47237627 1.11403913]
# (Manually) Weighted RMSE Train
# [ 1.54512232 40.4333375 ]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [8.41155847539119, 192.29875909292846] [0.49496031726465806, 33.603804842176515]
# Smiles Weight Mean and Std Dev
# 0.7415110357478517 0.07605951501966464
# Smiles Weight CI
# 0.5748497804986775 0.8637367697560432
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82986983 43.45331396] [ 2.35553632 56.64810562] [2.83844072 1.30365444]
# (Manually) Weighted RMSE Train
# [ 0.49496032 33.60380484]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [5.460734665212236, 131.1257447592764] [0.34688430206576165, 12.615280855070463]
# Smiles Weight Mean and Std Dev
# 0.7930777805299404 0.056525258701921745
# Smiles Weight CI
# 0.6733343538549874 0.8847042372963827
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.148837   22.23566907] [ 2.51356078 54.20304683] [16.88801069  2.43766206]
# (Manually) Weighted RMSE Train
# [ 0.3468843  12.61528086]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.258625730640592, 81.2287255755028] [0.31404928087335177, 10.366488710710707]
# Smiles Weight Mean and Std Dev
# 0.800569063663877 0.04887652075368062
# Smiles Weight CI
# 0.6904383653593634 0.8796896125567196
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.37879956 15.76833679] [ 2.45505501 55.76433378] [6.48114541 3.53647531]
# (Manually) Weighted RMSE Train
# [ 0.31404928 10.36648871]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.126062404891468, 54.27468219476002] [0.19530697752267126, 7.73129048436888]
# Smiles Weight Mean and Std Dev
# 0.8021954428679635 0.050655773161297574
# Smiles Weight CI
# 0.6795425898372254 0.8806941597387017
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.30520022 14.83746053] [ 2.47672521 54.9308893 ] [8.11508325 3.70217593]
# (Manually) Weighted RMSE Train
# [0.19530698 7.73129048]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [1.5737044419713062, 43.58663728844785] [0.19760207018266987, 6.58628656265591]
# Smiles Weight Mean and Std Dev
# 0.8024414620901082 0.04635053047089318
# Smiles Weight CI
# 0.6854559601625307 0.8712617030880773
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.3113749  13.57016378] [ 2.49239943 54.55246597] [8.00449681 4.02003004]
# (Manually) Weighted RMSE Train
# [0.19760207 6.58628656]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 0.9989572471324296] [1.1605724775873345, 31.56229795186717] [0.1799209280943847, 4.945942312998901]
# Smiles Weight Mean and Std Dev
# 0.8057629612786471 0.04091390641125033
# Smiles Weight CI
# 0.7083317966460273 0.8654412426065221
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.31983069 12.79421408] [ 2.48790144 53.69101952] [7.77880781 4.19650783]
# (Manually) Weighted RMSE Train
# [0.17992093 4.94594231]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9958289885297185] [1.0340673790997263, 27.026309728460518] [0.16832445289013237, 4.369108747287407]
# Smiles Weight Mean and Std Dev
# 0.8025410816758898 0.04139019428964406
# Smiles Weight CI
# 0.705848169753264 0.8643234908746018
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.35359643 13.72640632] [ 2.44021014 53.43603834] [6.90111651 3.89293724]
# (Manually) Weighted RMSE Train
# [0.16832445 4.36910875]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9812304483837331, 0.9895724713242962] [0.840301091554781, 26.297052403881946] [0.16629272381940213, 4.278710086053957]
# Smiles Weight Mean and Std Dev
# 0.7997564851533808 0.053063319383681855
# Smiles Weight CI
# 0.6487422712203753 0.8692959924767903
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.37852061 13.80084088] [ 2.44515588 53.36501407] [6.45976954 3.86679439]
# (Manually) Weighted RMSE Train
# [0.16629272 4.27871009]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9843587069864442] [0.7180511873797334, 22.93120672199584] [0.16319321513418922, 4.141872121128847]
# Smiles Weight Mean and Std Dev
# 0.8049814958004804 0.044583276504633784
# Smiles Weight CI
# 0.6916743605448797 0.8671713519795243
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.38681863 13.8101977 ] [ 2.44716308 53.51744039] [6.32638378 3.87521175]
# (Manually) Weighted RMSE Train
# [0.16319322 4.14187212]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9812304483837331] [0.605408467725661, 19.90509849249378] [0.1617812772817758, 4.040786905841594]
# Smiles Weight Mean and Std Dev
# 0.8034514045831893 0.043324562964312884
# Smiles Weight CI
# 0.6949777895354159 0.8677057181577683
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.38183215 13.857357  ] [ 2.44883131 53.23266489] [6.41337125 3.84147315]
# (Manually) Weighted RMSE Train
# [0.16178128 4.04078691]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.9739311783107404] [0.5846580890623394, 20.11207766035644] [0.16126897031800538, 4.028932558396957]
# Smiles Weight Mean and Std Dev
# 0.8043999452572038 0.041612642813938394
# Smiles Weight CI
# 0.6797416830108306 0.8645502230564994
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.36694298 14.03357029] [ 2.46238447 53.15019754] [6.71053713 3.78736105]
# (Manually) Weighted RMSE Train
# [0.16126897 4.02893256]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.8759124087591241, 0.9697601668404588] [0.5452745141388672, 18.225465954719397] [0.17157439114410555, 4.029853768288107]
# Smiles Weight Mean and Std Dev
# 0.7936599794587104 0.0412669840602435
# Smiles Weight CI
# 0.7056657733187988 0.8615450918587284
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.39831853 13.976452  ] [ 2.45036558 53.04886166] [6.15177404 3.79558859]
# (Manually) Weighted RMSE Train
# [0.17157439 4.02985377]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.8779979144942649, 0.9551616266944735] [0.520450741651474, 16.858731169534167] [0.16325763237715712, 3.9242683403725755]
# Smiles Weight Mean and Std Dev
# 0.8020269986346752 0.040760930108626456
# Smiles Weight CI
# 0.714738861668202 0.8564382190321158
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.36702826 13.9138717 ] [ 2.46048253 52.90878203] [6.70379579 3.80259235]
# (Manually) Weighted RMSE Train
# [0.16325763 3.92426834]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.8446298227320125, 0.954118873826903] [0.5018518449404109, 17.227546863634487] [0.1709533230780405, 3.937634218819238]
# Smiles Weight Mean and Std Dev
# 0.7936334889184891 0.04202274631359601
# Smiles Weight CI
# 0.6954636580300253 0.8604138782736427
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.38994529 13.84731951] [ 2.4536182  52.81843224] [6.29221147 3.81434343]
# (Manually) Weighted RMSE Train
# [0.17095332 3.93763422]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.8373305526590198, 0.9478623566214807] [0.4988303316947212, 16.250529577514836] [0.16926483008396345, 3.8786339129532146]
# Smiles Weight Mean and Std Dev
# 0.7971788301734455 0.04301171706125336
# Smiles Weight CI
# 0.7022484117620139 0.8559130700765856
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.37577885 13.81758985] [ 2.46333574 52.72488733] [6.55528037 3.81578031]
# (Manually) Weighted RMSE Train
# [0.16926483 3.87863391]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.9395203336809176] [0.4432569591706666, 15.405941469243391] [0.1663416159912854, 3.847193730572573]
# Smiles Weight Mean and Std Dev
# 0.801930878475264 0.04014059376394509
# Smiles Weight CI
# 0.7092484811659706 0.8588272195479294
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.35460307 13.83073752] [ 2.47805248 52.71893062] [6.98824315 3.8117223 ]
# (Manually) Weighted RMSE Train
# [0.16634162 3.84719373]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.9447340980187695] [0.4654441435278006, 16.97223480403883] [0.1737949506828848, 3.869473439940493]
# Smiles Weight Mean and Std Dev
# 0.7939723324040115 0.048585963511335706
# Smiles Weight CI
# 0.6784708571193488 0.8579628188719555
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.376386   13.63905458] [ 2.46973178 52.6292686 ] [6.56169932 3.85871823]
# (Manually) Weighted RMSE Train
# [0.17379495 3.86947344]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.7747653806047967, 0.9280500521376434] [0.4319483026690299, 15.765276053592896] [0.1713569226115946, 3.8182854018947605]
# Smiles Weight Mean and Std Dev
# 0.7974669820459999 0.0435920630062292
# Smiles Weight CI
# 0.6792866441501426 0.8625468157444073
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.36309406 13.55719633] [ 2.47616934 52.63573992] [6.81963601 3.88249448]
# (Manually) Weighted RMSE Train
# [0.17135692 3.8182854 ]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.7653806047966631, 0.9259645464025026] [0.4267814639919046, 15.26784671740982] [0.1711525346764481, 3.808227677047002]
# Smiles Weight Mean and Std Dev
# 0.797853660625277 0.04181219235618551
# Smiles Weight CI
# 0.6978039928434824 0.8571605175130903
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.35480325 13.52206507] [ 2.48348338 52.58294374] [6.99960729 3.88867702]
# (Manually) Weighted RMSE Train
# [0.17115253 3.80822768]
#
#
# done for fold0
# train_width[0.4432569591706666, 15.405941469243391]
# smiles_weight0.801930878475264
# rmse_train[0.08813681828504741, 0.08914688091603197]
# smiles_weight_ci[0.7092484811659706, 0.8588272195479294]
# CPU times: user 7min 13s, sys: 4min 38s, total: 11min 51s
# Wall time: 3min 45s

# %%
with open("..//Data/returned_stuff_config2.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
# returned_stuff2 = get_results(2, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-2], threshold = 0.75)

# %%
len(returned_stuff)
# Out:
# 9

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,14), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.40, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.6110531803962461, 0.7685088633993743] [0.42263774262997816, 15.787247406127802] [0.306675792386744, 10.526588688833481]
# Smiles Weight Mean and Std Dev
# 0.7867455672595574 0.04353127776288687
# Smiles Weight CI
# 0.6736556003642504 0.8426694642734276
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.51424268 18.26939145] [ 2.35977823 49.92201307] [4.58884164 2.73254931]
# (Manually) Weighted RMSE Train
# [ 0.30667579 10.52658869]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.6496350364963503, 0.8102189781021898] [0.4426866160627291, 15.25464714289313] [0.29682258026719693, 9.93256124814667]
# Smiles Weight Mean and Std Dev
# 0.7790637187478071 0.03998150042665418
# Smiles Weight CI
# 0.6891181268905372 0.8366132390729297
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.57615721 19.64205899] [ 2.2800398  47.10341353] [3.95732231 2.3980894 ]
# (Manually) Weighted RMSE Train
# [0.29682258 9.93256125]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.6600625651720542, 0.8331595411887383] [0.4265218968561311, 15.845980110102339] [0.28912326525523113, 9.48900565695829]
# Smiles Weight Mean and Std Dev
# 0.7650553071324296 0.04333971814632149
# Smiles Weight CI
# 0.6744470920119291 0.8247742135693175
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67261499 21.31428635] [ 2.18159691 44.6025053 ] [3.24345571 2.09261078]
# (Manually) Weighted RMSE Train
# [0.28912327 9.48900566]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.6736183524504692, 0.8467153284671532] [0.4307688014678856, 16.055515637659955] [0.2808126530817858, 9.280192411734149]
# Smiles Weight Mean and Std Dev
# 0.7535473241260298 0.046871620984405934
# Smiles Weight CI
# 0.6229560767069626 0.8231932104814726
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7477467  23.08382362] [ 2.10281381 42.26732536] [2.81220071 1.83103658]
# (Manually) Weighted RMSE Train
# [0.28081265 9.28019241]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.6517205422314911, 0.8133472367049009] [0.4068048430399433, 14.50407213834708] [0.2747363733195149, 9.109955026425245]
# Smiles Weight Mean and Std Dev
# 0.7477207307731009 0.03969476308244847
# Smiles Weight CI
# 0.6594329696879204 0.8058920012096932
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82730758 24.95480022] [ 2.035171   40.32134868] [2.45999318 1.61577525]
# (Manually) Weighted RMSE Train
# [0.27473637 9.10995503]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.6204379562043796, 0.7361835245046924] [0.3785604075620629, 13.267330276397452] [0.2735839591748127, 9.096260583007957]
# Smiles Weight Mean and Std Dev
# 0.7478036805983723 0.0358074145487309
# Smiles Weight CI
# 0.675979554840139 0.8032392712062905
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87987506 26.46534581] [ 2.00781272 38.93986109] [2.28192935 1.47135282]
# (Manually) Weighted RMSE Train
# [0.27358396 9.09626058]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.6266944734098019, 0.7789363920750783] [0.38655413605027217, 14.389142766920134] [0.26984486572133803, 8.752758376551748]
# Smiles Weight Mean and Std Dev
# 0.736241668864653 0.043350140035407006
# Smiles Weight CI
# 0.6320965018470289 0.8036918510193855
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.9605487  28.47082149] [ 1.93425643 36.90053309] [2.01369951 1.29608249]
# (Manually) Weighted RMSE Train
# [0.26984487 8.75275838]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.6173096976016684, 0.7778936392075079] [0.36557784641071617, 14.546663615204725] [0.2670764213169645, 8.782269017504914]
# Smiles Weight Mean and Std Dev
# 0.7383967642076915 0.039839015777045225
# Smiles Weight CI
# 0.6395853574003849 0.7986281791527442
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.99180778 30.01024289] [ 1.9032264  35.74750501] [1.91894683 1.1911768 ]
# (Manually) Weighted RMSE Train
# [0.26707642 8.78226902]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7330552659019812] [0.36102182276157174, 13.44227501591222] [0.2634359102405151, 8.446363908282216]
# Smiles Weight Mean and Std Dev
# 0.7318954262173057 0.03766717967973247
# Smiles Weight CI
# 0.6526954683424295 0.7851092562934607
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05302346 31.77623897] [ 1.84128724 33.96943686] [1.7485719  1.06902006]
# (Manually) Weighted RMSE Train
# [0.26343591 8.44636391]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.643378519290928, 0.7851929092805006] [0.39443226313605056, 15.368439664265006] [0.2595108172938096, 8.14405868431522]
# Smiles Weight Mean and Std Dev
# 0.7244468484130323 0.04435682916111655
# Smiles Weight CI
# 0.6366262205342065 0.7852226597592539
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.11100551 33.48694563] [ 1.77995545 32.48679769] [1.60211216 0.9701332 ]
# (Manually) Weighted RMSE Train
# [0.25951082 8.14405868]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.6548488008342023, 0.7956204379562044] [0.4134264313556671, 16.078630850015955] [0.2570047671630343, 7.840558282216518]
# Smiles Weight Mean and Std Dev
# 0.7202376682683523 0.043415976687045436
# Smiles Weight CI
# 0.6164513032498055 0.780247266388389
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17984124 34.6796934 ] [ 1.71434542 31.23675526] [1.4530306  0.90072178]
# (Manually) Weighted RMSE Train
# [0.25700477 7.84055828]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.6235662148070907, 0.7872784150156413] [0.39219158976705254, 14.972937203979683] [0.25598367198190614, 7.806826967243049]
# Smiles Weight Mean and Std Dev
# 0.720758905254232 0.03766358807451028
# Smiles Weight CI
# 0.6309771812396957 0.7751364422668154
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21403878 36.11462568] [ 1.68820361 30.24730807] [1.3905681  0.83753625]
# (Manually) Weighted RMSE Train
# [0.25598367 7.80682697]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.6506777893639207, 0.8196037539103233] [0.4201146449382961, 17.28950484139024] [0.254117775670611, 7.44499846035283]
# Smiles Weight Mean and Std Dev
# 0.7157330372413364 0.04745590207717995
# Smiles Weight CI
# 0.6111150555073076 0.783512430342557
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25819386 36.91057787] [ 1.64610126 29.18512693] [1.30830495 0.79069819]
# (Manually) Weighted RMSE Train
# [0.25411778 7.44499846]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.6256517205422315, 0.7737226277372263] [0.3972991938404589, 15.338877411508905] [0.25886981700063966, 7.752045175578947]
# Smiles Weight Mean and Std Dev
# 0.7187613212049554 0.040922741961535315
# Smiles Weight CI
# 0.6330904471969573 0.7805545990374934
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28364632 37.85215835] [ 1.63812389 28.64782737] [1.27614894 0.75683471]
# (Manually) Weighted RMSE Train
# [0.25886982 7.75204518]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.6246089676746611, 0.7695516162669447] [0.40042347998626826, 15.082401637016101] [0.25405900477588994, 7.675831370958365]
# Smiles Weight Mean and Std Dev
# 0.7153462625271888 0.040201472067396604
# Smiles Weight CI
# 0.6145780992292538 0.775317087539905
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.30425351 38.956434  ] [ 1.60907756 28.0146603 ] [1.23371534 0.71912794]
# (Manually) Weighted RMSE Train
# [0.254059   7.67583137]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.607924921793535, 0.8029197080291971] [0.39328856814775415, 16.312978094201462] [0.25359281966822733, 7.488682183216287]
# Smiles Weight Mean and Std Dev
# 0.7112536548788833 0.04410492666295618
# Smiles Weight CI
# 0.61036050014399 0.769203452978877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33487239 39.91703477] [ 1.58228065 27.11134128] [1.18534226 0.67919227]
# (Manually) Weighted RMSE Train
# [0.25359282 7.48868218]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.6037539103232534, 0.7872784150156413] [0.39572463014692505, 16.23639600098908] [0.2565290706724993, 7.760982573492933]
# Smiles Weight Mean and Std Dev
# 0.7140595100986878 0.03956888598985037
# Smiles Weight CI
# 0.6154075687790102 0.7725932673151947
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35741227 40.67728393] [ 1.5728636 26.7970828] [1.15872211 0.65877267]
# (Manually) Weighted RMSE Train
# [0.25652907 7.76098257]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.5828988529718456, 0.7236704900938478] [0.3661190592822919, 14.169232768308877] [0.2595769293293855, 7.992710915918025]
# Smiles Weight Mean and Std Dev
# 0.7188436304414513 0.03502170817753593
# Smiles Weight CI
# 0.6381946161612568 0.7742262242355674
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37544526 40.80542873] [ 1.56513415 26.7378895 ] [1.13791089 0.65525324]
# (Manually) Weighted RMSE Train
# [0.25957693 7.99271092]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7737226277372263] [0.4041347418192739, 15.035266129963906] [0.24969668769698813, 7.338286754126568]
# Smiles Weight Mean and Std Dev
# 0.7090175674261409 0.03913104473989768
# Smiles Weight CI
# 0.6192866698825823 0.7665659253902702
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41348055 41.54990908] [ 1.50768736 25.74701024] [1.06664882 0.61966466]
# (Manually) Weighted RMSE Train
# [0.24969669 7.33828675]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.6246089676746611, 0.781021897810219] [0.4119660221782445, 15.849838162596786] [0.25055730577615354, 7.4518373010969965]
# Smiles Weight Mean and Std Dev
# 0.710113012217514 0.04057900164066387
# Smiles Weight CI
# 0.6123765605037285 0.7717501734741654
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42655514 42.10619353] [ 1.49717777 25.34144476] [1.04950571 0.60184601]
# (Manually) Weighted RMSE Train
# [0.25055731 7.4518373 ]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.6339937434827946, 0.7966631908237748] [0.4356883151821019, 17.548172805434273] [0.2502099428599104, 7.289487618378702]
# Smiles Weight Mean and Std Dev
# 0.7073593141511821 0.04116636072612783
# Smiles Weight CI
# 0.6007607130704968 0.7668659698515962
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44550338 42.54338932] [ 1.47881011 24.72931502] [1.02304161 0.5812728 ]
# (Manually) Weighted RMSE Train
# [0.25020994 7.28948762]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7612095933263816] [0.40043724389408736, 15.127153227306167] [0.2503278920278961, 7.329796390100667]
# Smiles Weight Mean and Std Dev
# 0.7072340599049605 0.039737738615983086
# Smiles Weight CI
# 0.6125377360768632 0.773178253051265
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46204533 42.74889339] [ 1.46527472 24.46714043] [1.00220882 0.57234559]
# (Manually) Weighted RMSE Train
# [0.25032789 7.32979639]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.6277372262773723, 0.7466110531803962] [0.43838048841402766, 15.726768672033437] [0.2572082747435439, 7.741647664331271]
# Smiles Weight Mean and Std Dev
# 0.7111031506007355 0.041330731038584846
# Smiles Weight CI
# 0.6194929233392912 0.7821483659728672
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47206528 43.11433077] [ 1.47243609 24.41173824] [1.00025189 0.56620937]
# (Manually) Weighted RMSE Train
# [0.25720827 7.74164766]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.62148070907195, 0.7737226277372263] [0.4183704675553906, 16.110189139683854] [0.24946315142342454, 7.0651081646678655]
# Smiles Weight Mean and Std Dev
# 0.7020839684541469 0.04248090272556975
# Smiles Weight CI
# 0.6119477818622856 0.767345349209459
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50438641 43.48506663] [ 1.42587437 23.60247945] [0.94781125 0.54277207]
# (Manually) Weighted RMSE Train
# [0.24946315 7.06510816]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.59436913451512, 0.7288842544316997] [0.394297643576443, 14.380628920404108] [0.25243375796462036, 7.326368540300514]
# Smiles Weight Mean and Std Dev
# 0.7046152854471334 0.03780151559822082
# Smiles Weight CI
# 0.6165782044909416 0.7658139262355929
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50829151 43.79908475] [ 1.43240213 23.62168812] [0.9496852  0.53931922]
# (Manually) Weighted RMSE Train
# [0.25243376 7.32636854]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.5974973931178311, 0.7299270072992701] [0.39956441872521087, 15.03221972021195] [0.2539984585018767, 7.37931481409309]
# Smiles Weight Mean and Std Dev
# 0.7042856866974206 0.038853705469910856
# Smiles Weight CI
# 0.6164393711314963 0.7678635778121133
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51642113 44.12527478] [ 1.42876569 23.43092574] [0.94219584 0.53100917]
# (Manually) Weighted RMSE Train
# [0.25399846 7.37931481]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.5818561001042752, 0.7507820646506778] [0.39013049375736475, 14.615817099912666] [0.24919511264576863, 7.1327408470592975]
# Smiles Weight Mean and Std Dev
# 0.7018895424057869 0.0366746034598259
# Smiles Weight CI
# 0.6106665265118484 0.7558350713709359
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.52653166 44.55373107] [ 1.40985932 22.9624402 ] [0.92357031 0.51538759]
# (Manually) Weighted RMSE Train
# [0.24919511 7.13274085]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.6110531803962461, 0.7820646506777894] [0.41325648937189297, 16.090613143924863] [0.2461886462972767, 6.838173272325983]
# Smiles Weight Mean and Std Dev
# 0.6978378901462376 0.04133657017247233
# Smiles Weight CI
# 0.5950695798286386 0.7553149459876431
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.54427471 44.86191084] [ 1.38683132 22.52538273] [0.89804703 0.50210484]
# (Manually) Weighted RMSE Train
# [0.24618865 6.83817327]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.602711157455683, 0.7455683003128258] [0.40069436169782746, 15.1418480328841] [0.25155891579984346, 7.140537030012525]
# Smiles Weight Mean and Std Dev
# 0.7011048788510417 0.038001763054521964
# Smiles Weight CI
# 0.6108928445301396 0.7602238704502329
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55284753 45.1424229 ] [ 1.39004842 22.59725901] [0.89516092 0.50057701]
# (Manually) Weighted RMSE Train
# [0.25155892 7.14053703]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7038581856100105] [0.3964542033720229, 14.605282316469905] [0.2566446199132724, 7.43532815789273]
# Smiles Weight Mean and Std Dev
# 0.7040933787374086 0.03557270946464608
# Smiles Weight CI
# 0.6285528607996026 0.7645003017706881
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55993264 45.36185661] [ 1.39411495 22.65989626] [0.89370202 0.49953635]
# (Manually) Weighted RMSE Train
# [0.25664462 7.43532816]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.6047966631908238, 0.7278415015641293] [0.4175262041054216, 15.508367034342541] [0.25749282704458365, 7.4147628096709335]
# Smiles Weight Mean and Std Dev
# 0.7029193308136983 0.03914812990463052
# Smiles Weight CI
# 0.6123007101912062 0.7687466792487554
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56643062 45.70729382] [ 1.38895507 22.47818063] [0.88670066 0.49178542]
# (Manually) Weighted RMSE Train
# [0.25749283 7.41476281]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.602711157455683, 0.7226277372262774] [0.386022077404704, 14.794653282587868] [0.2559723649197504, 7.332569100711858]
# Smiles Weight Mean and Std Dev
# 0.7015873138936061 0.037015645578495446
# Smiles Weight CI
# 0.619564496179384 0.7520472698484766
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57524804 45.99690974] [ 1.37713924 22.28587622] [0.87423644 0.48450812]
# (Manually) Weighted RMSE Train
# [0.25597236 7.3325691 ]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.6068821689259646, 0.7330552659019812] [0.4169487403646764, 15.987914076520775] [0.25063278770490816, 6.99289697618245]
# Smiles Weight Mean and Std Dev
# 0.696616543362264 0.03854999975632182
# Smiles Weight CI
# 0.6118656189162841 0.7639560795698721
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.59257235 46.39308842] [ 1.3512851  21.96062713] [0.84849212 0.47335989]
# (Manually) Weighted RMSE Train
# [0.25063279 6.99289698]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7497393117831074] [0.4107108495054762, 16.183032238792872] [0.25260074301424673, 7.042863016977751]
# Smiles Weight Mean and Std Dev
# 0.6960904578381846 0.03970865312488907
# Smiles Weight CI
# 0.606639711004645 0.7575384044129779
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60350265 46.67728613] [ 1.34537891 21.82471536] [0.83902506 0.46756607]
# (Manually) Weighted RMSE Train
# [0.25260074 7.04286302]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.5787278415015641, 0.7205422314911366] [0.3813797297831012, 14.657453690747385] [0.2563737905240879, 7.264484940736183]
# Smiles Weight Mean and Std Dev
# 0.6979183066766923 0.03721632423754346
# Smiles Weight CI
# 0.6164151240945471 0.750914158296326
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.606013   46.74140276] [ 1.35095883 21.84694969] [0.84118798 0.46740039]
# (Manually) Weighted RMSE Train
# [0.25637379 7.26448494]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.6120959332638165, 0.735140771637122] [0.4164325009225192, 15.637013220059849] [0.2548486232335054, 7.19246212931991]
# Smiles Weight Mean and Std Dev
# 0.6966956615180989 0.039368783808177696
# Smiles Weight CI
# 0.6227825003851315 0.7547519837104996
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.61460546 46.94408876] [ 1.34033715 21.6571684 ] [0.83013292 0.46133963]
# (Manually) Weighted RMSE Train
# [0.25484862 7.19246213]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7330552659019812] [0.405854273049266, 15.653207211425174] [0.2542226998506511, 7.122283905540775]
# Smiles Weight Mean and Std Dev
# 0.6954219622748911 0.03821596770796631
# Smiles Weight CI
# 0.6052211701089155 0.75739841844474
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6233168  47.12846473] [ 1.33150466 21.51552092] [0.8202371  0.45652921]
# (Manually) Weighted RMSE Train
# [0.2542227  7.12228391]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.5954118873826904, 0.7111574556830031] [0.40466209391205715, 15.05886130211503] [0.25951006023788625, 7.324938233479915]
# Smiles Weight Mean and Std Dev
# 0.6971343603065489 0.037693244229208854
# Smiles Weight CI
# 0.6127055450317312 0.753379442913533
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63080235 47.40821608] [ 1.33517032 21.52743926] [0.81871989 0.45408668]
# (Manually) Weighted RMSE Train
# [0.25951006 7.32493823]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.670490093847758] [0.3737208421494284, 13.509389496096816] [0.26449375677085635, 7.650247833531397]
# Smiles Weight Mean and Std Dev
# 0.6995300164253212 0.03524856770741347
# Smiles Weight CI
# 0.6225873529782001 0.7556915757625113
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63290078 47.57576776] [ 1.3416468  21.62756694] [0.821634   0.45459207]
# (Manually) Weighted RMSE Train
# [0.26449376 7.65024783]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.6402502606882169, 0.7685088633993743] [0.4497951928699713, 17.085733323132924] [0.2513820839729482, 6.8839624931506345]
# Smiles Weight Mean and Std Dev
# 0.6913928425428516 0.04345055754409408
# Smiles Weight CI
# 0.5980038484560036 0.7535013577540888
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.64982589 47.81162656] [ 1.30044173 21.07511552] [0.78822968 0.44079478]
# (Manually) Weighted RMSE Train
# [0.25138208 6.88396249]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7445255474452555] [0.42647909697699943, 16.291389807113518] [0.2512573282742973, 6.879482215783269]
# Smiles Weight Mean and Std Dev
# 0.6901085456196024 0.04107110251562548
# Smiles Weight CI
# 0.6034032670082089 0.7490208276137992
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.65491824 47.94944858] [ 1.2955797  21.00160088] [0.78286629 0.43799463]
# (Manually) Weighted RMSE Train
# [0.25125733 6.87948222]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7549530761209593] [0.4268410180985135, 16.683222794857922] [0.2575604072776177, 7.19839075681515]
# Smiles Weight Mean and Std Dev
# 0.69349012585327 0.03915728771636502
# Smiles Weight CI
# 0.5992344885245678 0.7543536482252585
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.65534748 48.10877899] [ 1.30716506 21.07634868] [0.78966204 0.43809777]
# (Manually) Weighted RMSE Train
# [0.25756041 7.19839076]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7424400417101147] [0.41552840893473475, 15.819264381790324] [0.2541531605881074, 6.9849223728974374]
# Smiles Weight Mean and Std Dev
# 0.6903733588506703 0.03896040316348774
# Smiles Weight CI
# 0.5946203954059606 0.7514115288490598
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67009203 48.34006182] [ 1.28766927 20.91465051] [0.77101696 0.43265668]
# (Manually) Weighted RMSE Train
# [0.25415316 6.98492237]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.6558915537017727, 0.7841501564129302] [0.4988267183873975, 18.533828986972356] [0.26401809549619093, 7.445519204488338]
# Smiles Weight Mean and Std Dev
# 0.6950397109710681 0.04406879511875729
# Smiles Weight CI
# 0.5738507712283928 0.7571500238512606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67570101 48.32222419] [ 1.30021161 21.12049751] [0.775921   0.43707627]
# (Manually) Weighted RMSE Train
# [0.2640181 7.4455192]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.5870698644421272, 0.7122002085505735] [0.3927506232592658, 14.388459476939] [0.2511949820570778, 6.7427628464589535]
# Smiles Weight Mean and Std Dev
# 0.6861326525396145 0.03871435944755948
# Smiles Weight CI
# 0.6109102458121187 0.7428497542948758
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.69552184 48.51787562] [ 1.25830781 20.68691401] [0.742136   0.42637716]
# (Manually) Weighted RMSE Train
# [0.25119498 6.74276285]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7497393117831074] [0.4383430801117536, 16.7259435595168] [0.2515870638683935, 6.803732502954429]
# Smiles Weight Mean and Std Dev
# 0.6863488209283279 0.040982367780477265
# Smiles Weight CI
# 0.5902324680915838 0.7482451446316922
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70138353 48.6317108 ] [ 1.25399631 20.63897091] [0.73704505 0.42439327]
# (Manually) Weighted RMSE Train
# [0.25158706 6.8037325 ]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.6319082377476538, 0.7612095933263816] [0.4534439784166949, 16.90632603262973] [0.2560637752751993, 6.991810734499777]
# Smiles Weight Mean and Std Dev
# 0.688303176465793 0.04107394513856379
# Smiles Weight CI
# 0.585009558379299 0.7459420816401546
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7000303  48.73485495] [ 1.26218175 20.68212835] [0.74244662 0.42438063]
# (Manually) Weighted RMSE Train
# [0.25606378 6.99181073]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.5797705943691345, 0.7059436913451512] [0.4020434987084214, 15.378758084923794] [0.26349225725069797, 7.382851066331382]
# Smiles Weight Mean and Std Dev
# 0.6922867466747148 0.034902353951854155
# Smiles Weight CI
# 0.6104536112741744 0.7489726707905131
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.69708978 48.79900209] [ 1.27801364 20.78314703] [0.75306189 0.42589287]
# (Manually) Weighted RMSE Train
# [0.26349226 7.38285107]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.6204379562043796, 0.7507820646506778] [0.4459542444027544, 16.73271233971215] [0.2592954352471734, 7.100592242187298]
# Smiles Weight Mean and Std Dev
# 0.6897690548898654 0.03851433144689383
# Smiles Weight CI
# 0.5917627483608551 0.7485425678634556
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70625049 48.81934232] [ 1.26235756 20.60425255] [0.73984304 0.42205101]
# (Manually) Weighted RMSE Train
# [0.25929544 7.10059224]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.5954118873826904, 0.7132429614181439] [0.4131401183425912, 15.139292934341428] [0.2579471310012245, 6.986807608299797]
# Smiles Weight Mean and Std Dev
# 0.6886868403529055 0.0376656375430476
# Smiles Weight CI
# 0.604253989098457 0.7458471261376473
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7150994  48.94777568] [ 1.2517359 20.4637529] [0.72983286 0.41807319]
# (Manually) Weighted RMSE Train
# [0.25794713 6.98680761]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7539103232533889] [0.4465825534040199, 16.501826613611517] [0.2533192250425208, 6.7734263306699924]
# Smiles Weight Mean and Std Dev
# 0.6861975021775298 0.03954153828528946
# Smiles Weight CI
# 0.579741497568879 0.7418338356856841
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72691458 49.013118  ] [ 1.23287376 20.3182239 ] [0.71391705 0.41454665]
# (Manually) Weighted RMSE Train
# [0.25331923 6.77342633]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.5954118873826904, 0.7184567257559958] [0.41777689241603877, 15.243478691883778] [0.2553710367074913, 6.850036546933472]
# Smiles Weight Mean and Std Dev
# 0.6866362823066006 0.037730959802888056
# Smiles Weight CI
# 0.597734609093798 0.7481249207269924
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72800915 49.10533396] [ 1.23475527 20.29863559] [0.71455366 0.41336926]
# (Manually) Weighted RMSE Train
# [0.25537104 6.85003655]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.6183524504692388, 0.7580813347236705] [0.451714607205297, 16.97990347352215] [0.2516611527714532, 6.553739723641163]
# Smiles Weight Mean and Std Dev
# 0.6837892030606876 0.040633591613236715
# Smiles Weight CI
# 0.5846026992306701 0.7435620351854323
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73604585 49.23197967] [ 1.21971106 20.12393158] [0.70257998 0.40875731]
# (Manually) Weighted RMSE Train
# [0.25166115 6.55373972]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7361835245046924] [0.4228824247486819, 15.307439723972639] [0.2593653244716294, 6.938037755303163]
# Smiles Weight Mean and Std Dev
# 0.6877178240554435 0.037048664929389005
# Smiles Weight CI
# 0.5989358629369315 0.7432331000324487
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.736098   49.31740116] [ 1.23391095 20.27922646] [0.71073807 0.4111982 ]
# (Manually) Weighted RMSE Train
# [0.25936532 6.93803776]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.6016684045881127, 0.7403545359749739] [0.4340679925393296, 16.034024553563537] [0.2597221143163165, 6.963986867883802]
# Smiles Weight Mean and Std Dev
# 0.687854925359272 0.041622361601166016
# Smiles Weight CI
# 0.5937242155669367 0.7495528638714236
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73945709 49.47990323] [ 1.23160334 20.25675193] [0.70803893 0.40939352]
# (Manually) Weighted RMSE Train
# [0.25972211 6.96398687]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.7393117831074035] [0.43659712028373043, 16.499960984129913] [0.25572771439674075, 6.722900342483686]
# Smiles Weight Mean and Std Dev
# 0.6852855236037211 0.03819146510324008
# Smiles Weight CI
# 0.5921168656397772 0.7476779420561209
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7493986 49.5653061] [ 1.2153525  20.08370448] [0.69472589 0.40519682]
# (Manually) Weighted RMSE Train
# [0.25572771 6.72290034]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.6016684045881127, 0.7601668404588112] [0.4305707122327057, 16.21727905509301] [0.25105962631672096, 6.429949681223511]
# Smiles Weight Mean and Std Dev
# 0.682913016688792 0.04053263807846074
# Smiles Weight CI
# 0.5906651588794611 0.7378405038584875
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75774053 49.60166701] [ 1.19893259 19.91686806] [0.68208736 0.40153626]
# (Manually) Weighted RMSE Train
# [0.25105963 6.42994968]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7382690302398331] [0.4462202739967407, 16.04989091916801] [0.25587794394390484, 6.694441205313792]
# Smiles Weight Mean and Std Dev
# 0.6851712152773598 0.038153570905894704
# Smiles Weight CI
# 0.5939906510646794 0.7472765510518415
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75794208 49.69394391] [ 1.20780972 20.00032512] [0.68705888 0.40247007]
# (Manually) Weighted RMSE Train
# [0.25587794 6.69444121]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.6319082377476538, 0.7831074035453598] [0.4755609002775038, 18.275363755944156] [0.24466558994701454, 6.13010236286417]
# Smiles Weight Mean and Std Dev
# 0.6790377048787845 0.043776676617191035
# Smiles Weight CI
# 0.5784341256690917 0.7469508646814768
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77253685 49.75253097] [ 1.17364214 19.70945646] [0.66212567 0.39614983]
# (Manually) Weighted RMSE Train
# [0.24466559 6.13010236]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7518248175182481] [0.4409562893639047, 16.555290445430686] [0.2527188219075242, 6.540327819426161]
# Smiles Weight Mean and Std Dev
# 0.6837825669961831 0.03807335098875463
# Smiles Weight CI
# 0.5917418067493315 0.7505424211426504
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76846619 49.79983984] [ 1.19302338 19.93416644] [0.67460909 0.40028575]
# (Manually) Weighted RMSE Train
# [0.25271882 6.54032782]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.6360792492179353, 0.7612095933263816] [0.4741497376754655, 17.515276549050327] [0.2517442015490907, 6.462403229617149]
# Smiles Weight Mean and Std Dev
# 0.683006441382803 0.040957470120229184
# Smiles Weight CI
# 0.5853470322761636 0.7441951190683724
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77254429 49.89077996] [ 1.18819533 19.81764712] [0.67033323 0.39722063]
# (Manually) Weighted RMSE Train
# [0.2517442  6.46240323]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.6392075078206465, 0.7778936392075079] [0.47909705948954256, 17.740297482736754] [0.24799008642730985, 6.317033762740559]
# Smiles Weight Mean and Std Dev
# 0.6818374057408728 0.04244623575144363
# Smiles Weight CI
# 0.5776894149916503 0.7429419160191054
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77462986 50.01414986] [ 1.17948293 19.66491751] [0.66463602 0.39318708]
# (Manually) Weighted RMSE Train
# [0.24799009 6.31703376]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.7497393117831074] [0.42015972304937693, 15.541995611013697] [0.25166325498018466, 6.4685316881933534]
# Smiles Weight Mean and Std Dev
# 0.6832874300809075 0.037325152279633754
# Smiles Weight CI
# 0.590061254042387 0.7396539336411548
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77572999 50.1252065 ] [ 1.18493577 19.67149788] [0.66729502 0.39244722]
# (Manually) Weighted RMSE Train
# [0.25166325 6.46853169]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.5578727841501564, 0.6830031282586028] [0.38195272175556166, 13.78138607126264] [0.2601661820553525, 6.885459631891019]
# Smiles Weight Mean and Std Dev
# 0.687253105297247 0.03321321110233832
# Smiles Weight CI
# 0.6155927597918628 0.7447047831688789
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77552179 50.1865217 ] [ 1.19941765 19.8254104 ] [0.67552967 0.39503456]
# (Manually) Weighted RMSE Train
# [0.26016618 6.88545963]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7559958289885297] [0.45904253244289356, 16.986589435895695] [0.25163515862992225, 6.468332998477346]
# Smiles Weight Mean and Std Dev
# 0.682842321301889 0.03815041940810724
# Smiles Weight CI
# 0.5830358377874548 0.7426568466404804
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78797075 50.17318796] [ 1.17350662 19.57929846] [0.65633435 0.39023429]
# (Manually) Weighted RMSE Train
# [0.25163516 6.468333  ]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.6047966631908238, 0.7403545359749739] [0.44253006270846956, 16.085530960970022] [0.25685917274077463, 6.742124734139051]
# Smiles Weight Mean and Std Dev
# 0.6856311219801491 0.03568768179434818
# Smiles Weight CI
# 0.5984380872010364 0.7429872435501544
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78691439 50.2011698 ] [ 1.18399142 19.69450197] [0.6625899  0.39231161]
# (Manually) Weighted RMSE Train
# [0.25685917 6.74212473]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.6548488008342023, 0.7883211678832117] [0.5213394362111338, 19.080351513909054] [0.24639536371897083, 6.188098419645226]
# Smiles Weight Mean and Std Dev
# 0.6792637112390331 0.04474009139427958
# Smiles Weight CI
# 0.5592030529314543 0.7431763172841667
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79646292 50.37150759] [ 1.15621212 19.40575713] [0.64360478 0.38525266]
# (Manually) Weighted RMSE Train
# [0.24639536 6.18809842]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.5891553701772679, 0.7372262773722628] [0.41896319812035127, 15.521145135129991] [0.24467907571646802, 6.103609955871754]
# Smiles Weight Mean and Std Dev
# 0.6783868071022557 0.0381131886483219
# Smiles Weight CI
# 0.5973512013012464 0.7416834574871997
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80090591 50.46332276] [ 1.14959852 19.29960426] [0.63834458 0.38244815]
# (Manually) Weighted RMSE Train
# [0.24467908 6.10360996]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7539103232533889] [0.45220516764730967, 16.49956194821718] [0.2504282102084252, 6.405592925042875]
# Smiles Weight Mean and Std Dev
# 0.6814278973779017 0.03838291455230384
# Smiles Weight CI
# 0.5839784431980884 0.7415053141249938
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80028235 50.51521412] [ 1.16154192 19.42295216] [0.64519986 0.38449708]
# (Manually) Weighted RMSE Train
# [0.25042821 6.40559293]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.6110531803962461, 0.7559958289885297] [0.4503637708178722, 16.25436042104993] [0.2451664486029391, 6.121241003752698]
# Smiles Weight Mean and Std Dev
# 0.6784699390621466 0.038998764334488185
# Smiles Weight CI
# 0.5934517588796652 0.7385976224146392
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8063537  50.58890733] [ 1.14553624 19.25027211] [0.63417051 0.38052358]
# (Manually) Weighted RMSE Train
# [0.24516645 6.121241  ]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.6465067778936392, 0.7664233576642335] [0.505381272541816, 17.886507727364897] [0.24804992586537883, 6.314226565676739]
# Smiles Weight Mean and Std Dev
# 0.6807934007224602 0.04094080858514836
# Smiles Weight CI
# 0.5829873377776456 0.7522035427440508
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80632274 50.65609985] [ 1.15130625 19.2939304 ] [0.63737572 0.38088069]
# (Manually) Weighted RMSE Train
# [0.24804993 6.31422657]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.6047966631908238, 0.7424400417101147] [0.4439768616111893, 16.247224899585895] [0.2512950798977132, 6.445997801961917]
# Smiles Weight Mean and Std Dev
# 0.6818016877900624 0.035571008765681845
# Smiles Weight CI
# 0.5948741651940535 0.7382063547457381
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80568404 50.74338628] [ 1.15738623 19.35125375] [0.6409683  0.38135519]
# (Manually) Weighted RMSE Train
# [0.25129508 6.4459978 ]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.5985401459854015, 0.7466110531803962] [0.43563191681401514, 16.11041456971444] [0.2493162549031688, 6.3360555385339365]
# Smiles Weight Mean and Std Dev
# 0.6807863152056661 0.038018845169443184
# Smiles Weight CI
# 0.5957509732546924 0.738895904134436
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81129484 50.77224594] [ 1.14893955 19.26657396] [0.63431945 0.37947059]
# (Manually) Weighted RMSE Train
# [0.24931625 6.33605554]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.7205422314911366] [0.4259832138069461, 15.358522638262915] [0.2482854786333743, 6.299727193849211]
# Smiles Weight Mean and Std Dev
# 0.6804680911252854 0.036961891462634844
# Smiles Weight CI
# 0.6049420829698114 0.7433921011286022
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81314503 50.84737637] [ 1.14556875 19.28762464] [0.63181308 0.37932389]
# (Manually) Weighted RMSE Train
# [0.24828548 6.29972719]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.6120959332638165, 0.7507820646506778] [0.4627328552573213, 16.57899281905957] [0.24783336464516056, 6.263236879301858]
# Smiles Weight Mean and Std Dev
# 0.6799769951615329 0.03872595924030823
# Smiles Weight CI
# 0.5873040292225269 0.7411786193803347
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81458405 50.88875698] [ 1.14369569 19.20262373] [0.63027981 0.37734511]
# (Manually) Weighted RMSE Train
# [0.24783336 6.26323688]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.7382690302398331] [0.42427927551176825, 15.633737442913219] [0.24414664691830765, 6.0836729235151745]
# Smiles Weight Mean and Std Dev
# 0.6779952448810332 0.03601281055389239
# Smiles Weight CI
# 0.5896259603750544 0.7349724109808711
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82467701 50.9822956 ] [ 1.12729248 19.17024557] [0.61780385 0.3760177 ]
# (Manually) Weighted RMSE Train
# [0.24414665 6.08367292]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7580813347236705] [0.4566254148304363, 16.438947846374557] [0.23701666554836082, 5.760082941383682]
# Smiles Weight Mean and Std Dev
# 0.67406995632062 0.04041010773505422
# Smiles Weight CI
# 0.5869190892152354 0.7344682788940974
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83206725 51.06377123] [ 1.10637827 19.00582411] [0.6038961  0.37219782]
# (Manually) Weighted RMSE Train
# [0.23701667 5.76008294]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7476538060479666] [0.4341563544356299, 15.980734617811562] [0.24775620869927564, 6.275857154390973]
# Smiles Weight Mean and Std Dev
# 0.679443047078913 0.03737703466863219
# Smiles Weight CI
# 0.5919814395344541 0.7349700786866944
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82760383 51.13777426] [ 1.13201695 19.21234435] [0.61939953 0.3756977 ]
# (Manually) Weighted RMSE Train
# [0.24775621 6.27585715]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7591240875912408] [0.461950267404041, 16.423649196352148] [0.2501733357241479, 6.3985476974300255]
# Smiles Weight Mean and Std Dev
# 0.6806864558939455 0.0385590224597839
# Smiles Weight CI
# 0.5891852655185318 0.7351201426257558
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82881738 51.14768472] [ 1.13524176 19.24505864] [0.62075184 0.37626451]
# (Manually) Weighted RMSE Train
# [0.25017334 6.3985477 ]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.5787278415015641, 0.7226277372262774] [0.4228651732792989, 15.327004851608935] [0.25479362206604844, 6.618013328599616]
# Smiles Weight Mean and Std Dev
# 0.6824030192080365 0.03534883452467918
# Smiles Weight CI
# 0.5979785814618493 0.7406480840226799
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83174719 51.24864591] [ 1.14075999 19.28722917] [0.62277152 0.37634612]
# (Manually) Weighted RMSE Train
# [0.25479362 6.61801333]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.629822732012513, 0.7674661105318039] [0.4832336616890507, 17.25478048313897] [0.2491896940319524, 6.329353568504351]
# Smiles Weight Mean and Std Dev
# 0.6798021003201478 0.04112861161343996
# Smiles Weight CI
# 0.5748461436961 0.73811760439641
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83507415 51.3352651 ] [ 1.1272933  19.11182266] [0.61430395 0.37229422]
# (Manually) Weighted RMSE Train
# [0.24918969 6.32935357]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.6266944734098019, 0.7632950990615224] [0.47061798678868316, 16.72648704106656] [0.25183968030110176, 6.3997127445179505]
# Smiles Weight Mean and Std Dev
# 0.6805523547656535 0.03936432166486964
# Smiles Weight CI
# 0.5890286424890694 0.7407895913663283
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83984407 51.41139399] [ 1.12756776 19.14796296] [0.6128605 0.3724459]
# (Manually) Weighted RMSE Train
# [0.25183968 6.39971274]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.6068821689259646, 0.7466110531803962] [0.4478689505817105, 16.107890116529077] [0.24768006739056722, 6.227570851159457]
# Smiles Weight Mean and Std Dev
# 0.6788819117444228 0.03837161926599599
# Smiles Weight CI
# 0.594527300066227 0.7392155383480982
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84049376 51.49583533] [ 1.11973459 19.06701636] [0.60838815 0.37026327]
# (Manually) Weighted RMSE Train
# [0.24768007 6.22757085]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.6329509906152242, 0.762252346193952] [0.48679138092091295, 17.011057673888654] [0.23478698647878818, 5.593996382363416]
# Smiles Weight Mean and Std Dev
# 0.671664669516302 0.0417921396312759
# Smiles Weight CI
# 0.5729583018762426 0.7315109469677857
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85187687 51.49581306] [ 1.08468541 18.84889705] [0.58572221 0.36602776]
# (Manually) Weighted RMSE Train
# [0.23478699 5.59399638]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.6308654848800834, 0.7664233576642335] [0.47779408686586416, 17.233314096508643] [0.2349435100040922, 5.614952229189227]
# Smiles Weight Mean and Std Dev
# 0.6722653065137801 0.039396305339353274
# Smiles Weight CI
# 0.5834806065040279 0.732767230355056
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85315421 51.54438657] [ 1.08369937 18.85997167] [0.58478639 0.36589768]
# (Manually) Weighted RMSE Train
# [0.23494351 5.61495223]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.6444212721584984, 0.7758081334723671] [0.5270872770129583, 18.430189395516308] [0.2398735003818508, 5.82784744179016]
# Smiles Weight Mean and Std Dev
# 0.6748074700933893 0.04119112698503516
# Smiles Weight CI
# 0.5695162705980262 0.7379771937207835
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8501732  51.57787229] [ 1.09750398 18.94305229] [0.59318986 0.36727091]
# (Manually) Weighted RMSE Train
# [0.2398735  5.82784744]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7653806047966631] [0.4588956237799297, 16.994855577831807] [0.24572362887962773, 6.1153023581379]
# Smiles Weight Mean and Std Dev
# 0.6779728344690338 0.03789761729963578
# Smiles Weight CI
# 0.5874869383026388 0.7362336152102262
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8475544  51.61884862] [ 1.11157881 19.00614533] [0.60164876 0.36820165]
# (Manually) Weighted RMSE Train
# [0.24572363 6.11530236]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.5870698644421272, 0.7278415015641293] [0.4185160565145397, 15.385849761450848] [0.2510368593053043, 6.393774439277054]
# Smiles Weight Mean and Std Dev
# 0.6801591365045166 0.03480589969267406
# Smiles Weight CI
# 0.6002098667269126 0.7325620133323848
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84531546 51.69052185] [ 1.12342836 19.11737954] [0.60880017 0.36984304]
# (Manually) Weighted RMSE Train
# [0.25103686 6.39377444]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.5922836287799792, 0.7403545359749739] [0.4350645775546012, 16.109873569222312] [0.2516493553495799, 6.393112194696377]
# Smiles Weight Mean and Std Dev
# 0.680134772792119 0.0368663334201074
# Smiles Weight CI
# 0.5947753011335637 0.7439805399192567
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84711293 51.77112439] [ 1.12262668 19.08630838] [0.60777371 0.36866706]
# (Manually) Weighted RMSE Train
# [0.25164936 6.39311219]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.5307612095933264, 0.6631908237747653] [0.36206377714814036, 12.733824851110658] [0.25335919108229193, 6.478525763651015]
# Smiles Weight Mean and Std Dev
# 0.680605428077891 0.031418697569297764
# Smiles Weight CI
# 0.6143141156241338 0.7344383676293375
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84952318 51.8527711 ] [ 1.12370927 19.0795273 ] [0.60756701 0.36795579]
# (Manually) Weighted RMSE Train
# [0.25335919 6.47852576]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7539103232533889] [0.4528152188934584, 16.52167963730114] [0.23637056785350932, 5.671021061315921]
# Smiles Weight Mean and Std Dev
# 0.6722587511050666 0.03879383932016471
# Smiles Weight CI
# 0.5850177219522225 0.7393899812992135
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.858881   51.90521264] [ 1.08409612 18.80184863] [0.58319824 0.36223431]
# (Manually) Weighted RMSE Train
# [0.23637057 5.67102106]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.6068821689259646, 0.7580813347236705] [0.43757671904002077, 15.589535340228613] [0.24784840086186213, 6.217797238343365]
# Smiles Weight Mean and Std Dev
# 0.6783244784394744 0.03890384499422926
# Smiles Weight CI
# 0.5924289454401783 0.7354126904856918
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85343752 51.97257102] [ 1.11133224 18.96328934] [0.59960599 0.3648711 ]
# (Manually) Weighted RMSE Train
# [0.2478484  6.21779724]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.6016684045881127, 0.7434827945776851] [0.43197312346427086, 15.926481275201523] [0.24747822280974394, 6.199523036669928]
# Smiles Weight Mean and Std Dev
# 0.678029259329554 0.03631401070418161
# Smiles Weight CI
# 0.5836751151312246 0.7348982481677359
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85661261 52.0245182 ] [ 1.10805024 18.98170393] [0.59681284 0.36486073]
# (Manually) Weighted RMSE Train
# [0.24747822 6.19952304]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.6100104275286757, 0.7518248175182481] [0.4490303841295036, 16.164514438266256] [0.24530072200854958, 6.120804013515262]
# Smiles Weight Mean and Std Dev
# 0.6772817349768296 0.0388690346245314
# Smiles Weight CI
# 0.5893749774401144 0.7363332543404797
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85855478 52.0695898 ] [ 1.102495   18.94620403] [0.59320017 0.36386313]
# (Manually) Weighted RMSE Train
# [0.24530072 6.12080401]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.5974973931178311, 0.7434827945776851] [0.4376332936868187, 15.907519682182624] [0.23871526691794404, 5.792736102235616]
# Smiles Weight Mean and Std Dev
# 0.6737118818320703 0.03667356622600025
# Smiles Weight CI
# 0.5868267583208442 0.7273973975751817
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.86506031 52.15277029] [ 1.08421803 18.79397586] [0.58133135 0.3603639 ]
# (Manually) Weighted RMSE Train
# [0.23871527 5.7927361 ]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.602711157455683, 0.7549530761209593] [0.42558557306573874, 15.490759939219235] [0.2327561926956447, 5.481567803187079]
# Smiles Weight Mean and Std Dev
# 0.6703426748426173 0.038772107342355595
# Smiles Weight CI
# 0.5860030913853667 0.7247638431740102
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87149329 52.23356058] [ 1.0662934  18.73346583] [0.5697554  0.35864807]
# (Manually) Weighted RMSE Train
# [0.23275619 5.4815678 ]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.6256517205422315, 0.7612095933263816] [0.4606018807714924, 16.5778459894555] [0.23471491711527515, 5.594605433680286]
# Smiles Weight Mean and Std Dev
# 0.6715578640164704 0.0396787606379603
# Smiles Weight CI
# 0.5821557312470822 0.7331414053292377
# ...
# Smiles Weight CI
# 0.5846798422546624 0.7343690216335139
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95149339 53.87985202] [ 1.02623949 18.20341016] [0.52587392 0.3378519 ]
# (Manually) Weighted RMSE Train
# [0.24393137 6.0174509 ]
#
#
# epoch number:  169
# Coverages, CI Widths, RMSEs
# [0.635036496350365, 0.7632950990615224] [0.4762056125684863, 16.732571779706134] [0.23181972467092252, 5.439216424829534]
# Smiles Weight Mean and Std Dev
# 0.6647374824562734 0.0397127509443718
# Smiles Weight CI
# 0.5782264856881195 0.7258556725567606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96018265 53.90527832] [ 0.99679393 18.11922904] [0.50852094 0.33613089]
# (Manually) Weighted RMSE Train
# [0.23181972 5.43921642]
#
#
# epoch number:  170
# Coverages, CI Widths, RMSEs
# [0.6266944734098019, 0.7591240875912408] [0.4628343052948958, 16.452576503160053] [0.2350614970874588, 5.613165887076299]
# Smiles Weight Mean and Std Dev
# 0.6665121491315745 0.03756913711168256
# Smiles Weight CI
# 0.5739505950313537 0.7249584852431914
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95806569 53.9040109 ] [ 1.00508    18.11378843] [0.5133025  0.33603786]
# (Manually) Weighted RMSE Train
# [0.2350615  5.61316589]
#
#
# epoch number:  171
# Coverages, CI Widths, RMSEs
# [0.6329509906152242, 0.7580813347236705] [0.47562113971536096, 16.708767811892063] [0.22514880332213308, 5.142106511994862]
# Smiles Weight Mean and Std Dev
# 0.6612659262163422 0.0394056579998153
# Smiles Weight CI
# 0.5754783361645841 0.7256584386197167
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96460107 53.88679317] [ 0.9796265  18.04669678] [0.49863889 0.33490018]
# (Manually) Weighted RMSE Train
# [0.2251488  5.14210651]
#
#
# epoch number:  172
# Coverages, CI Widths, RMSEs
# [0.6652763295099061, 0.7789363920750783] [0.5539639709256587, 19.196212609531987] [0.22364012566369504, 5.073906927302023]
# Smiles Weight Mean and Std Dev
# 0.6601839291057076 0.041188106954829405
# Smiles Weight CI
# 0.5557626264332176 0.728819392947652
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96629984 53.90635042] [ 0.9748293  18.02461147] [0.49576838 0.33436898]
# (Manually) Weighted RMSE Train
# [0.22364013 5.07390693]
#
#
# epoch number:  173
# Coverages, CI Widths, RMSEs
# [0.6319082377476538, 0.762252346193952] [0.4986407337833042, 17.48496295401387] [0.2384336440036867, 5.7677762539477415]
# Smiles Weight Mean and Std Dev
# 0.6676008353984295 0.036957110980693146
# Smiles Weight CI
# 0.5613650354457429 0.723275115696281
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95799024 53.94217322] [ 1.0115521  18.11275586] [0.51662776 0.33578098]
# (Manually) Weighted RMSE Train
# [0.23843364 5.76777625]
#
#
# epoch number:  174
# Coverages, CI Widths, RMSEs
# [0.6246089676746611, 0.7549530761209593] [0.46699227152757794, 16.191421825453993] [0.23486843540861096, 5.599947707179461]
# Smiles Weight Mean and Std Dev
# 0.6660095970662011 0.03734982015190475
# Smiles Weight CI
# 0.5808425723273719 0.7252098795340512
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96066969 53.96659736] [ 1.00283925 18.10498591] [0.51147792 0.33548504]
# (Manually) Weighted RMSE Train
# [0.23486844 5.59994771]
#
#
# epoch number:  175
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7570385818561001] [0.45943495164361103, 16.47823960830857] [0.23584385786372172, 5.646560580390638]
# Smiles Weight Mean and Std Dev
# 0.6662700780450281 0.03762152408598002
# Smiles Weight CI
# 0.5768018729806484 0.7207391485235163
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95883698 53.99063343] [ 1.00617659 18.09703846] [0.5136602  0.33518848]
# (Manually) Weighted RMSE Train
# [0.23584386 5.64656058]
#
#
# epoch number:  176
# Coverages, CI Widths, RMSEs
# [0.6402502606882169, 0.7685088633993743] [0.5017731053806778, 17.86668642431907] [0.23905652077479472, 5.806584444813115]
# Smiles Weight Mean and Std Dev
# 0.6679470712486739 0.037821816733974827
# Smiles Weight CI
# 0.568742309093262 0.7310716900779372
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95895237 54.00747535] [ 1.01165988 18.13465871] [0.51642904 0.33578053]
# (Manually) Weighted RMSE Train
# [0.23905652 5.80658444]
#
#
# epoch number:  177
# Coverages, CI Widths, RMSEs
# [0.6339937434827946, 0.7601668404588112] [0.49722673140393897, 17.61243261495293] [0.23364882807716322, 5.554939755615696]
# Smiles Weight Mean and Std Dev
# 0.6652934318369854 0.038395631635391135
# Smiles Weight CI
# 0.5722679178114045 0.72545841950549
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.9630714  54.00919289] [ 0.99818699 18.08758366] [0.50848227 0.33489824]
# (Manually) Weighted RMSE Train
# [0.23364883 5.55493976]
#
#
# epoch number:  178
# Coverages, CI Widths, RMSEs
# [0.6673618352450469, 0.7893639207507821] [0.5575583476703245, 19.680701944009353] [0.22873322738125518, 5.296089222596226]
# Smiles Weight Mean and Std Dev
# 0.6626381399175865 0.04319038631891971
# Smiles Weight CI
# 0.558830435239415 0.736120437948799
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96627771 53.99487001] [ 0.98577614 18.04282125] [0.50134126 0.33415806]
# (Manually) Weighted RMSE Train
# [0.22873323 5.29608922]
#
#
# epoch number:  179
# Coverages, CI Widths, RMSEs
# [0.643378519290928, 0.7664233576642335] [0.501144356117207, 17.722260600756847] [0.2483946135054371, 6.222489208505859]
# Smiles Weight Mean and Std Dev
# 0.6717009198361729 0.037398848153185484
# Smiles Weight CI
# 0.5755743908440857 0.7321418922134562
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95672115 54.05564221] [ 1.02949687 18.18553422] [0.52613367 0.3364225 ]
# (Manually) Weighted RMSE Train
# [0.24839461 6.22248921]
#
#
# epoch number:  180
# Coverages, CI Widths, RMSEs
# [0.6152241918665277, 0.7382690302398331] [0.4443446847528137, 15.759180816267639] [0.23307503421566178, 5.49801777048017]
# Smiles Weight Mean and Std Dev
# 0.6647983173744445 0.03737331763688288
# Smiles Weight CI
# 0.5888151888589984 0.7271313519091456
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96580928 54.05817374] [ 0.99467223 18.05868087] [0.50598613 0.33406014]
# (Manually) Weighted RMSE Train
# [0.23307503 5.49801777]
#
#
# epoch number:  181
# Coverages, CI Widths, RMSEs
# [0.5964546402502607, 0.7267987486965589] [0.4292613350847526, 14.809947671811008] [0.2300498393742132, 5.379605830663098]
# Smiles Weight Mean and Std Dev
# 0.6633981602227086 0.03500841496115485
# Smiles Weight CI
# 0.5848045749890284 0.715993350504833
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96717372 54.07390162] [ 0.98770484 18.0222004 ] [0.50209335 0.33328833]
# (Manually) Weighted RMSE Train
# [0.23004984 5.37960583]
#
#
# epoch number:  182
# Coverages, CI Widths, RMSEs
# [0.643378519290928, 0.7580813347236705] [0.4936041688549928, 16.720615038418913] [0.22970896160106413, 5.355010385545975]
# Smiles Weight Mean and Std Dev
# 0.6629808476691248 0.04022519627702243
# Smiles Weight CI
# 0.5761700720740308 0.7252454193195907
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96870389 54.0712075 ] [ 0.98580276 18.0051874 ] [0.50073694 0.3329903 ]
# (Manually) Weighted RMSE Train
# [0.22970896 5.35501039]
#
#
# epoch number:  183
# Coverages, CI Widths, RMSEs
# [0.6308654848800834, 0.7612095933263816] [0.4730337124466243, 16.464552556135214] [0.23365044485413336, 5.546860158809032]
# Smiles Weight Mean and Std Dev
# 0.6649454003537488 0.03935740527644947
# Smiles Weight CI
# 0.5732386874399291 0.7240005347385958
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96736186 54.07735713] [ 0.99469205 18.02031062] [0.5055969  0.33323209]
# (Manually) Weighted RMSE Train
# [0.23365044 5.54686016]
#
#
# epoch number:  184
# Coverages, CI Widths, RMSEs
# [0.64859228362878, 0.7653806047966631] [0.5113760346884527, 17.55735690444542] [0.2345338812995084, 5.603604922703143]
# Smiles Weight Mean and Std Dev
# 0.665543848129167 0.0395290212853942
# Smiles Weight CI
# 0.5716736887161026 0.729390788518713
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96754551 54.08700204] [ 0.99636059 18.0087389 ] [0.50639773 0.33295872]
# (Manually) Weighted RMSE Train
# [0.23453388 5.60360492]
#
#
# epoch number:  185
# Coverages, CI Widths, RMSEs
# [0.6360792492179353, 0.7674661105318039] [0.5014253595207051, 17.62319814680525] [0.22100934009607956, 4.955993517770287]
# Smiles Weight Mean and Std Dev
# 0.6581099219795895 0.04046003173098709
# Smiles Weight CI
# 0.5675323148891588 0.7231725717421786
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97713823 54.07017173] [ 0.95954986 17.94124678] [0.4853226  0.33181413]
# (Manually) Weighted RMSE Train
# [0.22100934 4.95599352]
#
#
# epoch number:  186
# Coverages, CI Widths, RMSEs
# [0.6246089676746611, 0.7403545359749739] [0.46377078838521824, 16.197800914059016] [0.24206220856651542, 5.916783302673167]
# Smiles Weight Mean and Std Dev
# 0.6687266789229526 0.03644728608637923
# Smiles Weight CI
# 0.5848786754743435 0.7287417349584517
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.96699439 54.10109336] [ 1.01014834 18.04555212] [0.51354917 0.33355245]
# (Manually) Weighted RMSE Train
# [0.24206221 5.9167833 ]
#
#
# epoch number:  187
# Coverages, CI Widths, RMSEs
# [0.6402502606882169, 0.7664233576642335] [0.5060304785861585, 17.748481193519442] [0.23138176728145765, 5.447939148566947]
# Smiles Weight Mean and Std Dev
# 0.6639598879784262 0.03991531523278132
# Smiles Weight CI
# 0.5657403514566922 0.7248401951150366
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97356427 54.12553103] [ 0.98486245 17.97889347] [0.4990273  0.33217029]
# (Manually) Weighted RMSE Train
# [0.23138177 5.44793915]
#
#
# epoch number:  188
# Coverages, CI Widths, RMSEs
# [0.6110531803962461, 0.7455683003128258] [0.45010903038907984, 15.745105568420248] [0.23037583035953865, 5.41128319092817]
# Smiles Weight Mean and Std Dev
# 0.6633832665000587 0.03878765134777336
# Smiles Weight CI
# 0.5781858378498042 0.7201172044184944
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97482223 54.13902004] [ 0.98187484 17.97986056] [0.49719657 0.33210539]
# (Manually) Weighted RMSE Train
# [0.23037583 5.41128319]
#
#
# epoch number:  189
# Coverages, CI Widths, RMSEs
# [0.656934306569343, 0.7726798748696558] [0.5185829301078101, 18.1865521573072] [0.2278620273011464, 5.283417757819023]
# Smiles Weight Mean and Std Dev
# 0.6619823531911861 0.041971650343381336
# Smiles Weight CI
# 0.5679114578738349 0.7286260520401411
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.976795   54.14183139] [ 0.97524675 17.97798109] [0.49334744 0.33205343]
# (Manually) Weighted RMSE Train
# [0.22786203 5.28341776]
#
#
# epoch number:  190
# Coverages, CI Widths, RMSEs
# [0.6465067778936392, 0.7653806047966631] [0.5178544632896241, 17.712449431778225] [0.22956932617443393, 5.375526353522699]
# Smiles Weight Mean and Std Dev
# 0.6629232593709312 0.04038611469901884
# Smiles Weight CI
# 0.564705705116227 0.7224912088839683
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97768423 54.13636288] [ 0.978024   17.98317932] [0.49452991 0.332183  ]
# (Manually) Weighted RMSE Train
# [0.22956933 5.37552635]
#
#
# epoch number:  191
# Coverages, CI Widths, RMSEs
# [0.662148070907195, 0.7789363920750783] [0.5386132055528907, 18.485973444712855] [0.22842904941680728, 5.340821879260229]
# Smiles Weight Mean and Std Dev
# 0.6624761605422574 0.041918250003820226
# Smiles Weight CI
# 0.5558998527005676 0.7234145627582875
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97838806 54.1435386 ] [ 0.97527675 17.96564674] [0.49296534 0.33181516]
# (Manually) Weighted RMSE Train
# [0.22842905 5.34082188]
#
#
# epoch number:  192
# Coverages, CI Widths, RMSEs
# [0.6360792492179353, 0.7507820646506778] [0.48176092878552196, 16.936663790917603] [0.23537609254505445, 5.663577870357512]
# Smiles Weight Mean and Std Dev
# 0.6657221410041704 0.03790428964502541
# Smiles Weight CI
# 0.5752454697073803 0.7271278658692767
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97525643 54.17043157] [ 0.99126473 17.99470132] [0.50184104 0.33218678]
# (Manually) Weighted RMSE Train
# [0.23537609 5.66357787]
#
#
# epoch number:  193
# Coverages, CI Widths, RMSEs
# [0.6517205422314911, 0.7789363920750783] [0.5239459804761257, 18.708529851291036] [0.22627510905371007, 5.220504887207482]
# Smiles Weight Mean and Std Dev
# 0.6610259564376754 0.04222239162137965
# Smiles Weight CI
# 0.5544943038265898 0.7222746997172454
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98230397 54.16494059] [ 0.96752068 17.9346507 ] [0.48807887 0.33111179]
# (Manually) Weighted RMSE Train
# [0.22627511 5.22050489]
#
#
# epoch number:  194
# Coverages, CI Widths, RMSEs
# [0.6402502606882169, 0.7549530761209593] [0.4899496368665484, 17.045622613502832] [0.23184288436756317, 5.50485284408977]
# Smiles Weight Mean and Std Dev
# 0.6639402135600798 0.03783320648528206
# Smiles Weight CI
# 0.578044105410085 0.7317988149436445
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97992132 54.1901234 ] [ 0.9811122  17.94982208] [0.4955309  0.33123789]
# (Manually) Weighted RMSE Train
# [0.23184288 5.50485284]
#
#
# epoch number:  195
# Coverages, CI Widths, RMSEs
# [0.6110531803962461, 0.7267987486965589] [0.4475460292965259, 15.193823779425767] [0.23823072548911814, 5.780838200172212]
# Smiles Weight Mean and Std Dev
# 0.6668642244275933 0.03444473242907016
# Smiles Weight CI
# 0.5889398485237629 0.7240853033065078
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97813762 54.17864833] [ 0.99427305 17.95610465] [0.50263088 0.33142401]
# (Manually) Weighted RMSE Train
# [0.23823073 5.7808382 ]
#
#
# epoch number:  196
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7372262773722628] [0.46385747815254086, 15.781381867078242] [0.23516362049652278, 5.660260792985102]
# Smiles Weight Mean and Std Dev
# 0.6656273695167918 0.035442378961742085
# Smiles Weight CI
# 0.5793573072519373 0.7180036135645613
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.980992   54.16520024] [ 0.98633635 17.93361735] [0.49790022 0.33109113]
# (Manually) Weighted RMSE Train
# [0.23516362 5.66026079]
#
#
# epoch number:  197
# Coverages, CI Widths, RMSEs
# [0.6329509906152242, 0.7528675703858185] [0.4804964619833574, 16.69586455568303] [0.2332283305124921, 5.588554689463887]
# Smiles Weight Mean and Std Dev
# 0.664798683404933 0.03667428886244154
# Smiles Weight CI
# 0.5747069689338347 0.7250680837313257
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98235242 54.15930912] [ 0.98178718 17.92505942] [0.49526369 0.33096913]
# (Manually) Weighted RMSE Train
# [0.23322833 5.58855469]
#
#
# epoch number:  198
# Coverages, CI Widths, RMSEs
# [0.62148070907195, 0.7413972888425443] [0.4748328316543534, 16.330803217075456] [0.22973241772998532, 5.421584077624938]
# Smiles Weight Mean and Std Dev
# 0.6629951071754838 0.03525633276364857
# Smiles Weight CI
# 0.5730433093556819 0.7237507724755715
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98483821 54.15413028] [ 0.97303953 17.87875442] [0.4902362  0.33014572]
# (Manually) Weighted RMSE Train
# [0.22973242 5.42158408]
#
#
# epoch number:  199
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7361835245046924] [0.4479850590149863, 15.735312489557337] [0.22752945603964456, 5.304509569014298]
# Smiles Weight Mean and Std Dev
# 0.66155326730918 0.035168925048571525
# Smiles Weight CI
# 0.5740787099537765 0.7113332262398588
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98536793 54.17060593] [ 0.9681795  17.88935158] [0.48765747 0.33024094]
# (Manually) Weighted RMSE Train
# [0.22752946 5.30450957]
#
#
# done for fold1
# train_width[0.36206377714814036, 12.733824851110658]
# smiles_weight0.680605428077891
# rmse_train[0.13424345902971352, 0.15011991074164682]
# smiles_weight_ci[0.6143141156241338, 0.7344383676293375]
# CPU times: user 1h 1min 3s, sys: 37min 15s, total: 1h 38min 19s
# Wall time: 32min 7s

# %%
with open("..//Data/returned_stuff1_config2.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
