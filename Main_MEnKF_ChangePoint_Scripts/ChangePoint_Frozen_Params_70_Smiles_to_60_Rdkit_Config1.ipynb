# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-06-28 01:25:19.962842: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-28 01:25:19.965798: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-28 01:25:20.004439: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-28 01:25:20.005183: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-28 01:25:21.199408: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)
# Out:
# 2023-06-28 01:25:23.221878: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-06-28 01:25:23.221918: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: c3101.swan.hcc.unl.edu
# 2023-06-28 01:25:23.221930: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: c3101.swan.hcc.unl.edu
# 2023-06-28 01:25:23.222062: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 525.116.4
# 2023-06-28 01:25:23.222093: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 525.116.4
# 2023-06-28 01:25:23.222103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 525.116.4

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 7

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 313

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, fudging_var = 1.0):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_70_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_60_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200, fudging_var = 1.0):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
# returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 8.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-2)

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-4)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [59.43951420451741, 1412.892711073225] [3.306093605070608, 48.321358341257316]
# Smiles Weight Mean and Std Dev
# 0.49248636141970137 0.20865143163590638
# Smiles Weight CI
# 0.1084380909784028 0.8877565652375403
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.92511274 46.2559149 ] [ 3.16127588 58.9352532 ] [1.08073642 1.2741128 ]
# (Manually) Weighted RMSE Train
# [ 3.30609361 48.32135834]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [45.96660083498993, 1087.8737315108258] [3.5926016953620827, 30.18012470984373]
# Smiles Weight Mean and Std Dev
# 0.4864315052520401 0.19771562236171877
# Smiles Weight CI
# 0.1122802983919787 0.8452582304844878
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.72200864 41.82639269] [ 3.63706649 45.65654657] [1.33617007 1.09157266]
# (Manually) Weighted RMSE Train
# [ 3.5926017  30.18012471]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [37.26934310192211, 842.5214686505519] [3.458874600509832, 27.861526512190164]
# Smiles Weight Mean and Std Dev
# 0.5110707005714761 0.18699560105579024
# Smiles Weight CI
# 0.15787155033213107 0.8693647445747243
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.65494792 41.058465  ] [ 3.60898283 42.65249051] [1.35934224 1.03882331]
# (Manually) Weighted RMSE Train
# [ 3.4588746  27.86152651]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [31.88950041059916, 678.4809433931202] [3.1907795890072994, 25.6460087453728]
# Smiles Weight Mean and Std Dev
# 0.5241636207404695 0.17072231686753334
# Smiles Weight CI
# 0.20035645148026007 0.840147005296719
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.46489146 33.67802963] [ 3.49814162 43.48363336] [1.41918688 1.29115729]
# (Manually) Weighted RMSE Train
# [ 3.19077959 25.64600875]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [24.552868194566674, 534.1675045470929] [3.026293134774337, 19.378830384165276]
# Smiles Weight Mean and Std Dev
# 0.5668157283132478 0.17100306281914687
# Smiles Weight CI
# 0.23859956189926929 0.885657283206344
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.14141656 24.20250705] [ 3.66060617 39.134546  ] [1.70943209 1.61696249]
# (Manually) Weighted RMSE Train
# [ 3.02629313 19.37883038]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [19.49145111862816, 421.3123493602299] [3.045926070942809, 20.76936351881069]
# Smiles Weight Mean and Std Dev
# 0.5850187066716216 0.15414529599942745
# Smiles Weight CI
# 0.2824889390713988 0.8741663134903421
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08033576 24.12469521] [ 3.81749084 40.45324899] [1.83503592 1.6768398 ]
# (Manually) Weighted RMSE Train
# [ 3.04592607 20.76936352]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [15.280303934956168, 333.83529007546184] [2.521921550089999, 23.023489185355267]
# Smiles Weight Mean and Std Dev
# 0.6166461157071983 0.13651203284570554
# Smiles Weight CI
# 0.3113107179331099 0.8475490682309206
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62324242 24.96885661] [ 3.72417929 39.21508508] [2.29428411 1.57055991]
# (Manually) Weighted RMSE Train
# [ 2.52192155 23.02348919]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [11.90806094350314, 266.8270920751861] [1.8825651367361678, 24.800990280401845]
# Smiles Weight Mean and Std Dev
# 0.6399157540021518 0.12253477838812386
# Smiles Weight CI
# 0.40812233566399975 0.8711060781581131
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40031205 24.26266724] [ 3.31592716 41.28871146] [2.36799159 1.70173836]
# (Manually) Weighted RMSE Train
# [ 1.88256514 24.80099028]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [10.07156023399865, 220.5196950694974] [1.3982665949366857, 20.165882348370456]
# Smiles Weight Mean and Std Dev
# 0.6665220145715174 0.11223701704185031
# Smiles Weight CI
# 0.4613043621965176 0.8731786360355057
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26162998 19.91072584] [ 3.01368844 37.57849326] [2.38872608 1.88734924]
# (Manually) Weighted RMSE Train
# [ 1.39826659 20.16588235]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [7.952448866194205, 179.10842034987513] [1.2597893347335662, 19.486623779139954]
# Smiles Weight Mean and Std Dev
# 0.6910867647025789 0.10840171902772652
# Smiles Weight CI
# 0.4754498835154876 0.8638640071532383
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.02011404 20.49446866] [ 3.04185887 37.52364181] [2.98188119 1.83091557]
# (Manually) Weighted RMSE Train
# [ 1.25978933 19.48662378]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [6.653701830455378, 148.47300726089188] [0.9877691445312411, 15.162617570127157]
# Smiles Weight Mean and Std Dev
# 0.6823483807932882 0.10556491849091054
# Smiles Weight CI
# 0.47150259478735695 0.8585406111338836
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84143701 23.37332215] [ 2.90307386 35.95311534] [3.45013807 1.5382116 ]
# (Manually) Weighted RMSE Train
# [ 0.98776914 15.16261757]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [5.437078461990199, 121.55483109373779] [0.6677078398448026, 9.258842621194027]
# Smiles Weight Mean and Std Dev
# 0.6888671951677245 0.10118204909655512
# Smiles Weight CI
# 0.46624651688896573 0.8552125155696757
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81985233 23.56609901] [ 2.75372497 36.44892129] [3.35880604 1.54666758]
# (Manually) Weighted RMSE Train
# [0.66770784 9.25884262]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.580340233800596, 98.65950635228873] [0.4559213533475024, 8.472022443258846]
# Smiles Weight Mean and Std Dev
# 0.6955874481606105 0.0956865124620986
# Smiles Weight CI
# 0.475783166379191 0.8603947245505723
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.78428973 21.45519921] [ 2.58924092 38.97958701] [3.30138317 1.8167898 ]
# (Manually) Weighted RMSE Train
# [0.45592135 8.47202244]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.7701191576663864, 83.20113827370899] [0.43116050456660265, 6.358170997919021]
# Smiles Weight Mean and Std Dev
# 0.7042781086856641 0.09244571312245299
# Smiles Weight CI
# 0.5012921596238431 0.850758999468056
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.79517406 20.35046112] [ 2.53909013 36.8704531 ] [3.19312494 1.81177482]
# (Manually) Weighted RMSE Train
# [0.4311605 6.358171 ]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.2650289965420893, 69.5667434497063] [0.3808092640683847, 6.048774947102528]
# Smiles Weight Mean and Std Dev
# 0.6971493910941108 0.09652870607417649
# Smiles Weight CI
# 0.4916920049708606 0.8603520323032329
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85969084 21.23665716] [ 2.48808163 36.6454984 ] [2.89415858 1.72557753]
# (Manually) Weighted RMSE Train
# [0.38080926 6.04877495]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.8042781993769155, 59.85793540667842] [0.32615893818693004, 6.2778439851737335]
# Smiles Weight Mean and Std Dev
# 0.6963619520580879 0.09840301877418058
# Smiles Weight CI
# 0.48158732512524166 0.8597662452664664
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84863103 19.46770141] [ 2.47543978 35.80305258] [2.91698003 1.83910015]
# (Manually) Weighted RMSE Train
# [0.32615894 6.27784399]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.5025196612184555, 52.1805830057229] [0.2930578789348937, 5.972131866259686]
# Smiles Weight Mean and Std Dev
# 0.6896908870586149 0.09285939732308046
# Smiles Weight CI
# 0.4720756385058611 0.8402239463642008
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87158299 19.05978256] [ 2.39217157 35.9283391 ] [2.74462857 1.88503405]
# (Manually) Weighted RMSE Train
# [0.29305788 5.97213187]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.2978117665420887, 46.54316834151349] [0.277546701222327, 5.665747595572127]
# Smiles Weight Mean and Std Dev
# 0.6963398968068057 0.0926725047272145
# Smiles Weight CI
# 0.5117031257978528 0.8507741843555598
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85961878 18.95367106] [ 2.3890451  37.26047544] [2.77919138 1.96587117]
# (Manually) Weighted RMSE Train
# [0.2775467 5.6657476]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.1372408914431316, 43.249688170834666] [0.2766242217304164, 5.768893507476382]
# Smiles Weight Mean and Std Dev
# 0.6923109215146821 0.0929813694602854
# Smiles Weight CI
# 0.5199406086032574 0.8472213059716104
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88764626 18.68850893] [ 2.39163328 37.70718938] [2.69435405 2.01766709]
# (Manually) Weighted RMSE Train
# [0.27662422 5.76889351]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.0826321413432853, 38.38963557904476] [0.2696163545574726, 5.657098725127678]
# Smiles Weight Mean and Std Dev
# 0.6960676553264858 0.09462535569556972
# Smiles Weight CI
# 0.48128160230157024 0.8377944034704287
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90027759 18.03097103] [ 2.384699   38.07323212] [2.64884856 2.11154641]
# (Manually) Weighted RMSE Train
# [0.26961635 5.65709873]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 0.9989572471324296] [1.9419837070628279, 35.63936804896684] [0.26266166348967984, 5.64231549251216]
# Smiles Weight Mean and Std Dev
# 0.6954943424333359 0.09061490510752043
# Smiles Weight CI
# 0.506648146578161 0.8472124150316805
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88500271 18.1580728 ] [ 2.39216493 38.19543722] [2.70300292 2.1034962 ]
# (Manually) Weighted RMSE Train
# [0.26266166 5.64231549]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 0.9989572471324296] [1.921965943105114, 34.204007672707206] [0.2735932664276492, 5.609017615500727]
# Smiles Weight Mean and Std Dev
# 0.685396335821227 0.08845739515880108
# Smiles Weight CI
# 0.5025664754750387 0.8392476323740877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90118625 18.5233202 ] [ 2.3849948  37.75570606] [2.64650599 2.03827962]
# (Manually) Weighted RMSE Train
# [0.27359327 5.60901762]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9947862356621481] [1.7893894398581116, 31.173586123284394] [0.26263274559181093, 5.619469512590406]
# Smiles Weight Mean and Std Dev
# 0.6926477641873531 0.09292478648342359
# Smiles Weight CI
# 0.49524867311224613 0.849218223969095
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8857165 17.9980346] [ 2.36887926 38.15291926] [2.67453442 2.11983809]
# (Manually) Weighted RMSE Train
# [0.26263275 5.61946951]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9968717413972888] [1.6863304577884843, 30.539975654268627] [0.26269717220917854, 5.617975974037203]
# Smiles Weight Mean and Std Dev
# 0.6936720834659448 0.09271187934559288
# Smiles Weight CI
# 0.4933483580862041 0.8429686641380608
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88365438 18.29830805] [ 2.37036445 38.53004508] [2.68245652 2.10566163]
# (Manually) Weighted RMSE Train
# [0.26269717 5.61797597]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9927007299270073] [1.5637518685054468, 28.034762385513073] [0.2624662495443575, 5.59589802706464]
# Smiles Weight Mean and Std Dev
# 0.692830559428546 0.07909897004814402
# Smiles Weight CI
# 0.5279798295863595 0.8305037190742885
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88889013 18.07357099] [ 2.3664951  38.86300012] [2.66230326 2.15026682]
# (Manually) Weighted RMSE Train
# [0.26246625 5.59589803]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9927007299270073] [1.6593477469307412, 28.69593781954841] [0.2654613008981378, 5.565000033925645]
# Smiles Weight Mean and Std Dev
# 0.6918072432222383 0.092411939141288
# Smiles Weight CI
# 0.48464644175830696 0.8359390215880894
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87980103 17.94698262] [ 2.3663141  39.00081278] [2.68960143 2.17311253]
# (Manually) Weighted RMSE Train
# [0.2654613  5.56500003]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9885297184567258] [1.5180306850148613, 26.699024545621903] [0.26658560659428715, 5.554394977138914]
# Smiles Weight Mean and Std Dev
# 0.6927394962994419 0.09049691195491442
# Smiles Weight CI
# 0.5085534813557598 0.8493735961031915
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87848919 17.65005054] [ 2.3672063  38.79898921] [2.69463337 2.19823672]
# (Manually) Weighted RMSE Train
# [0.26658561 5.55439498]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.9843587069864442] [1.5779176128866141, 26.02420972869959] [0.26856997693769774, 5.6167433055750084]
# Smiles Weight Mean and Std Dev
# 0.6889301735702186 0.0841709426802963
# Smiles Weight CI
# 0.5297655400922487 0.8315286397571011
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89745855 17.99352541] [ 2.3555293 38.8876002] [2.62466639 2.16119961]
# (Manually) Weighted RMSE Train
# [0.26856998 5.61674331]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.9801876955161627] [1.5360835649456708, 25.099764893320245] [0.2667110743740633, 5.4712340852698755]
# Smiles Weight Mean and Std Dev
# 0.691258466556923 0.08784803879016041
# Smiles Weight CI
# 0.5166740408698379 0.8261531656865465
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88747274 18.08616062] [ 2.35399039 38.89936537] [2.65246501 2.15078071]
# (Manually) Weighted RMSE Train
# [0.26671107 5.47123409]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9822732012513035] [1.5461751151831726, 24.823410189238903] [0.2646874899583036, 5.465559161626146]
# Smiles Weight Mean and Std Dev
# 0.6935229270372019 0.08359291465433263
# Smiles Weight CI
# 0.5101433220322437 0.8380851622378707
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88759874 17.97767222] [ 2.35634042 38.97013677] [2.6547361  2.16769648]
# (Manually) Weighted RMSE Train
# [0.26468749 5.46555916]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9854014598540146, 0.9791449426485923] [1.526643411921263, 25.49752623206118] [0.26952894770699315, 5.432481949057974]
# Smiles Weight Mean and Std Dev
# 0.6938844391264055 0.08955067655339725
# Smiles Weight CI
# 0.5130522530125626 0.8322407338734228
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87853253 18.25481157] [ 2.38437082 38.84839489] [2.71403818 2.1281181 ]
# (Manually) Weighted RMSE Train
# [0.26952895 5.43248195]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9874869655891554, 0.9801876955161627] [1.500795846405867, 23.92703873959521] [0.25809658482679637, 5.45759145948126]
# Smiles Weight Mean and Std Dev
# 0.7043179399130309 0.09138417622517234
# Smiles Weight CI
# 0.5023369307968838 0.8509007802717371
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86283758 17.71682189] [ 2.39353546 39.27801832] [2.77402784 2.21699008]
# (Manually) Weighted RMSE Train
# [0.25809658 5.45759146]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9843587069864442, 0.9739311783107404] [1.4627605281410683, 24.429664512072495] [0.26356825480871127, 5.56564307672372]
# Smiles Weight Mean and Std Dev
# 0.6967244413965767 0.0895245466253852
# Smiles Weight CI
# 0.5147368103432624 0.8558501541818431
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87653125 18.32987526] [ 2.38479909 38.78220989] [2.72072343 2.11579235]
# (Manually) Weighted RMSE Train
# [0.26356825 5.56564308]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9801876955161627, 0.9718456725755996] [1.4881377455019689, 23.625149149549248] [0.26886509147985793, 5.631172054376945]
# Smiles Weight Mean and Std Dev
# 0.6940632659720027 0.08695651128261978
# Smiles Weight CI
# 0.5111939624203098 0.8356189551875688
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88079478 18.40539917] [ 2.38806412 38.47582586] [2.71126052 2.09046408]
# (Manually) Weighted RMSE Train
# [0.26886509 5.63117205]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9854014598540146, 0.9739311783107404] [1.39844957925784, 23.21565934520918] [0.26499516776637994, 5.521373288851224]
# Smiles Weight Mean and Std Dev
# 0.6972189718533464 0.08537453625645555
# Smiles Weight CI
# 0.515680823941463 0.8353875180584847
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88745911 18.4504564 ] [ 2.39120201 38.75473851] [2.69443628 2.10047587]
# (Manually) Weighted RMSE Train
# [0.26499517 5.52137329]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9791449426485923, 0.9697601668404588] [1.4287782421880055, 23.9113082364493] [0.2702382576650964, 5.530029564351458]
# Smiles Weight Mean and Std Dev
# 0.6942956664385022 0.08892114817186794
# Smiles Weight CI
# 0.5138300301681245 0.8353431027047676
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8881475  18.47554407] [ 2.38885121 38.60714909] [2.68970098 2.0896353 ]
# (Manually) Weighted RMSE Train
# [0.27023826 5.53002956]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.9822732012513035, 0.9708029197080292] [1.5087172185962012, 23.96218374370141] [0.2715588563401133, 5.608387264856348]
# Smiles Weight Mean and Std Dev
# 0.6916325802376707 0.09220007445670032
# Smiles Weight CI
# 0.49753738986803026 0.8454968586722674
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89250501 18.64331208] [ 2.3986368  38.38974638] [2.68753315 2.05916986]
# (Manually) Weighted RMSE Train
# [0.27155886 5.60838726]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.9801876955161627, 0.9624608967674662] [1.4166547776928236, 22.882925612690027] [0.2671336932537315, 5.595920850766135]
# Smiles Weight Mean and Std Dev
# 0.6984169672719666 0.0804774181617201
# Smiles Weight CI
# 0.5255584313806739 0.8335429251909514
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88422086 18.31917669] [ 2.40482158 38.78960769] [2.71970691 2.11743182]
# (Manually) Weighted RMSE Train
# [0.26713369 5.59592085]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9822732012513035, 0.9687174139728885] [1.4461703523325664, 23.26821451240645] [0.2686668006747272, 5.592230820792696]
# Smiles Weight Mean and Std Dev
# 0.6962993886821262 0.0895416769253087
# Smiles Weight CI
# 0.5107005869681295 0.847815869521691
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89062776 18.45536511] [ 2.40848643 38.71261759] [2.70425707 2.09763488]
# (Manually) Weighted RMSE Train
# [0.2686668  5.59223082]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.9781021897810219, 0.9624608967674662] [1.4193688350406404, 22.83016968448193] [0.26630536661020127, 5.613619953191455]
# Smiles Weight Mean and Std Dev
# 0.6992735830496442 0.08185699260636227
# Smiles Weight CI
# 0.5174071596380856 0.835033960316069
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88259083 18.4563432 ] [ 2.40587525 38.62843942] [2.72592368 2.09296278]
# (Manually) Weighted RMSE Train
# [0.26630537 5.61361995]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9801876955161627, 0.9614181438998958] [1.4106898553084715, 22.205027720492783] [0.2663001081873622, 5.595231399776813]
# Smiles Weight Mean and Std Dev
# 0.7015811704938109 0.08187038220048724
# Smiles Weight CI
# 0.5395421600749295 0.8348036563274264
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88025781 18.52553686] [ 2.4060507  38.70492902] [2.73334775 2.08927435]
# (Manually) Weighted RMSE Train
# [0.26630011 5.5952314 ]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.9801876955161627, 0.9687174139728885] [1.453731855809893, 23.221140339155202] [0.270605581397425, 5.604761754364591]
# Smiles Weight Mean and Std Dev
# 0.6919131648439558 0.09003377658819545
# Smiles Weight CI
# 0.5161499620281672 0.8388567144215365
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8897993  19.00978362] [ 2.40731558 38.34931636] [2.70545908 2.01734628]
# (Manually) Weighted RMSE Train
# [0.27060558 5.60476175]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.9791449426485923, 0.9655891553701773] [1.442428249514308, 22.464167850567975] [0.2702294283080306, 5.6106640666826335]
# Smiles Weight Mean and Std Dev
# 0.6955689936837411 0.08349218979207565
# Smiles Weight CI
# 0.516022049394056 0.8266280094217807
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88102717 18.83185316] [ 2.40210718 38.53551058] [2.72648479 2.04629413]
# (Manually) Weighted RMSE Train
# [0.27022943 5.61066407]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9509906152241918] [1.3268372772407113, 20.630073698838014] [0.2679592400185516, 5.618225855766108]
# Smiles Weight Mean and Std Dev
# 0.7015032438859896 0.07972042919684186
# Smiles Weight CI
# 0.5235819327949631 0.8260721132587423
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87856442 18.58265928] [ 2.40588796 38.84567993] [2.73843091 2.09042631]
# (Manually) Weighted RMSE Train
# [0.26795924 5.61822586]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.9791449426485923, 0.9447340980187695] [1.383057165686731, 20.98621963719558] [0.26730997637160997, 5.657560458251476]
# Smiles Weight Mean and Std Dev
# 0.6969217271885678 0.08212792415433798
# Smiles Weight CI
# 0.5262322872985525 0.8269622566586393
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88441643 18.83073918] [ 2.40122833 38.66625455] [2.71504266 2.0533583 ]
# (Manually) Weighted RMSE Train
# [0.26730998 5.65756046]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9478623566214807] [1.3795825702816478, 20.71290103406803] [0.26759001841337604, 5.7056570636346216]
# Smiles Weight Mean and Std Dev
# 0.700132969234275 0.08328696048775688
# Smiles Weight CI
# 0.5188034049629437 0.8336618464713594
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8816957  18.72285511] [ 2.40991413 38.66725067] [2.73327194 2.06524328]
# (Manually) Weighted RMSE Train
# [0.26759002 5.70565706]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9572471324296142] [1.4585753945976438, 21.96467014648696] [0.2681408507549879, 5.641289144424533]
# Smiles Weight Mean and Std Dev
# 0.7003079707309094 0.08748433331517437
# Smiles Weight CI
# 0.5189684827966268 0.8450806803945817
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88288205 18.80117783] [ 2.411003 38.740349] [2.7308325  2.06052777]
# (Manually) Weighted RMSE Train
# [0.26814085 5.64128914]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9395203336809176] [1.3400919113918497, 21.026128312322008] [0.2707773960719598, 5.667067813151741]
# Smiles Weight Mean and Std Dev
# 0.6956332749403478 0.08175366837496109
# Smiles Weight CI
# 0.5334504541046895 0.8194602912355815
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88820555 19.16343779] [ 2.40815672 38.38953124] [2.71126059 2.00326954]
# (Manually) Weighted RMSE Train
# [0.2707774  5.66706781]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9457768508863399] [1.284640031425347, 20.628781409205455] [0.26576202461822707, 5.64252597871424]
# Smiles Weight Mean and Std Dev
# 0.7051524180332575 0.08022578278446844
# Smiles Weight CI
# 0.5420264134164661 0.8374764936769256
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88152278 18.88820488] [ 2.41600928 38.79326828] [2.74072244 2.05383564]
# (Manually) Weighted RMSE Train
# [0.26576202 5.64252598]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9572471324296142] [1.338512728301758, 20.948752554015247] [0.2662809877184271, 5.645116868603889]
# Smiles Weight Mean and Std Dev
# 0.7076875354575156 0.07983212256190725
# Smiles Weight CI
# 0.5408802263726827 0.8276814606139314
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88068308 18.79095877] [ 2.42567861 38.89723973] [2.754315   2.06999761]
# (Manually) Weighted RMSE Train
# [0.26628099 5.64511687]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.954118873826903] [1.4106388679045658, 21.37328698540285] [0.2716341203059442, 5.668700415847015]
# Smiles Weight Mean and Std Dev
# 0.6961767055529555 0.08555750144160788
# Smiles Weight CI
# 0.532902317761402 0.8289748109643845
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88942537 19.34066374] [ 2.41453382 38.23514007] [2.71471211 1.97693009]
# (Manually) Weighted RMSE Train
# [0.27163412 5.66870042]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9770594369134515, 0.954118873826903] [1.424419297633287, 21.412663113870565] [0.2734348977507846, 5.6780430306755605]
# Smiles Weight Mean and Std Dev
# 0.6934012332714411 0.08087148147396865
# Smiles Weight CI
# 0.5190522329163522 0.8167661148243722
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89194151 19.45997323] [ 2.40764911 38.18888539] [2.69933521 1.96243258]
# (Manually) Weighted RMSE Train
# [0.2734349  5.67804303]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9520333680917622] [1.40619438785569, 21.41873769436147] [0.268114540574731, 5.605734909107123]
# Smiles Weight Mean and Std Dev
# 0.702282566938375 0.08560248708303246
# Smiles Weight CI
# 0.5198439855565335 0.8259946690032589
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88221697 19.17842777] [ 2.42298832 38.63252325] [2.74647667 2.01437384]
# (Manually) Weighted RMSE Train
# [0.26811454 5.60573491]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9551616266944735] [1.3811762877310894, 21.78200040580824] [0.2691414788450806, 5.619824282554024]
# Smiles Weight Mean and Std Dev
# 0.6990131253249134 0.08303936132515273
# Smiles Weight CI
# 0.517195791554214 0.8364497046935581
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88908559 19.22462791] [ 2.4240712  38.44377415] [2.72647676 1.99971486]
# (Manually) Weighted RMSE Train
# [0.26914148 5.61982428]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.9791449426485923, 0.9624608967674662] [1.4923911833044845, 21.939007073954926] [0.2761937682283034, 5.64552820466739]
# Smiles Weight Mean and Std Dev
# 0.6920033761646277 0.08771504178019265
# Smiles Weight CI
# 0.5073705094832384 0.8308226265711236
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89510647 19.69945779] [ 2.42135855 38.13579967] [2.70510674 1.93588068]
# (Manually) Weighted RMSE Train
# [0.27619377 5.6455282 ]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9426485922836287] [1.4105165551995464, 20.84616814646357] [0.2686945837979776, 5.665075106050522]
# Smiles Weight Mean and Std Dev
# 0.7011645419977656 0.08175453507056225
# Smiles Weight CI
# 0.5161618789471827 0.826712121504833
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88516755 19.33928821] [ 2.43355454 38.43176228] [2.74925865 1.98723768]
# (Manually) Weighted RMSE Train
# [0.26869458 5.66507511]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.954118873826903] [1.499047193459346, 21.910683789729575] [0.26859490782912837, 5.637067813011751]
# Smiles Weight Mean and Std Dev
# 0.7002173586408013 0.08666595209697658
# Smiles Weight CI
# 0.5184967992186605 0.8318842286379184
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88433512 19.4634163 ] [ 2.4311423  38.41078489] [2.74911878 1.97348627]
# (Manually) Weighted RMSE Train
# [0.26859491 5.63706781]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.948905109489051] [1.3857868203480128, 20.93649632663801] [0.2658323331371456, 5.623981014032844]
# Smiles Weight Mean and Std Dev
# 0.7072939060860568 0.07975488605402434
# Smiles Weight CI
# 0.5167891190778557 0.834524962807544
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87476462 19.18089036] [ 2.42960537 38.81841989] [2.777439   2.02380699]
# (Manually) Weighted RMSE Train
# [0.26583233 5.62398101]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9384775808133472] [1.36669441390012, 20.742313434886793] [0.26839148387206635, 5.641515890224043]
# Smiles Weight Mean and Std Dev
# 0.6997658535678613 0.08231820399498362
# Smiles Weight CI
# 0.5210171988482072 0.8365623617901395
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88487404 19.43626682] [ 2.42121073 38.4950713 ] [2.73622078 1.98057948]
# (Manually) Weighted RMSE Train
# [0.26839148 5.64151589]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9436913451511991] [1.3836851148804483, 20.686692665012036] [0.27015442823159014, 5.6468604556868005]
# Smiles Weight Mean and Std Dev
# 0.6996576852687568 0.08009502333405585
# Smiles Weight CI
# 0.528714229507217 0.8333383039518399
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88292222 19.4328492 ] [ 2.42361909 38.48776292] [2.74499729 1.98055172]
# (Manually) Weighted RMSE Train
# [0.27015443 5.64686046]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.948905109489051] [1.3871349120770924, 21.379065906948004] [0.2793733276404262, 5.657360801499991]
# Smiles Weight Mean and Std Dev
# 0.6912368823567197 0.08782171895493814
# Smiles Weight CI
# 0.5155332904998197 0.8249032066492933
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88543169 19.9178861 ] [ 2.42117812 37.94930146] [2.73446066 1.9052876 ]
# (Manually) Weighted RMSE Train
# [0.27937333 5.6573608 ]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9520333680917622] [1.4535783174433596, 21.68608966382713] [0.27592574006659215, 5.646636182351637]
# Smiles Weight Mean and Std Dev
# 0.6925389092665947 0.08936664937547538
# Smiles Weight CI
# 0.489362623205951 0.823145498484271
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88510365 19.90440638] [ 2.42442655 37.98946718] [2.73914421 1.90859584]
# (Manually) Weighted RMSE Train
# [0.27592574 5.64663618]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.940563086548488] [1.468735119703306, 21.77592619066153] [0.273866021208651, 5.643179530801071]
# Smiles Weight Mean and Std Dev
# 0.6994368246706756 0.08681777768701489
# Smiles Weight CI
# 0.502567735807394 0.8343709746007231
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87585215 19.73632502] [ 2.42212907 38.38227722] [2.76545426 1.944753  ]
# (Manually) Weighted RMSE Train
# [0.27386602 5.64317953]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9457768508863399] [1.4322440487770747, 21.60148847926277] [0.27336450132541074, 5.715107022002333]
# Smiles Weight Mean and Std Dev
# 0.6981671949738358 0.08248242633890523
# Smiles Weight CI
# 0.5266344716937037 0.8358413803499466
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89144916 19.77446255] [ 2.42719961 38.20317883] [2.72275717 1.93194524]
# (Manually) Weighted RMSE Train
# [0.2733645  5.71510702]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.9770594369134515, 0.9457768508863399] [1.410107441536153, 21.38652673720559] [0.26749071025150456, 5.652604237193505]
# Smiles Weight Mean and Std Dev
# 0.7077161954574125 0.08048250059284043
# Smiles Weight CI
# 0.5149815826590781 0.8341967526766411
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88801801 19.55481184] [ 2.43744628 38.64018898] [2.74481626 1.9759939 ]
# (Manually) Weighted RMSE Train
# [0.26749071 5.65260424]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9468196037539103] [1.3542277219510197, 21.12074294514775] [0.27086856943299054, 5.662543259458367]
# Smiles Weight Mean and Std Dev
# 0.6985086814442296 0.07978551967099004
# Smiles Weight CI
# 0.5316853259554952 0.8310165012854853
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89747721 19.9018259 ] [ 2.44187346 38.34333377] [2.72081945 1.92662392]
# (Manually) Weighted RMSE Train
# [0.27086857 5.66254326]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9520333680917622] [1.3368631351023628, 21.70662606920798] [0.2708202356992855, 5.641997873775146]
# Smiles Weight Mean and Std Dev
# 0.7008816558226689 0.08288003079322778
# Smiles Weight CI
# 0.5417790120698668 0.834344534891027
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89377444 20.00292257] [ 2.44256643 38.42895667] [2.73286674 1.9211671 ]
# (Manually) Weighted RMSE Train
# [0.27082024 5.64199787]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9509906152241918] [1.3780942415293753, 21.53447304408157] [0.27175111967600973, 5.6742871696011115]
# Smiles Weight Mean and Std Dev
# 0.6995951775092125 0.08342821245104946
# Smiles Weight CI
# 0.5238862241083397 0.8325131208237484
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88502958 19.99161382] [ 2.43226225 38.3365485 ] [2.74822707 1.91763151]
# (Manually) Weighted RMSE Train
# [0.27175112 5.67428717]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9509906152241918] [1.3991681078748732, 21.731901476242502] [0.2707863760738754, 5.695312217977546]
# Smiles Weight Mean and Std Dev
# 0.7045046605478018 0.08237825094122864
# Smiles Weight CI
# 0.5192276694185455 0.823942807873742
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88807892 19.86199726] [ 2.4371959  38.57036834] [2.74434609 1.94191792]
# (Manually) Weighted RMSE Train
# [0.27078638 5.69531222]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9530761209593326] [1.4205012172514424, 22.862173578089415] [0.2709534650922196, 5.710835992786217]
# Smiles Weight Mean and Std Dev
# 0.7008657802243503 0.08230377223322181
# Smiles Weight CI
# 0.5130641018855968 0.8277370716354642
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88982641 20.07074345] [ 2.43054816 38.46533605] [2.73148576 1.91648785]
# (Manually) Weighted RMSE Train
# [0.27095347 5.71083599]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9520333680917622] [1.3276224552597382, 21.832383721297973] [0.27332484022092324, 5.677185693203352]
# Smiles Weight Mean and Std Dev
# 0.698332066730452 0.08042594929760777
# Smiles Weight CI
# 0.5249434335077159 0.8189292002098193
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88950433 20.22921475] [ 2.4283506  38.31993333] [2.73000425 1.89428674]
# (Manually) Weighted RMSE Train
# [0.27332484 5.67718569]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9520333680917622] [1.3941271502802295, 22.312924905682927] [0.27134945218553086, 5.71470645552802]
# Smiles Weight Mean and Std Dev
# 0.702443618541834 0.08462888004618277
# Smiles Weight CI
# 0.5113652753181303 0.8281728102418179
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88275222 20.16560291] [ 2.43644164 38.30120609] [2.76005157 1.89933355]
# (Manually) Weighted RMSE Train
# [0.27134945 5.71470646]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9603753910323254] [1.3934355527290434, 22.693970331904076] [0.2688621412825606, 5.677425544594731]
# Smiles Weight Mean and Std Dev
# 0.7057539542013177 0.08712102655261389
# Smiles Weight CI
# 0.5145658132068635 0.8319383524312527
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87396338 20.13894305] [ 2.43657464 38.49426965] [2.78795964 1.91143446]
# (Manually) Weighted RMSE Train
# [0.26886214 5.67742554]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9478623566214807] [1.3389211593958747, 20.994554436560882] [0.2690051240689086, 5.662904888266914]
# Smiles Weight Mean and Std Dev
# 0.7102491634665837 0.0788896725231426
# Smiles Weight CI
# 0.5432921377002127 0.8365642121630074
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87968476 20.08229834] [ 2.43353101 38.67751857] [2.76636714 1.9259508 ]
# (Manually) Weighted RMSE Train
# [0.26900512 5.66290489]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.9478623566214807] [1.4448128338289044, 21.44221724469597] [0.2702825681305042, 5.70300263994395]
# Smiles Weight Mean and Std Dev
# 0.7087869221161055 0.08512753073016549
# Smiles Weight CI
# 0.5337783199087812 0.8308190260698561
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87746775 20.04271062] [ 2.44531502 38.64209495] [2.78678619 1.92798747]
# (Manually) Weighted RMSE Train
# [0.27028257 5.70300264]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.9676746611053181, 0.948905109489051] [1.3396256822931103, 21.050254021963898] [0.271113622514495, 5.65489098871901]
# Smiles Weight Mean and Std Dev
# 0.7049007791315713 0.07936702086106298
# Smiles Weight CI
# 0.535563130070376 0.8263462873799203
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87537415 20.12783361] [ 2.43976534 38.37943927] [2.78711148 1.90678441]
# (Manually) Weighted RMSE Train
# [0.27111362 5.65489099]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.9697601668404588, 0.9499478623566214] [1.3680014607896065, 22.42853244317663] [0.2710594120273822, 5.636028431066718]
# Smiles Weight Mean and Std Dev
# 0.7080949463604945 0.0816571376019107
# Smiles Weight CI
# 0.5291875962434924 0.8358081874206167
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87312334 20.01891698] [ 2.44158697 38.68219682] [2.79638267 1.93228219]
# (Manually) Weighted RMSE Train
# [0.27105941 5.63602843]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.9582898852971846] [1.366026894319115, 22.488819919014023] [0.2786924656310217, 5.682706770386531]
# Smiles Weight Mean and Std Dev
# 0.6974673176869205 0.08580681689096689
# Smiles Weight CI
# 0.5179304516951124 0.8356596937211364
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87576949 20.49620224] [ 2.43323514 38.0276941 ] [2.7783968  1.85535318]
# (Manually) Weighted RMSE Train
# [0.27869247 5.68270677]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.9697601668404588, 0.9530761209593326] [1.3546897838983258, 21.572746652233945] [0.2737616833594367, 5.613615537331126]
# Smiles Weight Mean and Std Dev
# 0.7056457390607488 0.08027721187217936
# Smiles Weight CI
# 0.5388404834543198 0.8285956065629964
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87039889 20.12067685] [ 2.44550709 38.47846914] [2.80963947 1.91238443]
# (Manually) Weighted RMSE Train
# [0.27376168 5.61361554]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.9687174139728885, 0.9457768508863399] [1.366882183029071, 21.499756635285816] [0.27478095652807705, 5.637224792518485]
# Smiles Weight Mean and Std Dev
# 0.7009107639049734 0.08017246223691041
# Smiles Weight CI
# 0.5380559308451073 0.8255257862168346
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87867305 20.33311678] [ 2.43001629 38.25449599] [2.76555233 1.88138869]
# (Manually) Weighted RMSE Train
# [0.27478096 5.63722479]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.948905109489051] [1.3155557084875662, 21.58764608305729] [0.27491553580526723, 5.668138997725873]
# Smiles Weight Mean and Std Dev
# 0.7002995195917255 0.08324875766723197
# Smiles Weight CI
# 0.5232141855383342 0.8289232943070132
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87431404 20.50455969] [ 2.42876873 38.15895291] [2.77791344 1.86099841]
# (Manually) Weighted RMSE Train
# [0.27491554 5.668139  ]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.9697601668404588, 0.9468196037539103] [1.3184293846855974, 21.39519009600486] [0.2691329403782939, 5.658250401045137]
# Smiles Weight Mean and Std Dev
# 0.7095492590649609 0.08261979263170822
# Smiles Weight CI
# 0.5460323938309165 0.8437077153457095
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87351087 19.98990586] [ 2.43628169 38.67572762] [2.78906856 1.93476287]
# (Manually) Weighted RMSE Train
# [0.26913294 5.6582504 ]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.9457768508863399] [1.3958677230899685, 21.235471477399624] [0.2718531942653411, 5.705461458668046]
# Smiles Weight Mean and Std Dev
# 0.7070016913217843 0.07739885734075123
# Smiles Weight CI
# 0.5395973442095172 0.8374642689993298
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87757284 19.97164531] [ 2.42859762 38.49676841] [2.76740289 1.9275712 ]
# (Manually) Weighted RMSE Train
# [0.27185319 5.70546146]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9520333680917622] [1.3486092823817113, 22.302488498422367] [0.2687578735367547, 5.742481753488467]
# Smiles Weight Mean and Std Dev
# 0.7106114997243744 0.08271610578003033
# Smiles Weight CI
# 0.5343488505439458 0.838415222908957
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87682602 19.92734601] [ 2.43122088 38.70946833] [2.77275175 1.94253004]
# (Manually) Weighted RMSE Train
# [0.26875787 5.74248175]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9562043795620438] [1.416611722166736, 23.001447042581777] [0.2762076834409357, 5.68364020654068]
# Smiles Weight Mean and Std Dev
# 0.6986134746839365 0.08724181504457759
# Smiles Weight CI
# 0.5159737903702184 0.8438429550653785
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88579368 20.42776565] [ 2.4213962  38.18483492] [2.73358939 1.86926145]
# (Manually) Weighted RMSE Train
# [0.27620768 5.68364021]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9530761209593326] [1.4226297841124425, 22.40376767556999] [0.2750159912726084, 5.652438300942642]
# Smiles Weight Mean and Std Dev
# 0.6988194731580396 0.08608255877764526
# Smiles Weight CI
# 0.512756740176587 0.8279085300714027
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88809237 20.56554653] [ 2.42534007 38.17046178] [2.73095473 1.85603926]
# (Manually) Weighted RMSE Train
# [0.27501599 5.6524383 ]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.954118873826903] [1.2892699119180988, 21.96965006568408] [0.274326321929575, 5.665064607436949]
# Smiles Weight Mean and Std Dev
# 0.703430845991689 0.07842731833911526
# Smiles Weight CI
# 0.5409044889700636 0.8407036406833941
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87654774 20.35114789] [ 2.42344621 38.34774539] [2.76476239 1.8843038 ]
# (Manually) Weighted RMSE Train
# [0.27432632 5.66506461]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9509906152241918] [1.3851776233431576, 22.76130365098904] [0.2719208288809756, 5.628262968108565]
# Smiles Weight Mean and Std Dev
# 0.7045673124527031 0.0804418362100438
# Smiles Weight CI
# 0.5336298011160288 0.8323441280972617
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.885726   20.49153889] [ 2.42075039 38.35865283] [2.73306914 1.87192641]
# (Manually) Weighted RMSE Train
# [0.27192083 5.62826297]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.9687174139728885, 0.9551616266944735] [1.3451214361510035, 22.437173580939042] [0.27348244352539014, 5.658708304851196]
# Smiles Weight Mean and Std Dev
# 0.7003403316282727 0.0818881312497982
# Smiles Weight CI
# 0.5309168927140964 0.8315842626459244
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88942059 20.78386986] [ 2.42333434 38.15453597] [2.72462136 1.83577631]
# (Manually) Weighted RMSE Train
# [0.27348244 5.6587083 ]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9478623566214807] [1.3370435532464022, 21.58352433105729] [0.27054957713741873, 5.712829383141172]
# Smiles Weight Mean and Std Dev
# 0.7093302364563487 0.08198230571515837
# Smiles Weight CI
# 0.5446551962125245 0.83334308276275
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87818018 20.35046039] [ 2.42442413 38.42628054] [2.76073656 1.8882266 ]
# (Manually) Weighted RMSE Train
# [0.27054958 5.71282938]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.9697601668404588, 0.954118873826903] [1.4472826642208556, 23.317595584903472] [0.2773863237828961, 5.705583052688003]
# Smiles Weight Mean and Std Dev
# 0.6977578391485283 0.08671015847754306
# Smiles Weight CI
# 0.5049905162203204 0.8329117317706407
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89232971 20.95696442] [ 2.42788797 37.93029402] [2.72084181 1.80991356]
# (Manually) Weighted RMSE Train
# [0.27738632 5.70558305]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9509906152241918] [1.3776062521848031, 22.072374138660603] [0.27289031201075736, 5.7042509642131005]
# Smiles Weight Mean and Std Dev
# 0.7079776999709851 0.07803064923133791
# Smiles Weight CI
# 0.5314937379758419 0.8328834564353118
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88602529 20.68668216] [ 2.44341929 38.38991559] [2.75773087 1.85577925]
# (Manually) Weighted RMSE Train
# [0.27289031 5.70425096]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9562043795620438] [1.3689763250603846, 21.81927904006396] [0.27523617356771185, 5.6661260322633185]
# Smiles Weight Mean and Std Dev
# 0.7016287639274054 0.08255057130132074
# Smiles Weight CI
# 0.5295689894038428 0.8329067998436621
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88512393 20.93879185] [ 2.43676289 38.13710807] [2.75301889 1.82136144]
# (Manually) Weighted RMSE Train
# [0.27523617 5.66612603]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.97288842544317, 0.9582898852971846] [1.3848263206535882, 23.31315284288426] [0.2716603904879184, 5.7005662111026005]
# Smiles Weight Mean and Std Dev
# 0.7085688775938315 0.08443894762720765
# Smiles Weight CI
# 0.5350401246779779 0.8285543094544344
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87207444 20.50023081] [ 2.45227967 38.37141023] [2.81200726 1.87175503]
# (Manually) Weighted RMSE Train
# [0.27166039 5.70056621]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.948905109489051] [1.4139886079199255, 22.053817959420027] [0.27513745148866947, 5.725981852391205]
# Smiles Weight Mean and Std Dev
# 0.7017939662580773 0.0818785053015263
# Smiles Weight CI
# 0.5218666909900763 0.8263442604341208
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88676923 20.72362019] [ 2.44164799 38.05717667] [2.75341983 1.83641547]
# (Manually) Weighted RMSE Train
# [0.27513745 5.72598185]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9572471324296142] [1.354040727596248, 22.900242379472846] [0.2724096822849814, 5.704073807801126]
# Smiles Weight Mean and Std Dev
# 0.7054061066332946 0.08155474839145152
# Smiles Weight CI
# 0.5311053474558542 0.8304385649330717
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88311305 20.66595071] [ 2.43976566 38.21887357] [2.76268781 1.8493644 ]
# (Manually) Weighted RMSE Train
# [0.27240968 5.70407381]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.9676746611053181, 0.9582898852971846] [1.3779235486500567, 23.62689272386868] [0.28266552389245464, 5.852965230533203]
# Smiles Weight Mean and Std Dev
# 0.6956988878856342 0.08564318071609762
# Smiles Weight CI
# 0.518119538573706 0.8294091180857354
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88956394 20.88559825] [ 2.43708734 37.74836512] [2.73964269 1.8073873 ]
# (Manually) Weighted RMSE Train
# [0.28266552 5.85296523]
#
#
# epoch number:  97
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9436913451511991] [1.3281227876145267, 21.650181864075627] [0.2729625297329976, 5.722972970177364]
# Smiles Weight Mean and Std Dev
# 0.7074784093884215 0.0779153654842387
# Smiles Weight CI
# 0.5426665402125918 0.8366385313651411
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87681256 20.67028052] [ 2.44173087 38.41252293] [2.78478089 1.85834551]
# ...
# Smiles Weight CI
# 0.5445017186290613 0.8404637537067873
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87640354 22.47749136] [ 2.49024335 38.5678227 ] [2.84143462 1.71584195]
# (Manually) Weighted RMSE Train
# [0.28615735 6.04223494]
#
#
# epoch number:  469
# Coverages, CI Widths, RMSEs
# [0.9614181438998958, 0.9509906152241918] [1.3493937833843759, 23.343982225019438] [0.29343728051935153, 6.042125619010261]
# Smiles Weight Mean and Std Dev
# 0.709754942005115 0.07735528204727851
# Smiles Weight CI
# 0.5573469180398357 0.8278895701873576
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87825664 22.61739247] [ 2.47732087 38.13761423] [2.82072546 1.68620739]
# (Manually) Weighted RMSE Train
# [0.29343728 6.04212562]
#
#
# epoch number:  470
# Coverages, CI Widths, RMSEs
# [0.9676746611053181, 0.9603753910323254] [1.3916503904473727, 25.29291620059511] [0.2954220081926885, 6.058162437271222]
# Smiles Weight Mean and Std Dev
# 0.707713642110464 0.08057668856164536
# Smiles Weight CI
# 0.5338458370793983 0.8308360460102654
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88097101 22.55373427] [ 2.48210948 37.93561413] [2.8174701  1.68201033]
# (Manually) Weighted RMSE Train
# [0.29542201 6.05816244]
#
#
# epoch number:  471
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9718456725755996] [1.3889792388273552, 25.691244639464216] [0.2966750924653366, 6.011061643598842]
# Smiles Weight Mean and Std Dev
# 0.7073638534255339 0.08233216668616361
# Smiles Weight CI
# 0.5356508970577213 0.837757162056735
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87322859 22.66426434] [ 2.47510512 37.92797561] [2.83442978 1.6734704 ]
# (Manually) Weighted RMSE Train
# [0.29667509 6.01106164]
#
#
# epoch number:  472
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9603753910323254] [1.4316706189112345, 25.341196911385314] [0.2936034600411781, 6.053872947279839]
# Smiles Weight Mean and Std Dev
# 0.7093011606016838 0.08218706894319812
# Smiles Weight CI
# 0.5265500563680474 0.8365735804488011
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87608704 22.77560267] [ 2.47719046 37.96278555] [2.82756203 1.66681805]
# (Manually) Weighted RMSE Train
# [0.29360346 6.05387295]
#
#
# epoch number:  473
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9655891553701773] [1.341599863324064, 24.865684689333218] [0.2916171953668908, 6.007484321209131]
# Smiles Weight Mean and Std Dev
# 0.7142415032294519 0.08155588423300054
# Smiles Weight CI
# 0.5439026647879337 0.8391683262892067
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8665008  22.49127466] [ 2.46896274 38.23627944] [2.84934848 1.70004946]
# (Manually) Weighted RMSE Train
# [0.2916172  6.00748432]
#
#
# epoch number:  474
# Coverages, CI Widths, RMSEs
# [0.9603753910323254, 0.9635036496350365] [1.379942455828473, 25.68013531894421] [0.29075820525422585, 6.024374951680465]
# Smiles Weight Mean and Std Dev
# 0.7128533090116942 0.08238646836290202
# Smiles Weight CI
# 0.5423991485465134 0.837926101491688
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87695497 22.45488661] [ 2.48379171 38.06522911] [2.83229105 1.69518688]
# (Manually) Weighted RMSE Train
# [0.29075821 6.02437495]
#
#
# epoch number:  475
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9666319082377477] [1.4267251780699473, 26.079863117062178] [0.29653925327728653, 6.009601481679836]
# Smiles Weight Mean and Std Dev
# 0.7065774263373733 0.08141143975403221
# Smiles Weight CI
# 0.5161141191925489 0.8251121211712006
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88607911 22.6364433 ] [ 2.47423118 37.75663535] [2.79233667 1.66795794]
# (Manually) Weighted RMSE Train
# [0.29653925 6.00960148]
#
#
# epoch number:  476
# Coverages, CI Widths, RMSEs
# [0.9614181438998958, 0.9655891553701773] [1.4283586774734558, 25.49582882076301] [0.2997364054022452, 6.045810216339075]
# Smiles Weight Mean and Std Dev
# 0.7026287950869619 0.08417812028564733
# Smiles Weight CI
# 0.5113989388093431 0.8284533270778497
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88998865 22.86969099] [ 2.47438636 37.62574592] [2.78024486 1.64522319]
# (Manually) Weighted RMSE Train
# [0.29973641 6.04581022]
#
#
# epoch number:  477
# Coverages, CI Widths, RMSEs
# [0.9676746611053181, 0.9655891553701773] [1.3948011979333808, 25.76519165227615] [0.29527478663254775, 6.025272937442544]
# Smiles Weight Mean and Std Dev
# 0.706727647744256 0.08142796153790303
# Smiles Weight CI
# 0.527711404904535 0.8256150306645071
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88637486 22.88032335] [ 2.48778976 37.64636511] [2.80670161 1.64535984]
# (Manually) Weighted RMSE Train
# [0.29527479 6.02527294]
#
#
# epoch number:  478
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9603753910323254] [1.5004844648617235, 25.582599444712447] [0.2927879723022705, 5.989846037209545]
# Smiles Weight Mean and Std Dev
# 0.7111152486546668 0.08476536170484662
# Smiles Weight CI
# 0.5189522795775393 0.842067360006703
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87950578 22.68026116] [ 2.49228914 37.9782356 ] [2.83373821 1.6745061 ]
# (Manually) Weighted RMSE Train
# [0.29278797 5.98984604]
#
#
# epoch number:  479
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9655891553701773] [1.436946483541677, 25.446684793232844] [0.29306002331251846, 6.019009667601524]
# Smiles Weight Mean and Std Dev
# 0.7095456768598195 0.0848954285198219
# Smiles Weight CI
# 0.5379149381523485 0.841839529975529
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88242342 22.73053183] [ 2.48417483 37.79031632] [2.81517329 1.66253551]
# (Manually) Weighted RMSE Train
# [0.29306002 6.01900967]
#
#
# epoch number:  480
# Coverages, CI Widths, RMSEs
# [0.9676746611053181, 0.9708029197080292] [1.4233437630263495, 26.163260754392503] [0.29621089610350165, 6.0506008648287395]
# Smiles Weight Mean and Std Dev
# 0.7066106677213669 0.08238532776392707
# Smiles Weight CI
# 0.5376246364942228 0.8338947594278037
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88698445 22.80595683] [ 2.48923025 37.6160129 ] [2.80639673 1.6493942 ]
# (Manually) Weighted RMSE Train
# [0.2962109  6.05060086]
#
#
# epoch number:  481
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9635036496350365] [1.4689562204142372, 25.70728003102013] [0.29128670128692186, 6.040808000171541]
# Smiles Weight Mean and Std Dev
# 0.7120372258458463 0.08355264511972404
# Smiles Weight CI
# 0.5337617146969948 0.8361336926536131
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88246043 22.55265625] [ 2.49294763 37.92808874] [2.82499651 1.68175705]
# (Manually) Weighted RMSE Train
# [0.2912867 6.040808 ]
#
#
# epoch number:  482
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9635036496350365] [1.428844502588756, 25.316695470652373] [0.302979334548411, 6.150665175803615]
# Smiles Weight Mean and Std Dev
# 0.7005112770824905 0.08278220618517336
# Smiles Weight CI
# 0.5288652821190029 0.8275727542144296
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88747056 22.99620489] [ 2.48306128 37.35538034] [2.79790835 1.62441501]
# (Manually) Weighted RMSE Train
# [0.30297933 6.15066518]
#
#
# epoch number:  483
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9614181438998958] [1.3950879080524512, 24.742149280143206] [0.29662269029106725, 6.105953975730762]
# Smiles Weight Mean and Std Dev
# 0.7057442623438737 0.0823037165111281
# Smiles Weight CI
# 0.5316851580913873 0.834560987074396
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88177341 22.68598872] [ 2.483292   37.56231472] [2.81624733 1.65574951]
# (Manually) Weighted RMSE Train
# [0.29662269 6.10595398]
#
#
# epoch number:  484
# Coverages, CI Widths, RMSEs
# [0.959332638164755, 0.9603753910323254] [1.341736197171793, 25.180761613646045] [0.2925300845169734, 6.068679172116725]
# Smiles Weight Mean and Std Dev
# 0.7080439550230814 0.0786479587752537
# Smiles Weight CI
# 0.5533419167291223 0.8394960163055862
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8911781  22.71643763] [ 2.48444013 37.63853493] [2.78781552 1.65688545]
# (Manually) Weighted RMSE Train
# [0.29253008 6.06867917]
#
#
# epoch number:  485
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9572471324296142] [1.4292967475479328, 24.4860077449361] [0.29912020342093054, 6.104453985457747]
# Smiles Weight Mean and Std Dev
# 0.7019989244017921 0.08124310406880905
# Smiles Weight CI
# 0.5284189902463883 0.8248991884143594
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90051236 23.00706268] [ 2.48424132 37.36128293] [2.75869765 1.62390495]
# (Manually) Weighted RMSE Train
# [0.2991202  6.10445399]
#
#
# epoch number:  486
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9645464025026069] [1.448299188735394, 25.279923523676906] [0.29101626102568556, 6.04600278304104]
# Smiles Weight Mean and Std Dev
# 0.7101291314097335 0.08581722783353361
# Smiles Weight CI
# 0.5276997446244016 0.8391996726082707
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89779282 22.74358408] [ 2.48333647 37.7414827 ] [2.76604626 1.65943426]
# (Manually) Weighted RMSE Train
# [0.29101626 6.04600278]
#
#
# epoch number:  487
# Coverages, CI Widths, RMSEs
# [0.9624608967674662, 0.9603753910323254] [1.3909384756236363, 25.6134257343865] [0.2980250199417013, 6.159791513536141]
# Smiles Weight Mean and Std Dev
# 0.7034820789120094 0.08125372933958586
# Smiles Weight CI
# 0.5374945026497585 0.8373809686342202
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89904593 22.88880584] [ 2.48137781 37.42552466] [2.76001229 1.63510167]
# (Manually) Weighted RMSE Train
# [0.29802502 6.15979151]
#
#
# epoch number:  488
# Coverages, CI Widths, RMSEs
# [0.9614181438998958, 0.9655891553701773] [1.426801063348786, 25.490326511552965] [0.29083922310107113, 6.046712260352532]
# Smiles Weight Mean and Std Dev
# 0.7118395943562814 0.08338411995394449
# Smiles Weight CI
# 0.5256471128430904 0.8329116472181209
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89424198 22.54632879] [ 2.48122355 37.89618721] [2.77466681 1.68081409]
# (Manually) Weighted RMSE Train
# [0.29083922 6.04671226]
#
#
# epoch number:  489
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9635036496350365] [1.4068662255856552, 25.367519945645366] [0.29599238919943155, 6.105195481939122]
# Smiles Weight Mean and Std Dev
# 0.707273673597723 0.08158679462726784
# Smiles Weight CI
# 0.5405425432057008 0.8333120783884842
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89359024 22.75662696] [ 2.48939486 37.61620565] [2.78583487 1.65297809]
# (Manually) Weighted RMSE Train
# [0.29599239 6.10519548]
#
#
# epoch number:  490
# Coverages, CI Widths, RMSEs
# [0.9687174139728885, 0.9676746611053181] [1.4925171767673744, 26.489021659828836] [0.2909784378520617, 6.084071778495191]
# Smiles Weight Mean and Std Dev
# 0.7095015506481848 0.08653293350982463
# Smiles Weight CI
# 0.5286925097081863 0.8324483258718501
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88841697 22.62387388] [ 2.47715834 37.75887456] [2.78828344 1.6689836 ]
# (Manually) Weighted RMSE Train
# [0.29097844 6.08407178]
#
#
# epoch number:  491
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9572471324296142] [1.4790629071435561, 25.70849508849876] [0.2876178119475615, 6.051729188158876]
# Smiles Weight Mean and Std Dev
# 0.7127030845910151 0.08712922599939067
# Smiles Weight CI
# 0.5234291570682471 0.8387727762589862
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89001191 22.52436461] [ 2.48270659 37.9905575 ] [2.78952063 1.6866428 ]
# (Manually) Weighted RMSE Train
# [0.28761781 6.05172919]
#
#
# epoch number:  492
# Coverages, CI Widths, RMSEs
# [0.9697601668404588, 0.9655891553701773] [1.4822771266566852, 26.027409590722932] [0.2873029857767164, 6.063124496297594]
# Smiles Weight Mean and Std Dev
# 0.7136274804002947 0.0876203375671984
# Smiles Weight CI
# 0.5173664388353703 0.8466480109198292
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8954916  22.51527709] [ 2.47665396 38.02447404] [2.76569202 1.68882994]
# (Manually) Weighted RMSE Train
# [0.28730299 6.0631245 ]
#
#
# epoch number:  493
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9603753910323254] [1.41569026897523, 25.360075423943016] [0.28957489958656524, 6.088639851360918]
# Smiles Weight Mean and Std Dev
# 0.7105707384762108 0.08099848188236747
# Smiles Weight CI
# 0.5435707001907074 0.8406152257583794
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8980327  22.56239362] [ 2.46882543 37.80790246] [2.74914872 1.67570441]
# (Manually) Weighted RMSE Train
# [0.2895749  6.08863985]
#
#
# epoch number:  494
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9676746611053181] [1.4481053363692293, 25.998681986622252] [0.28732240946077825, 6.053353696714225]
# Smiles Weight Mean and Std Dev
# 0.7152142519072772 0.08376446846538914
# Smiles Weight CI
# 0.5269675975808024 0.8396849129578351
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89816061 22.43477623] [ 2.47618395 38.09615096] [2.75695005 1.69808473]
# (Manually) Weighted RMSE Train
# [0.28732241 6.0533537 ]
#
#
# epoch number:  495
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9708029197080292] [1.4798129939886364, 26.076156332944695] [0.2947834656841428, 6.094623192489703]
# Smiles Weight Mean and Std Dev
# 0.7066129855887255 0.0810216558842391
# Smiles Weight CI
# 0.5338929797128461 0.8364994276232364
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8972917  22.82063259] [ 2.47023869 37.65288746] [2.75299404 1.64994933]
# (Manually) Weighted RMSE Train
# [0.29478347 6.09462319]
#
#
# epoch number:  496
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9624608967674662] [1.4550779903618822, 25.701411485325934] [0.3005855758468392, 6.16779596874519]
# Smiles Weight Mean and Std Dev
# 0.7020137263116774 0.08743809746196309
# Smiles Weight CI
# 0.5216711580927696 0.8413088186635046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90206517 22.86502719] [ 2.47097028 37.32081601] [2.73923698 1.63222268]
# (Manually) Weighted RMSE Train
# [0.30058558 6.16779597]
#
#
# epoch number:  497
# Coverages, CI Widths, RMSEs
# [0.9666319082377477, 0.9708029197080292] [1.4579196780648018, 26.467959641594547] [0.28909974222875895, 6.036866529463703]
# Smiles Weight Mean and Std Dev
# 0.7127786466622962 0.0847109835847959
# Smiles Weight CI
# 0.5298924516015409 0.8421373266975584
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90490668 22.66534823] [ 2.47852558 37.79653984] [2.73898473 1.6675914 ]
# (Manually) Weighted RMSE Train
# [0.28909974 6.03686653]
#
#
# epoch number:  498
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9562043795620438] [1.425060782903371, 25.566992908981845] [0.29151159360628004, 6.06553498010686]
# Smiles Weight Mean and Std Dev
# 0.7076920356811598 0.07954351330125425
# Smiles Weight CI
# 0.5376118356201139 0.8259389304366817
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90364425 23.04367621] [ 2.47157367 37.60133907] [2.735118   1.63174221]
# (Manually) Weighted RMSE Train
# [0.29151159 6.06553498]
#
#
# epoch number:  499
# Coverages, CI Widths, RMSEs
# [0.9635036496350365, 0.9624608967674662] [1.4150165694615342, 25.17154101571115] [0.28641492230673726, 6.042577109045718]
# Smiles Weight Mean and Std Dev
# 0.7139908730735701 0.08225968734947586
# Smiles Weight CI
# 0.532436989889998 0.8291940652273925
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89838339 22.82246681] [ 2.47919888 37.80762008] [2.75962234 1.65659656]
# (Manually) Weighted RMSE Train
# [0.28641492 6.04257711]
#
#
# done for fold0
# train_width[1.284640031425347, 20.628781409205455]
# smiles_weight0.7051524180332575
# rmse_train[0.14081514741020226, 0.1307481910018072]
# smiles_weight_ci[0.5420264134164661, 0.8374764936769256]
# CPU times: user 4h 40min 7s, sys: 2h 40min 22s, total: 7h 20min 30s
# Wall time: 1h 57min 20s

# %%
with open("..//Data/returned_stuff_config3.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.65, epochs = 2000, fudging_var = 1e-4)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.9614181438998958] [1.3257544375726922, 21.193939725638014] [0.2774427020499001, 5.9843299048119425]
# Smiles Weight Mean and Std Dev
# 0.7007989169870622 0.08140808212709573
# Smiles Weight CI
# 0.5551787863804135 0.8328092289237351
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.92536462 21.83448297] [ 2.37635736 37.08016033] [2.56802272 1.69823853]
# (Manually) Weighted RMSE Train
# [0.2774427 5.9843299]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9801876955161627] [1.3897471570116062, 22.731533006704012] [0.26789822746537817, 5.5866520582823]
# Smiles Weight Mean and Std Dev
# 0.6919532731420007 0.08622622259892222
# Smiles Weight CI
# 0.5111475661039074 0.8282081839834727
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97804682 23.93538392] [ 2.32410826 35.14852437] [2.37627505 1.46847548]
# (Manually) Weighted RMSE Train
# [0.26789823 5.58665206]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.9812304483837331, 0.9812304483837331] [1.3983665072569123, 22.420176354966106] [0.2514768030059287, 5.335666798616305]
# Smiles Weight Mean and Std Dev
# 0.7028080223030586 0.08632333969948569
# Smiles Weight CI
# 0.5147195306119403 0.8357442299791442
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.0087157  25.04515272] [ 2.27049261 34.35534928] [2.25087467 1.37173647]
# (Manually) Weighted RMSE Train
# [0.2514768 5.3356668]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9885297184567258] [1.366718882345711, 23.561379867640547] [0.24005918997774653, 5.072875260315175]
# Smiles Weight Mean and Std Dev
# 0.69598438426985 0.08235407893570963
# Smiles Weight CI
# 0.5231321799881319 0.8289568370812411
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.07810788 26.72144759] [ 2.18305894 32.62821743] [2.02489842 1.22104977]
# (Manually) Weighted RMSE Train
# [0.24005919 5.07287526]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9791449426485923] [1.4242084449176147, 22.474376268996537] [0.23232357951158872, 5.074558805156077]
# Smiles Weight Mean and Std Dev
# 0.6979015022603015 0.08191201021039472
# Smiles Weight CI
# 0.5280160069144328 0.8266777226240434
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.15182512 28.1778994 ] [ 2.11763037 31.62077148] [1.83849991 1.12218342]
# (Manually) Weighted RMSE Train
# [0.23232358 5.07455881]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9874869655891554] [1.4874654354164951, 25.34370146740256] [0.22078073163836592, 4.673844684862175]
# Smiles Weight Mean and Std Dev
# 0.6844268411305048 0.08528629276658524
# Smiles Weight CI
# 0.5104938287490496 0.8283618733100988
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23106123 29.91505583] [ 2.04224896 29.38334193] [1.6589337  0.98222588]
# (Manually) Weighted RMSE Train
# [0.22078073 4.67384468]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9833159541188738] [1.4779817713546655, 25.221619705550342] [0.22063661159736103, 4.688684406082858]
# Smiles Weight Mean and Std Dev
# 0.6889574202945936 0.08415211920139552
# Smiles Weight CI
# 0.5114012178905214 0.8196824007171585
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29054938 31.19531267] [ 1.98597628 28.8036577 ] [1.53886113 0.92333287]
# (Manually) Weighted RMSE Train
# [0.22063661 4.68868441]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.986444212721585] [1.4206034194222272, 25.622334484825743] [0.22436366389432733, 4.718226080690073]
# Smiles Weight Mean and Std Dev
# 0.6875733548205235 0.08144479180540802
# Smiles Weight CI
# 0.5182792160152163 0.8201024542751527
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34386129 32.39340394] [ 1.94989683 28.05326638] [1.45096584 0.86601786]
# (Manually) Weighted RMSE Train
# [0.22436366 4.71822608]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9812304483837331] [1.4291282303656823, 25.74120288543765] [0.2252739511228773, 4.691115356726192]
# Smiles Weight Mean and Std Dev
# 0.6829577886490584 0.07863810361392597
# Smiles Weight CI
# 0.5294509448657349 0.8040449531322253
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39969542 33.58588385] [ 1.91289689 27.15014143] [1.36665225 0.80837954]
# (Manually) Weighted RMSE Train
# [0.22527395 4.69111536]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9822732012513035] [1.5822512004221407, 26.450571431567667] [0.22293934751181874, 4.735623622219196]
# Smiles Weight Mean and Std Dev
# 0.6815192902301118 0.08515874325733795
# Smiles Weight CI
# 0.5025846091849306 0.8136058883650277
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44444369 34.50770682] [ 1.86992101 26.47051578] [1.29456138 0.76708997]
# (Manually) Weighted RMSE Train
# [0.22293935 4.73562362]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9791449426485923] [1.4880130159281626, 25.64661740063815] [0.2260166309261926, 4.830637187278514]
# Smiles Weight Mean and Std Dev
# 0.6798030420214368 0.08125041560451308
# Smiles Weight CI
# 0.5070996139341579 0.8108550317980028
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48455524 35.4272077 ] [ 1.83834284 26.04603521] [1.23831218 0.73519865]
# (Manually) Weighted RMSE Train
# [0.22601663 4.83063719]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9812304483837331] [1.5291352333352046, 27.57024658829805] [0.22480591187001955, 4.7052850902970444]
# Smiles Weight Mean and Std Dev
# 0.6765288863893286 0.07915732162615385
# Smiles Weight CI
# 0.5118992358227863 0.8071920159657682
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53022507 36.29394089] [ 1.80652204 25.17045875] [1.18055969 0.69351683]
# (Manually) Weighted RMSE Train
# [0.22480591 4.70528509]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.9760166840458812] [1.5043445237848074, 25.98350915679457] [0.23547998815356538, 4.954760202141158]
# Smiles Weight Mean and Std Dev
# 0.6803539570744769 0.07885053552506596
# Smiles Weight CI
# 0.5111323214197555 0.799171125444494
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56354762 36.81840589] [ 1.78705383 25.25868854] [1.14294813 0.68603428]
# (Manually) Weighted RMSE Train
# [0.23547999 4.9547602 ]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9781021897810219] [1.467930488828586, 26.964604445931013] [0.22035179343749434, 4.862436250392304]
# Smiles Weight Mean and Std Dev
# 0.6776771595792076 0.07838338067627806
# Smiles Weight CI
# 0.5291248911464576 0.7977654830060013
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5883156  37.53465374] [ 1.75446429 24.85892881] [1.10460685 0.66229274]
# (Manually) Weighted RMSE Train
# [0.22035179 4.86243625]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9812304483837331] [1.5210243850796221, 27.896497693582987] [0.20996809480046807, 4.674594636788844]
# Smiles Weight Mean and Std Dev
# 0.6715513485883119 0.08047940752123305
# Smiles Weight CI
# 0.49407040149501824 0.7986449027718072
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.61354841 38.36286895] [ 1.71891124 24.24855226] [1.06529883 0.63208391]
# (Manually) Weighted RMSE Train
# [0.20996809 4.67459464]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9749739311783108] [1.6313575186690663, 27.787644876348452] [0.20950049596808895, 4.756363463510698]
# Smiles Weight Mean and Std Dev
# 0.6733151506734382 0.08040355512663006
# Smiles Weight CI
# 0.5021861206068439 0.8047429819658323
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63129449 38.95746928] [ 1.71176012 24.04203573] [1.04932625 0.61713546]
# (Manually) Weighted RMSE Train
# [0.2095005  4.75636346]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9781021897810219] [1.6046126832014727, 28.840090636486604] [0.20177242625162656, 4.516077434450823]
# Smiles Weight Mean and Std Dev
# 0.6687872248128971 0.08359297608704148
# Smiles Weight CI
# 0.48823929839568414 0.8036723455600606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6514084  39.21636712] [ 1.68239575 23.50329244] [1.01876419 0.59932355]
# (Manually) Weighted RMSE Train
# [0.20177243 4.51607743]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9760166840458812] [1.5573177776577412, 28.417814433485123] [0.2000264475832007, 4.5273278232650895]
# Smiles Weight Mean and Std Dev
# 0.6686445587735558 0.0791828940903289
# Smiles Weight CI
# 0.501188045931013 0.7913824041828478
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.66712552 39.59745827] [ 1.6656619  23.45319162] [0.99912207 0.59229033]
# (Manually) Weighted RMSE Train
# [0.20002645 4.52732782]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9791449426485923] [1.5525738674762157, 28.653935648421786] [0.18899175569849164, 4.302352175631354]
# Smiles Weight Mean and Std Dev
# 0.6553382361607765 0.08095562355391454
# Smiles Weight CI
# 0.5019563987826068 0.790425769039912
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70207986 40.20785172] [ 1.62151048 22.45654224] [0.95266416 0.55851137]
# (Manually) Weighted RMSE Train
# [0.18899176 4.30235218]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9687174139728885] [1.5109824255631907, 26.791146624204156] [0.200557988124694, 4.760836148138536]
# Smiles Weight Mean and Std Dev
# 0.6688506481364151 0.08127389109077103
# Smiles Weight CI
# 0.4955559632904745 0.7916923213922681
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70718359 40.11040814] [ 1.63961081 23.28039647] [0.96041856 0.58040787]
# (Manually) Weighted RMSE Train
# [0.20055799 4.76083615]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9666319082377477] [1.4736933511508443, 26.823119106637694] [0.19188218509164495, 4.568221518906334]
# Smiles Weight Mean and Std Dev
# 0.6608985182835756 0.07770621057634754
# Smiles Weight CI
# 0.4817126058804478 0.7846224040823018
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73427831 40.63600754] [ 1.61012494 22.65182196] [0.92841208 0.55743227]
# (Manually) Weighted RMSE Train
# [0.19188219 4.56822152]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9749739311783108] [1.6018581738725468, 29.423153335080457] [0.18390466652134724, 4.327449627898628]
# Smiles Weight Mean and Std Dev
# 0.6530685432101757 0.08199103057747123
# Smiles Weight CI
# 0.464270358533218 0.7817115070430973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76025232 41.02957366] [ 1.57617258 22.1140112 ] [0.89542423 0.53897736]
# (Manually) Weighted RMSE Train
# [0.18390467 4.32744963]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9749739311783108] [1.6132930054653285, 30.160393131616456] [0.19096300821366344, 4.4198961269286166]
# Smiles Weight Mean and Std Dev
# 0.6585021188781133 0.0852173055173052
# Smiles Weight CI
# 0.49218953979060015 0.8018672969379042
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78079806 41.24794176] [ 1.57985971 22.43091138] [0.88716387 0.5438068 ]
# (Manually) Weighted RMSE Train
# [0.19096301 4.41989613]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9760166840458812] [1.6204301083155381, 29.498908794193003] [0.18831082693163573, 4.421487777091406]
# Smiles Weight Mean and Std Dev
# 0.6564297258230158 0.0841297015777414
# Smiles Weight CI
# 0.47789794573121286 0.7938752665489396
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8019061  41.52639877] [ 1.55662811 22.33976718] [0.8638786  0.53796544]
# (Manually) Weighted RMSE Train
# [0.18831083 4.42148778]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9781021897810219] [1.5951554345359473, 30.024740644803867] [0.19300701035074194, 4.5011145713557745]
# Smiles Weight Mean and Std Dev
# 0.6583993815728553 0.07747581554363796
# Smiles Weight CI
# 0.4873768034890155 0.787249561197655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82059182 41.76000573] [ 1.55155777 22.44048362] [0.85222714 0.53736783]
# (Manually) Weighted RMSE Train
# [0.19300701 4.50111457]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9718456725755996] [1.5414920116390713, 27.660318062105027] [0.20220600951723117, 4.706738325819461]
# Smiles Weight Mean and Std Dev
# 0.66161951449318 0.07611188555597466
# Smiles Weight CI
# 0.4836605863242927 0.7892585304878764
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83888721 41.88663928] [ 1.54841693 22.63828688] [0.84204019 0.54046558]
# (Manually) Weighted RMSE Train
# [0.20220601 4.70673833]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9801876955161627] [1.6533810383127283, 30.538876121397966] [0.18960764904332822, 4.459574892844251]
# Smiles Weight Mean and Std Dev
# 0.6557142894709186 0.0825278166177001
# Smiles Weight CI
# 0.48927889931554785 0.7942531544363263
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.85860453 42.07712673] [ 1.52541201 22.34970923] [0.82072974 0.53116054]
# (Manually) Weighted RMSE Train
# [0.18960765 4.45957489]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9760166840458812] [1.6848304349255727, 30.001850279685016] [0.19183234317274622, 4.6482605290485655]
# Smiles Weight Mean and Std Dev
# 0.6589789449995025 0.0790936098553768
# Smiles Weight CI
# 0.4915103815273067 0.7886222427042414
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.86366897 42.331833  ] [ 1.52261138 22.43194248] [0.81699669 0.52990719]
# (Manually) Weighted RMSE Train
# [0.19183234 4.64826053]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.97288842544317] [1.5215238289488067, 28.98632312982554] [0.19610564899550814, 4.649892347590649]
# Smiles Weight Mean and Std Dev
# 0.6599144660700315 0.07753557505694522
# Smiles Weight CI
# 0.5071430409293168 0.7890641558868677
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87217316 42.49732389] [ 1.52075837 22.51526904] [0.81229579 0.5298044 ]
# (Manually) Weighted RMSE Train
# [0.19610565 4.64989235]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9760166840458812] [1.6101586538861619, 28.65050433292359] [0.1912838220673699, 4.644362963922324]
# Smiles Weight Mean and Std Dev
# 0.6579088474728665 0.07478522605930836
# Smiles Weight CI
# 0.509909044593014 0.7845478811390647
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88064701 42.8058645 ] [ 1.50736594 22.37952409] [0.80151455 0.52281444]
# (Manually) Weighted RMSE Train
# [0.19128382 4.64436296]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9749739311783108] [1.6198951177691792, 29.25356617962809] [0.1896237592048839, 4.595455651900735]
# Smiles Weight Mean and Std Dev
# 0.6559632676264169 0.07943181541938873
# Smiles Weight CI
# 0.4865300108905613 0.7753062186462037
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89580457 42.99607015] [ 1.49617398 22.32765051] [0.78920265 0.51929515]
# (Manually) Weighted RMSE Train
# [0.18962376 4.59545565]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9718456725755996] [1.6628477947707263, 30.680730151751344] [0.18315286208134055, 4.566910574479375]
# Smiles Weight Mean and Std Dev
# 0.654510891702485 0.07924254523700436
# Smiles Weight CI
# 0.48188094266844145 0.7854839088596512
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.90271949 43.23548512] [ 1.48068165 22.23543733] [0.7781923  0.51428675]
# (Manually) Weighted RMSE Train
# [0.18315286 4.56691057]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9666319082377477] [1.6468959331737836, 30.571928896830524] [0.18455443663593596, 4.667220710863216]
# Smiles Weight Mean and Std Dev
# 0.6560263115273941 0.07717842890271374
# Smiles Weight CI
# 0.4866732419746245 0.7829220663263673
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.91770542 43.47182904] [ 1.47762116 22.34686756] [0.77051519 0.514054  ]
# (Manually) Weighted RMSE Train
# [0.18455444 4.66722071]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9791449426485923] [1.7829155243279144, 33.21734587969505] [0.17915843381876584, 4.476845755201001]
# Smiles Weight Mean and Std Dev
# 0.6526268394630705 0.08414878523410699
# Smiles Weight CI
# 0.4658450648272498 0.7824655718272858
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.92791502 43.54216307] [ 1.46439276 22.33673515] [0.75957329 0.51299094]
# (Manually) Weighted RMSE Train
# [0.17915843 4.47684576]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9812304483837331] [1.7649869869503503, 31.272396419344613] [0.18607624442636553, 4.66636040339833]
# Smiles Weight Mean and Std Dev
# 0.6582962369522077 0.081101967699828
# Smiles Weight CI
# 0.48683417698584724 0.7918714123322652
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.92908591 43.48324016] [ 1.46970024 22.67681926] [0.76186355 0.52150712]
# (Manually) Weighted RMSE Train
# [0.18607624 4.6663604 ]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9749739311783108] [1.7055577035405844, 31.29968002180734] [0.18039111335897304, 4.555078124803051]
# Smiles Weight Mean and Std Dev
# 0.6541442238718008 0.07945856939009156
# Smiles Weight CI
# 0.4695525899627121 0.7801946805804515
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.94415243 43.78643522] [ 1.45366934 22.56291641] [0.74771366 0.51529466]
# (Manually) Weighted RMSE Train
# [0.18039111 4.55507812]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9760166840458812] [1.591216760815123, 30.765739693621693] [0.18167789522821118, 4.477405815999996]
# Smiles Weight Mean and Std Dev
# 0.6525155627541416 0.0775433774927119
# Smiles Weight CI
# 0.4873640459589145 0.7798315521040567
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95542646 43.83329692] [ 1.44595264 22.68508879] [0.73945642 0.51753097]
# (Manually) Weighted RMSE Train
# [0.1816779  4.47740582]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9781021897810219] [1.7660121994245774, 32.59872151243548] [0.18854648070017097, 4.810013431410736]
# Smiles Weight Mean and Std Dev
# 0.6571014867431949 0.0813239617809614
# Smiles Weight CI
# 0.4892791557906206 0.79284489839996
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.95338091 44.15203486] [ 1.4482713  22.90236984] [0.74141776 0.51871607]
# (Manually) Weighted RMSE Train
# [0.18854648 4.81001343]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9749739311783108] [1.7856632448542746, 31.765358590606553] [0.175191180739741, 4.539794865228512]
# Smiles Weight Mean and Std Dev
# 0.6463777358459533 0.08329536810123139
# Smiles Weight CI
# 0.46428661225005424 0.7848859120821974
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.9754038  44.45061653] [ 1.42126011 22.35910209] [0.71947827 0.50300994]
# (Manually) Weighted RMSE Train
# [0.17519118 4.53979487]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9697601668404588] [1.693371426068035, 31.956517905935776] [0.18160042096832335, 4.653437458838545]
# Smiles Weight Mean and Std Dev
# 0.651878324113052 0.08025501617119954
# Smiles Weight CI
# 0.4756030165677545 0.781068015284499
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97783499 44.37556969] [ 1.42788073 22.74964936] [0.72194128 0.51266157]
# (Manually) Weighted RMSE Train
# [0.18160042 4.65343746]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9687174139728885] [1.5877748454204001, 30.77754918927187] [0.17841842050867046, 4.650830921721935]
# Smiles Weight Mean and Std Dev
# 0.6495876490003089 0.0777570597444066
# Smiles Weight CI
# 0.4943334556802074 0.7757206612679416
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98307496 44.47978296] [ 1.42250552 22.70685688] [0.71732312 0.51049837]
# (Manually) Weighted RMSE Train
# [0.17841842 4.65083092]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9697601668404588] [1.6575189449063705, 30.50428490933864] [0.1943981487419644, 5.0397058402981445]
# Smiles Weight Mean and Std Dev
# 0.6578891898000806 0.076336600614523
# Smiles Weight CI
# 0.4930726926645082 0.7868978313635281
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98513544 44.29086697] [ 1.43462852 23.0990704 ] [0.72268546 0.52153123]
# (Manually) Weighted RMSE Train
# [0.19439815 5.03970584]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9760166840458812] [1.7293527299724796, 31.084580218357686] [0.1762728231694101, 4.583747398418732]
# Smiles Weight Mean and Std Dev
# 0.6471676803417917 0.0794807816113121
# Smiles Weight CI
# 0.48131108325954836 0.7816797252401816
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.9942234  44.38704796] [ 1.41068583 22.72020164] [0.70738606 0.51186557]
# (Manually) Weighted RMSE Train
# [0.17627282 4.5837474 ]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9718456725755996] [1.7022918800016997, 30.8299166120273] [0.19256068316233865, 5.077321058019569]
# Smiles Weight Mean and Std Dev
# 0.6570517948913099 0.08270832159438425
# Smiles Weight CI
# 0.48457017494881266 0.7865811458030695
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.98891445 44.26799525] [ 1.43498715 23.28197228] [0.72149265 0.52593238]
# (Manually) Weighted RMSE Train
# [0.19256068 5.07732106]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9708029197080292] [1.641442561351341, 29.41617232885368] [0.18702048767340207, 5.092438074368209]
# Smiles Weight Mean and Std Dev
# 0.6546560564966989 0.07309593654641262
# Smiles Weight CI
# 0.49787834988722207 0.7816425921283721
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.99382965 44.37168039] [ 1.43088983 23.21069842] [0.71765902 0.52309712]
# (Manually) Weighted RMSE Train
# [0.18702049 5.09243807]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9718456725755996] [1.6444842232130548, 29.70639383577502] [0.1880202686021809, 4.9738539043382115]
# Smiles Weight Mean and Std Dev
# 0.6541059901466526 0.07596737356413148
# Smiles Weight CI
# 0.49521510390323104 0.7703821278994911
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.00018278 44.42241532] [ 1.43463262 23.25009535] [0.71725076 0.52338656]
# (Manually) Weighted RMSE Train
# [0.18802027 4.9738539 ]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9645464025026069] [1.6441359448500885, 30.745082434827346] [0.18057144609721396, 4.787568685758439]
# Smiles Weight Mean and Std Dev
# 0.650754233707585 0.07632903166921713
# Smiles Weight CI
# 0.4818137689015226 0.7805584470407811
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.00051836 44.52922937] [ 1.42512022 23.24224028] [0.71237548 0.52195469]
# (Manually) Weighted RMSE Train
# [0.18057145 4.78756869]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9718456725755996] [1.6759435890590635, 30.532074393395295] [0.1898584405836616, 4.96103699754604]
# Smiles Weight Mean and Std Dev
# 0.6539933773001319 0.07723602517304025
# Smiles Weight CI
# 0.48854407582209997 0.7776480973779332
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.00726483 44.49561103] [ 1.42889642 23.44487452] [0.71186243 0.52690308]
# (Manually) Weighted RMSE Train
# [0.18985844 4.961037  ]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9655891553701773] [1.6478845465408956, 30.576930610421684] [0.16884173341958403, 4.575392536401944]
# Smiles Weight Mean and Std Dev
# 0.6426531287590733 0.07882148480791251
# Smiles Weight CI
# 0.4841398734204524 0.7740661776675052
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.01470705 44.66389452] [ 1.40597562 23.03822471] [0.69785611 0.51581316]
# (Manually) Weighted RMSE Train
# [0.16884173 4.57539254]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9718456725755996] [1.783483977543121, 31.7029634507349] [0.17008391591234687, 4.604293904009139]
# Smiles Weight Mean and Std Dev
# 0.6432430427191644 0.08633929346227935
# Smiles Weight CI
# 0.46768454004917714 0.7852137391371705
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.01786761 44.68730295] [ 1.40982519 23.13435101] [0.6986708  0.51769405]
# (Manually) Weighted RMSE Train
# [0.17008392 4.6042939 ]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9676746611053181] [1.7699785772916365, 31.522263044011524] [0.171692858779009, 4.663009260111458]
# Smiles Weight Mean and Std Dev
# 0.6449320379844702 0.0801294734603318
# Smiles Weight CI
# 0.46414161453796604 0.7680657876372674
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.02245928 44.8094168 ] [ 1.40746088 23.14197435] [0.69591556 0.51645337]
# (Manually) Weighted RMSE Train
# [0.17169286 4.66300926]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9718456725755996] [1.6669396258511433, 30.60804994059908] [0.1821953429928768, 4.933910062928153]
# Smiles Weight Mean and Std Dev
# 0.6503071750657667 0.07679688303407294
# Smiles Weight CI
# 0.5074610971260973 0.7875500063453782
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.02495006 44.87577177] [ 1.41872733 23.41510608] [0.70062337 0.52177612]
# (Manually) Weighted RMSE Train
# [0.18219534 4.93391006]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9676746611053181] [1.728574686876733, 31.629324797522344] [0.17897472143261384, 4.780885738476177]
# Smiles Weight Mean and Std Dev
# 0.6469571249941255 0.07758429313407397
# Smiles Weight CI
# 0.48168350226275525 0.7684502248218315
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.03522926 44.92619904] [ 1.41177246 23.37741382] [0.69366753 0.52035147]
# (Manually) Weighted RMSE Train
# [0.17897472 4.78088574]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9687174139728885] [1.7111273469430028, 31.270108566565153] [0.18718669964146625, 5.104350095957938]
# Smiles Weight Mean and Std Dev
# 0.6511841205552668 0.07506472999192124
# Smiles Weight CI
# 0.4736894923476274 0.7735027116817916
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.03100846 45.12293585] [ 1.42166918 23.5797043 ] [0.69998191 0.52256583]
# (Manually) Weighted RMSE Train
# [0.1871867 5.1043501]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9687174139728885] [1.684142465508314, 30.4399520745178] [0.1904903636584386, 5.117748735448954]
# Smiles Weight Mean and Std Dev
# 0.6505590161605133 0.07629909161989623
# Smiles Weight CI
# 0.4897252410779958 0.7795531937405644
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.03708518 45.22726223] [ 1.42083333 23.57537919] [0.69748352 0.52126479]
# (Manually) Weighted RMSE Train
# [0.19049036 5.11774874]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9687174139728885] [1.713156759259631, 30.018010692432377] [0.19701638681492245, 5.282612565893549]
# Smiles Weight Mean and Std Dev
# 0.6521583293433311 0.07648389591395381
# Smiles Weight CI
# 0.47489002543564024 0.7813723783835832
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.04106954 45.30507075] [ 1.42307424 23.76949306] [0.69721987 0.52465414]
# (Manually) Weighted RMSE Train
# [0.19701639 5.28261257]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9687174139728885] [1.815058764453491, 32.7531974234506] [0.1876281361095824, 4.991451302191929]
# Smiles Weight Mean and Std Dev
# 0.6485142210845122 0.0842257871160439
# Smiles Weight CI
# 0.47000168280726834 0.7808000480844898
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.05092171 45.24553704] [ 1.41169452 23.68067925] [0.68832199 0.52338155]
# (Manually) Weighted RMSE Train
# [0.18762814 4.9914513 ]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9687174139728885] [1.7964810989756193, 33.3586037169084] [0.17977248003506915, 4.734998902441242]
# Smiles Weight Mean and Std Dev
# 0.6429873403386777 0.08251907518005949
# Smiles Weight CI
# 0.46864463951423163 0.7736776019383246
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.05591649 45.29801916] [ 1.40337219 23.62493157] [0.68260175 0.52154447]
# (Manually) Weighted RMSE Train
# [0.17977248 4.7349989 ]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9666319082377477] [1.746157685800664, 31.212136558472697] [0.17928110449716345, 4.797026343738235]
# Smiles Weight Mean and Std Dev
# 0.6440617756163124 0.07651353086447817
# Smiles Weight CI
# 0.48626431717443935 0.7773856809971407
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.06096994 45.36344264] [ 1.39182704 23.81873726] [0.67532622 0.52506459]
# (Manually) Weighted RMSE Train
# [0.1792811  4.79702634]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9687174139728885] [1.6800320431707791, 30.15026969449176] [0.1776950527476351, 4.819424382475135]
# Smiles Weight Mean and Std Dev
# 0.6426988887911085 0.07708037468230478
# Smiles Weight CI
# 0.476107342257858 0.7702406331562038
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.06918967 45.40117107] [ 1.38777603 23.82848781] [0.67068575 0.52484302]
# (Manually) Weighted RMSE Train
# [0.17769505 4.81942438]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9687174139728885] [1.7323511932873745, 31.32186735431989] [0.17615998615014364, 4.7881953407088655]
# Smiles Weight Mean and Std Dev
# 0.6412876937418395 0.08082411577169223
# Smiles Weight CI
# 0.4865355629573771 0.7879802958672484
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.07166244 45.53731749] [ 1.38908617 23.96568327] [0.67051762 0.52628667]
# (Manually) Weighted RMSE Train
# [0.17615999 4.78819534]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9687174139728885] [1.6860474966211205, 30.75455777434912] [0.1713175219343567, 4.625487451274544]
# Smiles Weight Mean and Std Dev
# 0.6365201714617711 0.07595115421777154
# Smiles Weight CI
# 0.4717601452303305 0.7665413019255871
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08503059 45.53752041] [ 1.37532105 23.79207385] [0.65961673 0.52247188]
# (Manually) Weighted RMSE Train
# [0.17131752 4.62548745]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9697601668404588] [1.7245808895273476, 32.40216421169832] [0.18285479498901194, 4.996201897585378]
# Smiles Weight Mean and Std Dev
# 0.6469706746283557 0.0750927490100678
# Smiles Weight CI
# 0.48038392391154844 0.7699509343033852
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.067904   45.33357638] [ 1.38794879 24.23953588] [0.67118628 0.53469278]
# (Manually) Weighted RMSE Train
# [0.18285479 4.9962019 ]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9697601668404588] [1.7141038975169232, 32.81144985752123] [0.1848702566900744, 5.104301152786021]
# Smiles Weight Mean and Std Dev
# 0.6481485461919237 0.08029439384511708
# Smiles Weight CI
# 0.47655125746703464 0.7850931746003709
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.07058453 45.40155779] [ 1.38530303 24.26255515] [0.66903959 0.53439918]
# (Manually) Weighted RMSE Train
# [0.18487026 5.10430115]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9676746611053181] [1.8586343141758315, 33.21000649932035] [0.17508266421766802, 4.95762885793907]
# Smiles Weight Mean and Std Dev
# 0.6440538321811426 0.08136852475495776
# Smiles Weight CI
# 0.466786424151825 0.7861667399700759
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.06727428 45.56057904] [ 1.37585535 24.31944438] [0.66554079 0.5337826 ]
# (Manually) Weighted RMSE Train
# [0.17508266 4.95762886]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9687174139728885] [1.7706696809669475, 34.19006505005436] [0.17478784388608207, 4.879656674909144]
# Smiles Weight Mean and Std Dev
# 0.6437282476290602 0.08196109994510115
# Smiles Weight CI
# 0.4802505260157547 0.7897209013381289
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.06860335 45.46715674] [ 1.37259102 24.32937583] [0.66353514 0.53509781]
# (Manually) Weighted RMSE Train
# [0.17478784 4.87965667]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.97288842544317] [1.7834684748998415, 33.23331899558487] [0.1727410633427063, 4.765161294046077]
# Smiles Weight Mean and Std Dev
# 0.6402734966874801 0.08234088441336598
# Smiles Weight CI
# 0.47078322072527135 0.7900366140461692
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08250248 45.59733827] [ 1.36611431 24.30791172] [0.65599649 0.53309936]
# (Manually) Weighted RMSE Train
# [0.17274106 4.76516129]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9708029197080292] [1.7906466356169977, 32.90310692230776] [0.1803115128722995, 5.063052611096734]
# Smiles Weight Mean and Std Dev
# 0.6466078650425453 0.08136425625298555
# Smiles Weight CI
# 0.46411944895206414 0.7720153137882351
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.0703679  45.60653745] [ 1.37495943 24.45889582] [0.66411358 0.53630241]
# (Manually) Weighted RMSE Train
# [0.18031151 5.06305261]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9655891553701773] [1.711976983693322, 30.989447785986] [0.19491337663954905, 5.364327399034562]
# Smiles Weight Mean and Std Dev
# 0.6499765433874157 0.07791812906590662
# Smiles Weight CI
# 0.4739641939115239 0.7745090478522152
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.07493172 45.75165013] [ 1.3886634  24.50220745] [0.6692574  0.53554806]
# (Manually) Weighted RMSE Train
# [0.19491338 5.3643274 ]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9718456725755996] [1.7302897425787906, 32.565068499439654] [0.16891036325668962, 4.716196995455409]
# Smiles Weight Mean and Std Dev
# 0.6377531622060981 0.08068674740995148
# Smiles Weight CI
# 0.47386294980104654 0.7659666873898785
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.078943   45.94338236] [ 1.35691    24.27642388] [0.65269226 0.52839871]
# (Manually) Weighted RMSE Train
# [0.16891036 4.716197  ]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9676746611053181] [1.7033092828124652, 32.40029859393709] [0.17079523678835598, 4.715375934389944]
# Smiles Weight Mean and Std Dev
# 0.6376860826201927 0.08103568742971244
# Smiles Weight CI
# 0.4856728291246661 0.7875351389917984
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.0825588  45.98626506] [ 1.35806607 24.30479366] [0.65211416 0.52852289]
# (Manually) Weighted RMSE Train
# [0.17079524 4.71537593]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9697601668404588] [1.7205385852301762, 31.659609547418558] [0.17427590320984546, 4.910268544212366]
# Smiles Weight Mean and Std Dev
# 0.641119050230818 0.07986652524519192
# Smiles Weight CI
# 0.4665321183829202 0.7739995171600136
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.07873938 46.19643626] [ 1.36259953 24.51752109] [0.6554932  0.53072321]
# (Manually) Weighted RMSE Train
# [0.1742759  4.91026854]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9697601668404588] [1.725533111662388, 34.052657006164026] [0.188430406109345, 5.095509396670209]
# Smiles Weight Mean and Std Dev
# 0.6463677686473438 0.07994688138268924
# Smiles Weight CI
# 0.48877524085045904 0.7795864370263655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08464184 46.24939395] [ 1.37273575 24.66466086] [0.65849957 0.53329695]
# (Manually) Weighted RMSE Train
# [0.18843041 5.0955094 ]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9739311783107404] [1.8051661894078428, 34.873246666634195] [0.1791745654180158, 4.844044392620491]
# Smiles Weight Mean and Std Dev
# 0.6412467905959642 0.08226571271789954
# Smiles Weight CI
# 0.46392720866154247 0.7714586908773188
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08670854 46.3929057 ] [ 1.37056889 24.56634109] [0.65680897 0.52952797]
# (Manually) Weighted RMSE Train
# [0.17917457 4.84404439]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9708029197080292] [1.7223155508490045, 32.776142867847604] [0.18320562162231951, 4.918006468773315]
# Smiles Weight Mean and Std Dev
# 0.6429644655116734 0.0775806151223435
# Smiles Weight CI
# 0.47823593547003984 0.7573908101173649
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.09067624 46.41515595] [ 1.37049057 24.61930094] [0.65552501 0.53041513]
# (Manually) Weighted RMSE Train
# [0.18320562 4.91800647]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9666319082377477] [1.7337497577573981, 33.11853895933223] [0.1950782718721032, 5.178083924973511]
# Smiles Weight Mean and Std Dev
# 0.6475300249999147 0.07999893781332612
# Smiles Weight CI
# 0.48569194299748975 0.7885297075412135
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08583188 46.44441458] [ 1.38616547 24.77204714] [0.66456241 0.53336978]
# (Manually) Weighted RMSE Train
# [0.19507827 5.17808392]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9655891553701773] [1.7553489102629596, 32.65136710806996] [0.19372761314744857, 5.191412128468694]
# Smiles Weight Mean and Std Dev
# 0.6477584451672826 0.0782826992741014
# Smiles Weight CI
# 0.47888055459143086 0.7845973558488324
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08605658 46.53503195] [ 1.37948624 24.75581367] [0.66128899 0.53198231]
# (Manually) Weighted RMSE Train
# [0.19372761 5.19141213]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.97288842544317] [1.8299626527285657, 34.26506334813475] [0.17429916728856965, 4.746618806494991]
# Smiles Weight Mean and Std Dev
# 0.6379013910123333 0.08451311039428121
# Smiles Weight CI
# 0.4562642687992553 0.7800178479113372
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.09187969 46.49427255] [ 1.36373111 24.60390291] [0.65191661 0.52918137]
# (Manually) Weighted RMSE Train
# [0.17429917 4.74661881]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9666319082377477] [1.7078909418332366, 31.990013724854684] [0.17304707576568795, 4.706724528812455]
# Smiles Weight Mean and Std Dev
# 0.6360246003470746 0.07913801904644163
# Smiles Weight CI
# 0.4735181377695071 0.7725923468498269
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.0947014  46.65426524] [ 1.35854187 24.70862892] [0.64856111 0.52961136]
# (Manually) Weighted RMSE Train
# [0.17304708 4.70672453]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9676746611053181] [1.7527904807560735, 33.72615001053624] [0.19202356634229306, 5.319101006453394]
# Smiles Weight Mean and Std Dev
# 0.6485836437801915 0.07741141381724632
# Smiles Weight CI
# 0.4768190909124069 0.7780496765613711
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08791911 46.7835698 ] [ 1.37288113 24.88713672] [0.65753559 0.53196318]
# (Manually) Weighted RMSE Train
# [0.19202357 5.31910101]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9697601668404588] [1.7435296274699852, 33.701740687137324] [0.1911054212206461, 5.196466658075575]
# Smiles Weight Mean and Std Dev
# 0.648194224858782 0.07812328574938487
# Smiles Weight CI
# 0.48148225703349196 0.7748529046106205
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.08874655 46.89203691] [ 1.37253987 24.98090728] [0.65711173 0.5327324 ]
# (Manually) Weighted RMSE Train
# [0.19110542 5.19646666]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9760166840458812] [1.849508585036041, 35.968922563281986] [0.17938142919594854, 4.936911074423035]
# Smiles Weight Mean and Std Dev
# 0.6414115049288251 0.08423274953169739
# Smiles Weight CI
# 0.4625996509809924 0.7790725620556473
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.0920968  46.94966271] [ 1.35936909 24.71783662] [0.64976395 0.52647528]
# (Manually) Weighted RMSE Train
# [0.17938143 4.93691107]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9635036496350365] [1.7440239758011746, 33.486563207581256] [0.19880995184807626, 5.396595491809303]
# Smiles Weight Mean and Std Dev
# 0.6502137041177741 0.08006102006175798
# Smiles Weight CI
# 0.4768786974074771 0.7765113020205535
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.09425315 46.98826345] [ 1.37063775 24.93252929] [0.65447568 0.53061185]
# (Manually) Weighted RMSE Train
# [0.19880995 5.39659549]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9676746611053181] [1.8102958086998915, 33.40565837150967] [0.18195295138071169, 5.08861106908117]
# Smiles Weight Mean and Std Dev
# 0.642806318456468 0.08323657620392727
# Smiles Weight CI
# 0.45715347632038467 0.7965254390711577
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10343858 47.04166721] [ 1.34689531 24.76822951] [0.64033023 0.52651683]
# (Manually) Weighted RMSE Train
# [0.18195295 5.08861107]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9718456725755996] [1.8070132257663212, 35.875001182328] [0.19504267465661887, 5.249983071347612]
# Smiles Weight Mean and Std Dev
# 0.6470952345727077 0.07903560104352136
# Smiles Weight CI
# 0.4700130978331407 0.7743164906193015
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.1036399  47.17744241] [ 1.36229003 24.8953072 ] [0.64758708 0.52769514]
# (Manually) Weighted RMSE Train
# [0.19504267 5.24998307]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9645464025026069] [1.6284986418957113, 31.467957491840863] [0.1917139023165357, 5.188272500884055]
# Smiles Weight Mean and Std Dev
# 0.6449126872312391 0.07444991237184788
# Smiles Weight CI
# 0.47118418067046924 0.7568187808292447
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10229169 47.22344997] [ 1.36156104 24.78170263] [0.64765563 0.52477535]
# (Manually) Weighted RMSE Train
# [0.1917139 5.1882725]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9708029197080292] [1.6738187341736577, 32.43466853181588] [0.20752003945465475, 5.579101471110627]
# Smiles Weight Mean and Std Dev
# 0.6505177013549597 0.07700050617372857
# Smiles Weight CI
# 0.492089298968846 0.7805964194429209
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.09728219 47.35365839] [ 1.36950803 24.86402809] [0.65299178 0.5250709 ]
# (Manually) Weighted RMSE Train
# [0.20752004 5.57910147]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9687174139728885] [1.6870587854770265, 32.85754571488577] [0.18243820632618718, 5.101786740229606]
# Smiles Weight Mean and Std Dev
# 0.6417260315312403 0.0784785849369824
# Smiles Weight CI
# 0.4762143201895269 0.770998399272155
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10513777 47.4267588 ] [ 1.35275195 24.663689  ] [0.64259545 0.52003741]
# (Manually) Weighted RMSE Train
# [0.18243821 5.10178674]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9697601668404588] [1.6709939608924826, 33.41880325759523] [0.1869971889538793, 5.06316823824577]
# Smiles Weight Mean and Std Dev
# 0.641752640715731 0.08005519985917606
# Smiles Weight CI
# 0.47411576350915813 0.7737547238806426
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10641808 47.35981382] [ 1.34677166 24.65897572] [0.63936579 0.52067299]
# (Manually) Weighted RMSE Train
# [0.18699719 5.06316824]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.9895724713242962, 0.9739311783107404] [1.6488257817902123, 32.811708673348896] [0.19310918475185113, 5.255778398435255]
# Smiles Weight Mean and Std Dev
# 0.6449444150708104 0.07674423689762508
# Smiles Weight CI
# 0.4863373029403626 0.7743590484154688
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10346979 47.44217143] [ 1.35196039 24.84348615] [0.64272869 0.52365829]
# (Manually) Weighted RMSE Train
# [0.19310918 5.2557784 ]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9655891553701773] [1.7251119785280784, 33.842676297083145] [0.1897534437913842, 5.160008475943685]
# Smiles Weight Mean and Std Dev
# 0.6430794842672299 0.07843123345966944
# Smiles Weight CI
# 0.4728586261662035 0.7672358234747577
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10851237 47.40117088] [ 1.34968099 24.69925239] [0.64011054 0.5210684 ]
# (Manually) Weighted RMSE Train
# [0.18975344 5.16000848]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9655891553701773] [1.723254056642775, 32.969582280212514] [0.18520878628302725, 5.1562649173653705]
# Smiles Weight Mean and Std Dev
# 0.6412469636295048 0.08135735516114115
# Smiles Weight CI
# 0.4609102215736412 0.7663146083592836
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10913589 47.45399358] [ 1.34441831 24.87501588] [0.63742612 0.52419225]
# (Manually) Weighted RMSE Train
# [0.18520879 5.15626492]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.9718456725755996] [1.7299160446622932, 33.51186817055944] [0.17888520673506716, 4.855053933305985]
# Smiles Weight Mean and Std Dev
# 0.6365292293130216 0.07992252942897615
# Smiles Weight CI
# 0.4594238479858161 0.7629245969259929
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.11547915 47.61576777] [ 1.32783575 24.99099194] [0.62767612 0.52484698]
# (Manually) Weighted RMSE Train
# [0.17888521 4.85505393]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.97288842544317] [1.7715191019322787, 33.489637636099104] [0.18439954160921362, 5.0657345275331]
# Smiles Weight Mean and Std Dev
# 0.6414199440112833 0.07896738831061284
# Smiles Weight CI
# 0.4802168233515379 0.768397598149336
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.10998905 47.7501496 ] [ 1.33606068 24.92868344] [0.6332074  0.52206503]
# (Manually) Weighted RMSE Train
# [0.18439954 5.06573453]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9718456725755996] [1.734653695321408, 33.51514111016166] [0.19737296393243248, 5.33604333280849]
# Smiles Weight Mean and Std Dev
# 0.6466630906753814 0.07873862271068904
# Smiles Weight CI
# 0.4723433623925317 0.7746870113861962
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.1095366  47.66400877] [ 1.34853923 25.04254704] [0.63925851 0.52539742]
# (Manually) Weighted RMSE Train
# [0.19737296 5.33604333]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9708029197080292] [1.6788525098745557, 34.05821654392695] [0.1871978500527047, 5.1533161080557885]
# Smiles Weight Mean and Std Dev
# 0.6415914503510332 0.07562373043226389
# Smiles Weight CI
# 0.4733929161396125 0.7633499099683091
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.11151748 47.83670083] [ 1.33719459 24.95747283] [0.63328606 0.52172228]
# (Manually) Weighted RMSE Train
# [0.18719785 5.15331611]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.97288842544317] [1.8304146291088934, 34.93694217164875] [0.17528064371440488, 4.88450459253959]
# Smiles Weight Mean and Std Dev
# 0.6369634736008553 0.08528035492303541
# Smiles Weight CI
# 0.4585337032689939 0.7803592567234051
# ...
# (Manually) Weighted RMSE Train
# [0.18927053 5.264195  ]
#
#
# epoch number:  476
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9562043795620438] [1.8046995360745326, 32.723512320580255] [0.18825630946982427, 5.237710935806984]
# Smiles Weight Mean and Std Dev
# 0.6141472724171265 0.07303474901864267
# Smiles Weight CI
# 0.460139007125191 0.7367655768892596
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.31853688 48.81685797] [ 1.30380221 26.25339362] [0.56233835 0.5377936 ]
# (Manually) Weighted RMSE Train
# [0.18825631 5.23771094]
#
#
# epoch number:  477
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9614181438998958] [1.8761706117722943, 35.60837767352342] [0.1929044951818869, 5.1937440940667186]
# Smiles Weight Mean and Std Dev
# 0.6080159260141911 0.07403760927781933
# Smiles Weight CI
# 0.43503480363784425 0.7319052172302097
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32807113 48.78251433] [ 1.2963235  26.19598721] [0.55682298 0.53699543]
# (Manually) Weighted RMSE Train
# [0.1929045  5.19374409]
#
#
# epoch number:  478
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9509906152241918] [1.8557404334474334, 34.21120651388228] [0.1928069862989307, 5.248669257016465]
# Smiles Weight Mean and Std Dev
# 0.6181780642625244 0.0764339880384878
# Smiles Weight CI
# 0.44821253469770733 0.7504129596560136
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32896777 48.77982783] [ 1.31011757 26.20022122] [0.56253143 0.5371118 ]
# (Manually) Weighted RMSE Train
# [0.19280699 5.24866926]
#
#
# epoch number:  479
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9572471324296142] [1.9730528033919965, 34.93257198044207] [0.19871110210488485, 5.248605141390415]
# Smiles Weight Mean and Std Dev
# 0.6042715088434257 0.08030166335003974
# Smiles Weight CI
# 0.4410476101520131 0.749434520594433
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32214411 48.87101826] [ 1.30144829 26.24452907] [0.56045113 0.53701621]
# (Manually) Weighted RMSE Train
# [0.1987111  5.24860514]
#
#
# epoch number:  480
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9666319082377477] [1.9307694888921623, 35.807886196745365] [0.19000314881351354, 5.199512585488512]
# Smiles Weight Mean and Std Dev
# 0.6104828514395979 0.08253519868320826
# Smiles Weight CI
# 0.43076392118313084 0.7570815807148054
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32352745 48.8579706 ] [ 1.30611901 26.07950708] [0.56212764 0.53378204]
# (Manually) Weighted RMSE Train
# [0.19000315 5.19951259]
#
#
# epoch number:  481
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9572471324296142] [1.754592544570713, 32.09022986340053] [0.19388030577117554, 5.188562271173988]
# Smiles Weight Mean and Std Dev
# 0.607346909581421 0.07435323319014055
# Smiles Weight CI
# 0.46208547881610806 0.7380860366460583
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32372331 48.84526009] [ 1.29776287 26.12529774] [0.55848425 0.5348584 ]
# (Manually) Weighted RMSE Train
# [0.19388031 5.18856227]
#
#
# epoch number:  482
# Coverages, CI Widths, RMSEs
# [0.9947862356621481, 0.9562043795620438] [1.8852424758785273, 34.935507258511244] [0.19571679565008798, 5.270175587932956]
# Smiles Weight Mean and Std Dev
# 0.6176076606108672 0.07855545544846283
# Smiles Weight CI
# 0.4417522140132392 0.749704829726473
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.3271896  48.79998135] [ 1.31170619 26.09835856] [0.56364389 0.53480263]
# (Manually) Weighted RMSE Train
# [0.1957168  5.27017559]
#
#
# epoch number:  483
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.959332638164755] [1.9699805779204052, 35.28613360432639] [0.19215003838839215, 5.213600187654985]
# Smiles Weight Mean and Std Dev
# 0.6089735614278571 0.0806124356381895
# Smiles Weight CI
# 0.448662489048798 0.7503305253342454
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32713122 48.87192601] [ 1.30531088 26.09310992] [0.56090987 0.53390795]
# (Manually) Weighted RMSE Train
# [0.19215004 5.21360019]
#
#
# epoch number:  484
# Coverages, CI Widths, RMSEs
# [0.9895724713242962, 0.9635036496350365] [1.7914288006784167, 34.08440569880736] [0.19110364801185745, 5.260022957832074]
# Smiles Weight Mean and Std Dev
# 0.6150741165405453 0.07465301200003063
# Smiles Weight CI
# 0.46776046366915586 0.7514357113073366
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33267652 48.87794443] [ 1.30379269 25.9763094 ] [0.55892563 0.53145257]
# (Manually) Weighted RMSE Train
# [0.19110365 5.26002296]
#
#
# epoch number:  485
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9551616266944735] [1.8039088121953857, 32.77033271631823] [0.19167928002283005, 5.335377743836236]
# Smiles Weight Mean and Std Dev
# 0.6170351217889941 0.07165886977116741
# Smiles Weight CI
# 0.4795775368534681 0.7538344579889616
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33391746 48.83154642] [ 1.3015082  26.05125717] [0.55764963 0.53349236]
# (Manually) Weighted RMSE Train
# [0.19167928 5.33537774]
#
#
# epoch number:  486
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.9603753910323254] [1.8853945795964264, 35.39369555949434] [0.2059749723518975, 5.4671365991638465]
# Smiles Weight Mean and Std Dev
# 0.6000643458383178 0.07999796317374835
# Smiles Weight CI
# 0.42884219583672534 0.7329476352956583
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33772631 48.68826048] [ 1.29239012 26.16855182] [0.55284064 0.53747149]
# (Manually) Weighted RMSE Train
# [0.20597497 5.4671366 ]
#
#
# epoch number:  487
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9582898852971846] [1.8459815604809826, 33.54858472571297] [0.1902449907930318, 5.231590723467538]
# Smiles Weight Mean and Std Dev
# 0.6111108237074958 0.0749062290481467
# Smiles Weight CI
# 0.4530552600777298 0.7516848618473716
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33375448 48.70196374] [ 1.29840232 26.01993894] [0.55635772 0.53426878]
# (Manually) Weighted RMSE Train
# [0.19024499 5.23159072]
#
#
# epoch number:  488
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.959332638164755] [1.8057345943873273, 34.12793693097045] [0.19019168983312712, 5.2876622889109655]
# Smiles Weight Mean and Std Dev
# 0.6134313066193882 0.07311055031370618
# Smiles Weight CI
# 0.44190465344909335 0.729701404232949
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33739844 48.82768854] [ 1.30463434 26.01857163] [0.55815659 0.53286511]
# (Manually) Weighted RMSE Train
# [0.19019169 5.28766229]
#
#
# epoch number:  489
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9624608967674662] [1.8351813786686757, 34.030658483302894] [0.19051393670448893, 5.23953843494704]
# Smiles Weight Mean and Std Dev
# 0.6112132341939513 0.0764392759432347
# Smiles Weight CI
# 0.446582755758221 0.7447918502921083
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32768421 48.66445673] [ 1.3053596  26.01848045] [0.56079755 0.53465059]
# (Manually) Weighted RMSE Train
# [0.19051394 5.23953843]
#
#
# epoch number:  490
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9551616266944735] [1.8039809597591445, 32.273924867956545] [0.1895963801413582, 5.284062270656531]
# Smiles Weight Mean and Std Dev
# 0.615633533487939 0.07488564016712376
# Smiles Weight CI
# 0.4569455811611637 0.7395201014416427
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32543551 48.63921416] [ 1.309543   26.11795318] [0.56313881 0.53697317]
# (Manually) Weighted RMSE Train
# [0.18959638 5.28406227]
#
#
# epoch number:  491
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9562043795620438] [1.79330174759888, 33.08316221167877] [0.19275623725548563, 5.230472534538722]
# Smiles Weight Mean and Std Dev
# 0.6076335617446021 0.0752986796252531
# Smiles Weight CI
# 0.4527304959437804 0.7348038096845959
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32305756 48.75871453] [ 1.30285424 26.20869383] [0.56083597 0.53751815]
# (Manually) Weighted RMSE Train
# [0.19275624 5.23047253]
#
#
# epoch number:  492
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.959332638164755] [1.833311860676761, 33.04146735512733] [0.18773989105572053, 5.249604407850275]
# Smiles Weight Mean and Std Dev
# 0.6123041483885502 0.07567083480642522
# Smiles Weight CI
# 0.4583458895452962 0.7421836938424933
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32417259 48.73940491] [ 1.29970051 26.15061209] [0.55920998 0.53653942]
# (Manually) Weighted RMSE Train
# [0.18773989 5.24960441]
#
#
# epoch number:  493
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9614181438998958] [1.8478567702054318, 34.0345395426978] [0.18924248396563084, 5.294399645477286]
# Smiles Weight Mean and Std Dev
# 0.6172798388331313 0.07806566900326697
# Smiles Weight CI
# 0.45647247820201914 0.7425113949669359
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32483288 48.7081541 ] [ 1.30581964 26.19125981] [0.56168323 0.53771818]
# (Manually) Weighted RMSE Train
# [0.18924248 5.29439965]
#
#
# epoch number:  494
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9572471324296142] [1.9484960446517936, 34.18567368273285] [0.1917471565825667, 5.2707704894175125]
# Smiles Weight Mean and Std Dev
# 0.6084381320186109 0.07841028277637689
# Smiles Weight CI
# 0.4404041800737571 0.7378864112329051
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32530834 48.71686449] [ 1.29928318 26.15968666] [0.55875737 0.53697394]
# (Manually) Weighted RMSE Train
# [0.19174716 5.27077049]
#
#
# epoch number:  495
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9624608967674662] [1.8893224800849433, 35.02856566068993] [0.19239348655012556, 5.287772549477212]
# Smiles Weight Mean and Std Dev
# 0.6058375912188508 0.07975484631437005
# Smiles Weight CI
# 0.4367039295851288 0.7440511714716954
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32839212 48.65373376] [ 1.30518935 26.14427255] [0.56055393 0.53735388]
# (Manually) Weighted RMSE Train
# [0.19239349 5.28777255]
#
#
# epoch number:  496
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9635036496350365] [1.7502326187413797, 33.965462533284] [0.1986135693398767, 5.349238063592093]
# Smiles Weight Mean and Std Dev
# 0.6025928494520212 0.07562995809257599
# Smiles Weight CI
# 0.44694896566141085 0.7341380484575124
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33510313 48.82034328] [ 1.30117744 26.09920161] [0.55722483 0.53459685]
# (Manually) Weighted RMSE Train
# [0.19861357 5.34923806]
#
#
# epoch number:  497
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9614181438998958] [1.910396447655859, 35.80023036244417] [0.19095229184909013, 5.252374303318888]
# Smiles Weight Mean and Std Dev
# 0.6084434611404405 0.07835854358998638
# Smiles Weight CI
# 0.44120268653542866 0.74172015945772
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33125352 48.72561373] [ 1.30734322 26.2131647 ] [0.56078981 0.53797505]
# (Manually) Weighted RMSE Train
# [0.19095229 5.2523743 ]
#
#
# epoch number:  498
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9655891553701773] [1.9404777473958033, 35.923948110838225] [0.18919207733690271, 5.251509010181127]
# Smiles Weight Mean and Std Dev
# 0.6119889516931565 0.07728676286811721
# Smiles Weight CI
# 0.4506082443798796 0.7436623980946543
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33533353 48.81458582] [ 1.31105627 26.15124137] [0.56140001 0.53572597]
# (Manually) Weighted RMSE Train
# [0.18919208 5.25150901]
#
#
# epoch number:  499
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.954118873826903] [1.8120385962571126, 32.76555712078787] [0.18879902604413987, 5.290533349964477]
# Smiles Weight Mean and Std Dev
# 0.6155414418559104 0.07744067932369358
# Smiles Weight CI
# 0.4583632797667778 0.7389286229517325
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32821902 48.80061928] [ 1.30390674 26.21355028] [0.56004471 0.5371561 ]
# (Manually) Weighted RMSE Train
# [0.18879903 5.29053335]
#
#
# epoch number:  500
# Coverages, CI Widths, RMSEs
# [0.9916579770594369, 0.9666319082377477] [1.833058221594383, 34.12753928625863] [0.19688386048840914, 5.335556696938898]
# Smiles Weight Mean and Std Dev
# 0.602875039936047 0.08148807392461992
# Smiles Weight CI
# 0.4486546454065675 0.7399174445329116
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33399488 48.80580061] [ 1.29775559 26.24896239] [0.55602332 0.53782465]
# (Manually) Weighted RMSE Train
# [0.19688386 5.3355567 ]
#
#
# epoch number:  501
# Coverages, CI Widths, RMSEs
# [0.9906152241918665, 0.959332638164755] [1.8585275382663253, 35.16540176623728] [0.19020698318215543, 5.257664115635671]
# Smiles Weight Mean and Std Dev
# 0.6154400960524119 0.07598173069884331
# Smiles Weight CI
# 0.45917005908178393 0.7503390581238256
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33087439 48.94608417] [ 1.30496444 26.32771453] [0.55986047 0.53789215]
# (Manually) Weighted RMSE Train
# [0.19020698 5.25766412]
#
#
# epoch number:  502
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9603753910323254] [1.8152395194787079, 33.68709660566601] [0.19221375054321885, 5.269341458267894]
# Smiles Weight Mean and Std Dev
# 0.6076201328987322 0.07752057209872205
# Smiles Weight CI
# 0.45605481454387287 0.7389054915394402
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33286962 48.94476646] [ 1.29949784 26.18411953] [0.55703835 0.53497282]
# (Manually) Weighted RMSE Train
# [0.19221375 5.26934146]
#
#
# epoch number:  503
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9582898852971846] [1.8402468834842796, 33.3194211301119] [0.19045958281537248, 5.241815047616742]
# Smiles Weight Mean and Std Dev
# 0.6090781715294188 0.0741171491100399
# Smiles Weight CI
# 0.4693187357141864 0.7392723091936881
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.32904799 48.86824125] [ 1.29685781 26.24084445] [0.55681884 0.53697133]
# (Manually) Weighted RMSE Train
# [0.19045958 5.24181505]
#
#
# epoch number:  504
# Coverages, CI Widths, RMSEs
# [0.9958289885297185, 0.9666319082377477] [1.9118390602510045, 35.63604601937609] [0.1909281522627136, 5.236109119177233]
# Smiles Weight Mean and Std Dev
# 0.6075228092147538 0.08159867645312985
# Smiles Weight CI
# 0.4318291015889548 0.7511231639622505
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33164483 48.8781172 ] [ 1.30508793 26.19974084] [0.55972844 0.53602189]
# (Manually) Weighted RMSE Train
# [0.19092815 5.23610912]
#
#
# epoch number:  505
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.9655891553701773] [1.8827146263617733, 36.03488440164622] [0.18952140864816913, 5.234304080771926]
# Smiles Weight Mean and Std Dev
# 0.6097964298470561 0.08026477633683857
# Smiles Weight CI
# 0.44418583930019523 0.7432559198706777
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33180659 48.89836207] [ 1.30164676 26.22126486] [0.55821386 0.53624015]
# (Manually) Weighted RMSE Train
# [0.18952141 5.23430408]
#
#
# epoch number:  506
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9645464025026069] [1.9648954709197204, 35.21390800418427] [0.19100728211921622, 5.231832507856436]
# Smiles Weight Mean and Std Dev
# 0.6073033791867469 0.07929885309056335
# Smiles Weight CI
# 0.4457982628594304 0.7518226478669239
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33652111 48.95916405] [ 1.30389577 26.18574504] [0.55805007 0.5348487 ]
# (Manually) Weighted RMSE Train
# [0.19100728 5.23183251]
#
#
# epoch number:  507
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 0.954118873826903] [1.743676711324162, 32.278180307174374] [0.18933133483702436, 5.2047483277657784]
# Smiles Weight Mean and Std Dev
# 0.612272403365581 0.07457405744325031
# Smiles Weight CI
# 0.4607864129838563 0.7405388421833271
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.33057774 48.90682831] [ 1.30737194 26.19427709] [0.56096474 0.5355955 ]
# (Manually) Weighted RMSE Train
# [0.18933133 5.20474833]
#
#
# epoch number:  508

# %%
with open("..//Data/returned_stuff1_config3.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
# with open("..//Data/returned_stuff_config4.pickle", "rb") as f: 
#     returned_stuff = pickle.load(f)

# %%
# with open("..//Data/returned_stuff1_config3.pickle", "rb") as f: 
#     returned_stuff1 = pickle.load(f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
