# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-07-13 16:56:43.675554: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-13 16:56:43.679220: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 16:56:43.720346: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 16:56:43.721405: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 16:56:44.624642: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, fudging_var = 1.0):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_70_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_60_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200, fudging_var = 1.0):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
# returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 8.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-2)

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 100, fudging_var = 1e-5)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [46.45215805889769, 966.6857735279872] [3.1961187474673367, 74.2031745557688]
# Smiles Weight Mean and Std Dev
# 0.585976509062792 0.19448580971009544
# Smiles Weight CI
# 0.1874517960190148 0.9028390786275716
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 3.11192304 55.8125487 ] [ 2.85620303 73.00703711] [0.91782573 1.30807567]
# (Manually) Weighted RMSE Train
# [ 3.19611875 74.20317456]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [26.887095427124276, 680.0390939181053] [3.33555177086988, 50.41700872889559]
# Smiles Weight Mean and Std Dev
# 0.6350582737673615 0.1593799930848562
# Smiles Weight CI
# 0.3257548923017217 0.9130668285265785
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.67127548 53.4775841 ] [ 3.42240022 51.53977938] [1.2811858  0.96376417]
# (Manually) Weighted RMSE Train
# [ 3.33555177 50.41700873]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [18.65771499774802, 411.7856010412804] [2.3880761542535236, 34.518824744061675]
# Smiles Weight Mean and Std Dev
# 0.6676116546747293 0.13820150083809807
# Smiles Weight CI
# 0.3916145895408986 0.8908678275245074
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.91376397 48.1740803 ] [ 3.21543573 39.32871041] [1.68016317 0.81638736]
# (Manually) Weighted RMSE Train
# [ 2.38807615 34.51882474]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [12.92102271522459, 287.6028581813593] [2.3835071594063986, 24.285901895817034]
# Smiles Weight Mean and Std Dev
# 0.6887980956196288 0.11150795857199143
# Smiles Weight CI
# 0.463361660974547 0.8712831102915849
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47815885 42.63216684] [ 3.62027041 36.28360087] [2.44917548 0.85108507]
# (Manually) Weighted RMSE Train
# [ 2.38350716 24.2859019 ]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [8.694823103732627, 188.45713975776724] [1.570734055363599, 31.42067600101009]
# Smiles Weight Mean and Std Dev
# 0.7265409988264195 0.09698303048083093
# Smiles Weight CI
# 0.5221059184356719 0.8880985951201397
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.11452216 44.55804612] [ 3.24477435 41.93541983] [2.91135921 0.94114135]
# (Manually) Weighted RMSE Train
# [ 1.57073406 31.420676  ]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [6.2925821276937635, 139.82061615609283] [0.7834296556013408, 29.08117302293807]
# Smiles Weight Mean and Std Dev
# 0.7267834589355222 0.09792896252423383
# Smiles Weight CI
# 0.5397305036060444 0.8824546423579067
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.71980772 40.50203887] [ 2.92788826 44.66787537] [4.06759773 1.10285498]
# (Manually) Weighted RMSE Train
# [ 0.78342966 29.08117302]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.621001149502592, 96.05931113322819] [0.6625202199321034, 16.2759365677258]
# Smiles Weight Mean and Std Dev
# 0.7400183034739515 0.09190452793720831
# Smiles Weight CI
# 0.5485665450781702 0.8897719071837095
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.59590801 35.16577851] [ 2.89068178 38.08271003] [4.85088595 1.08294801]
# (Manually) Weighted RMSE Train
# [ 0.66252022 16.27593657]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [3.163574903687017, 66.21418118831886] [0.5064912676852441, 9.883704345645626]
# Smiles Weight Mean and Std Dev
# 0.739561677799683 0.08187578834684357
# Smiles Weight CI
# 0.5633800409305262 0.8777477256305501
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.52809921 29.12923064] [ 2.87606167 37.51325009] [5.44606321 1.28782152]
# (Manually) Weighted RMSE Train
# [0.50649127 9.88370435]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 1.0] [2.4051596116060825, 50.02930860231669] [0.3332673234128416, 5.223294191922132]
# Smiles Weight Mean and Std Dev
# 0.7371555606055513 0.0845309263910661
# Smiles Weight CI
# 0.5610994675092033 0.8657493119157771
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45171606 24.17993043] [ 2.84880675 37.74002194] [6.30663156 1.56079944]
# (Manually) Weighted RMSE Train
# [0.33326732 5.22329419]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9989572471324296] [2.060149105328779, 37.48401890817279] [0.2740166009767741, 5.447966846357309]
# Smiles Weight Mean and Std Dev
# 0.7341989099036524 0.08054245643130206
# Smiles Weight CI
# 0.5573829859269673 0.8651819020293046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.42980268 23.88421991] [ 2.83921065 37.97026399] [6.60584676 1.58976362]
# (Manually) Weighted RMSE Train
# [0.2740166  5.44796685]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9895724713242962, 0.9979144942648592] [1.6575731710543071, 33.025952786903] [0.3038703835544158, 4.851837134450143]
# Smiles Weight Mean and Std Dev
# 0.7440359630832831 0.08089367591655
# Smiles Weight CI
# 0.5630912120645098 0.8703358354251549
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45268756 22.13599321] [ 2.80466544 38.36991943] [6.19558768 1.73337239]
# (Manually) Weighted RMSE Train
# [0.30387038 4.85183713]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9958289885297185] [1.7374316305493014, 31.552576932225094] [0.2639405412235729, 4.824319914489439]
# Smiles Weight Mean and Std Dev
# 0.7179104251499214 0.09057375750834121
# Smiles Weight CI
# 0.5395223618264368 0.8593450192937887
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.41088026 23.1067272 ] [ 2.79002603 36.55149283] [6.79036272 1.58185504]
# (Manually) Weighted RMSE Train
# [0.26394054 4.82431991]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9906152241918665] [1.4141436997349408, 27.498726273234777] [0.2753708007206948, 5.060587237941086]
# Smiles Weight Mean and Std Dev
# 0.7301577163790614 0.08384590059956813
# Smiles Weight CI
# 0.5516218635883915 0.860746627584316
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.42171952 22.59397156] [ 2.76441326 37.11623175] [6.55509912 1.64274933]
# (Manually) Weighted RMSE Train
# [0.2753708  5.06058724]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9562043795620438, 0.9854014598540146] [1.456014255872339, 25.61392378627268] [0.27128124752273786, 4.895922806355043]
# Smiles Weight Mean and Std Dev
# 0.7220662401081246 0.0881019826323363
# Smiles Weight CI
# 0.5302559805668856 0.852514933789155
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.42459742 22.96082048] [ 2.74680949 36.52807001] [6.46920904 1.59088696]
# (Manually) Weighted RMSE Train
# [0.27128125 4.89592281]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9436913451511991, 0.9791449426485923] [1.2923880929432805, 24.36249109918363] [0.28061504218283334, 5.0645137483891665]
# Smiles Weight Mean and Std Dev
# 0.7348386994092125 0.08075412255618074
# Smiles Weight CI
# 0.5648485941829264 0.8626116066065875
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.43627778 22.6711434 ] [ 2.7605946  37.20708555] [6.32760759 1.64116493]
# (Manually) Weighted RMSE Train
# [0.28061504 5.06451375]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9739311783107404] [1.3609822670479674, 25.219700920077187] [0.28067619465284555, 4.943243674516397]
# Smiles Weight Mean and Std Dev
# 0.7247202678072163 0.08669978398515787
# Smiles Weight CI
# 0.539509074065825 0.8523647340717829
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.44151431 22.98421841] [ 2.75781376 36.63220518] [6.2462613  1.59379817]
# (Manually) Weighted RMSE Train
# [0.28067619 4.94324367]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9676746611053181] [1.2371546325459737, 24.14649171234785] [0.2862220720742567, 4.939414620700676]
# Smiles Weight Mean and Std Dev
# 0.7291316692459797 0.08175087278519153
# Smiles Weight CI
# 0.5595919771016684 0.8533182645515296
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45683718 22.58314583] [ 2.7632933  36.86635983] [6.0487487  1.63247229]
# (Manually) Weighted RMSE Train
# [0.28622207 4.93941462]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9040667361835245, 0.9582898852971846] [1.1603632520340075, 24.40742156249466] [0.2829601746570818, 4.969193136406256]
# Smiles Weight Mean and Std Dev
# 0.7236352468623534 0.08396987828797392
# Smiles Weight CI
# 0.5450578330249893 0.8530142653827583
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45489542 23.06368912] [ 2.7504815  36.41083296] [6.04640398 1.57870811]
# (Manually) Weighted RMSE Train
# [0.28296017 4.96919314]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.954118873826903] [1.1724172140845583, 21.614903108116597] [0.28214054576024694, 4.9651845530054395]
# Smiles Weight Mean and Std Dev
# 0.7253723189114508 0.08516340477286789
# Smiles Weight CI
# 0.5511435735633582 0.8572267676686008
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45399739 23.08942192] [ 2.75054758 36.51718025] [6.05850967 1.58155455]
# (Manually) Weighted RMSE Train
# [0.28214055 4.96518455]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9562043795620438] [1.1619214999627365, 22.006827529450714] [0.2731780525502453, 4.95238241178955]
# Smiles Weight Mean and Std Dev
# 0.7169684416509827 0.08553010650014063
# Smiles Weight CI
# 0.5479873949626602 0.8448602003158956
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45018368 23.33406779] [ 2.75895976 36.08587168] [6.12852022 1.54648868]
# (Manually) Weighted RMSE Train
# [0.27317805 4.95238241]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.959332638164755] [1.2171239766390372, 23.050781220472214] [0.27502308165077116, 5.058729807548529]
# Smiles Weight Mean and Std Dev
# 0.7212591969098449 0.08593334873201071
# Smiles Weight CI
# 0.5319274332797531 0.8513298732710878
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.44796312 23.15656215] [ 2.74920346 36.17755153] [6.13712003 1.56230235]
# (Manually) Weighted RMSE Train
# [0.27502308 5.05872981]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.8800834202294057, 0.948905109489051] [1.1258516252237565, 21.562329568279512] [0.2882837376192361, 5.169518111458066]
# Smiles Weight Mean and Std Dev
# 0.7280064742700535 0.08213005092398547
# Smiles Weight CI
# 0.5554447018929265 0.8593501809583363
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.46093968 23.05634289] [ 2.73887134 36.54060138] [5.94193011 1.58483943]
# (Manually) Weighted RMSE Train
# [0.28828374 5.16951811]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.8686131386861314, 0.9530761209593326] [1.0696629085617064, 20.968199644477878] [0.27256419113063224, 5.016786672416981]
# Smiles Weight Mean and Std Dev
# 0.7171952283419717 0.08398035917846754
# Smiles Weight CI
# 0.5576214829677197 0.8480505010664665
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4508527  23.26430643] [ 2.74161592 35.90538822] [6.08095705 1.54336809]
# (Manually) Weighted RMSE Train
# [0.27256419 5.01678667]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.8769551616266945, 0.9332638164754953] [1.1044430308353559, 20.2877528675228] [0.2739209898850751, 5.065091575835794]
# Smiles Weight Mean and Std Dev
# 0.7229919762699277 0.08463221781880248
# Smiles Weight CI
# 0.5338830962376225 0.8434492469956204
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45736329 23.08451706] [ 2.74888475 36.13616953] [6.0102873  1.56538555]
# (Manually) Weighted RMSE Train
# [0.27392099 5.06509158]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.9363920750782064] [1.1362859431766916, 21.364080738167868] [0.273020414426176, 5.089162377851227]
# Smiles Weight Mean and Std Dev
# 0.7235524211910653 0.08377365914981652
# Smiles Weight CI
# 0.5351328096700143 0.8434632285157911
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.45970985 23.08840135] [ 2.75247534 36.20496243] [5.9874187  1.56810174]
# (Manually) Weighted RMSE Train
# [0.27302041 5.08916238]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.8686131386861314, 0.9395203336809176] [1.0594957879796432, 19.9808405003573] [0.27957338289880757, 5.141338869715546]
# Smiles Weight Mean and Std Dev
# 0.7284582804367191 0.0815824033876152
# Smiles Weight CI
# 0.5555292536179777 0.8522477803273315
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.46481372 23.0011784 ] [ 2.74558822 36.48796137] [5.90685706 1.58635183]
# (Manually) Weighted RMSE Train
# [0.27957338 5.14133887]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.8748696558915537, 0.948905109489051] [1.1463543323941199, 21.858540073839922] [0.2673210370140181, 5.087423177763459]
# Smiles Weight Mean and Std Dev
# 0.7108946365097905 0.09080717477001195
# Smiles Weight CI
# 0.5311594611286283 0.8465749926388578
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.46058741 23.60199153] [ 2.74673434 35.51234701] [5.96354626 1.5046335 ]
# (Manually) Weighted RMSE Train
# [0.26732104 5.08742318]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.8446298227320125, 0.9103232533889468] [0.9559655447487806, 18.34510860065636] [0.27655286808198803, 5.152703819916114]
# Smiles Weight Mean and Std Dev
# 0.724743263245637 0.0766142958680504
# Smiles Weight CI
# 0.569867106694045 0.8402803091429168
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.46881476 23.15755862] [ 2.74679459 36.23240347] [5.85901903 1.56460377]
# (Manually) Weighted RMSE Train
# [0.27655287 5.15270382]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.9311783107403545] [1.0482666480167948, 19.61886579056931] [0.27543536282159337, 5.099806699882802]
# Smiles Weight Mean and Std Dev
# 0.72283635159322 0.08225905918396187
# Smiles Weight CI
# 0.5367337485169755 0.8447441930304777
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47091323 23.41790207] [ 2.74656186 36.13661483] [5.832416   1.54311922]
# (Manually) Weighted RMSE Train
# [0.27543536 5.0998067 ]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.8665276329509907, 0.9447340980187695] [1.1597857578843973, 21.012317086033388] [0.27654701125757947, 5.137323276390892]
# Smiles Weight Mean and Std Dev
# 0.7239760090256806 0.08873126498700312
# Smiles Weight CI
# 0.5365667338045289 0.8517460023398034
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4736831  23.55007005] [ 2.75215102 36.13938143] [5.81011019 1.53457639]
# (Manually) Weighted RMSE Train
# [0.27654701 5.13732328]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.8342022940563086, 0.921793534932221] [0.9888203332094531, 19.534856058567517] [0.2753863092663339, 5.108369199768416]
# Smiles Weight Mean and Std Dev
# 0.7223011756813859 0.08008031609356167
# Smiles Weight CI
# 0.5468248689214906 0.8538034295520015
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47380155 23.54455898] [ 2.74504209 36.0090555 ] [5.79365372 1.5294003 ]
# (Manually) Weighted RMSE Train
# [0.27538631 5.1083692 ]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.9332638164754953] [1.0791747612696516, 21.217248552938457] [0.270395714291741, 5.103618950889647]
# Smiles Weight Mean and Std Dev
# 0.7139284869524934 0.08972119428902427
# Smiles Weight CI
# 0.5430410647823007 0.843817909424955
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47121312 23.8799618 ] [ 2.74604036 35.46392227] [5.82759739 1.48509125]
# (Manually) Weighted RMSE Train
# [0.27039571 5.10361895]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.9468196037539103] [1.1354990319921825, 22.02572586262769] [0.2694317227127029, 5.132553062677586]
# Smiles Weight Mean and Std Dev
# 0.7147986752717008 0.08698959559184248
# Smiles Weight CI
# 0.5323887938636424 0.8372754013840114
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4694666 23.8514275] [ 2.74910572 35.55815926] [5.85580681 1.49081891]
# (Manually) Weighted RMSE Train
# [0.26943172 5.13255306]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.8425443169968717, 0.9249217935349322] [1.0289633003873955, 18.58350367696617] [0.2817309909792369, 5.21162755688473]
# Smiles Weight Mean and Std Dev
# 0.7279520886060219 0.07573889450544082
# Smiles Weight CI
# 0.5524059786985215 0.8493596665868232
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47695198 23.36399073] [ 2.746664   36.39528381] [5.75878523 1.55775117]
# (Manually) Weighted RMSE Train
# [0.28173099 5.21162756]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.8362877997914494, 0.9301355578727841] [1.0516115319289319, 19.603043192504657] [0.2786421492517833, 5.211139192626181]
# Smiles Weight Mean and Std Dev
# 0.7261392791599639 0.08172888177509621
# Smiles Weight CI
# 0.5092084317242112 0.8419262941645789
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47544099 23.48117397] [ 2.74862026 36.16831055] [5.78120166 1.540311  ]
# (Manually) Weighted RMSE Train
# [0.27864215 5.21113919]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.8467153284671532, 0.9322210636079249] [1.019037613126261, 19.84182170906351] [0.26962107640081845, 5.118455927426412]
# Smiles Weight Mean and Std Dev
# 0.7173923327488974 0.08413154346397357
# Smiles Weight CI
# 0.5478553479134336 0.8470784006362486
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.46958861 23.81471443] [ 2.74661491 35.66921042] [5.84898116 1.49778031]
# (Manually) Weighted RMSE Train
# [0.26962108 5.11845593]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.835245046923879, 0.9259645464025026] [0.992394716715943, 19.12043049682696] [0.2727006787046008, 5.119466619341028]
# Smiles Weight Mean and Std Dev
# 0.7222202457323484 0.07761083848762308
# Smiles Weight CI
# 0.5587248922338569 0.8422450797302306
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47149003 23.61979749] [ 2.74767337 35.92437032] [5.82763839 1.5209432 ]
# (Manually) Weighted RMSE Train
# [0.27270068 5.11946662]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.8456725755995829, 0.9186652763295099] [1.0268102385606719, 19.324158625710947] [0.2713292977168702, 5.170028272713093]
# Smiles Weight Mean and Std Dev
# 0.7206892329336387 0.08310781121509661
# Smiles Weight CI
# 0.5474104013204524 0.8531546240470115
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47276972 23.59399889] [ 2.74795898 35.85906028] [5.81246822 1.51983818]
# (Manually) Weighted RMSE Train
# [0.2713293  5.17002827]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.8435870698644421, 0.9238790406673618] [1.000928060758896, 18.973022519398636] [0.2742627624543061, 5.150293904583084]
# Smiles Weight Mean and Std Dev
# 0.7221916589768006 0.07930966052352717
# Smiles Weight CI
# 0.5509596590846251 0.8392087186627039
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4750761  23.50029712] [ 2.74848748 35.96674893] [5.78536254 1.5304806 ]
# (Manually) Weighted RMSE Train
# [0.27426276 5.1502939 ]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.8237747653806048, 0.9124087591240876] [0.9717889242988978, 18.022592194159685] [0.269138791493661, 5.092981392568156]
# Smiles Weight Mean and Std Dev
# 0.7143244413922298 0.07464903829079061
# Smiles Weight CI
# 0.5677585590569266 0.8328764843992238
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47301943 23.70628176] [ 2.75000929 35.55839689] [5.81373428 1.49995673]
# (Manually) Weighted RMSE Train
# [0.26913879 5.09298139]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.8237747653806048, 0.8988529718456726] [0.9939911932482445, 18.051384412522694] [0.2776552261543828, 5.158281256834013]
# Smiles Weight Mean and Std Dev
# 0.7253646875271552 0.0782375404366856
# Smiles Weight CI
# 0.5529201237261234 0.8395830964205082
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48006093 23.30615578] [ 2.74965793 36.2077238 ] [5.72772693 1.55356911]
# (Manually) Weighted RMSE Train
# [0.27765523 5.15828126]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.8467153284671532, 0.927007299270073] [1.061251478876282, 20.410736070143393] [0.27759184886153676, 5.107257251871138]
# Smiles Weight Mean and Std Dev
# 0.7247904125944722 0.08342983477383849
# Smiles Weight CI
# 0.536974092656548 0.8443644731133925
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48137105 23.28837474] [ 2.75071295 36.20912261] [5.71432978 1.55481535]
# (Manually) Weighted RMSE Train
# [0.27759185 5.10725725]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.8258602711157456, 0.9374348279457768] [1.0421645906712869, 20.276198250935593] [0.26962654440754114, 5.110470839128022]
# Smiles Weight Mean and Std Dev
# 0.7130703534515668 0.08233076399454202
# Smiles Weight CI
# 0.5285301781182226 0.8374744558602311
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47746912 23.67579579] [ 2.74860108 35.51964259] [5.75660491 1.50025127]
# (Manually) Weighted RMSE Train
# [0.26962654 5.11047084]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.8415015641293013, 0.9259645464025026] [1.0859248844477527, 19.16725109048436] [0.2710309874027746, 5.0938528261167]
# Smiles Weight Mean and Std Dev
# 0.7182147511104635 0.08509844900857821
# Smiles Weight CI
# 0.5377040155185914 0.8500613710109947
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48049937 23.51477976] [ 2.75396597 35.8325315 ] [5.7314664 1.5238302]
# (Manually) Weighted RMSE Train
# [0.27103099 5.09385283]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.8321167883211679, 0.9249217935349322] [1.016723031019594, 18.544661077297572] [0.2699122047163806, 5.063317496624129]
# Smiles Weight Mean and Std Dev
# 0.7137400796139702 0.08208262871454028
# Smiles Weight CI
# 0.5449244320450043 0.8429566188990943
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48183619 23.58093385] [ 2.75139394 35.65874454] [5.71022684 1.51218543]
# (Manually) Weighted RMSE Train
# [0.2699122 5.0633175]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.8258602711157456, 0.9311783107403545] [1.0770668065399367, 19.603291685367903] [0.26980740730182856, 5.094901191693473]
# Smiles Weight Mean and Std Dev
# 0.7167012903533452 0.08390326450187006
# Smiles Weight CI
# 0.5235502901854536 0.8352088352298084
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48227751 23.45821581] [ 2.75879    35.86159749] [5.72033721 1.52874361]
# (Manually) Weighted RMSE Train
# [0.26980741 5.09490119]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.8321167883211679, 0.9186652763295099] [1.0546897033508873, 19.16908069195694] [0.2693018640156981, 5.08194949854319]
# Smiles Weight Mean and Std Dev
# 0.7127728583918138 0.08256946519804849
# Smiles Weight CI
# 0.5416905729757966 0.848305249927463
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4820632  23.52525689] [ 2.75635111 35.6283131 ] [5.71782109 1.51447074]
# (Manually) Weighted RMSE Train
# [0.26930186 5.0819495 ]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.8394160583941606, 0.9290928050052137] [1.1064000454461975, 20.06396018916839] [0.270580002455935, 5.067416810077]
# Smiles Weight Mean and Std Dev
# 0.7153869492876527 0.08906934006744675
# Smiles Weight CI
# 0.5427513089356812 0.8423302501542009
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48617765 23.38684704] [ 2.76266169 35.78720999] [5.68241193 1.53022808]
# (Manually) Weighted RMSE Train
# [0.27058    5.06741681]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.9124087591240876] [1.059797509650203, 17.913719543120656] [0.2765930501054068, 5.14109743043868]
# Smiles Weight Mean and Std Dev
# 0.7221623449583059 0.07917087816655222
# Smiles Weight CI
# 0.5597304773674985 0.8369508224302932
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49388807 23.14309515] [ 2.76011763 36.17943508] [5.58854895 1.56329285]
# (Manually) Weighted RMSE Train
# [0.27659305 5.14109743]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.8154327424400417, 0.9144942648592284] [1.0014819872714082, 17.91078301870037] [0.2720994327927356, 5.084644969694329]
# Smiles Weight Mean and Std Dev
# 0.714348924815248 0.07850181348492713
# Smiles Weight CI
# 0.5485921425724222 0.8385661134914454
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49024885 23.37696441] [ 2.7565258  35.70635076] [5.62270736 1.52741605]
# (Manually) Weighted RMSE Train
# [0.27209943 5.08464497]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.8331595411887383, 0.9280500521376434] [1.1163709067434908, 19.243012920968884] [0.2702259583652755, 5.114200100984921]
# Smiles Weight Mean and Std Dev
# 0.7069216298985265 0.0894968888180804
# Smiles Weight CI
# 0.5115577799174317 0.839365392956174
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48813286 23.57724743] [ 2.76224174 35.30007832] [5.65879083 1.49720948]
# (Manually) Weighted RMSE Train
# [0.27022596 5.1142001 ]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.8373305526590198, 0.9363920750782064] [1.0820179015875273, 20.1778729565885] [0.2717192720698606, 5.105291189418857]
# Smiles Weight Mean and Std Dev
# 0.7158638278379053 0.08677055612434156
# Smiles Weight CI
# 0.5227926676019835 0.8467556397944865
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49167495 23.30810876] [ 2.7640603  35.80901955] [5.62172283 1.53633312]
# (Manually) Weighted RMSE Train
# [0.27171927 5.10529119]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.8196037539103233, 0.9228362877997914] [1.0235927629648562, 18.76269874207872] [0.2715220760489161, 5.1199326899676665]
# Smiles Weight Mean and Std Dev
# 0.7159066478045275 0.08141914566002903
# Smiles Weight CI
# 0.5424676414123751 0.8440765847069908
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49038078 23.22961403] [ 2.76300925 35.78801715] [5.63441587 1.5406204 ]
# (Manually) Weighted RMSE Train
# [0.27152208 5.11993269]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.8394160583941606, 0.9238790406673618] [1.0778613217135282, 18.666558755997684] [0.27024084173710683, 5.107511075647322]
# Smiles Weight Mean and Std Dev
# 0.710794689979468 0.08334507364196155
# Smiles Weight CI
# 0.5397542176546869 0.8419491809542021
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48895185 23.35839663] [ 2.76597011 35.52194091] [5.65693762 1.52073541]
# (Manually) Weighted RMSE Train
# [0.27024084 5.10751108]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.8415015641293013, 0.9311783107403545] [1.1461683579882234, 19.566963036124076] [0.2756180421529505, 5.084745288883236]
# Smiles Weight Mean and Std Dev
# 0.7193604693431025 0.08569869578172777
# Smiles Weight CI
# 0.5034843099916895 0.8374592172283962
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49463609 23.12580963] [ 2.76275503 36.08099036] [5.58542958 1.56020442]
# (Manually) Weighted RMSE Train
# [0.27561804 5.08474529]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.821689259645464, 0.9280500521376434] [1.0686302245237091, 18.725770289147107] [0.2707553714640649, 5.086022260793745]
# Smiles Weight Mean and Std Dev
# 0.7127631411418042 0.08328761299950664
# Smiles Weight CI
# 0.5157090949062489 0.8405885899522655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.48987247 23.40286951] [ 2.76709191 35.69607645] [5.64859642 1.52528631]
# (Manually) Weighted RMSE Train
# [0.27075537 5.08602226]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.8362877997914494, 0.9124087591240876] [1.0762833994879752, 18.946764975526257] [0.274361230277667, 5.133891410310629]
# Smiles Weight Mean and Std Dev
# 0.7220307472681959 0.08586712031743171
# Smiles Weight CI
# 0.5405627349214269 0.8456079052491798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49418415 23.07848884] [ 2.7664859  36.18361463] [5.59808709 1.56785026]
# (Manually) Weighted RMSE Train
# [0.27436123 5.13389141]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.8248175182481752, 0.9332638164754953] [1.0237058866453705, 19.716495668191218] [0.2711886721286677, 5.090613041982614]
# Smiles Weight Mean and Std Dev
# 0.7147365234573668 0.08320899234731023
# Smiles Weight CI
# 0.544399173661162 0.8417293044745753
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49049026 23.2097804 ] [ 2.76035393 35.78426084] [5.62774461 1.54177507]
# (Manually) Weighted RMSE Train
# [0.27118867 5.09061304]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.8039624608967675, 0.9176225234619395] [0.994692878755542, 17.9229806684858] [0.27297686408445576, 5.0971469209612374]
# Smiles Weight Mean and Std Dev
# 0.7172484582230234 0.08402084132599616
# Smiles Weight CI
# 0.5296367011400587 0.8389334598785326
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49168683 23.03470113] [ 2.75647169 35.97525324] [5.6061532  1.56178511]
# (Manually) Weighted RMSE Train
# [0.27297686 5.09714692]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.8164754953076121, 0.9124087591240876] [1.0527058538701277, 18.362400156127222] [0.2776304409432862, 5.158030605761081]
# Smiles Weight Mean and Std Dev
# 0.7240392489815306 0.08315295922757046
# Smiles Weight CI
# 0.5419495950274208 0.8408278302434088
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49753663 22.85938844] [ 2.76351169 36.2915593 ] [5.55438838 1.58759975]
# (Manually) Weighted RMSE Train
# [0.27763044 5.15803061]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.8237747653806048, 0.9176225234619395] [1.0286131716083184, 18.31100275346837] [0.28140125152328027, 5.147412518817807]
# Smiles Weight Mean and Std Dev
# 0.727355470102259 0.08306135787919193
# Smiles Weight CI
# 0.5585940420317944 0.8498205605279324
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50151558 22.79525285] [ 2.76239905 36.53297453] [5.50810219 1.60265713]
# (Manually) Weighted RMSE Train
# [0.28140125 5.14741252]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.8112617309697602, 0.9009384775808134] [0.9986880789915701, 17.50251440442606] [0.2718513030613156, 5.086783664763992]
# Smiles Weight Mean and Std Dev
# 0.7160851328686387 0.08196746074204782
# Smiles Weight CI
# 0.557821766832486 0.8492932112862848
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4952365  23.18004288] [ 2.7636259  35.90641525] [5.58041637 1.54902281]
# (Manually) Weighted RMSE Train
# [0.2718513  5.08678366]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.8258602711157456, 0.9259645464025026] [1.063941916107297, 18.593511109855505] [0.270557427092536, 5.090041030496706]
# Smiles Weight Mean and Std Dev
# 0.7147538184819826 0.08789691476072324
# Smiles Weight CI
# 0.529866369108267 0.8447670649520279
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49353885 23.1957861 ] [ 2.763997   35.82829832] [5.60036356 1.54460375]
# (Manually) Weighted RMSE Train
# [0.27055743 5.09004103]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.9124087591240876] [1.0141802236915518, 18.67638138491677] [0.2895094464300811, 5.201682693679879]
# Smiles Weight Mean and Std Dev
# 0.7329226519337622 0.0813581729412936
# Smiles Weight CI
# 0.5594044612555209 0.8611075942319731
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50762127 22.61820376] [ 2.76083942 36.94684025] [5.438778   1.63350019]
# (Manually) Weighted RMSE Train
# [0.28950945 5.20168269]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.8258602711157456, 0.9384775808133472] [1.062986600788276, 19.351947280081237] [0.27076119859943293, 5.0553930892454275]
# Smiles Weight Mean and Std Dev
# 0.7151010497940135 0.08593840759308799
# Smiles Weight CI
# 0.5414586177084053 0.847057945504989
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.4922174  23.16919004] [ 2.76807953 35.86055049] [5.62369295 1.54776884]
# (Manually) Weighted RMSE Train
# [0.2707612  5.05539309]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.8164754953076121, 0.9228362877997914] [1.0490002401382588, 18.72210117031614] [0.27298920458501763, 5.050818663221578]
# Smiles Weight Mean and Std Dev
# 0.7194753878376429 0.0834357455919036
# Smiles Weight CI
# 0.5394152136388014 0.8453086204202995
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49516441 23.02507837] [ 2.76618483 36.17348891] [5.58639675 1.57104737]
# (Manually) Weighted RMSE Train
# [0.2729892  5.05081866]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.8258602711157456, 0.940563086548488] [1.1081964525929027, 18.79104552961033] [0.2697297711585051, 5.076696518514035]
# Smiles Weight Mean and Std Dev
# 0.708814026190125 0.09001974239429879
# Smiles Weight CI
# 0.529764831960495 0.8407138457725216
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49089643 23.32717426] [ 2.77081746 35.53661184] [5.64440339 1.52339977]
# (Manually) Weighted RMSE Train
# [0.26972977 5.07669652]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.7966631908237748, 0.8884254431699687] [0.9434400723474234, 16.63396561166068] [0.27617587352660533, 5.097283900244583]
# Smiles Weight Mean and Std Dev
# 0.7227296444153369 0.07700623590413407
# Smiles Weight CI
# 0.5873341920681444 0.8391502431279728
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.49924879 22.88688588] [ 2.77079341 36.31757107] [5.54992515 1.58682886]
# (Manually) Weighted RMSE Train
# [0.27617587 5.0972839 ]
#
#
# done for fold0
# train_width[0.9986880789915701, 17.50251440442606]
# smiles_weight0.7160851328686387
# rmse_train[0.14404157777897075, 0.11787057276649268]
# smiles_weight_ci[0.557821766832486, 0.8492932112862848]
# CPU times: user 45min 24s, sys: 29min 34s, total: 1h 14min 59s
# Wall time: 13min 47s

# %%
with open("..//Data/returned_stuff_config3.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.65, epochs = 1000, fudging_var = 1e-5)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.8070907194994786, 0.9113660062565172] [1.020966344241404, 18.416191370460943] [0.29896165969091104, 5.9679695041898855]
# Smiles Weight Mean and Std Dev
# 0.7234595502438619 0.07979459344528
# Smiles Weight CI
# 0.5646927025365693 0.8500040221039681
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50916817 24.10410353] [ 2.72977589 35.66564757] [5.36124619 1.47965045]
# (Manually) Weighted RMSE Train
# [0.29896166 5.9679695 ]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.8008342022940563, 0.927007299270073] [0.9932819077258086, 19.46323327218126] [0.28606686327936676, 5.702136158446789]
# Smiles Weight Mean and Std Dev
# 0.7176486691097596 0.08727457481860795
# Smiles Weight CI
# 0.5299233147822858 0.8502930021354862
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50597373 24.96766005] [ 2.69946855 34.87303719] [5.33519511 1.39672829]
# (Manually) Weighted RMSE Train
# [0.28606686 5.70213616]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.8154327424400417, 0.9447340980187695] [0.9727924895926527, 20.115002096183126] [0.2778663953163571, 5.491651285572931]
# Smiles Weight Mean and Std Dev
# 0.7158858896257555 0.08363958746992049
# Smiles Weight CI
# 0.5421684163938241 0.84533444706125
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.5093502  25.76211137] [ 2.66273904 34.35886123] [5.22771764 1.33369741]
# (Manually) Weighted RMSE Train
# [0.2778664  5.49165129]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.9416058394160584] [0.9259773950114546, 19.35885259724734] [0.27099253219914965, 5.350158090137586]
# Smiles Weight Mean and Std Dev
# 0.7132456783601977 0.08540199704300691
# Smiles Weight CI
# 0.5304664598284912 0.8348431092454468
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.52079464 26.40898447] [ 2.62023262 33.8448186 ] [5.03122041 1.28156456]
# (Manually) Weighted RMSE Train
# [0.27099253 5.35015809]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.8133472367049009, 0.9363920750782064] [0.8850042221614477, 18.985540351988696] [0.26548136712540493, 5.2544530024536185]
# Smiles Weight Mean and Std Dev
# 0.7118936455087914 0.08157137891975
# Smiles Weight CI
# 0.5434939058991926 0.833898767772825
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.53671788 26.96326705] [ 2.59106712 33.38163406] [4.8276147  1.23804115]
# (Manually) Weighted RMSE Train
# [0.26548137 5.254453  ]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.9363920750782064] [0.9079172030086523, 19.658341149006727] [0.26157654258495167, 5.253305434711149]
# Smiles Weight Mean and Std Dev
# 0.7168336082790799 0.08083089634994614
# Smiles Weight CI
# 0.5232111531763499 0.8258833779699013
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.54452411 27.37553803] [ 2.55786797 33.37616835] [4.69743752 1.2191968 ]
# (Manually) Weighted RMSE Train
# [0.26157654 5.25330543]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.8279457768508863, 0.9416058394160584] [0.8743409082218577, 19.67506656431327] [0.2542604697345209, 5.123978503364917]
# Smiles Weight Mean and Std Dev
# 0.7108711929002577 0.08258560824832256
# Smiles Weight CI
# 0.5292963319590922 0.8464977515024973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.56508919 28.07217027] [ 2.52714705 32.72079028] [4.4721207  1.16559532]
# (Manually) Weighted RMSE Train
# [0.25426047 5.1239785 ]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.8227320125130344, 0.9363920750782064] [0.8155433707959986, 19.761749585974716] [0.24952481465884233, 4.938108749325446]
# Smiles Weight Mean and Std Dev
# 0.6999219235260087 0.08185750405895574
# Smiles Weight CI
# 0.5317476314544931 0.8254687568841845
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.59518156 28.83813039] [ 2.48309664 31.74449416] [4.17199863 1.10078198]
# (Manually) Weighted RMSE Train
# [0.24952481 4.93810875]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.8321167883211679, 0.935349322210636] [0.8130502966366333, 19.60267408475085] [0.24476555008246823, 4.978104405013987]
# Smiles Weight Mean and Std Dev
# 0.7073089835722168 0.07787118176378179
# Smiles Weight CI
# 0.5298752505800549 0.8171446716407568
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.59820174 29.08582809] [ 2.4594548  31.96957761] [4.11141365 1.09914621]
# (Manually) Weighted RMSE Train
# [0.24476555 4.97810441]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.8498435870698644, 0.9290928050052137] [0.7965426129718116, 19.87576889050234] [0.23913777802599306, 4.8169300246853135]
# Smiles Weight Mean and Std Dev
# 0.700087804412595 0.07878690167076181
# Smiles Weight CI
# 0.5255751179130952 0.8162372734510751
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.62824259 29.78934326] [ 2.42667796 31.220944  ] [3.86264479 1.04805748]
# (Manually) Weighted RMSE Train
# [0.23913778 4.81693002]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.8446298227320125, 0.9186652763295099] [0.7717738043620997, 19.20397345963338] [0.23483992250205765, 4.781488890738841]
# Smiles Weight Mean and Std Dev
# 0.7000139094935877 0.077759828594459
# Smiles Weight CI
# 0.5243478536200219 0.8266228370885986
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.64541111 30.26899134] [ 2.40039812 30.93509437] [3.71917696 1.02200612]
# (Manually) Weighted RMSE Train
# [0.23483992 4.78148889]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.8654848800834203, 0.9259645464025026] [0.7899246210684635, 20.10670601502389] [0.23246163133066008, 4.869367368789115]
# Smiles Weight Mean and Std Dev
# 0.7048904845211149 0.07810230587067754
# Smiles Weight CI
# 0.5331668295428755 0.8388536569211077
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.65248011 30.55380138] [ 2.38737314 31.05938358] [3.65892093 1.01654728]
# (Manually) Weighted RMSE Train
# [0.23246163 4.86936737]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.921793534932221] [0.8247463969874209, 21.00243304129296] [0.22860167263071776, 4.825041464185966]
# Smiles Weight Mean and Std Dev
# 0.701592990982856 0.0810380463705602
# Smiles Weight CI
# 0.5225006984850957 0.8172366387586633
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67659209 31.09560878] [ 2.36579266 30.64899128] [3.49663067 0.98563728]
# (Manually) Weighted RMSE Train
# [0.22860167 4.82504146]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.9343065693430657] [0.8591179803570702, 22.751009015426675] [0.22678361834034755, 4.5189911397570794]
# Smiles Weight Mean and Std Dev
# 0.6814752852210303 0.08769957539220591
# Smiles Weight CI
# 0.500491386039081 0.8285847250862409
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.72799703 31.99729449] [ 2.32317386 29.18273169] [3.19118591 0.91203748]
# (Manually) Weighted RMSE Train
# [0.22678362 4.51899114]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.9238790406673618] [0.7602135029468018, 20.95931949863426] [0.22576127186591663, 4.8097350734115185]
# Smiles Weight Mean and Std Dev
# 0.6993269770033292 0.07764306926011477
# Smiles Weight CI
# 0.5269528996018916 0.826107433155487
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7111993  32.00585371] [ 2.32054348 30.21111652] [3.26285961 0.94392472]
# (Manually) Weighted RMSE Train
# [0.22576127 4.80973507]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.921793534932221] [0.7349804337080927, 20.57784286423316] [0.2204898916295424, 4.5887705893017054]
# Smiles Weight Mean and Std Dev
# 0.6900238110398185 0.0770164645686986
# Smiles Weight CI
# 0.5300771773752161 0.8125560832860016
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.74435654 32.69462724] [ 2.28654861 29.47975608] [3.07184595 0.90166974]
# (Manually) Weighted RMSE Train
# [0.22048989 4.58877059]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.927007299270073] [0.8176357938446711, 23.337285556557898] [0.22061524934761897, 4.788255038714545]
# Smiles Weight Mean and Std Dev
# 0.6959810965202997 0.0825654679441096
# Smiles Weight CI
# 0.5157857973005967 0.824233968893764
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.74812367 32.92763664] [ 2.27530044 29.71751891] [3.04134267 0.90250993]
# (Manually) Weighted RMSE Train
# [0.22061525 4.78825504]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.927007299270073] [0.7919564187654904, 21.267185328956536] [0.21730930191992687, 4.699587764476424]
# Smiles Weight Mean and Std Dev
# 0.6906569896758504 0.08053524872057445
# Smiles Weight CI
# 0.5316350292972576 0.8232086219091235
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7730855  33.47083852] [ 2.24906896 29.28642615] [2.90921117 0.87498334]
# (Manually) Weighted RMSE Train
# [0.2173093  4.69958776]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9176225234619395] [0.7551991777625416, 21.234012799822978] [0.21416800213872134, 4.550688502011618]
# Smiles Weight Mean and Std Dev
# 0.6834345427825398 0.07697029213873571
# Smiles Weight CI
# 0.5224781318313314 0.8080156614815185
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80200577 33.95848766] [ 2.22124119 28.76835408] [2.76960749 0.84716241]
# (Manually) Weighted RMSE Train
# [0.214168  4.5506885]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.9259645464025026] [0.8027922765031661, 22.763498603199537] [0.21596722091269546, 4.77209048523043]
# Smiles Weight Mean and Std Dev
# 0.6900542551388839 0.07859329302099657
# Smiles Weight CI
# 0.5164976554324296 0.8179701320123011
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80416848 34.09394706] [ 2.21575001 29.05924537] [2.75533061 0.85232858]
# (Manually) Weighted RMSE Train
# [0.21596722 4.77209049]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9113660062565172, 0.9207507820646507] [0.737445909937904, 21.468633508955698] [0.2144882646188361, 4.792928990381132]
# Smiles Weight Mean and Std Dev
# 0.6876896797781101 0.07785478483986497
# Smiles Weight CI
# 0.5279442952304833 0.8103049738031746
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82400829 34.51585782] [ 2.19471367 28.84038832] [2.66346067 0.83556922]
# (Manually) Weighted RMSE Train
# [0.21448826 4.79292899]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.927007299270073] [0.7448708318832523, 21.675918036203335] [0.21600949491524024, 4.993650142357414]
# Smiles Weight Mean and Std Dev
# 0.6887012766095336 0.07578025202298141
# Smiles Weight CI
# 0.5261745147125961 0.8046338049506495
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83569199 34.79949382] [ 2.18026352 28.85684852] [2.60893193 0.82923185]
# (Manually) Weighted RMSE Train
# [0.21600949 4.99365014]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9311783107403545] [0.7212677299268577, 21.494396473082762] [0.21050233181185454, 4.756975115872911]
# Smiles Weight Mean and Std Dev
# 0.6817678594003674 0.07706602661186597
# Smiles Weight CI
# 0.5294474688300861 0.8109433099008437
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86330299 35.13562123] [ 2.15854152 28.37922533] [2.50032902 0.80770524]
# (Manually) Weighted RMSE Train
# [0.21050233 4.75697512]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9290928050052137] [0.7634509426099827, 22.027114108916507] [0.21611114209583454, 5.146290017292768]
# Smiles Weight Mean and Std Dev
# 0.6883220582240042 0.0796379718746106
# Smiles Weight CI
# 0.5191764987818613 0.8146344979648259
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86103159 35.2805341 ] [ 2.15189278 28.71997324] [2.49920307 0.81404587]
# (Manually) Weighted RMSE Train
# [0.21611114 5.14629002]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.935349322210636] [0.7972238199747873, 23.513500096279614] [0.21273468662109024, 5.055046406666137]
# Smiles Weight Mean and Std Dev
# 0.6847177439401805 0.08460014185644056
# Smiles Weight CI
# 0.512056681627415 0.8183126225957773
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88247396 35.56195898] [ 2.13621308 28.44228172] [2.42070949 0.79979513]
# (Manually) Weighted RMSE Train
# [0.21273469 5.05504641]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9290928050052137] [0.7437235068759166, 22.57380559947249] [0.21470537412336685, 5.233904639329844]
# Smiles Weight Mean and Std Dev
# 0.6871291638518316 0.08040774061267295
# Smiles Weight CI
# 0.5042097316025821 0.8034810015703041
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89092205 35.72146266] [ 2.12574562 28.53617106] [2.38600631 0.79885226]
# (Manually) Weighted RMSE Train
# [0.21470537 5.23390464]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9280500521376434] [0.7836908953244536, 22.986740592909936] [0.21467591722091892, 5.266082304260168]
# Smiles Weight Mean and Std Dev
# 0.6876681787668304 0.08170464098085703
# Smiles Weight CI
# 0.5248048353743967 0.8170887649557143
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90468081 35.72621536] [ 2.11312244 28.54814786] [2.33576574 0.79908122]
# (Manually) Weighted RMSE Train
# [0.21467592 5.2660823 ]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9176225234619395] [0.725248431005063, 20.345648762524394] [0.21982597408596352, 5.592188564380871]
# Smiles Weight Mean and Std Dev
# 0.6928488752272238 0.0751348481030551
# Smiles Weight CI
# 0.5383646516326493 0.811650460140349
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90891    35.71981987] [ 2.11590626 28.78742813] [2.32796016 0.8059231 ]
# (Manually) Weighted RMSE Train
# [0.21982597 5.59218856]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9249217935349322] [0.7601615911284321, 21.981334500124895] [0.20555771668861372, 4.7055473656118565]
# Smiles Weight Mean and Std Dev
# 0.676009587668676 0.07809873315856428
# Smiles Weight CI
# 0.5183344113747353 0.8043839061749899
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.95516771 36.17199077] [ 2.07089255 27.56707042] [2.16809312 0.76211095]
# (Manually) Weighted RMSE Train
# [0.20555772 4.70554737]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.9301355578727841] [0.7920813002084217, 22.416029713315933] [0.20819546906402095, 5.018348242333109]
# Smiles Weight Mean and Std Dev
# 0.681921040542632 0.07961847991536251
# Smiles Weight CI
# 0.5176464947435596 0.8190629518541828
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.96033556 36.22114887] [ 2.07272547 27.80589172] [2.1583346  0.76767007]
# (Manually) Weighted RMSE Train
# [0.20819547 5.01834824]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9301355578727841] [0.7546048619994199, 22.501493112014497] [0.21519903483663017, 5.4241380531123005]
# Smiles Weight Mean and Std Dev
# 0.6880826514500022 0.07586066174766001
# Smiles Weight CI
# 0.5046658217275052 0.8047381690473623
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.963864   36.29147778] [ 2.07035513 28.15439242] [2.14797433 0.77578523]
# (Manually) Weighted RMSE Train
# [0.21519903 5.42413805]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.9280500521376434] [0.7817708096574048, 22.568824040938544] [0.2099227175305401, 5.252347430187825]
# Smiles Weight Mean and Std Dev
# 0.6846710353207419 0.08071741221716797
# Smiles Weight CI
# 0.5103192030515307 0.8112802346305328
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.98611046 36.45696999] [ 2.04790968 27.82933191] [2.07675485 0.76334736]
# (Manually) Weighted RMSE Train
# [0.20992272 5.25234743]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9249217935349322] [0.76958456006829, 22.605968434675507] [0.20555089372191124, 5.020926743519374]
# Smiles Weight Mean and Std Dev
# 0.679348276863646 0.08050912503686762
# Smiles Weight CI
# 0.5017250298114393 0.8039301028782064
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00613746 36.71932997] [ 2.02753828 27.44053753] [2.01517025 0.74730496]
# (Manually) Weighted RMSE Train
# [0.20555089 5.02092674]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9228362877997914] [0.752345776077844, 20.992101769934653] [0.20508739537307452, 5.050451216708497]
# Smiles Weight Mean and Std Dev
# 0.6788081037254757 0.07720679309564536
# Smiles Weight CI
# 0.5288109995730477 0.8064526600353692
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.02102569 36.79642599] [ 2.02038785 27.33032199] [1.97878258 0.74274393]
# (Manually) Weighted RMSE Train
# [0.2050874  5.05045122]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9238790406673618] [0.7777601790295234, 22.381514483708887] [0.202559263404239, 4.899290814988627]
# Smiles Weight Mean and Std Dev
# 0.675692180789152 0.08288081833777708
# Smiles Weight CI
# 0.48932118204668923 0.8052290714700266
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.03824905 36.8997037 ] [ 1.99874965 27.06182768] [1.9251158  0.73338875]
# (Manually) Weighted RMSE Train
# [0.20255926 4.89929081]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9051094890510949, 0.9249217935349322] [0.7613766155602913, 22.889930103690563] [0.20127883320929646, 4.892266841564983]
# Smiles Weight Mean and Std Dev
# 0.6747986238379868 0.0785649893448171
# Smiles Weight CI
# 0.5145527615357954 0.8032030824379967
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05163065 37.04285415] [ 1.97534459 26.91102558] [1.87836345 0.72648359]
# (Manually) Weighted RMSE Train
# [0.20127883 4.89226684]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.9207507820646507] [0.7373257735941271, 21.452537559223217] [0.2048042867849965, 5.120890709667931]
# Smiles Weight Mean and Std Dev
# 0.6770522323995547 0.07813430376159244
# Smiles Weight CI
# 0.5116779245939062 0.7959652677403998
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.06187275 37.12483048] [ 1.96942618 26.99366263] [1.85467249 0.72710534]
# (Manually) Weighted RMSE Train
# [0.20480429 5.12089071]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.9228362877997914] [0.743524636758579, 21.69963463755778] [0.20474287056117652, 5.1906623626951705]
# Smiles Weight Mean and Std Dev
# 0.6773174619090213 0.08183115162956586
# Smiles Weight CI
# 0.5239166378743451 0.8129635043972596
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.0664192  37.21314361] [ 1.96799742 26.97138917] [1.84542573 0.72478126]
# (Manually) Weighted RMSE Train
# [0.20474287 5.19066236]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9051094890510949, 0.9165797705943691] [0.742843858879257, 21.31313182502003] [0.21055608610911547, 5.54868851408574]
# Smiles Weight Mean and Std Dev
# 0.6829416579986564 0.07756868162570983
# Smiles Weight CI
# 0.5126981429909017 0.7941443933823336
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05913806 37.2308513 ] [ 1.9763805  27.24899235] [1.86602727 0.73189281]
# (Manually) Weighted RMSE Train
# [0.21055609 5.54868851]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.927007299270073] [0.8269405598269418, 24.082804479018346] [0.20844311352418446, 5.454438865050623]
# Smiles Weight Mean and Std Dev
# 0.6809203760282316 0.08805500081141743
# Smiles Weight CI
# 0.48900571410500293 0.8156993914851944
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.06749798 37.34809782] [ 1.96898744 27.10537745] [1.84448821 0.72574988]
# (Manually) Weighted RMSE Train
# [0.20844311 5.45443887]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.9176225234619395] [0.7448314580813628, 21.86514656604437] [0.20146386081085016, 5.196411966295459]
# Smiles Weight Mean and Std Dev
# 0.6758063029792029 0.07899015080955837
# Smiles Weight CI
# 0.5129119302492791 0.8067637102084356
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08265753 37.65039885] [ 1.95220265 26.70569207] [1.80315805 0.70930702]
# (Manually) Weighted RMSE Train
# [0.20146386 5.19641197]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9155370177267987] [0.7343660265008992, 21.3342363438074] [0.1982886070429026, 4.939477454338924]
# Smiles Weight Mean and Std Dev
# 0.6721645656795611 0.07857142415502325
# Smiles Weight CI
# 0.5168622658963 0.7911156837640262
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.095439   37.85334398] [ 1.9397763  26.35531977] [1.77077527 0.69624812]
# (Manually) Weighted RMSE Train
# [0.19828861 4.93947745]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.9155370177267987] [0.7508931262494951, 22.540529119188523] [0.20944699196919647, 5.723957806823204]
# Smiles Weight Mean and Std Dev
# 0.6843213670194718 0.08098486302584806
# Smiles Weight CI
# 0.513205492179482 0.8076786750766762
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08168752 37.8240813 ] [ 1.96717151 27.07435638] [1.81861348 0.7157968 ]
# (Manually) Weighted RMSE Train
# [0.20944699 5.72395781]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9144942648592284] [0.7904014964813182, 22.885006426814154] [0.19830539658035903, 5.103714627340272]
# Smiles Weight Mean and Std Dev
# 0.6753607568586009 0.08263184208764791
# Smiles Weight CI
# 0.5110492334120301 0.8071847641363973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.10002773 38.05922953] [ 1.94934372 26.338887  ] [1.77208599 0.69204993]
# (Manually) Weighted RMSE Train
# [0.1983054  5.10371463]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.9144942648592284] [0.7645107364381486, 22.47532755937941] [0.20957674545217925, 5.9612008961866785]
# Smiles Weight Mean and Std Dev
# 0.6862337607229108 0.08023441481359081
# Smiles Weight CI
# 0.5131698935483721 0.8173035776195576
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08480222 38.07579179] [ 1.9618211  26.98704022] [1.80845971 0.70877161]
# (Manually) Weighted RMSE Train
# [0.20957675 5.9612009 ]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9165797705943691] [0.748887082556883, 22.467985426122603] [0.20630968029057983, 5.829528457813905]
# Smiles Weight Mean and Std Dev
# 0.6845383047025777 0.07845610019282703
# Smiles Weight CI
# 0.513670244054065 0.8051607885483937
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09205706 38.21771574] [ 1.95704025 26.73720679] [1.79206776 0.69960243]
# (Manually) Weighted RMSE Train
# [0.20630968 5.82952846]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9228362877997914] [0.790183695663715, 23.192961306405174] [0.19713481206877195, 5.299766388311932]
# Smiles Weight Mean and Std Dev
# 0.6770605059049845 0.0855546211622416
# Smiles Weight CI
# 0.5014411753613183 0.8115099263568694
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.11155813 38.51289637] [ 1.93427202 26.18080793] [1.74014472 0.67979327]
# (Manually) Weighted RMSE Train
# [0.19713481 5.29976639]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.9197080291970803] [0.8006387290874284, 23.43695468119316] [0.19499300770073774, 5.2189884298027005]
# Smiles Weight Mean and Std Dev
# 0.6748458959137208 0.08435140900897631
# Smiles Weight CI
# 0.5009168188071799 0.8095321028820194
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.12202734 38.7568727 ] [ 1.92526765 25.96139886] [1.71588302 0.66985278]
# (Manually) Weighted RMSE Train
# [0.19499301 5.21898843]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9176225234619395] [0.7670475183947129, 23.14536433046105] [0.18902765656560033, 4.775929070349802]
# Smiles Weight Mean and Std Dev
# 0.6673559167581747 0.08175609363412872
# Smiles Weight CI
# 0.5120852468671168 0.7943258535981272
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13867603 38.94315614] [ 1.90247658 25.47810135] [1.67077951 0.65423823]
# (Manually) Weighted RMSE Train
# [0.18902766 4.77592907]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.9061522419186653, 0.9071949947862357] [0.698398489336278, 21.32577198119985] [0.19604973856092464, 5.338658144161556]
# Smiles Weight Mean and Std Dev
# 0.6757653511819621 0.07303437550441338
# Smiles Weight CI
# 0.5224096639442922 0.7977100931518373
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.12678355 38.93147628] [ 1.92181115 26.00296379] [1.7055726 0.6679162]
# (Manually) Weighted RMSE Train
# [0.19604974 5.33865814]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.927007299270073] [0.8175824256155934, 24.886083076374852] [0.19463684924401436, 5.246112754621629]
# Smiles Weight Mean and Std Dev
# 0.6745052677510699 0.08497098144904319
# Smiles Weight CI
# 0.47967040727179283 0.8003552828830475
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13265348 38.98055499] [ 1.91331701 25.8769038 ] [1.68923422 0.66384134]
# (Manually) Weighted RMSE Train
# [0.19463685 5.24611275]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.9124087591240876] [0.7710401496192832, 22.826865512781126] [0.1916324423881168, 5.047965598484302]
# Smiles Weight Mean and Std Dev
# 0.6701396444484723 0.08042105829584098
# Smiles Weight CI
# 0.496760607820241 0.7983690234779837
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.14139789 39.23594006] [ 1.90469374 25.51581818] [1.66873775 0.65031749]
# (Manually) Weighted RMSE Train
# [0.19163244 5.0479656 ]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.927007299270073, 0.9155370177267987] [0.7633966977488341, 23.527839322936096] [0.19571707367170588, 5.380958091046897]
# Smiles Weight Mean and Std Dev
# 0.676354235914802 0.08418248856550396
# Smiles Weight CI
# 0.5159873496439827 0.8123927613467987
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13243592 39.17525596] [ 1.91359069 25.77997177] [1.68980043 0.65806773]
# (Manually) Weighted RMSE Train
# [0.19571707 5.38095809]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.913451511991658] [0.7993619991188168, 23.640687860459803] [0.19183954782770407, 5.0910762429600345]
# Smiles Weight Mean and Std Dev
# 0.6732760889126519 0.07933456909643986
# Smiles Weight CI
# 0.5039080315776179 0.8040992392859854
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.143126   39.18978744] [ 1.90426577 25.53458799] [1.66584067 0.6515623 ]
# (Manually) Weighted RMSE Train
# [0.19183955 5.09107624]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9197080291970803] [0.80292808382039, 23.413305350235486] [0.2017107860981298, 5.807867746711909]
# Smiles Weight Mean and Std Dev
# 0.6829782324418543 0.08216498511422636
# Smiles Weight CI
# 0.5131672434318862 0.8159672820845435
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13483312 39.07174136] [ 1.92363949 26.14741295] [1.69508578 0.66921545]
# (Manually) Weighted RMSE Train
# [0.20171079 5.80786775]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9103232533889468] [0.7347804977441577, 22.317131647466084] [0.2032399017069826, 5.926332875435277]
# Smiles Weight Mean and Std Dev
# 0.6841546896483827 0.0786192676158441
# Smiles Weight CI
# 0.5164878764370303 0.8046235515124371
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13913014 39.13722384] [ 1.92106175 26.15125442] [1.68642869 0.6681939 ]
# (Manually) Weighted RMSE Train
# [0.2032399  5.92633288]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9103232533889468] [0.7622535189115529, 23.0344492791206] [0.20924142363054468, 6.2393802286326485]
# Smiles Weight Mean and Std Dev
# 0.6890126991921307 0.07879450335831503
# Smiles Weight CI
# 0.5208899816923667 0.8122638071853004
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13799924 39.11818253] [ 1.92360995 26.47142592] [1.69034379 0.67670388]
# (Manually) Weighted RMSE Train
# [0.20924142 6.23938023]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.9124087591240876] [0.7159248843810876, 22.675101188847087] [0.19631524332474046, 5.385942108565986]
# Smiles Weight Mean and Std Dev
# 0.6781742867354318 0.07340607615568
# Smiles Weight CI
# 0.5304954063505637 0.7996226147190628
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.16438627 39.30292901] [ 1.89145889 25.68511058] [1.62442561 0.65351645]
# (Manually) Weighted RMSE Train
# [0.19631524 5.38594211]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9322210636079249] [0.8599205266597684, 25.079261587259435] [0.1856648327223743, 4.7318314586218]
# Smiles Weight Mean and Std Dev
# 0.6671360545892053 0.09085290253907574
# Smiles Weight CI
# 0.48148779765234434 0.80926956479677
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18606061 39.56801355] [ 1.85831143 24.9528159 ] [1.56679297 0.630631  ]
# (Manually) Weighted RMSE Train
# [0.18566483 4.73183146]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.9186652763295099] [0.7477103910977348, 22.256092870307743] [0.19000268026139638, 5.0065077596536725]
# Smiles Weight Mean and Std Dev
# 0.6721106459990831 0.07591488357161742
# Smiles Weight CI
# 0.5068442730701535 0.785634510524387
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1836735 39.5117416] [ 1.86927721 25.19146826] [1.5792169  0.63756917]
# (Manually) Weighted RMSE Train
# [0.19000268 5.00650776]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9207507820646507] [0.7948481116460743, 24.872897398891727] [0.18519151393986275, 4.708026230582466]
# Smiles Weight Mean and Std Dev
# 0.6664799107599237 0.08292931575326196
# Smiles Weight CI
# 0.4922840763137063 0.8149004822361159
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19780547 39.67883713] [ 1.85614238 24.81694689] [1.54961923 0.62544542]
# (Manually) Weighted RMSE Train
# [0.18519151 4.70802623]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.8978102189781022, 0.9259645464025026] [0.7684315552523001, 22.621437345185072] [0.20630331703334454, 5.8981931524305615]
# Smiles Weight Mean and Std Dev
# 0.6849357780850306 0.07675108598220012
# Smiles Weight CI
# 0.5024101646629769 0.7983034614592261
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17176815 39.45611191] [ 1.89062627 25.93982212] [1.61348153 0.65743483]
# (Manually) Weighted RMSE Train
# [0.20630332 5.89819315]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9176225234619395] [0.7342869064485065, 22.335132160675144] [0.19971179139732567, 5.764208088228059]
# Smiles Weight Mean and Std Dev
# 0.6813993959284671 0.07794672405946783
# Smiles Weight CI
# 0.5067758771130919 0.8034465976076764
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18233249 39.68102289] [ 1.87865094 25.71444716] [1.58893625 0.64802884]
# (Manually) Weighted RMSE Train
# [0.19971179 5.76420809]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.9238790406673618] [0.7540231477964774, 23.651833622560932] [0.1932969035905961, 5.40182964638677]
# Smiles Weight Mean and Std Dev
# 0.6761062556387147 0.08051887131692732
# Smiles Weight CI
# 0.5030093080630574 0.8081346286131782
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19411341 39.82746931] [ 1.86279932 25.38053202] [1.55998526 0.63726198]
# (Manually) Weighted RMSE Train
# [0.1932969  5.40182965]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9311783107403545] [0.7832953620661731, 24.262984164033057] [0.18626413705151898, 5.051103480447255]
# Smiles Weight Mean and Std Dev
# 0.6708538250839815 0.07951443340148842
# Smiles Weight CI
# 0.4866754838178987 0.7943195293938771
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20445404 40.05518894] [ 1.85036757 24.98228666] [1.5362708  0.62369664]
# (Manually) Weighted RMSE Train
# [0.18626414 5.05110348]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9322210636079249] [0.8214251767749213, 25.48820677494446] [0.18745896406574156, 5.080060204050964]
# Smiles Weight Mean and Std Dev
# 0.6720957896959288 0.08803072200572383
# Smiles Weight CI
# 0.4891922102971437 0.8037682081091579
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20592113 40.01978518] [ 1.85419634 25.06100446] [1.53757679 0.62621537]
# (Manually) Weighted RMSE Train
# [0.18745896 5.0800602 ]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.9249217935349322] [0.776269325546235, 23.83934032327707] [0.18904686241163635, 5.103942358226766]
# Smiles Weight Mean and Std Dev
# 0.6731100342431047 0.0804377920196795
# Smiles Weight CI
# 0.5040164803781725 0.7993878549931429
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20831104 40.03748787] [ 1.85253921 25.0325407 ] [1.53316419 0.62522756]
# (Manually) Weighted RMSE Train
# [0.18904686 5.10394236]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9290928050052137] [0.7879235675809437, 24.345572772109463] [0.18793940295480407, 5.239301916825497]
# Smiles Weight Mean and Std Dev
# 0.6746552426514903 0.08629326836964453
# Smiles Weight CI
# 0.5067546805425984 0.8101906783628104
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20979618 40.12678905] [ 1.84934449 25.10206457] [1.52864138 0.62556873]
# (Manually) Weighted RMSE Train
# [0.1879394  5.23930192]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.921793534932221] [0.8244830334058342, 25.11879519795787] [0.1931497126876144, 5.60465884886416]
# Smiles Weight Mean and Std Dev
# 0.6788441079367276 0.08451890044088077
# Smiles Weight CI
# 0.492307841455837 0.8101560778442141
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20205834 40.10493348] [ 1.8632996  25.38550573] [1.55009082 0.63297713]
# (Manually) Weighted RMSE Train
# [0.19314971 5.60465885]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9155370177267987] [0.69790505698711, 21.943143780867157] [0.20198255745370336, 6.2200437597325084]
# Smiles Weight Mean and Std Dev
# 0.6860965142706192 0.07193528707811903
# Smiles Weight CI
# 0.5487907692640966 0.8071382637724657
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19127222 40.08508893] [ 1.88171022 25.84690332] [1.57958038 0.64480095]
# (Manually) Weighted RMSE Train
# [0.20198256 6.22004376]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9280500521376434] [0.7884604853894623, 24.235810040375515] [0.18812485865489623, 5.290592821707911]
# Smiles Weight Mean and Std Dev
# 0.6739384454670967 0.08292378297855264
# Smiles Weight CI
# 0.48541020233342735 0.7942862434979728
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21444983 40.35986031] [ 1.85075895 25.01297696] [1.52394846 0.61974885]
# (Manually) Weighted RMSE Train
# [0.18812486 5.29059282]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.9238790406673618] [0.7757844922242324, 23.00028539166866] [0.19055892368210103, 5.4408305368543015]
# Smiles Weight Mean and Std Dev
# 0.6754152119154625 0.0816920805133565
# Smiles Weight CI
# 0.5094260172959505 0.795885037706249
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21598434 40.43678587] [ 1.85132993 25.09077156] [1.52249487 0.62049372]
# (Manually) Weighted RMSE Train
# [0.19055892 5.44083054]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9363920750782064] [0.8214005677797156, 25.32127973467672] [0.19091003392173425, 5.545599854482418]
# Smiles Weight Mean and Std Dev
# 0.6763518439676495 0.08249905193757355
# Smiles Weight CI
# 0.4970033209030726 0.8097363141664198
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21646428 40.49648537] [ 1.85584637 25.1354021 ] [1.52560696 0.62068108]
# (Manually) Weighted RMSE Train
# [0.19091003 5.54559985]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9259645464025026] [0.7444776304102669, 22.531950797065818] [0.1868502112888894, 5.1141408319625254]
# Smiles Weight Mean and Std Dev
# 0.6716282273956083 0.0780244231636796
# Smiles Weight CI
# 0.5186592760601291 0.7926637642758496
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2258895  40.56868805] [ 1.84544164 24.7505282 ] [1.50538988 0.61008944]
# (Manually) Weighted RMSE Train
# [0.18685021 5.11414083]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.9155370177267987, 0.9384775808133472] [0.7933382476771896, 24.19960847009408] [0.1955266144927828, 5.6540424091661325]
# Smiles Weight Mean and Std Dev
# 0.6777078023376885 0.08103534599947547
# Smiles Weight CI
# 0.49947729139998387 0.8011484745240607
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21777933 40.53880518] [ 1.86315742 25.19948683] [1.52996308 0.62161395]
# (Manually) Weighted RMSE Train
# [0.19552661 5.65404241]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9301355578727841] [0.8085063482153214, 24.269662025024996] [0.18599375136399363, 5.066501422614428]
# Smiles Weight Mean and Std Dev
# 0.6690209163952974 0.08128519961635514
# Smiles Weight CI
# 0.49637205792135847 0.795845907169655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23097892 40.82090108] [ 1.84831594 24.60956899] [1.50150088 0.60286687]
# (Manually) Weighted RMSE Train
# [0.18599375 5.06650142]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.935349322210636] [0.8067118253926392, 24.577790128039027] [0.1989708639594278, 6.068813021696029]
# Smiles Weight Mean and Std Dev
# 0.6805394191756124 0.08076682494805384
# Smiles Weight CI
# 0.5056471434014733 0.8017434533705246
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21440772 40.75093919] [ 1.87153771 25.34545756] [1.54111151 0.62196008]
# (Manually) Weighted RMSE Train
# [0.19897086 6.06881302]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9238790406673618] [0.7615678557299237, 23.116900947739833] [0.18625953706390702, 5.143897407757832]
# Smiles Weight Mean and Std Dev
# 0.6683775533690651 0.07902277908938102
# Smiles Weight CI
# 0.5021950538074842 0.8002733371408975
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23362378 40.94583343] [ 1.8469139  24.61080129] [1.49714518 0.60105752]
# (Manually) Weighted RMSE Train
# [0.18625954 5.14389741]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.9155370177267987] [0.7671421214381116, 23.239264984940807] [0.19324195689749887, 5.538813305598749]
# Smiles Weight Mean and Std Dev
# 0.6742669210620131 0.07650777621529738
# Smiles Weight CI
# 0.5223657892888119 0.8104212719660983
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22394293 40.82563163] [ 1.85992557 24.91713105] [1.51961788 0.61033057]
# (Manually) Weighted RMSE Train
# [0.19324196 5.53881331]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9228362877997914] [0.7898353549180408, 23.258574995006683] [0.19343744924390996, 5.461742733178893]
# Smiles Weight Mean and Std Dev
# 0.673529361450271 0.07582924912480363
# Smiles Weight CI
# 0.5077943852741383 0.7988241824402346
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22765531 40.86111284] [ 1.85790956 24.86428039] [1.51338046 0.60850718]
# (Manually) Weighted RMSE Train
# [0.19343745 5.46174273]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9249217935349322] [0.7932107540955631, 24.475144662209864] [0.19429687464242557, 5.395943494957923]
# Smiles Weight Mean and Std Dev
# 0.6731985511585418 0.07960969759590472
# Smiles Weight CI
# 0.49012316300564207 0.8004583871664775
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23347048 40.76818565] [ 1.85933328 24.86558342] [1.50739989 0.60992617]
# (Manually) Weighted RMSE Train
# [0.19429687 5.39594349]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9228362877997914] [0.8112559523444636, 23.87583936806525] [0.20888608369720058, 6.122455002277908]
# Smiles Weight Mean and Std Dev
# 0.6823882141506343 0.07830008952199281
# Smiles Weight CI
# 0.5066311418378241 0.8172626190411967
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22417899 40.67894123] [ 1.88429846 25.44394002] [1.53923443 0.62548186]
# (Manually) Weighted RMSE Train
# [0.20888608 6.122455  ]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9311783107403545] [0.8150132998278008, 25.051884805613547] [0.19939532922834038, 5.570678064798541]
# Smiles Weight Mean and Std Dev
# 0.6758273769456954 0.08333122851873842
# Smiles Weight CI
# 0.5000996652482074 0.8038145887211189
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23251224 40.87325704] [ 1.86747597 24.92572297] [1.51517845 0.60982962]
# (Manually) Weighted RMSE Train
# [0.19939533 5.57067806]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.9280500521376434] [0.7782813344451311, 23.0240668796411] [0.189078650488483, 4.967731756063186]
# Smiles Weight Mean and Std Dev
# 0.6670075951901571 0.07920396567783279
# Smiles Weight CI
# 0.5115325285415446 0.7896161823408612
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25055497 41.03151324] [ 1.85096285 24.41626381] [1.48011315 0.59506126]
# (Manually) Weighted RMSE Train
# [0.18907865 4.96773176]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.927007299270073] [0.8047277970477409, 23.82358129733233] [0.1879195357955346, 4.944382288391838]
# Smiles Weight Mean and Std Dev
# 0.6674679679068993 0.07827547323734238
# Smiles Weight CI
# 0.5006235577187503 0.7956470770174662
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24970435 41.08441932] [ 1.84524865 24.41172629] [1.47654816 0.59418453]
# (Manually) Weighted RMSE Train
# [0.18791954 4.94438229]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9280500521376434] [0.8180766296739297, 24.5530186574935] [0.19216208722788497, 5.208612814712052]
# Smiles Weight Mean and Std Dev
# 0.670436201851336 0.07948604854331268
# Smiles Weight CI
# 0.4875849203566044 0.7937241385352521
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24866763 41.09295671] [ 1.84778434 24.61859736] [1.47980479 0.5990953 ]
# (Manually) Weighted RMSE Train
# [0.19216209 5.20861281]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9259645464025026] [0.8413910141511586, 24.97802251381738] [0.18851780693963544, 4.924414051228268]
# Smiles Weight Mean and Std Dev
# 0.6667200656713035 0.0853869749982588
# Smiles Weight CI
# 0.46992408703800387 0.7926901933223772
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25766237 41.09911062] [ 1.83470423 24.41272585] [1.45882096 0.59399645]
# (Manually) Weighted RMSE Train
# [0.18851781 4.92441405]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.9249217935349322] [0.7893876131820212, 24.11710260070831] [0.19048920400038064, 5.050659252585225]
# Smiles Weight Mean and Std Dev
# 0.6671331189079379 0.07918919942660979
# Smiles Weight CI
# 0.478399665023516 0.791368823978516
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26110385 41.19420911] [ 1.83915974 24.49199208] [1.45837295 0.59454939]
# (Manually) Weighted RMSE Train
# [0.1904892  5.05065925]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9207507820646507] [0.7946882750014271, 23.91612076660236] [0.19262910774333736, 5.157121972648124]
# Smiles Weight Mean and Std Dev
# 0.6693415217376207 0.07971022247425616
# Smiles Weight CI
# 0.5097614562359501 0.8047951661854651
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26226387 41.11316971] [ 1.84301651 24.5567249 ] [1.46008815 0.59729583]
# (Manually) Weighted RMSE Train
# [0.19262911 5.15712197]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.9186652763295099] [0.7593359634016755, 22.5881826928247] [0.19348621661609425, 5.301766755573736]
# Smiles Weight Mean and Std Dev
# 0.6701048566260333 0.07489156177219605
# Smiles Weight CI
# 0.5249520056284035 0.790784725260806
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26520833 41.17956049] [ 1.83917529 24.61888087] [1.4536541  0.59784224]
# (Manually) Weighted RMSE Train
# [0.19348622 5.30176676]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.9290928050052137] [0.8387389718104075, 24.731148129438836] [0.19302386185897158, 5.313283647222348]
# Smiles Weight Mean and Std Dev
# 0.6708655013260733 0.08256140740577847
# Smiles Weight CI
# 0.4982843933523306 0.7962713934654356
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26591255 41.20464611] [ 1.83935153 24.67073753] [1.45298467 0.59873679]
# (Manually) Weighted RMSE Train
# [0.19302386 5.31328365]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9238790406673618] [0.7944293976238119, 23.807689770905665] [0.20393776401236371, 5.942349131841732]
# Smiles Weight Mean and Std Dev
# 0.6791531193960927 0.07692005573491754
# Smiles Weight CI
# 0.5063043392305053 0.7997130980987956
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25511678 41.10829604] [ 1.86051119 25.18201048] [1.4823411  0.61257734]
# (Manually) Weighted RMSE Train
# [0.20393776 5.94234913]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9322210636079249] [0.868733149303521, 25.595132250504328] [0.18950480986431623, 5.095879832195166]
# Smiles Weight Mean and Std Dev
# 0.6680931036929043 0.08270162424016785
# Smiles Weight CI
# 0.49650508554673844 0.8119682500362441
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27496139 41.32798428] [ 1.83303028 24.47884295] [1.43771434 0.59230672]
# (Manually) Weighted RMSE Train
# [0.18950481 5.09587983]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.927007299270073] [0.815013545789998, 24.62013391633171] [0.18873647083545741, 4.913993382998723]
# Smiles Weight Mean and Std Dev
# 0.6663670725358001 0.07840730107645877
# Smiles Weight CI
# 0.5035589384264951 0.7995215377429948
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28481896 41.40913322] [ 1.82630273 24.37673873] [1.42144753 0.58868025]
# (Manually) Weighted RMSE Train
# [0.18873647 4.91399338]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.9176225234619395] [0.760022834132633, 23.014715947325854] [0.20293969997768505, 5.781613298396989]
# Smiles Weight Mean and Std Dev
# 0.6775782726612243 0.07523903566230007
# Smiles Weight CI
# 0.5235839621022093 0.7971292276491374
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2707606  41.36576162] [ 1.85104448 25.05399056] [1.45664296 0.60566975]
# (Manually) Weighted RMSE Train
# [0.2029397 5.7816133]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9343065693430657] [0.8663385530360387, 25.264145590019645] [0.18166763899682337, 4.525889742866349]
# Smiles Weight Mean and Std Dev
# 0.659824856616322 0.08332072302830373
# Smiles Weight CI
# 0.49042414818518376 0.7909852240293467
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3001616  41.63065467] [ 1.80842261 23.98367978] [1.39092141 0.57610624]
# (Manually) Weighted RMSE Train
# [0.18166764 4.52588974]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.921793534932221] [0.8290446859216107, 23.9488691183806] [0.20143358512774426, 5.657221181988023]
# Smiles Weight Mean and Std Dev
# 0.6755378726881108 0.07954917159709132
# Smiles Weight CI
# 0.49215681485787627 0.798096141833014
# ...
# Smiles Weight CI
# 0.47486517168169906 0.764764366952327
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77503961 50.65474774] [ 1.54596531 27.45245614] [0.87094694 0.54195228]
# (Manually) Weighted RMSE Train
# [0.19055824 4.8490835 ]
#
#
# epoch number:  969
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9103232533889468] [1.1954926273396196, 33.71120579451443] [0.19279874434527478, 5.009820035961382]
# Smiles Weight Mean and Std Dev
# 0.6398825373167328 0.0801670245448072
# Smiles Weight CI
# 0.4545791421939141 0.7657238073767334
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76923092 50.66722722] [ 1.56305448 27.43898255] [0.8834655  0.54155287]
# (Manually) Weighted RMSE Train
# [0.19279874 5.00982004]
#
#
# epoch number:  970
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9124087591240876] [1.2150674046206347, 34.165804541236064] [0.19015997530505602, 4.847854681492157]
# Smiles Weight Mean and Std Dev
# 0.6332632055436598 0.08449144994005368
# Smiles Weight CI
# 0.4785800774613179 0.7646919040147077
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77594049 50.65609697] [ 1.54900065 27.5093778 ] [0.87221427 0.54306154]
# (Manually) Weighted RMSE Train
# [0.19015998 4.84785468]
#
#
# epoch number:  971
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9030239833159541] [1.1322485001204998, 31.718949323267132] [0.18955187004904647, 4.840064112149589]
# Smiles Weight Mean and Std Dev
# 0.6333182177669406 0.07646906574352896
# Smiles Weight CI
# 0.4888121977451916 0.7637287140340703
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77616384 50.65021762] [ 1.5480357  27.48976922] [0.87156132 0.54273744]
# (Manually) Weighted RMSE Train
# [0.18955187 4.84006411]
#
#
# epoch number:  972
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9030239833159541] [1.1150963718307314, 30.892860340137833] [0.19020484916734404, 4.828744353476537]
# Smiles Weight Mean and Std Dev
# 0.6308534622890978 0.07389122358268697
# Smiles Weight CI
# 0.4778422742847407 0.7572940247513694
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77663616 50.57762589] [ 1.54618701 27.5147023 ] [0.87028906 0.54400937]
# (Manually) Weighted RMSE Train
# [0.19020485 4.82874435]
#
#
# epoch number:  973
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.9113660062565172] [1.2395250016646568, 34.666999794989756] [0.189987708545477, 4.9296622601224405]
# Smiles Weight Mean and Std Dev
# 0.6369425332629584 0.08685587676025015
# Smiles Weight CI
# 0.4676175793482823 0.7762160247357233
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76887159 50.59556081] [ 1.55618804 27.40230672] [0.87976315 0.54159508]
# (Manually) Weighted RMSE Train
# [0.18998771 4.92966226]
#
#
# epoch number:  974
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9051094890510949] [1.183412772879253, 33.30624063905283] [0.18940590634155935, 4.834520519196423]
# Smiles Weight Mean and Std Dev
# 0.6317076147323151 0.08009782223096329
# Smiles Weight CI
# 0.471809803764662 0.7711504569505883
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7743971  50.56739945] [ 1.54828316 27.50482782] [0.87256858 0.54392411]
# (Manually) Weighted RMSE Train
# [0.18940591 4.83452052]
#
#
# epoch number:  975
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.8988529718456726] [1.1454726390593566, 32.64665305003844] [0.19059321348042926, 5.013687113001663]
# Smiles Weight Mean and Std Dev
# 0.6387862122696888 0.07631284734119764
# Smiles Weight CI
# 0.46532452722571627 0.7593111716197151
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76680497 50.58777265] [ 1.5606594  27.42422272] [0.88332296 0.54211169]
# (Manually) Weighted RMSE Train
# [0.19059321 5.01368711]
#
#
# epoch number:  976
# Coverages, CI Widths, RMSEs
# [0.9332638164754953, 0.9186652763295099] [1.2005423718195192, 34.1922949643248] [0.19016077416163527, 4.831633084790627]
# Smiles Weight Mean and Std Dev
# 0.6307570172102315 0.0851516558778848
# Smiles Weight CI
# 0.46910336594511415 0.7676601539150849
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77393981 50.51547273] [ 1.54528601 27.51609155] [0.87110397 0.54470621]
# (Manually) Weighted RMSE Train
# [0.19016077 4.83163308]
#
#
# epoch number:  977
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.8936392075078207] [1.0997085797494879, 31.000202226617798] [0.19149448306736586, 5.061095917436661]
# Smiles Weight Mean and Std Dev
# 0.640106666644003 0.07235336680570155
# Smiles Weight CI
# 0.4931217923233168 0.7769466939084182
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76537399 50.53605608] [ 1.56269269 27.38478739] [0.88519073 0.54188612]
# (Manually) Weighted RMSE Train
# [0.19149448 5.06109592]
#
#
# epoch number:  978
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9092805005213764] [1.1904945028345433, 34.768093765987004] [0.18958183142058546, 4.950035612473158]
# Smiles Weight Mean and Std Dev
# 0.6366053670981737 0.08156225691414387
# Smiles Weight CI
# 0.46504578600649943 0.7822912363811482
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76822913 50.5770618 ] [ 1.55757204 27.40852735] [0.8808655  0.54191616]
# (Manually) Weighted RMSE Train
# [0.18958183 4.95003561]
#
#
# epoch number:  979
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.8988529718456726] [1.075732247081532, 30.066306285959392] [0.20333440095033198, 5.7140929129888365]
# Smiles Weight Mean and Std Dev
# 0.6504733022011655 0.07264056020269886
# Smiles Weight CI
# 0.4938365808006329 0.7707184480965328
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75452145 50.69277713] [ 1.58744408 27.33759856] [0.90477325 0.53927995]
# (Manually) Weighted RMSE Train
# [0.2033344  5.71409291]
#
#
# epoch number:  980
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9103232533889468] [1.1823429953003066, 35.187708616703446] [0.19066320042391963, 4.977581909776284]
# Smiles Weight Mean and Std Dev
# 0.6383207558964177 0.07923172900260947
# Smiles Weight CI
# 0.4704453750836759 0.7672456182341046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76671678 50.61608415] [ 1.5653111  27.40571474] [0.88600002 0.54144281]
# (Manually) Weighted RMSE Train
# [0.1906632  4.97758191]
#
#
# epoch number:  981
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.9061522419186653] [1.1900846287366542, 33.31921453506636] [0.18863424905546186, 4.919136327131885]
# Smiles Weight Mean and Std Dev
# 0.6358364064983102 0.07891608305152718
# Smiles Weight CI
# 0.46580856481368643 0.7600914662856794
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76893146 50.6046399 ] [ 1.55686943 27.4145281 ] [0.88011857 0.54173942]
# (Manually) Weighted RMSE Train
# [0.18863425 4.91913633]
#
#
# epoch number:  982
# Coverages, CI Widths, RMSEs
# [0.9332638164754953, 0.9061522419186653] [1.1412330846018806, 32.74746295374884] [0.18913702360056003, 4.828758352470863]
# Smiles Weight Mean and Std Dev
# 0.6312105341615476 0.0798262929267185
# Smiles Weight CI
# 0.48709561462220463 0.7659913654195041
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77362538 50.63029   ] [ 1.54859724 27.51612526] [0.87312533 0.54347161]
# (Manually) Weighted RMSE Train
# [0.18913702 4.82875835]
#
#
# epoch number:  983
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9124087591240876] [1.1727329223920013, 34.314239332135955] [0.19020140650144932, 4.829696808142419]
# Smiles Weight Mean and Std Dev
# 0.628831570963622 0.08398789389362102
# Smiles Weight CI
# 0.46014883116609895 0.7534963975562581
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77696306 50.53823399] [ 1.54920956 27.54254611] [0.87182992 0.54498434]
# (Manually) Weighted RMSE Train
# [0.19020141 4.82969681]
#
#
# epoch number:  984
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.9019812304483837] [1.1609547713453534, 32.78799780544439] [0.1896141628006824, 4.917371232417347]
# Smiles Weight Mean and Std Dev
# 0.6371902122918224 0.07582370267918309
# Smiles Weight CI
# 0.4673288283199569 0.7576480041958976
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76919108 50.59981542] [ 1.5632162  27.52693149] [0.8835768  0.54401249]
# (Manually) Weighted RMSE Train
# [0.18961416 4.91737123]
#
#
# epoch number:  985
# Coverages, CI Widths, RMSEs
# [0.927007299270073, 0.9040667361835245] [1.071652788226616, 29.90945849501617] [0.18973160786697296, 4.904707636066297]
# Smiles Weight Mean and Std Dev
# 0.6365895131078732 0.07531001178891392
# Smiles Weight CI
# 0.497641137212026 0.7638950194351178
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76910024 50.57833247] [ 1.56527119 27.50254891] [0.88478378 0.54376148]
# (Manually) Weighted RMSE Train
# [0.18973161 4.90470764]
#
#
# epoch number:  986
# Coverages, CI Widths, RMSEs
# [0.9332638164754953, 0.908237747653806] [1.1506889224085286, 33.23170803888366] [0.18949178512966888, 4.95730669241363]
# Smiles Weight Mean and Std Dev
# 0.6370998471351614 0.07994215073172771
# Smiles Weight CI
# 0.47800406493971254 0.7645501924331177
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7675316 50.6525684] [ 1.56717014 27.46496149] [0.88664335 0.54222248]
# (Manually) Weighted RMSE Train
# [0.18949179 4.95730669]
#
#
# epoch number:  987
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9103232533889468] [1.2073470919257565, 35.11263289416522] [0.18932434512225832, 4.948311844474851]
# Smiles Weight Mean and Std Dev
# 0.6367198086543695 0.07936645242006182
# Smiles Weight CI
# 0.47077667732504785 0.7638967434874313
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76760213 50.64834727] [ 1.56386458 27.48332869] [0.88473789 0.54263032]
# (Manually) Weighted RMSE Train
# [0.18932435 4.94831184]
#
#
# epoch number:  988
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.913451511991658] [1.2019875164828928, 35.12847331664522] [0.18979127899354742, 4.969086869328499]
# Smiles Weight Mean and Std Dev
# 0.6371228094138661 0.07696284363992897
# Smiles Weight CI
# 0.46531078659029107 0.7688388392372283
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76749452 50.71045539] [ 1.56656225 27.50748976] [0.88631802 0.54244218]
# (Manually) Weighted RMSE Train
# [0.18979128 4.96908687]
#
#
# epoch number:  989
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9030239833159541] [1.1230946228755685, 31.619755497323997] [0.19392607534721545, 5.2366115082467335]
# Smiles Weight Mean and Std Dev
# 0.6426788874411569 0.0748542312479103
# Smiles Weight CI
# 0.47193380539143676 0.7570253246071018
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76396061 50.75332811] [ 1.57579831 27.44400995] [0.89332965 0.54073321]
# (Manually) Weighted RMSE Train
# [0.19392608 5.23661151]
#
#
# epoch number:  990
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9019812304483837] [1.0731671445644733, 30.788456250906712] [0.19648612369807178, 5.4546466348271565]
# Smiles Weight Mean and Std Dev
# 0.6456908147438999 0.0728161952687417
# Smiles Weight CI
# 0.487017090014923 0.7518841837541843
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76034952 50.76186354] [ 1.58088151 27.38817463] [0.89804979 0.53954234]
# (Manually) Weighted RMSE Train
# [0.19648612 5.45464663]
#
#
# epoch number:  991
# Coverages, CI Widths, RMSEs
# [0.9155370177267987, 0.894681960375391] [1.065764164577736, 30.487664277836718] [0.19527507111507417, 5.39239443549476]
# Smiles Weight Mean and Std Dev
# 0.6450621960663638 0.07047513510984295
# Smiles Weight CI
# 0.49969984838080916 0.7639941070196149
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76015321 50.74029483] [ 1.57664538 27.41655796] [0.89574326 0.54033107]
# (Manually) Weighted RMSE Train
# [0.19527507 5.39239444]
#
#
# epoch number:  992
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9092805005213764] [1.133811987574278, 32.91150076978121] [0.18861557792917744, 4.935471752449193]
# Smiles Weight Mean and Std Dev
# 0.6358720349712903 0.07605851932463627
# Smiles Weight CI
# 0.47812780040199554 0.7603274938293791
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7694524  50.71231998] [ 1.55840874 27.54005003] [0.88072939 0.54306429]
# (Manually) Weighted RMSE Train
# [0.18861558 4.93547175]
#
#
# epoch number:  993
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.8988529718456726] [1.095845339762731, 31.222700973078346] [0.19220967002755077, 5.112756272310743]
# Smiles Weight Mean and Std Dev
# 0.6405309357766896 0.07510026993448064
# Smiles Weight CI
# 0.481879463203474 0.755617982502629
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76853268 50.73447348] [ 1.56867812 27.51348343] [0.88699414 0.54230352]
# (Manually) Weighted RMSE Train
# [0.19220967 5.11275627]
#
#
# epoch number:  994
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9103232533889468] [1.2272789006397997, 34.811164104167794] [0.19159369197480627, 5.003560681405043]
# Smiles Weight Mean and Std Dev
# 0.6383121828156084 0.0841717417546308
# Smiles Weight CI
# 0.46353293839590753 0.7665485091370093
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77051611 50.65809385] [ 1.56728111 27.55970538] [0.88521144 0.5440336 ]
# (Manually) Weighted RMSE Train
# [0.19159369 5.00356068]
#
#
# epoch number:  995
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9040667361835245] [1.2011566289776168, 35.038295935077855] [0.19157490976675864, 5.036089914939366]
# Smiles Weight Mean and Std Dev
# 0.6389043849771997 0.07617063439884421
# Smiles Weight CI
# 0.4670192422737536 0.7574882268441578
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77077691 50.69473899] [ 1.56980954 27.55092061] [0.88650893 0.54346706]
# (Manually) Weighted RMSE Train
# [0.19157491 5.03608991]
#
#
# epoch number:  996
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.8978102189781022] [1.1207235071967077, 31.082529073959144] [0.1909248088491481, 4.8722786428409055]
# Smiles Weight Mean and Std Dev
# 0.6264830615455552 0.07512969787061563
# Smiles Weight CI
# 0.4663389845423505 0.7463572670779713
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78302413 50.74984571] [ 1.54588455 27.6855239 ] [0.86700147 0.54552922]
# (Manually) Weighted RMSE Train
# [0.19092481 4.87227864]
#
#
# epoch number:  997
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.8988529718456726] [1.1297135980267334, 31.860478318203832] [0.18891672944775165, 4.916041792580334]
# Smiles Weight Mean and Std Dev
# 0.63217021385913 0.07407867358574578
# Smiles Weight CI
# 0.46969491593982443 0.759444487735349
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77705252 50.80626023] [ 1.55421517 27.52662082] [0.87460283 0.54179585]
# (Manually) Weighted RMSE Train
# [0.18891673 4.91604179]
#
#
# epoch number:  998
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.913451511991658] [1.184185752210888, 34.10544557348308] [0.1896042140018336, 5.012093589783689]
# Smiles Weight Mean and Std Dev
# 0.6366174481697893 0.08003471016881265
# Smiles Weight CI
# 0.4593155819489903 0.7655625352449187
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77290884 50.81012958] [ 1.55961685 27.50123296] [0.87969376 0.54125493]
# (Manually) Weighted RMSE Train
# [0.18960421 5.01209359]
#
#
# epoch number:  999
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9092805005213764] [1.1375493531897827, 32.49343665877516] [0.19075644621282797, 5.113100430243601]
# Smiles Weight Mean and Std Dev
# 0.6385523368184034 0.077256169300814
# Smiles Weight CI
# 0.4650499629728917 0.7563912655349235
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77154428 50.86913125] [ 1.56620195 27.50963042] [0.88408851 0.54079222]
# (Manually) Weighted RMSE Train
# [0.19075645 5.11310043]
#
#
# done for fold1
# train_width[1.020966344241404, 18.416191370460943]
# smiles_weight0.7234595502438619
# rmse_train[0.15840611675605537, 0.13828933902378002]
# smiles_weight_ci[0.5646927025365693, 0.8500040221039681]
# CPU times: user 10h 41min 6s, sys: 7h 36s, total: 17h 41min 42s
# Wall time: 3h 1min 54s

# %%
with open("..//Data/returned_stuff1_config3.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
# with open("..//Data/returned_stuff_config4.pickle", "rb") as f: 
#     returned_stuff = pickle.load(f)

# %%
# with open("..//Data/returned_stuff1_config3.pickle", "rb") as f: 
#     returned_stuff1 = pickle.load(f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
