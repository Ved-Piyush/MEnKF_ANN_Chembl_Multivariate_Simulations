# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-08-03 16:26:30.068464: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-03 16:26:30.071279: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 16:26:30.111630: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 16:26:30.112351: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 16:26:31.198645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_heavy_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_heavy_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,14), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 100)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [51.76817778531396, 1039.4877532939893] [4.059479842079666, 62.3835914201741]
# Smiles Weight Mean and Std Dev
# 0.49331950050787743 0.23587682389122208
# Smiles Weight CI
# 0.11909211091305234 0.9121361269251723
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.63063864 60.0339588 ] [ 4.21776319 61.21419923] [1.60332291 1.01965955]
# (Manually) Weighted RMSE Train
# [ 4.05947984 62.38359142]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [30.940480020484838, 695.9641482428806] [2.6759187471349737, 67.48012749440194]
# Smiles Weight Mean and Std Dev
# 0.5391157991351406 0.20672408815007653
# Smiles Weight CI
# 0.1607963525710225 0.9164027535733537
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.71701416 54.48767657] [ 2.72867678 71.81813154] [1.00429244 1.31806192]
# (Manually) Weighted RMSE Train
# [ 2.67591875 67.48012749]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [21.233506909663536, 501.11729862026607] [1.5515523840528385, 52.08848073504066]
# Smiles Weight Mean and Std Dev
# 0.5510720030017109 0.17866162893873744
# Smiles Weight CI
# 0.22854109014622484 0.8783310021551746
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.31394045 49.58161317] [ 2.0067656  58.38054457] [0.86725032 1.1774636 ]
# (Manually) Weighted RMSE Train
# [ 1.55155238 52.08848074]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [13.419348617912448, 306.09554292246446] [1.662810671541559, 43.216656690529554]
# Smiles Weight Mean and Std Dev
# 0.6098396329743506 0.1382636334969924
# Smiles Weight CI
# 0.32692387553075486 0.8655810087745083
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.07105106 44.8488609 ] [ 2.37149027 53.87921038] [1.14506606 1.2013507 ]
# (Manually) Weighted RMSE Train
# [ 1.66281067 43.21665669]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [9.43636380618419, 212.84413166331936] [1.5609214321775562, 42.00934124152732]
# Smiles Weight Mean and Std Dev
# 0.64031844798201 0.10575040842910119
# Smiles Weight CI
# 0.4359549395252434 0.8490191246751986
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.54643465 36.95278361] [ 2.78948963 60.09348518] [1.80381993 1.6262235 ]
# (Manually) Weighted RMSE Train
# [ 1.56092143 42.00934124]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [6.285313750606903, 142.11906893069585] [0.8493915498266774, 25.57116985432081]
# Smiles Weight Mean and Std Dev
# 0.7005229842046305 0.08727209343980744
# Smiles Weight CI
# 0.5303308010259935 0.8549145090535554
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97402988 26.89652642] [ 2.60234119 53.93356574] [2.67172622 2.0052242 ]
# (Manually) Weighted RMSE Train
# [ 0.84939155 25.57116985]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.746353224604148, 102.39899652104258] [0.618576373116365, 19.569004698350316]
# Smiles Weight Mean and Std Dev
# 0.7163304695735196 0.07501530105332554
# Smiles Weight CI
# 0.5690434983998061 0.8592374003663663
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88642796 18.50114065] [ 2.45178961 55.83409392] [2.7659209  3.01787306]
# (Manually) Weighted RMSE Train
# [ 0.61857637 19.5690047 ]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.2170960683280887, 78.79918456764534] [0.4715758138400791, 9.943749036067095]
# Smiles Weight Mean and Std Dev
# 0.7160692949710745 0.07186512678670101
# Smiles Weight CI
# 0.582307421218364 0.844308972359226
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.70592769 10.93160856] [ 2.51264325 54.16751875] [3.55934934 4.95512792]
# (Manually) Weighted RMSE Train
# [0.47157581 9.94374904]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.40494604935147, 55.9315633550866] [0.3351845606048419, 3.2316087451522746]
# Smiles Weight Mean and Std Dev
# 0.716139384559389 0.05951474302828238
# Smiles Weight CI
# 0.6026197762473007 0.8285547062080287
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.57442167 5.97253037] [ 2.438912   52.17380257] [4.24585654 8.73562784]
# (Manually) Weighted RMSE Train
# [0.33518456 3.23160875]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [1.797810975538579, 41.234550295202716] [0.20574738616674138, 3.1249869053361494]
# Smiles Weight Mean and Std Dev
# 0.711942707653361 0.0537626734156618
# Smiles Weight CI
# 0.5890465367704305 0.8070584469553123
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.49950965 5.78345112] [ 2.38941368 53.1338932 ] [4.7835186  9.18722957]
# (Manually) Weighted RMSE Train
# [0.20574739 3.12498691]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 1.0] [1.428699180841753, 33.97451839262332] [0.19076911188983128, 3.1126595530126386]
# Smiles Weight Mean and Std Dev
# 0.7170162458300211 0.05358006061941043
# Smiles Weight CI
# 0.5885518259051373 0.79974188642059
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.44880042 7.03994819] [ 2.44531497 53.90690595] [5.44855762 7.65728732]
# (Manually) Weighted RMSE Train
# [0.19076911 3.11265955]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 1.0] [1.1744992329668562, 29.653581086032933] [0.1838226778258704, 2.9742130763710515]
# Smiles Weight Mean and Std Dev
# 0.7066632262579198 0.05555818830998679
# Smiles Weight CI
# 0.5937286161974837 0.7950093439705194
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.42574666 7.00981927] [ 2.44335753 53.69171249] [5.73899401 7.65950026]
# (Manually) Weighted RMSE Train
# [0.18382268 2.97421308]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 1.0] [1.0606197340639316, 24.597009255330615] [0.1793461252230274, 3.0167800693061997]
# Smiles Weight Mean and Std Dev
# 0.7035452322809319 0.048032190358204635
# Smiles Weight CI
# 0.6028738736527518 0.7901259715237694
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.41448482 6.72721084] [ 2.46126906 54.13279541] [5.93814039 8.04684092]
# (Manually) Weighted RMSE Train
# [0.17934613 3.01678007]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9760166840458812, 0.9989572471324296] [0.9391906085479097, 23.24152822219099] [0.18141293690547008, 3.079194506985923]
# Smiles Weight Mean and Std Dev
# 0.7023551241120222 0.04893364224976857
# Smiles Weight CI
# 0.5948147755085639 0.7861214502799556
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.39951776 6.63309662] [ 2.48795833 54.47416246] [6.22740354 8.21247837]
# (Manually) Weighted RMSE Train
# [0.18141294 3.07919451]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9582898852971846, 0.9989572471324296] [0.844189569502187, 21.327711439046713] [0.17646783689286422, 3.1494307225845946]
# Smiles Weight Mean and Std Dev
# 0.7011538701895746 0.051750590288961104
# Smiles Weight CI
# 0.5806240705132419 0.792599300736917
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.37815909 6.90286914] [ 2.50876459 54.57935451] [6.63415121 7.90676361]
# (Manually) Weighted RMSE Train
# [0.17646784 3.14943072]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9416058394160584, 0.9979144942648592] [0.8134021595397466, 20.182907974960365] [0.17677909532093186, 3.1353678886970053]
# Smiles Weight Mean and Std Dev
# 0.6970039912409512 0.04941313777834303
# Smiles Weight CI
# 0.5976738533833574 0.7813567328960698
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.37290744 6.59203757] [ 2.52469576 54.62866552] [6.77030133 8.28706829]
# (Manually) Weighted RMSE Train
# [0.1767791  3.13536789]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9968717413972888] [0.7854344829437389, 18.49621530215668] [0.17877065795224406, 3.0125356526968488]
# Smiles Weight Mean and Std Dev
# 0.695853336666383 0.043904691204219796
# Smiles Weight CI
# 0.6140592114243564 0.7740492978455445
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.36770236 6.40602774] [ 2.53755387 54.82891416] [6.90110839 8.55895671]
# (Manually) Weighted RMSE Train
# [0.17877066 3.01253565]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9927007299270073] [0.7177099157703279, 16.788872876804103] [0.1765554093635547, 3.041965815808101]
# Smiles Weight Mean and Std Dev
# 0.6981190833601174 0.04485555659869166
# Smiles Weight CI
# 0.5825216344667165 0.7729701933924249
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34993844 6.47314406] [ 2.55372581 54.9353654 ] [7.29764305 8.48665886]
# (Manually) Weighted RMSE Train
# [0.17655541 3.04196582]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.986444212721585] [0.684198289689113, 16.344463850191584] [0.17868786484212693, 3.10187206844022]
# Smiles Weight Mean and Std Dev
# 0.695508168682982 0.044224701426177446
# Smiles Weight CI
# 0.5856415125503687 0.7625357688768091
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.3421517  6.54934972] [ 2.55707567 55.04705983] [7.47351454 8.40496571]
# (Manually) Weighted RMSE Train
# [0.17868786 3.10187207]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.9843587069864442] [0.672546215032547, 15.643739923113623] [0.18267849254459012, 3.0770170941525716]
# Smiles Weight Mean and Std Dev
# 0.6923941354135295 0.043561301955244464
# Smiles Weight CI
# 0.5825320959750874 0.7638903698573839
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.35066103 6.57863777] [ 2.56789909 55.10343833] [7.32302381 8.3761168 ]
# (Manually) Weighted RMSE Train
# [0.18267849 3.07701709]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.8561001042752867, 0.9812304483837331] [0.6199333859501569, 14.743218790654877] [0.1781609287227332, 3.197323095543394]
# Smiles Weight Mean and Std Dev
# 0.699177862621029 0.03816497016681998
# Smiles Weight CI
# 0.617856695121627 0.7771436085436622
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.32928511 6.81829681] [ 2.57333671 55.1836173 ] [7.81491965 8.0934607 ]
# (Manually) Weighted RMSE Train
# [0.17816093 3.1973231 ]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.8592283628779979, 0.9749739311783108] [0.6135640334324265, 14.633060959207365] [0.18174944679767455, 3.1080709641927213]
# Smiles Weight Mean and Std Dev
# 0.6909907949655494 0.04492506314128897
# Smiles Weight CI
# 0.5891973686062547 0.7671182847499735
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34279243 6.75974037] [ 2.57582228 55.28138768] [7.51423324 8.17803416]
# (Manually) Weighted RMSE Train
# [0.18174945 3.10807096]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.97288842544317] [0.6484831488502313, 15.015904999261476] [0.18373219171131963, 3.1271721072070235]
# Smiles Weight Mean and Std Dev
# 0.6871804839916902 0.04492826609559413
# Smiles Weight CI
# 0.5874103421639826 0.7597072238283156
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34216732 6.77232783] [ 2.57921982 55.31383035] [7.53789066 8.16762445]
# (Manually) Weighted RMSE Train
# [0.18373219 3.12717211]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.8227320125130344, 0.9603753910323254] [0.5876397593542133, 14.36577095947269] [0.1854246173938512, 3.1489126211750675]
# Smiles Weight Mean and Std Dev
# 0.6848854086834117 0.04202086258672872
# Smiles Weight CI
# 0.5897142101891426 0.751063278681193
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.341731   6.88822369] [ 2.58518519 55.37965953] [7.56497114 8.03975917]
# (Manually) Weighted RMSE Train
# [0.18542462 3.14891262]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.8206465067778936, 0.9520333680917622] [0.5884728357788587, 13.897087893128942] [0.18415799078765757, 3.1906114717899876]
# Smiles Weight Mean and Std Dev
# 0.6865437327308639 0.04408192543471536
# Smiles Weight CI
# 0.5872877831438689 0.7561106519128847
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.33851547 6.92613423] [ 2.59180702 55.36483019] [7.6563916  7.99361207]
# (Manually) Weighted RMSE Train
# [0.18415799 3.19061147]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.948905109489051] [0.6140227758792561, 14.208346105746486] [0.18410852916410414, 3.159861810108565]
# Smiles Weight Mean and Std Dev
# 0.6858023646306401 0.046260133980713526
# Smiles Weight CI
# 0.5773525258000108 0.7575868437464557
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.33590683 6.89922916] [ 2.59637439 55.4197842 ] [7.72944805 8.03275017]
# (Manually) Weighted RMSE Train
# [0.18410853 3.15986181]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.799791449426486, 0.940563086548488] [0.544841845364546, 13.143681179731786] [0.18526071008433428, 3.153408439216736]
# Smiles Weight Mean and Std Dev
# 0.6831808339264769 0.04181694014656843
# Smiles Weight CI
# 0.5911163216668849 0.757971417672046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.33859787 6.98012302] [ 2.59532453 55.45410876] [7.66491697 7.9445747 ]
# (Manually) Weighted RMSE Train
# [0.18526071 3.15340844]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.7924921793534933, 0.940563086548488] [0.5752325446859899, 13.915808782761067] [0.18467933364918998, 3.177575303392781]
# Smiles Weight Mean and Std Dev
# 0.6831526386352668 0.04362953909924265
# Smiles Weight CI
# 0.576836146271809 0.7476205287113399
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34333068 7.09985021] [ 2.59936881 55.49018252] [7.57103565 7.81568355]
# (Manually) Weighted RMSE Train
# [0.18467933 3.1775753 ]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.8050052137643379, 0.9384775808133472] [0.580616396174553, 13.212627362686845] [0.1835573952335929, 3.1689162039109813]
# Smiles Weight Mean and Std Dev
# 0.6852455053014262 0.04425473053689273
# Smiles Weight CI
# 0.575710259188738 0.7503330206670047
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34298849 7.23097274] [ 2.60621815 55.51840423] [7.59855858 7.67786108]
# (Manually) Weighted RMSE Train
# [0.1835574 3.1689162]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.7674661105318039, 0.921793534932221] [0.511591323974476, 11.701741345504095] [0.1856771195672191, 3.1714225269244603]
# Smiles Weight Mean and Std Dev
# 0.6819847911880484 0.03886376714649897
# Smiles Weight CI
# 0.6045890942700325 0.7546249421975426
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.34797936 7.25605645] [ 2.60829074 55.52908563] [7.49553286 7.6527913 ]
# (Manually) Weighted RMSE Train
# [0.18567712 3.17142253]
#
#
# done for fold0
# train_width[0.544841845364546, 13.143681179731786]
# smiles_weight0.6831808339264769
# rmse_train[0.09816118379591263, 0.07307053494191636]
# smiles_weight_ci[0.5911163216668849, 0.757971417672046]
# CPU times: user 9min 11s, sys: 5min 45s, total: 14min 56s
# Wall time: 4min 28s

# %%
with open("..//Data/returned_stuff_config1_rerun.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
# returned_stuff2 = get_results(2, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-2], threshold = 0.75)

# %%
len(returned_stuff)
# Out:
# 9

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,14), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.40, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.6329509906152242, 0.7205422314911366] [0.4898233419069277, 12.375642723790978] [0.3254758526801601, 10.570318379551711]
# Smiles Weight Mean and Std Dev
# 0.6917293136935238 0.036531448858410795
# Smiles Weight CI
# 0.6139215682709583 0.7447738822882276
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.47376492 12.30866183] [ 2.47486917 54.35695578] [5.22383367 4.41615478]
# (Manually) Weighted RMSE Train
# [ 0.32547585 10.57031838]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.6923879040667362, 0.7664233576642335] [0.552633128082151, 13.779009354072592] [0.31323503289935667, 10.296611530596653]
# Smiles Weight Mean and Std Dev
# 0.68938260509044 0.046155335397908
# Smiles Weight CI
# 0.5689042811319326 0.7643877615641469
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.52810718 12.14707245] [ 2.39912051 53.37759573] [4.54286664 4.39427656]
# (Manually) Weighted RMSE Train
# [ 0.31323503 10.29661153]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.6558915537017727, 0.748696558915537] [0.46604175546249343, 12.025460313953975] [0.3045512057790905, 10.002167405782101]
# Smiles Weight Mean and Std Dev
# 0.6891552686347404 0.0408705068764036
# Smiles Weight CI
# 0.6003790891818069 0.7593466595645606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.57507436 12.27323208] [ 2.33988751 52.25268403] [4.0688434  4.25745099]
# (Manually) Weighted RMSE Train
# [ 0.30455121 10.00216741]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.6684045881126173, 0.762252346193952] [0.47477487024684667, 12.33309381536939] [0.2965730276705629, 9.67778977026417]
# Smiles Weight Mean and Std Dev
# 0.6862296894230704 0.042496735247569174
# Smiles Weight CI
# 0.5919194234818279 0.7480249156793486
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.6296116 12.7956085] [ 2.26528349 50.92249369] [3.5979062  3.97968519]
# (Manually) Weighted RMSE Train
# [0.29657303 9.67778977]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.6642335766423357, 0.7518248175182481] [0.4503312029109437, 11.828077635281188] [0.29013081549309666, 9.406978581726666]
# Smiles Weight Mean and Std Dev
# 0.6837362344486643 0.03914814027013182
# Smiles Weight CI
# 0.5914041235174097 0.7452592255411925
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.69753667 13.53634012] [ 2.1973131  49.48520315] [3.15010405 3.65572989]
# (Manually) Weighted RMSE Train
# [0.29013082 9.40697858]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.6631908237747653, 0.7601668404588112] [0.4403922870624834, 12.166284770950721] [0.2831000138381072, 9.131331215107394]
# Smiles Weight Mean and Std Dev
# 0.6826856647351814 0.03809098929686358
# Smiles Weight CI
# 0.5923402106747271 0.7530400792403854
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.76313808 14.41685346] [ 2.12896083 48.3913922 ] [2.78974523 3.35658487]
# (Manually) Weighted RMSE Train
# [0.28310001 9.13133122]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.6527632950990615, 0.7507820646506778] [0.4204810497480895, 11.677461199572777] [0.27884960784750057, 8.86896302100112]
# Smiles Weight Mean and Std Dev
# 0.680118160522817 0.03919908717574421
# Smiles Weight CI
# 0.6057790600908141 0.7462770490705626
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8186495  15.24020558] [ 2.08972598 47.13106108] [2.55265041 3.09254759]
# (Manually) Weighted RMSE Train
# [0.27884961 8.86896302]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.6454640250260688, 0.762252346193952] [0.40091540711580437, 11.898328059056082] [0.27565954443889723, 8.613288337189111]
# Smiles Weight Mean and Std Dev
# 0.6768544505584082 0.03818860019846515
# Smiles Weight CI
# 0.602709229737682 0.7454149288920008
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87751291 16.43044082] [ 2.04497203 45.99878768] [2.33041818 2.79960764]
# (Manually) Weighted RMSE Train
# [0.27565954 8.61328834]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.670490093847758, 0.7935349322210636] [0.42942893657731196, 12.414118712742622] [0.2711972488037081, 8.379634181913309]
# Smiles Weight Mean and Std Dev
# 0.6701384534671195 0.042021278626055605
# Smiles Weight CI
# 0.5671138411414688 0.7486373749193627
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.93114304 17.68698973] [ 1.99903998 44.64083043] [2.14686668 2.52393602]
# (Manually) Weighted RMSE Train
# [0.27119725 8.37963418]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.6412930135557873, 0.7643378519290928] [0.4084790036772969, 11.780397714776147] [0.2703787268648514, 8.124433965158607]
# Smiles Weight Mean and Std Dev
# 0.6657685116868978 0.038960288686041455
# Smiles Weight CI
# 0.5822287116201882 0.7229778443385968
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.96970419 18.93574554] [ 1.9765409  43.40017935] [2.03829262 2.29197098]
# (Manually) Weighted RMSE Train
# [0.27037873 8.12443397]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.643378519290928, 0.7601668404588112] [0.4067058976327713, 11.656363211422022] [0.26742392081570393, 7.93515550089839]
# Smiles Weight Mean and Std Dev
# 0.6600975520999516 0.041868518854676594
# Smiles Weight CI
# 0.5665388069808129 0.7220084261769416
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00981385 20.14783173] [ 1.94842552 41.94898109] [1.9294898  2.08205933]
# (Manually) Weighted RMSE Train
# [0.26742392 7.9351555 ]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.6235662148070907, 0.7090719499478624] [0.3769350978389662, 10.397109317964206] [0.26900229153617866, 7.765346627454815]
# Smiles Weight Mean and Std Dev
# 0.6634089424506268 0.03604204359223711
# Smiles Weight CI
# 0.5938139494997655 0.7175590701955659
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.03491246 21.08955679] [ 1.94362484 41.04448605] [1.87805724 1.94619956]
# (Manually) Weighted RMSE Train
# [0.26900229 7.76534663]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.6496350364963503, 0.7466110531803962] [0.4104997411684921, 11.4941385362622] [0.2668903105051925, 7.591867327046314]
# Smiles Weight Mean and Std Dev
# 0.6588872248797726 0.04225184983829003
# Smiles Weight CI
# 0.5564142119677544 0.7255358134347596
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08072407 22.27446837] [ 1.90421851 39.90747391] [1.76198399 1.79162408]
# (Manually) Weighted RMSE Train
# [0.26689031 7.59186733]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.6465067778936392, 0.7507820646506778] [0.40615702489133104, 11.428768935654343] [0.26481310228950655, 7.416026002181018]
# Smiles Weight Mean and Std Dev
# 0.6548739728298234 0.04187026374879873
# Smiles Weight CI
# 0.563327609643395 0.7233085748820199
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.11156065 23.50707134] [ 1.8789342  38.79886619] [1.69035689 1.65051893]
# (Manually) Weighted RMSE Train
# [0.2648131 7.416026 ]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.6235662148070907, 0.7299270072992701] [0.37857620342039244, 11.014185789580239] [0.2643194073985355, 7.255782374555733]
# Smiles Weight Mean and Std Dev
# 0.655853696085404 0.03906023819218794
# Smiles Weight CI
# 0.5806824527615337 0.7257393885073892
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13315748 24.5580968 ] [ 1.86879256 37.99380281] [1.64919051 1.54709883]
# (Manually) Weighted RMSE Train
# [0.26431941 7.25578237]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.6454640250260688, 0.7330552659019812] [0.40395041337318155, 11.175238912179417] [0.2625659064693873, 7.118618532588595]
# Smiles Weight Mean and Std Dev
# 0.6492159774856235 0.04181420660617126
# Smiles Weight CI
# 0.5575304262172093 0.7228269470145798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1752849  25.85078491] [ 1.83128711 36.95749113] [1.55816442 1.42964677]
# (Manually) Weighted RMSE Train
# [0.26256591 7.11861853]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.6381647549530761, 0.7580813347236705] [0.40941892424781356, 12.148343634328333] [0.2636505896001154, 6.9922632211658495]
# Smiles Weight Mean and Std Dev
# 0.6539024903290896 0.040500666828214724
# Smiles Weight CI
# 0.5440259551002039 0.7168933004772431
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.193002   26.65719288] [ 1.82592376 36.34773135] [1.53052867 1.36352434]
# (Manually) Weighted RMSE Train
# [0.26365059 6.99226322]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.616266944734098, 0.7403545359749739] [0.38532085731148336, 11.69596663026036] [0.26396001019885024, 6.878795390669361]
# Smiles Weight Mean and Std Dev
# 0.6528096068503838 0.04021410882671587
# Smiles Weight CI
# 0.548695450517511 0.7149404972556512
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21446158 27.64206103] [ 1.8130424  35.62566109] [1.49287753 1.28882072]
# (Manually) Weighted RMSE Train
# [0.26396001 6.87879539]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.5954118873826904, 0.7194994786235662] [0.37068696063417783, 10.921156281588974] [0.2656715365340158, 6.791092662416135]
# Smiles Weight Mean and Std Dev
# 0.6554774813071539 0.03652301837501707
# Smiles Weight CI
# 0.5671589984461378 0.7187660258671642
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22768048 28.26932799] [ 1.80953118 35.20387773] [1.47394311 1.24530296]
# (Manually) Weighted RMSE Train
# [0.26567154 6.79109266]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7184567257559958] [0.37711686544118245, 11.125725945595502] [0.26376392777911606, 6.696420880344651]
# Smiles Weight Mean and Std Dev
# 0.65260557192263 0.03769892776874429
# Smiles Weight CI
# 0.5581601056793143 0.7159242525657505
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24835645 29.04805354] [ 1.79038323 34.52009125] [1.43419232 1.18837881]
# (Manually) Weighted RMSE Train
# [0.26376393 6.69642088]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.6058394160583942, 0.7257559958289885] [0.3802003401087423, 11.522755223753379] [0.2629785732182944, 6.641962625645394]
# Smiles Weight Mean and Std Dev
# 0.6510221916335812 0.039366543129507256
# Smiles Weight CI
# 0.5548917122758177 0.7117360156344338
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26939144 29.69889055] [ 1.77201009 34.06386411] [1.39595245 1.1469743 ]
# (Manually) Weighted RMSE Train
# [0.26297857 6.64196263]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.5870698644421272, 0.7069864442127216] [0.3656922915893599, 10.817477059338266] [0.2613038498483087, 6.56119188111624]
# Smiles Weight Mean and Std Dev
# 0.6461350338699374 0.03616934946572528
# Smiles Weight CI
# 0.561614338651663 0.7091660321997467
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29184572 30.43248861] [ 1.75065889 33.44256227] [1.35516096 1.09890988]
# (Manually) Weighted RMSE Train
# [0.26130385 6.56119188]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.5808133472367049, 0.7038581856100105] [0.36452137456020905, 11.108901237656172] [0.2614860838805445, 6.507648001020326]
# Smiles Weight Mean and Std Dev
# 0.6470838263087205 0.03684288659047142
# Smiles Weight CI
# 0.5651003832338196 0.7117050653601872
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.30428888 30.96823582] [ 1.74266775 33.05061047] [1.33610565 1.06724228]
# (Manually) Weighted RMSE Train
# [0.26148608 6.507648  ]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.6120959332638165, 0.7445255474452555] [0.3962661595817863, 12.371973351269743] [0.2627766375256251, 6.455750213117368]
# Smiles Weight Mean and Std Dev
# 0.6493474787168082 0.04314928673289264
# Smiles Weight CI
# 0.5468690588403569 0.7273649127859304
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31179957 31.41830756] [ 1.73960066 32.71028216] [1.32611772 1.04112171]
# (Manually) Weighted RMSE Train
# [0.26277664 6.45575021]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.708029197080292] [0.36417127735095145, 11.48157234565276] [0.26086663993081094, 6.380122552943625]
# Smiles Weight Mean and Std Dev
# 0.6458166637705337 0.03725746869250357
# Smiles Weight CI
# 0.5659154806614957 0.7065831505477259
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32975586 32.05957088] [ 1.72164514 32.1422093 ] [1.29470769 1.00257765]
# (Manually) Weighted RMSE Train
# [0.26086664 6.38012255]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7424400417101147] [0.384932308314717, 12.344365358419106] [0.25947548804719006, 6.32603285380546]
# Smiles Weight Mean and Std Dev
# 0.6419550411116957 0.03903636724138331
# Smiles Weight CI
# 0.5559254959751307 0.7165723186968794
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34748907 32.6010986 ] [ 1.70337192 31.65996507] [1.26410815 0.97113185]
# (Manually) Weighted RMSE Train
# [0.25947549 6.32603285]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.5891553701772679, 0.7340980187695516] [0.38337021055817794, 12.45280648660897] [0.25983307312489357, 6.2943027879576094]
# Smiles Weight Mean and Std Dev
# 0.6446276646919464 0.03919073869891155
# Smiles Weight CI
# 0.5496913558115699 0.7069158815174066
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35173993 32.94123854] [ 1.69982954 31.49332048] [1.25751227 0.95604543]
# (Manually) Weighted RMSE Train
# [0.25983307 6.29430279]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.5974973931178311, 0.7403545359749739] [0.3824914655674758, 12.495061370888148] [0.25817071570507877, 6.246037815079154]
# Smiles Weight Mean and Std Dev
# 0.6414794238779571 0.04057888361364408
# Smiles Weight CI
# 0.5584206671968137 0.7091891744651878
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36518929 33.44151004] [ 1.68487524 31.15544816] [1.23416969 0.93163999]
# (Manually) Weighted RMSE Train
# [0.25817072 6.24603782]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.5891553701772679, 0.7393117831074035] [0.37451082861495916, 12.180731132453195] [0.2601208531536, 6.226473177534695]
# Smiles Weight Mean and Std Dev
# 0.6458870517937922 0.03799757281251845
# Smiles Weight CI
# 0.5523585399671499 0.7186600568756787
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36825551 33.74562078] [ 1.6873705  31.02676198] [1.23322763 0.91943077]
# (Manually) Weighted RMSE Train
# [0.26012085 6.22647318]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.7288842544316997] [0.3712803090804775, 11.988907158774465] [0.2564226800606141, 6.177420700804921]
# Smiles Weight Mean and Std Dev
# 0.6389402100056952 0.039700342395329144
# Smiles Weight CI
# 0.5520812131266954 0.7053068615740108
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38901912 34.30397771] [ 1.66274501 30.44684195] [1.19706417 0.8875601 ]
# (Manually) Weighted RMSE Train
# [0.25642268 6.1774207 ]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.5610010427528676, 0.7226277372262774] [0.3443310837950346, 11.51179506257142] [0.25788217829536453, 6.152738168858448]
# Smiles Weight Mean and Std Dev
# 0.644231916799174 0.035276331958538285
# Smiles Weight CI
# 0.5659560642306216 0.7083763402503537
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38653778 34.49807372] [ 1.66836716 30.46776855] [1.20326123 0.88317304]
# (Manually) Weighted RMSE Train
# [0.25788218 6.15273817]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.5818561001042752, 0.7226277372262774] [0.36514904705184364, 12.305962588580892] [0.2565417853524011, 6.105603932284879]
# Smiles Weight Mean and Std Dev
# 0.6410105283279328 0.04105302361244041
# Smiles Weight CI
# 0.5524979481531631 0.7040104846819721
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40313484 34.87505519] [ 1.65082718 30.15141236] [1.17652782 0.86455526]
# (Manually) Weighted RMSE Train
# [0.25654179 6.10560393]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.5599582898852972, 0.721584984358707] [0.3474623979228213, 11.714725421548193] [0.25689305510876853, 6.070520886875944]
# Smiles Weight Mean and Std Dev
# 0.6414997660043658 0.0363731558282557
# Smiles Weight CI
# 0.5605215576424332 0.7124264410914931
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4107303  35.19645496] [ 1.64703147 29.94718539] [1.16750272 0.850858  ]
# (Manually) Weighted RMSE Train
# [0.25689306 6.07052089]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.5578727841501564, 0.7049009384775808] [0.343012585758502, 11.370202412174873] [0.259398758437382, 6.0838098692998726]
# Smiles Weight Mean and Std Dev
# 0.6464529234501406 0.0370983203611702
# Smiles Weight CI
# 0.5639460526187063 0.7042151302600042
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41026512 35.41452913] [ 1.65133296 30.04130055] [1.17093795 0.84827615]
# (Manually) Weighted RMSE Train
# [0.25939876 6.08380987]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.5464025026068822, 0.6903023983315955] [0.33064429531634143, 11.01013647778906] [0.2576965389936237, 6.037829202398043]
# Smiles Weight Mean and Std Dev
# 0.6435399270164038 0.03535812898462113
# Smiles Weight CI
# 0.5702506573970658 0.702768006130604
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42390966 35.74123662] [ 1.63584298 29.734294  ] [1.14883902 0.83193243]
# (Manually) Weighted RMSE Train
# [0.25769654 6.0378292 ]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.5787278415015641, 0.7288842544316997] [0.3633094967003013, 12.82445353205247] [0.2555969309926168, 6.021881906291018]
# Smiles Weight Mean and Std Dev
# 0.6409032792521969 0.03875225746466094
# Smiles Weight CI
# 0.5418589950501287 0.7058616335286527
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4369177  36.07974891] [ 1.62052764 29.52562083] [1.12778042 0.8183433 ]
# (Manually) Weighted RMSE Train
# [0.25559693 6.02188191]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7278415015641293] [0.38432508662552756, 13.520892484346696] [0.257702588169172, 6.016908731070894]
# Smiles Weight Mean and Std Dev
# 0.64377028864517 0.04001689133133072
# Smiles Weight CI
# 0.5478915973610498 0.7077899154728509
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44104294 36.26390365] [ 1.62338461 29.49080335] [1.12653452 0.81322749]
# (Manually) Weighted RMSE Train
# [0.25770259 6.01690873]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.7257559958289885] [0.35746282720849376, 12.098772705289571] [0.25319499418377345, 5.961503845232767]
# Smiles Weight Mean and Std Dev
# 0.6366816380306892 0.038990876482508055
# Smiles Weight CI
# 0.5563256254037832 0.7047259505116861
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46147886 36.62058976] [ 1.59532817 29.09693053] [1.09158484 0.79455112]
# (Manually) Weighted RMSE Train
# [0.25319499 5.96150385]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.5724713242961418, 0.7163712200208551] [0.35054814438292997, 11.865841442369916] [0.2549239538514047, 5.94595144644819]
# Smiles Weight Mean and Std Dev
# 0.6395247892787089 0.03650823234489529
# Smiles Weight CI
# 0.5691090211095992 0.6991994989322329
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46464315 36.80045903] [ 1.59773847 29.11834509] [1.09087218 0.79124951]
# (Manually) Weighted RMSE Train
# [0.25492395 5.94595145]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.59436913451512, 0.7309697601668405] [0.3728771625805012, 13.125638071656573] [0.2564572309739268, 5.944558314927595]
# Smiles Weight Mean and Std Dev
# 0.6416730559097976 0.04099501142894738
# Smiles Weight CI
# 0.5560706072023226 0.7120789364384269
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46811305 36.96631029] [ 1.59765411 29.16579703] [1.08823643 0.78898318]
# (Manually) Weighted RMSE Train
# [0.25645723 5.94455831]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.5776850886339937, 0.7267987486965589] [0.34831306375122634, 12.592819042280311] [0.25579092889825605, 5.916833536592256]
# Smiles Weight Mean and Std Dev
# 0.6406346229993151 0.03762255107109248
# Smiles Weight CI
# 0.5507729637651491 0.6983363561679178
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47877442 37.19949868] [ 1.58656414 29.08567073] [1.07289125 0.78188341]
# (Manually) Weighted RMSE Train
# [0.25579093 5.91683354]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7299270072992701] [0.3667928944724718, 12.757055007822919] [0.25281970781663055, 5.877081110081469]
# Smiles Weight Mean and Std Dev
# 0.6360384742077358 0.04039830163696404
# Smiles Weight CI
# 0.5402869312892651 0.699516142966189
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48964574 37.48553045] [ 1.56949812 28.75377867] [1.05360494 0.76706341]
# (Manually) Weighted RMSE Train
# [0.25281971 5.87708111]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.5912408759124088, 0.7413972888425443] [0.3672287626464484, 13.48989239600442] [0.25510943709492834, 5.874083085025159]
# Smiles Weight Mean and Std Dev
# 0.6398462671466336 0.04029089634390571
# Smiles Weight CI
# 0.545132878949617 0.7052745384224114
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.49032234 37.65278817] [ 1.57467615 28.83135502] [1.05660105 0.76571634]
# (Manually) Weighted RMSE Train
# [0.25510944 5.87408309]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.5693430656934306, 0.7413972888425443] [0.347641229197667, 12.926566030815447] [0.2525277700990144, 5.836345729960891]
# Smiles Weight Mean and Std Dev
# 0.6363513414973001 0.039310336758998754
# Smiles Weight CI
# 0.540387078510591 0.6941465457298981
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50230371 37.96151107] [ 1.5590808 28.562475 ] [1.03779334 0.75240617]
# (Manually) Weighted RMSE Train
# [0.25252777 5.83634573]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.5808133472367049, 0.7340980187695516] [0.359453428283794, 13.20056966620331] [0.2550190947514532, 5.8395165363253945]
# Smiles Weight Mean and Std Dev
# 0.6400098074433506 0.0385047556434849
# Smiles Weight CI
# 0.5532169059191753 0.7022779748303865
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50455761 38.12907535] [ 1.56269325 28.62725449] [1.03863969 0.75079855]
# (Manually) Weighted RMSE Train
# [0.25501909 5.83951654]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.7288842544316997] [0.3705331267720974, 13.1535922264333] [0.25337846284637405, 5.8096624123716625]
# Smiles Weight Mean and Std Dev
# 0.6379186694359117 0.03794982861205802
# Smiles Weight CI
# 0.5551837243798523 0.7004563003016291
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51234465 38.37464814] [ 1.55272118 28.4348654 ] [1.02669797 0.74098049]
# (Manually) Weighted RMSE Train
# [0.25337846 5.80966241]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.7340980187695516] [0.3515252066892067, 12.946609294862371] [0.2538496206064346, 5.813323460825139]
# Smiles Weight Mean and Std Dev
# 0.6388066034788297 0.03598488886645006
# Smiles Weight CI
# 0.5579618475254048 0.6999310119107456
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51561567 38.52364585] [ 1.54995853 28.44405268] [1.02265935 0.73835308]
# (Manually) Weighted RMSE Train
# [0.25384962 5.81332346]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.7393117831074035] [0.3712150684964633, 13.866088744802944] [0.25468733495080964, 5.814625658058363]
# Smiles Weight Mean and Std Dev
# 0.6398184411312351 0.03773734579625291
# Smiles Weight CI
# 0.5465267403383266 0.6983006336813166
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5237955  38.64884659] [ 1.54319584 28.47624633] [1.01273158 0.73679421]
# (Manually) Weighted RMSE Train
# [0.25468733 5.81462566]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.735140771637122] [0.3612917941537545, 13.071864357002125] [0.25124515072409864, 5.770488581727961]
# Smiles Weight Mean and Std Dev
# 0.6353518521156001 0.03724387292163909
# Smiles Weight CI
# 0.5549628708641047 0.7055679641845499
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53533574 38.92523187] [ 1.5252555  28.20224082] [0.99343451 0.72452339]
# (Manually) Weighted RMSE Train
# [0.25124515 5.77048858]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.583941605839416, 0.7466110531803962] [0.3726581682852233, 13.69205747480309] [0.25186524975643915, 5.756985951323668]
# Smiles Weight Mean and Std Dev
# 0.6357325674451634 0.038731255280074414
# Smiles Weight CI
# 0.5482125342739591 0.7054051320253714
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53930481 39.09187722] [ 1.52405082 28.18271491] [0.99009034 0.72093532]
# (Manually) Weighted RMSE Train
# [0.25186525 5.75698595]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.5610010427528676, 0.7455683003128258] [0.35074260367614285, 13.257156367978697] [0.2540908886994028, 5.770407620527735]
# Smiles Weight Mean and Std Dev
# 0.6391912975936495 0.03622131484073068
# Smiles Weight CI
# 0.5606007085633838 0.7038543531094696
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53739083 39.21371449] [ 1.5295502  28.24345976] [0.99490004 0.72024444]
# (Manually) Weighted RMSE Train
# [0.25409089 5.77040762]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.570385818561001, 0.7445255474452555] [0.3516582639157967, 13.625913135025367] [0.24864332453909876, 5.718203332700319]
# Smiles Weight Mean and Std Dev
# 0.6319376475197562 0.03747248717873173
# Smiles Weight CI
# 0.545055743865264 0.6930234863481582
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55363867 39.50416481] [ 1.50360695 27.94987404] [0.96779707 0.70751715]
# (Manually) Weighted RMSE Train
# [0.24864332 5.71820333]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.5683003128258602, 0.7361835245046924] [0.35889211497056256, 13.061915090074715] [0.2531219140082623, 5.725226931207147]
# Smiles Weight Mean and Std Dev
# 0.6376230837822995 0.03802066014997242
# Smiles Weight CI
# 0.5519568439589769 0.7007138956078388
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55170859 39.53668935] [ 1.51492379 28.15134976] [0.976294   0.71203103]
# (Manually) Weighted RMSE Train
# [0.25312191 5.72522693]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.5735140771637122, 0.7528675703858185] [0.35910633506907236, 13.817443603307094] [0.2512575440280201, 5.692085388002633]
# Smiles Weight Mean and Std Dev
# 0.6349698551343422 0.0402219087800707
# Smiles Weight CI
# 0.5551659562763511 0.7032326289812539
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56013861 39.70965471] [ 1.50408406 28.02756163] [0.96407079 0.70581227]
# (Manually) Weighted RMSE Train
# [0.25125754 5.69208539]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.5557872784150156, 0.7330552659019812] [0.33820244553584133, 13.004245488034549] [0.25409925569762526, 5.7287007199989315]
# Smiles Weight Mean and Std Dev
# 0.6390995572212207 0.03648220262936398
# Smiles Weight CI
# 0.544134801886553 0.6932743538871997
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55922226 39.82251739] [ 1.50975468 28.12413671] [0.9682742  0.70623704]
# (Manually) Weighted RMSE Train
# [0.25409926 5.72870072]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.5630865484880083, 0.7278415015641293] [0.3493278234772204, 13.068908359229056] [0.2512613970887713, 5.6733429172970835]
# Smiles Weight Mean and Std Dev
# 0.6352727952062479 0.03610216204837184
# Smiles Weight CI
# 0.5546768691259277 0.694204675712798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57172606 40.01591386] [ 1.49301658 27.91217076] [0.94992163 0.69752676]
# (Manually) Weighted RMSE Train
# [0.2512614  5.67334292]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7580813347236705] [0.3813725353232106, 14.45315105487948] [0.24917667180702663, 5.648901514066439]
# Smiles Weight Mean and Std Dev
# 0.6319325328742987 0.03924196647636681
# Smiles Weight CI
# 0.5303152767453156 0.7000815948398851
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58229146 40.20509906] [ 1.47813597 27.77288585] [0.93417427 0.69078019]
# (Manually) Weighted RMSE Train
# [0.24917667 5.64890151]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.7664233576642335] [0.38039423061240146, 14.768185433697829] [0.24942294344313923, 5.633072873649184]
# Smiles Weight Mean and Std Dev
# 0.6326402012521295 0.03826447753942315
# Smiles Weight CI
# 0.5438366135112693 0.7070431585883749
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58718262 40.39427337] [ 1.47360979 27.75955885] [0.92844376 0.6872152 ]
# (Manually) Weighted RMSE Train
# [0.24942294 5.63307287]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.5828988529718456, 0.7643378519290928] [0.38202715204025117, 14.737915897370591] [0.2549562451581384, 5.675033181042126]
# Smiles Weight Mean and Std Dev
# 0.639174541488985 0.03945927601287181
# Smiles Weight CI
# 0.5437024410641318 0.7029362354173646
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58319261 40.40850996] [ 1.48631089 27.92444826] [0.93880611 0.69105365]
# (Manually) Weighted RMSE Train
# [0.25495625 5.67503318]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.7685088633993743] [0.3825373291864962, 14.89931517298029] [0.25838576432212385, 5.729924850084388]
# Smiles Weight Mean and Std Dev
# 0.6421150745138712 0.03790361886387024
# Smiles Weight CI
# 0.5536323315963757 0.7190923352603105
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58497532 40.48793144] [ 1.49104173 28.03188032] [0.94073498 0.69235151]
# (Manually) Weighted RMSE Train
# [0.25838576 5.72992485]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.6037539103232534, 0.7872784150156413] [0.4064115095868589, 16.36501180616842] [0.249560341733311, 5.615650588485213]
# Smiles Weight Mean and Std Dev
# 0.6318359443245625 0.04253278109295946
# Smiles Weight CI
# 0.5217645143311737 0.7079306159485995
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60716259 40.73591973] [ 1.45633322 27.69599528] [0.90615177 0.67989125]
# (Manually) Weighted RMSE Train
# [0.24956034 5.61565059]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.5620437956204379, 0.7413972888425443] [0.3501012770589321, 13.490830113586979] [0.2549615186768419, 5.6449275612374015]
# Smiles Weight Mean and Std Dev
# 0.6383068529088577 0.03803074202665424
# Smiles Weight CI
# 0.5562186889313822 0.698245561691135
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60239628 40.78826425] [ 1.46985925 27.87288815] [0.91728823 0.68335558]
# (Manually) Weighted RMSE Train
# [0.25496152 5.64492756]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.5870698644421272, 0.7778936392075079] [0.3896217438744787, 15.309457675798784] [0.251673524364272, 5.600649548074765]
# Smiles Weight Mean and Std Dev
# 0.6346300220727574 0.040652711708067855
# Smiles Weight CI
# 0.5318377174185039 0.6955429924556602
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.61419413 40.94545807] [ 1.45388163 27.72984303] [0.90068574 0.67723856]
# (Manually) Weighted RMSE Train
# [0.25167352 5.60064955]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.5776850886339937, 0.7685088633993743] [0.37613904909529217, 14.984640834776577] [0.25244282220991804, 5.591608060097383]
# Smiles Weight Mean and Std Dev
# 0.6350175755317903 0.03957457160947169
# Smiles Weight CI
# 0.5404184463813861 0.6984391980048912
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.61742862 41.07078645] [ 1.45249502 27.68169469] [0.89802728 0.67399963]
# (Manually) Weighted RMSE Train
# [0.25244282 5.59160806]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.570385818561001, 0.762252346193952] [0.37438309162346717, 14.30261826583324] [0.25036801729710256, 5.570807456642655]
# Smiles Weight Mean and Std Dev
# 0.6329714408376463 0.036594019359216814
# Smiles Weight CI
# 0.5517967916099523 0.6998562267133094
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62414379 41.22994715] [ 1.44189495 27.56393672] [0.88778774 0.66854165]
# (Manually) Weighted RMSE Train
# [0.25036802 5.57080746]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.5683003128258602, 0.7497393117831074] [0.36358862230106326, 14.131013384554103] [0.2497467059602872, 5.561591503054788]
# Smiles Weight Mean and Std Dev
# 0.6318322213121783 0.03808165648775053
# Smiles Weight CI
# 0.5588511081611062 0.7005720731312469
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63156749 41.36274986] [ 1.4344537  27.50569943] [0.87918748 0.66498721]
# (Manually) Weighted RMSE Train
# [0.24974671 5.5615915 ]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.543274244004171, 0.7497393117831074] [0.34830497377640435, 13.819180630796202] [0.2563871905144911, 5.618236777697196]
# Smiles Weight Mean and Std Dev
# 0.6387260253970675 0.03593798280749228
# Smiles Weight CI
# 0.5613096112583066 0.7094569425291845
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62649725 41.41177443] [ 1.45035529 27.73108822] [0.89170473 0.6696426 ]
# (Manually) Weighted RMSE Train
# [0.25638719 5.61823678]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.5714285714285714, 0.7528675703858185] [0.3599209183159938, 14.261851766351228] [0.25074224752231566, 5.553454518600267]
# Smiles Weight Mean and Std Dev
# 0.633094193899965 0.03918847172879744
# Smiles Weight CI
# 0.5483758601415959 0.7011854811032452
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63917304 41.60003952] [ 1.42795874 27.53735259] [0.87114582 0.66195496]
# (Manually) Weighted RMSE Train
# [0.25074225 5.55345452]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.5380604796663191, 0.7466110531803962] [0.3402278905077187, 13.326590387765169] [0.2524260954982304, 5.550130331417841]
# Smiles Weight Mean and Std Dev
# 0.6348038078914201 0.03625136058630217
# Smiles Weight CI
# 0.557587644591798 0.6925335462647364
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.64214499 41.69685665] [ 1.42830057 27.5715879 ] [0.86977738 0.661239  ]
# (Manually) Weighted RMSE Train
# [0.2524261  5.55013033]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.5818561001042752, 0.7612095933263816] [0.36473795352772237, 14.193064730429876] [0.25083029432064785, 5.5269692796161936]
# Smiles Weight Mean and Std Dev
# 0.6334866139387737 0.03800277490577626
# Smiles Weight CI
# 0.5508602896599901 0.6982911348007906
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.64696269 41.80667094] [ 1.42165936 27.43961569] [0.86320071 0.65634539]
# (Manually) Weighted RMSE Train
# [0.25083029 5.52696928]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7831074035453598] [0.4046785423668733, 16.03860963703306] [0.25167923528307135, 5.520509246788752]
# Smiles Weight Mean and Std Dev
# 0.6343557934790722 0.04048289364842327
# Smiles Weight CI
# 0.5253810114303918 0.6998724430199046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.65053043 41.90175276] [ 1.42011854 27.43266958] [0.86040131 0.65469026]
# (Manually) Weighted RMSE Train
# [0.25167924 5.52050925]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.5401459854014599, 0.7382690302398331] [0.34300935046395326, 13.03295826978252] [0.2543731916830382, 5.548567318565053]
# Smiles Weight Mean and Std Dev
# 0.6371313054423564 0.03787378603982916
# Smiles Weight CI
# 0.5606800281862974 0.6982329461817851
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6523453  41.95209225] [ 1.42310828 27.53587636] [0.86126567 0.65636479]
# (Manually) Weighted RMSE Train
# [0.25437319 5.54856732]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.5370177267987487, 0.7361835245046924] [0.3403697893492279, 13.372911419356415] [0.25297499357717446, 5.523251080381948]
# Smiles Weight Mean and Std Dev
# 0.6359243074033313 0.03388561425516073
# Smiles Weight CI
# 0.5610949645533215 0.6977603641494119
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.65951697 42.06025219] [ 1.41417352 27.4327166 ] [0.85215972 0.65222425]
# (Manually) Weighted RMSE Train
# [0.25297499 5.52325108]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.5693430656934306, 0.7539103232533889] [0.3658022754885372, 14.213382310379394] [0.25068502982010193, 5.497821105646628]
# Smiles Weight Mean and Std Dev
# 0.633905670690743 0.03694698248901046
# Smiles Weight CI
# 0.5493699221456048 0.6967622312365509
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.66831336 42.19772397] [ 1.40265671 27.35445402] [0.84076334 0.64824477]
# (Manually) Weighted RMSE Train
# [0.25068503 5.49782111]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.7653806047966631] [0.3734261588216917, 14.554505102968678] [0.2542157055564257, 5.519093605274468]
# Smiles Weight Mean and Std Dev
# 0.6371938765200323 0.037484179071910005
# Smiles Weight CI
# 0.5512212248325954 0.6976913002878832
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.66621047 42.26748476] [ 1.40977683 27.35034542] [0.84609769 0.64707767]
# (Manually) Weighted RMSE Train
# [0.25421571 5.51909361]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.5766423357664233, 0.7559958289885297] [0.3642513329482914, 14.171796100187247] [0.2518710611732796, 5.491874702476676]
# Smiles Weight Mean and Std Dev
# 0.6348848875054941 0.0395277723282316
# Smiles Weight CI
# 0.5439039585433425 0.6887614794378174
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67400194 42.39146139] [ 1.39951681 27.3012935 ] [0.83603058 0.64402813]
# (Manually) Weighted RMSE Train
# [0.25187106 5.4918747 ]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.556830031282586, 0.7455683003128258] [0.35157590614376544, 13.72874515508735] [0.25210913795705475, 5.485238355475785]
# Smiles Weight Mean and Std Dev
# 0.6354715145828239 0.034961956749772365
# Smiles Weight CI
# 0.5587003900384045 0.69453523206176
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67663226 42.50446223] [ 1.39735099 27.27589643] [0.83342723 0.64171842]
# (Manually) Weighted RMSE Train
# [0.25210914 5.48523836]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.5495307612095933, 0.7445255474452555] [0.35093972014403213, 13.463974695424156] [0.25453521146698865, 5.497408439393653]
# Smiles Weight Mean and Std Dev
# 0.6373231602303417 0.036501536270021284
# Smiles Weight CI
# 0.5643817581089904 0.7010140371053428
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67874726 42.6050055 ] [ 1.39958658 27.3151327 ] [0.83370893 0.64112497]
# (Manually) Weighted RMSE Train
# [0.25453521 5.49740844]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.5526590198123045, 0.7413972888425443] [0.35287133548229455, 13.656293969387583] [0.2520828135248531, 5.46382766225189]
# Smiles Weight Mean and Std Dev
# 0.6349958573950715 0.0366037064954258
# Smiles Weight CI
# 0.5596178667492293 0.700552398515157
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6869181  42.70742844] [ 1.38806031 27.23479704] [0.822838   0.63770632]
# (Manually) Weighted RMSE Train
# [0.25208281 5.46382766]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.5755995828988529, 0.7758081334723671] [0.3914310113934424, 15.53520465796756] [0.25249911192434493, 5.466338948574885]
# Smiles Weight Mean and Std Dev
# 0.635606922274754 0.03747025086634311
# Smiles Weight CI
# 0.5429273597274799 0.7046733674962843
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.68871703 42.81320622] [ 1.38709028 27.23661662] [0.82138704 0.63617325]
# (Manually) Weighted RMSE Train
# [0.25249911 5.46633895]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.5808133472367049, 0.7695516162669447] [0.3963795471209369, 15.503324866601055] [0.24724534726319328, 5.445471774565267]
# Smiles Weight Mean and Std Dev
# 0.6299225015857902 0.038704706168837026
# Smiles Weight CI
# 0.5360977689349598 0.6902433205947394
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.69964685 42.97950121] [ 1.36704974 27.05449018] [0.80431399 0.62947427]
# (Manually) Weighted RMSE Train
# [0.24724535 5.44547177]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.5620437956204379, 0.7705943691345151] [0.3681711265289705, 15.288164060981723] [0.25389790636034276, 5.465872407214731]
# Smiles Weight Mean and Std Dev
# 0.6365948574112149 0.0379339837384995
# Smiles Weight CI
# 0.5485481044574531 0.7027846981739728
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.69272323 43.02065934] [ 1.3851233  27.17592183] [0.81828103 0.63169468]
# (Manually) Weighted RMSE Train
# [0.25389791 5.46587241]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.5881126173096975, 0.7768508863399375] [0.397638375818852, 15.669878595517423] [0.24591601947903674, 5.442259272003595]
# Smiles Weight Mean and Std Dev
# 0.6286597138284659 0.040224883816378745
# Smiles Weight CI
# 0.5329096262352075 0.697294971347994
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70646091 43.19130829] [ 1.35780637 26.94866815] [0.7956856 0.6239373]
# (Manually) Weighted RMSE Train
# [0.24591602 5.44225927]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.5589155370177268, 0.7570385818561001] [0.36037760432219734, 14.218649991581495] [0.2504720848557731, 5.437626275496787]
# Smiles Weight Mean and Std Dev
# 0.633496617225646 0.03599765216132501
# Smiles Weight CI
# 0.5549358300118854 0.6978217599116731
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70519244 43.22480959] [ 1.36829262 27.08623687] [0.80242709 0.62663635]
# (Manually) Weighted RMSE Train
# [0.25047208 5.43762628]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.570385818561001, 0.7695516162669447] [0.37856990907207727, 15.117233846450246] [0.25146550214230645, 5.44115379314276]
# Smiles Weight Mean and Std Dev
# 0.6343979354166279 0.03738748122928966
# Smiles Weight CI
# 0.5547658648819938 0.7075366259845164
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70691055 43.30856513] [ 1.36899828 27.11633972] [0.80203282 0.62611956]
# (Manually) Weighted RMSE Train
# [0.2514655  5.44115379]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.5620437956204379, 0.7518248175182481] [0.35908235747494094, 14.253140476580263] [0.251767914879659, 5.434173989825154]
# Smiles Weight Mean and Std Dev
# 0.6345673493214576 0.035157927906414
# Smiles Weight CI
# 0.5539267581843066 0.6935469518786241
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70910743 43.40454869] [ 1.3674643  27.08230914] [0.80010435 0.62395094]
# (Manually) Weighted RMSE Train
# [0.25176791 5.43417399]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.602711157455683, 0.7831074035453598] [0.4165727767358159, 16.219929836063475] [0.24944970999198188, 5.422952327280597]
# Smiles Weight Mean and Std Dev
# 0.6325861346904398 0.04243675473488849
# Smiles Weight CI
# 0.5433054048688268 0.7011111287245955
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.71654095 43.48338555] [ 1.35671119 27.01379758] [0.79037508 0.62124412]
# (Manually) Weighted RMSE Train
# [0.24944971 5.42295233]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.5922836287799792, 0.7726798748696558] [0.4114747819840286, 16.306377612235554] [0.2477962346721573, 5.423015295534591]
# Smiles Weight Mean and Std Dev
# 0.6308579346265135 0.03926135176416106
# Smiles Weight CI
# 0.5363887092673547 0.6950106788529986
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72325728 43.54550932] [ 1.34794141 27.01224115] [0.78220555 0.62032209]
# (Manually) Weighted RMSE Train
# [0.24779623 5.4230153 ]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.5849843587069864, 0.7789363920750783] [0.39609642615446294, 15.716265919986483] [0.2506132481748833, 5.423354016314929]
# Smiles Weight Mean and Std Dev
# 0.6334072944353505 0.03945643524786648
# Smiles Weight CI
# 0.549213751738592 0.7015280286875615
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72113725 43.62297549] [ 1.35498032 27.084178  ] [0.78725873 0.62086957]
# (Manually) Weighted RMSE Train
# [0.25061325 5.42335402]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.6037539103232534, 0.7747653806047967] [0.41533379994119807, 16.179633958194763] [0.2482839250428435, 5.418182506342242]
# Smiles Weight Mean and Std Dev
# 0.6316446933240559 0.04067481009690036
# Smiles Weight CI
# 0.5381968954836529 0.6957887459212344
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72723163 43.73123737] [ 1.34560478 27.02601589] [0.77905289 0.61800254]
# (Manually) Weighted RMSE Train
# [0.24828393 5.41818251]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.5922836287799792, 0.7820646506777894] [0.41113691949653386, 16.455016539193156] [0.24854409914861042, 5.415735325527644]
# Smiles Weight Mean and Std Dev
# 0.6319315425317604 0.039799807539415866
# Smiles Weight CI
# 0.5313323567241054 0.6967944792923644
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73046889 43.80346859] [ 1.34315434 27.01033075] [0.77617942 0.61662539]
# (Manually) Weighted RMSE Train
# [0.2485441  5.41573533]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.5651720542231491, 0.7507820646506778] [0.36217172953832966, 14.096995911339432] [0.25623748713336, 5.470525879937604]
# Smiles Weight Mean and Std Dev
# 0.6387032152651472 0.03436499007862681
# Smiles Weight CI
# 0.5595193713453472 0.696622760339906
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72482817 43.81885913] [ 1.36129516 27.12792088] [0.78923523 0.61909236]
# (Manually) Weighted RMSE Train
# [0.25623749 5.47052588]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.5974973931178311, 0.7893639207507821] [0.41860745401840055, 16.831201926502953] [0.2556850361622016, 5.463758839403788]
# Smiles Weight Mean and Std Dev
# 0.6381461135258011 0.03980401286833255
# Smiles Weight CI
# 0.5548272775109578 0.7212365081895427
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72977406 43.90934101] [ 1.35628644 27.12106509] [0.784083   0.61766049]
# (Manually) Weighted RMSE Train
# [0.25568504 5.46375884]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.6183524504692388, 0.7987486965589156] [0.4523631738160752, 18.4270032601331] [0.24807049691576114, 5.409530181377989]
# Smiles Weight Mean and Std Dev
# 0.6310702707121223 0.04201372266313748
# Smiles Weight CI
# 0.5225061747054522 0.7044129897727209
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.74210417 44.04085382] [ 1.33197576 26.93664877] [0.76457871 0.61162867]
# (Manually) Weighted RMSE Train
# [0.2480705  5.40953018]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.5641293013555787, 0.7591240875912408] [0.3743893358896349, 14.63601149763534] [0.25644447911639123, 5.471637189577186]
# Smiles Weight Mean and Std Dev
# 0.6384623845832199 0.035569913828409044
# Smiles Weight CI
# 0.5590991415540847 0.6994206691142979
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73530106 44.02767585] [ 1.3524261  27.12663331] [0.77936107 0.61612685]
# (Manually) Weighted RMSE Train
# [0.25644448 5.47163719]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.5933263816475496, 0.7747653806047967] [0.40772404269234974, 16.485434289268138] [0.2528679383667734, 5.4289282650547825]
# Smiles Weight Mean and Std Dev
# 0.6353787444998484 0.040122433398283114
# Smiles Weight CI
# 0.5373419778195404 0.7038968803433858
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.74290315 44.12404576] [ 1.34001325 27.08652078] [0.76883977 0.6138721 ]
# (Manually) Weighted RMSE Train
# [0.25286794 5.42892827]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.5745568300312826, 0.7716371220020855] [0.3891498375087712, 15.826651961156418] [0.25205630179253613, 5.420100862857386]
# Smiles Weight Mean and Std Dev
# 0.634744696162421 0.03790411084339009
# Smiles Weight CI
# ...
# Smiles Weight CI
# 0.5522909922224213 0.6973527506780035
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87284206 47.12605101] [ 1.19772385 26.2378412 ] [0.63952208 0.55675875]
# (Manually) Weighted RMSE Train
# [0.24124012 5.17166376]
#
#
# epoch number:  169
# Coverages, CI Widths, RMSEs
# [0.656934306569343, 0.8143899895724713] [0.4945323956483578, 20.073427989465827] [0.2459762349779433, 5.2077660858465284]
# Smiles Weight Mean and Std Dev
# 0.638146843575574 0.042790376754919125
# Smiles Weight CI
# 0.5299946761802921 0.7101144538745157
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87027325 47.13297099] [ 1.20927281 26.25563389] [0.64657547 0.55705451]
# (Manually) Weighted RMSE Train
# [0.24597623 5.20776609]
#
#
# epoch number:  170
# Coverages, CI Widths, RMSEs
# [0.6308654848800834, 0.8050052137643379] [0.45670903649014344, 18.22659509939543] [0.2383076113719984, 5.164323716854536]
# Smiles Weight Mean and Std Dev
# 0.6322373223326027 0.040746667805149336
# Smiles Weight CI
# 0.5435179888117072 0.7032692081247397
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87836871 47.1702338 ] [ 1.18615733 26.18453588] [0.63148269 0.55510719]
# (Manually) Weighted RMSE Train
# [0.23830761 5.16432372]
#
#
# epoch number:  171
# Coverages, CI Widths, RMSEs
# [0.5620437956204379, 0.7737226277372263] [0.3847338192435754, 15.049967616304283] [0.24765820727061857, 5.231257898058612]
# Smiles Weight Mean and Std Dev
# 0.6397081007272291 0.03527843726079654
# Smiles Weight CI
# 0.5650919465114657 0.7055656062565362
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87046448 47.16937009] [ 1.21185062 26.23506791] [0.64788754 0.55618864]
# (Manually) Weighted RMSE Train
# [0.24765821 5.2312579 ]
#
#
# epoch number:  172
# Coverages, CI Widths, RMSEs
# [0.5766423357664233, 0.7685088633993743] [0.3897427049956089, 15.50709685513911] [0.2401725617309499, 5.1570480794090185]
# Smiles Weight Mean and Std Dev
# 0.6342074112730851 0.036585866388258156
# Smiles Weight CI
# 0.5612326861600073 0.694707898513474
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87757781 47.20561254] [ 1.19118663 26.15476938] [0.63442731 0.55406059]
# (Manually) Weighted RMSE Train
# [0.24017256 5.15704808]
#
#
# epoch number:  173
# Coverages, CI Widths, RMSEs
# [0.6204379562043796, 0.794577685088634] [0.4438756770938524, 17.325344325685723] [0.2404339832430538, 5.154368996334804]
# Smiles Weight Mean and Std Dev
# 0.6343951667783309 0.04035629326558088
# Smiles Weight CI
# 0.5378376384688339 0.6964564723448762
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87866565 47.2267588 ] [ 1.19101084 26.14794929] [0.63396637 0.55366809]
# (Manually) Weighted RMSE Train
# [0.24043398 5.154369  ]
#
#
# epoch number:  174
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.7737226277372263] [0.41438936420794587, 16.235375491944726] [0.24037241970974355, 5.154811332418334]
# Smiles Weight Mean and Std Dev
# 0.6344880078388511 0.037064791370519365
# Smiles Weight CI
# 0.5454679381720641 0.6919304842450154
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87912652 47.23913995] [ 1.19045114 26.15642505] [0.63351304 0.5537024 ]
# (Manually) Weighted RMSE Train
# [0.24037242 5.15481133]
#
#
# epoch number:  175
# Coverages, CI Widths, RMSEs
# [0.6266944734098019, 0.7924921793534933] [0.4531016766164734, 17.681576782612385] [0.243010800775568, 5.171046603707879]
# Smiles Weight Mean and Std Dev
# 0.6367266395491987 0.04171478402462693
# Smiles Weight CI
# 0.5374905377423776 0.7006953161055695
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87790841 47.26631362] [ 1.19707649 26.1427082 ] [0.63745201 0.55309387]
# (Manually) Weighted RMSE Train
# [0.2430108 5.1710466]
#
#
# epoch number:  176
# Coverages, CI Widths, RMSEs
# [0.5693430656934306, 0.7664233576642335] [0.3919163650422532, 15.158946953476828] [0.2475704141660122, 5.228300756993455]
# Smiles Weight Mean and Std Dev
# 0.6401567285679238 0.03547361510111715
# Smiles Weight CI
# 0.5663755658410525 0.7048445058112052
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87414769 47.28998367] [ 1.20859478 26.17370277] [0.64487702 0.55347244]
# (Manually) Weighted RMSE Train
# [0.24757041 5.22830076]
#
#
# epoch number:  177
# Coverages, CI Widths, RMSEs
# [0.6016684045881127, 0.7851929092805006] [0.4252330116858331, 16.723898873739778] [0.24012444753693055, 5.1483220940407355]
# Smiles Weight Mean and Std Dev
# 0.6345793229358484 0.039211239481223334
# Smiles Weight CI
# 0.5471311339827719 0.6983929424195632
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88174391 47.31773643] [ 1.18816817 26.10365115] [0.63141864 0.55166737]
# (Manually) Weighted RMSE Train
# [0.24012445 5.14832209]
#
#
# epoch number:  178
# Coverages, CI Widths, RMSEs
# [0.6204379562043796, 0.7977059436913452] [0.45546515905038054, 17.564032308123114] [0.24174821107764677, 5.159095154791614]
# Smiles Weight Mean and Std Dev
# 0.6360765819586117 0.03852784882708519
# Smiles Weight CI
# 0.5457225854761311 0.7051213451520603
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88108527 47.34670313] [ 1.19223069 26.11712715] [0.63379938 0.55161448]
# (Manually) Weighted RMSE Train
# [0.24174821 5.15909515]
#
#
# epoch number:  179
# Coverages, CI Widths, RMSEs
# [0.5891553701772679, 0.7695516162669447] [0.40207596073146973, 15.766570630450337] [0.24501623751482893, 5.192453142531018]
# Smiles Weight Mean and Std Dev
# 0.638792508728492 0.035784860867451695
# Smiles Weight CI
# 0.5562929455556044 0.6978762137312673
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.87870391 47.37692118] [ 1.20005111 26.10671381] [0.63876543 0.55104285]
# (Manually) Weighted RMSE Train
# [0.24501624 5.19245314]
#
#
# epoch number:  180
# Coverages, CI Widths, RMSEs
# [0.5860271115745568, 0.7768508863399375] [0.4151634080620203, 15.809601262357395] [0.24160080893647556, 5.155337461883941]
# Smiles Weight Mean and Std Dev
# 0.636527580998854 0.036721305345940244
# Smiles Weight CI
# 0.5628803933449502 0.7068343432808879
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88177653 47.39654218] [ 1.19055324 26.06795235] [0.63267514 0.54999692]
# (Manually) Weighted RMSE Train
# [0.24160081 5.15533746]
#
#
# epoch number:  181
# Coverages, CI Widths, RMSEs
# [0.5881126173096975, 0.7716371220020855] [0.4051022767349486, 15.673211276851667] [0.2439503540556046, 5.174242520260444]
# Smiles Weight Mean and Std Dev
# 0.6382471268637409 0.03555556975064624
# Smiles Weight CI
# 0.5512180198732417 0.6976622208109197
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88131734 47.42066456] [ 1.19551451 26.0801803 ] [0.63546669 0.54997501]
# (Manually) Weighted RMSE Train
# [0.24395035 5.17424252]
#
#
# epoch number:  182
# Coverages, CI Widths, RMSEs
# [0.5881126173096975, 0.7664233576642335] [0.40289630982530833, 15.628176749967235] [0.23942080361408355, 5.138287980438212]
# Smiles Weight Mean and Std Dev
# 0.6347640397725555 0.03492094424333335
# Smiles Weight CI
# 0.5586430981326064 0.6957660144059057
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88568752 47.45791323] [ 1.18238191 26.04212715] [0.62702961 0.54874151]
# (Manually) Weighted RMSE Train
# [0.2394208  5.13828798]
#
#
# epoch number:  183
# Coverages, CI Widths, RMSEs
# [0.6183524504692388, 0.7924921793534933] [0.43729651348361276, 16.897902925887557] [0.23895391515270895, 5.133471052959969]
# Smiles Weight Mean and Std Dev
# 0.6343950851609804 0.03930496898196414
# Smiles Weight CI
# 0.5473952790526789 0.6988774508173876
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8866122  47.49862601] [ 1.18064223 26.03185347] [0.62580017 0.54805487]
# (Manually) Weighted RMSE Train
# [0.23895392 5.13347105]
#
#
# epoch number:  184
# Coverages, CI Widths, RMSEs
# [0.583941605839416, 0.7789363920750783] [0.4010373001169375, 15.804529803181437] [0.24389717692060012, 5.171728094981112]
# Smiles Weight Mean and Std Dev
# 0.6386824259966773 0.034803355631900366
# Smiles Weight CI
# 0.5607504813179067 0.6974436101242659
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88252899 47.48591054] [ 1.19390782 26.05737202] [0.63420421 0.54873902]
# (Manually) Weighted RMSE Train
# [0.24389718 5.17172809]
#
#
# epoch number:  185
# Coverages, CI Widths, RMSEs
# [0.6100104275286757, 0.7820646506777894] [0.4295564649817846, 16.5087536696732] [0.2400966141478016, 5.136922655075765]
# Smiles Weight Mean and Std Dev
# 0.6358592750200327 0.037173493287357896
# Smiles Weight CI
# 0.5525675436005315 0.6981628037523797
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88727228 47.50284595] [ 1.18251092 26.02651231] [0.62657144 0.54789375]
# (Manually) Weighted RMSE Train
# [0.24009661 5.13692266]
#
#
# epoch number:  186
# Coverages, CI Widths, RMSEs
# [0.6131386861313869, 0.7956204379562044] [0.448915188911718, 17.853298376213388] [0.2437379283895828, 5.168468550799255]
# Smiles Weight Mean and Std Dev
# 0.6385611986888783 0.03856436593498869
# Smiles Weight CI
# 0.5456418901074332 0.7123926361467705
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.885545   47.51325743] [ 1.19108843 26.05094693] [0.63169452 0.54828796]
# (Manually) Weighted RMSE Train
# [0.24373793 5.16846855]
#
#
# epoch number:  187
# Coverages, CI Widths, RMSEs
# [0.6037539103232534, 0.7851929092805006] [0.4256742318581243, 16.68656024764495] [0.24062895868842776, 5.135460869228559]
# Smiles Weight Mean and Std Dev
# 0.6363253980553131 0.03910466073263381
# Smiles Weight CI
# 0.5394407598639052 0.6964791294757379
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88902129 47.54520776] [ 1.18180265 26.00184688] [0.62561638 0.54688681]
# (Manually) Weighted RMSE Train
# [0.24062896 5.13546087]
#
#
# epoch number:  188
# Coverages, CI Widths, RMSEs
# [0.5724713242961418, 0.7612095933263816] [0.383880527658169, 14.57497040366709] [0.2426411218351971, 5.151982269904631]
# Smiles Weight Mean and Std Dev
# 0.6380116093863192 0.03586140650103808
# Smiles Weight CI
# 0.5629157586986425 0.6953869577831396
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88786815 47.5706142 ] [ 1.18660673 26.00534693] [0.62854322 0.5466683 ]
# (Manually) Weighted RMSE Train
# [0.24264112 5.15198227]
#
#
# epoch number:  189
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7831074035453598] [0.43066735926847255, 16.66168103357851] [0.24005813455058134, 5.129115760738718]
# Smiles Weight Mean and Std Dev
# 0.6359652371574197 0.0390540132309324
# Smiles Weight CI
# 0.5483897107002801 0.6978334350588293
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89156284 47.60866199] [ 1.17801559 25.95252177] [0.6227737  0.54512185]
# (Manually) Weighted RMSE Train
# [0.24005813 5.12911576]
#
#
# epoch number:  190
# Coverages, CI Widths, RMSEs
# [0.6141814389989573, 0.786235662148071] [0.4390017748369524, 17.024302063998775] [0.24372365694174197, 5.163474510246399]
# Smiles Weight Mean and Std Dev
# 0.6387823842504846 0.0373354389265939
# Smiles Weight CI
# 0.5495223376295988 0.7011909161109409
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.88942826 47.61501693] [ 1.18664695 25.98549073] [0.62804552 0.5457415 ]
# (Manually) Weighted RMSE Train
# [0.24372366 5.16347451]
#
#
# epoch number:  191
# Coverages, CI Widths, RMSEs
# [0.5891553701772679, 0.7768508863399375] [0.4086260141030971, 15.835120753599556] [0.241423319221275, 5.137597411859139]
# Smiles Weight Mean and Std Dev
# 0.6372055077548016 0.03571930554440226
# Smiles Weight CI
# 0.5580586050115816 0.6972445157206612
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89230658 47.65513399] [ 1.1793903 25.9390049] [0.6232554  0.54430662]
# (Manually) Weighted RMSE Train
# [0.24142332 5.13759741]
#
#
# epoch number:  192
# Coverages, CI Widths, RMSEs
# [0.5797705943691345, 0.7653806047966631] [0.4075680085756629, 15.314622060169814] [0.24230287157522046, 5.143160513114699]
# Smiles Weight Mean and Std Dev
# 0.6380161375648388 0.03372513232827999
# Smiles Weight CI
# 0.5583520253885331 0.6961327853425888
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89284589 47.67201723] [ 1.18042145 25.9413011 ] [0.62362259 0.54416202]
# (Manually) Weighted RMSE Train
# [0.24230287 5.14316051]
#
#
# epoch number:  193
# Coverages, CI Widths, RMSEs
# [0.6089676746611054, 0.7893639207507821] [0.44802584142602664, 17.155572027237163] [0.2458270704465839, 5.1925703470024684]
# Smiles Weight Mean and Std Dev
# 0.6405895478136481 0.03673222959880334
# Smiles Weight CI
# 0.5516014801534723 0.7063200948817615
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89054405 47.68252898] [ 1.18900603 25.95939954] [0.62892268 0.54442162]
# (Manually) Weighted RMSE Train
# [0.24582707 5.19257035]
#
#
# epoch number:  194
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.7851929092805006] [0.41298363034962066, 16.215832594196797] [0.2406288078595272, 5.128084991553194]
# Smiles Weight Mean and Std Dev
# 0.63675273892906 0.03733176880494347
# Smiles Weight CI
# 0.5516781344427768 0.6937725023271255
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89612762 47.71246651] [ 1.17398781 25.8981035 ] [0.61915021 0.54279532]
# (Manually) Weighted RMSE Train
# [0.24062881 5.12808499]
#
#
# epoch number:  195
# Coverages, CI Widths, RMSEs
# [0.6006256517205423, 0.7747653806047967] [0.41577358331416475, 15.9161886462718] [0.24096846728514829, 5.129650750250014]
# Smiles Weight Mean and Std Dev
# 0.6371013662531222 0.03686575223171056
# Smiles Weight CI
# 0.5509412165388773 0.6925655083104537
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89739391 47.71719669] [ 1.17337812 25.88783667] [0.61841566 0.54252635]
# (Manually) Weighted RMSE Train
# [0.24096847 5.12965075]
#
#
# epoch number:  196
# Coverages, CI Widths, RMSEs
# [0.6475495307612096, 0.8008342022940563] [0.500107847450376, 18.968094960383493] [0.24209426573375184, 5.140244318372872]
# Smiles Weight Mean and Std Dev
# 0.6379181896499456 0.04040634544076303
# Smiles Weight CI
# 0.5265162408381873 0.6988582959064292
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89727357 47.72947625] [ 1.17590964 25.89086803] [0.61978918 0.54245029]
# (Manually) Weighted RMSE Train
# [0.24209427 5.14024432]
#
#
# epoch number:  197
# Coverages, CI Widths, RMSEs
# [0.607924921793535, 0.7883211678832117] [0.4337209138499183, 16.771862794473524] [0.2409852596282477, 5.124608374435516]
# Smiles Weight Mean and Std Dev
# 0.6371599427133683 0.037987539614251976
# Smiles Weight CI
# 0.5548052015732703 0.7024915719156429
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89805834 47.75593806] [ 1.17272039 25.8737661 ] [0.61785266 0.5417916 ]
# (Manually) Weighted RMSE Train
# [0.24098526 5.12460837]
#
#
# epoch number:  198
# Coverages, CI Widths, RMSEs
# [0.6100104275286757, 0.7831074035453598] [0.4312529787263843, 16.31378637432169] [0.24020442913936746, 5.12012031724579]
# Smiles Weight Mean and Std Dev
# 0.6366086596563382 0.0363258936739669
# Smiles Weight CI
# 0.5499951037222884 0.6928690152581792
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.89920627 47.7649661 ] [ 1.17027779 25.8748592 ] [0.61619309 0.54171208]
# (Manually) Weighted RMSE Train
# [0.24020443 5.12012032]
#
#
# epoch number:  199
# Coverages, CI Widths, RMSEs
# [0.5995828988529719, 0.7768508863399375] [0.42444835962297967, 16.354122324642262] [0.2347827863692138, 5.108330104085157]
# Smiles Weight Mean and Std Dev
# 0.631669594589016 0.03738636042323499
# Smiles Weight CI
# 0.5469639912566724 0.6932924870158407
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.90567613 47.79388928] [ 1.15203115 25.81573843] [0.6045262  0.54014726]
# (Manually) Weighted RMSE Train
# [0.23478279 5.1083301 ]
#
#
# done for fold1
# train_width[0.3769350978389662, 10.397109317964206]
# smiles_weight0.6634089424506268
# rmse_train[0.14253201603337035, 0.17993801869295364]
# smiles_weight_ci[0.5938139494997655, 0.7175590701955659]
# CPU times: user 1h 3min 11s, sys: 38min 21s, total: 1h 41min 32s
# Wall time: 31min 18s

# %%
with open("..//Data/returned_stuff1_config1_rerun.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
fig = plt.figure()
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2], linewidth = 3)
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2], linewidth = 3)
# plt.xlabel("Update Index")
# plt.ylabel("Average Smiles Weight")
plt.xlabel("Epochs", fontweight = "bold",fontsize = 15)
plt.ylabel("Average Smiles Weight", fontweight = "bold", fontsize = 15)
plt.xticks(fontsize = 15, fontweight = "bold")
plt.yticks(fontsize = 15, fontweight = "bold")
fig.savefig('Plots/Avg_Smile_Weight_Tajectory_Changepoint_100_0.pdf', bbox_inches='tight', format = "pdf")
fig.savefig('Plots/Avg_Smile_Weight_Tajectory_Changepoint_100_0.png', bbox_inches='tight')
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
fig, axs = plt.subplots(1, 2,figsize=(12, 6))
# fig, axs = plt.subplots(4, 2)
axs = axs.ravel()
axs[0].plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0], linewidth = 3)
axs[0].plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0], linewidth = 3)
# axs[0].fill_between(range(0,len_updates), rmse_at_each_update.iloc[:,0]-std_weights_at_each_update.iloc[:,0], rmse_at_each_update.iloc[:,0]+std_weights_at_each_update.iloc[:,0], color = "green")
axs[1].plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1], linewidth = 3)
axs[1].plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1], linewidth = 3)
# axs[1].fill_between(range(0,len_updates), rmse_at_each_update.iloc[:,1]-std_weights_at_each_update.iloc[:,1], rmse_at_each_update.iloc[:,1]+std_weights_at_each_update.iloc[:,1], color = "green")
plt.setp(axs[0].get_xticklabels(), fontsize=14, fontweight="bold"
        )
    
plt.setp(axs[0].get_yticklabels(), fontsize=14, fontweight="bold")
plt.setp(axs[1].get_xticklabels(), fontsize=14, fontweight="bold"
        )
    
plt.setp(axs[1].get_yticklabels(), fontsize=14, fontweight="bold")
axs[0].set(xlabel="Epochs", ylabel="RDKIT LogP RMSE/ Smiles LogP RMSE")
axs[1].set(xlabel="Epochs", ylabel="RDKIT PSA RMSE/ Smiles PSA RMSE")
axs[0].xaxis.label.set(fontsize=14, fontweight="bold")
axs[1].xaxis.label.set(fontsize=14, fontweight="bold")
axs[0].yaxis.label.set(fontsize=14, fontweight="bold")
axs[1].yaxis.label.set(fontsize=14, fontweight="bold")
fig.savefig('Plots/Ratio_LogP_PSA_Changepoint_100_0.pdf', bbox_inches='tight', format = "pdf")
fig.savefig('Plots/Ratio_LogP_PSA_Changepoint_100_0.png', bbox_inches='tight')
plt.show()
