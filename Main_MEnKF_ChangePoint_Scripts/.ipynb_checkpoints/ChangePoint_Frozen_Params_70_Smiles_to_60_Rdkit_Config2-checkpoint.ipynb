# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-07-13 16:56:41.638145: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-13 16:56:41.684480: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 16:56:41.940943: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 16:56:41.942836: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 16:56:43.310820: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, fudging_var = 1.0):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_70_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_60_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200, fudging_var = 1.0):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
# returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 8.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-2)

# %%
# %%time
returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 5.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 100, fudging_var = 1e-6)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [150.50294595150527, 3382.0252513029573] [3.4330570180866036, 141.17025173113635]
# Smiles Weight Mean and Std Dev
# 0.47023921521536294 0.23980216800910878
# Smiles Weight CI
# 0.09607721247598158 0.9222273182997539
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.18018282 98.06275247] [  3.99489014 100.21524562] [1.83236475 1.02195016]
# (Manually) Weighted RMSE Train
# [  3.43305702 141.17025173]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [82.14470310457753, 1728.9728270749672] [5.046290127322623, 133.6365027626246]
# Smiles Weight Mean and Std Dev
# 0.4777955148761969 0.21812157719554107
# Smiles Weight CI
# 0.1145418705372751 0.86689156024776
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.97476528 81.84747207] [  5.70331763 109.5023266 ] [2.888099   1.33788282]
# (Manually) Weighted RMSE Train
# [  5.04629013 133.63650276]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [46.732088655388445, 940.3189724402084] [2.524139421244149, 62.19616536893275]
# Smiles Weight Mean and Std Dev
# 0.5461958471685688 0.1738140427222853
# Smiles Weight CI
# 0.21847802206239475 0.8815991409087088
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7587412  52.01974832] [ 3.47196055 74.69520831] [1.9741168  1.43590099]
# (Manually) Weighted RMSE Train
# [ 2.52413942 62.19616537]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [25.076380728078803, 556.9380062799879] [2.829371784323696, 52.547678077546685]
# Smiles Weight Mean and Std Dev
# 0.6182528242790141 0.1457583308689679
# Smiles Weight CI
# 0.32238370435621894 0.8635754348835561
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28528405 33.72920492] [ 3.97855392 73.13719449] [3.09546666 2.16836402]
# (Manually) Weighted RMSE Train
# [ 2.82937178 52.54767808]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [13.5577190909218, 307.96329619134434] [1.7118220077867405, 28.102664820575434]
# Smiles Weight Mean and Std Dev
# 0.6701293489582868 0.10841784716154133
# Smiles Weight CI
# 0.4586562570463709 0.8729574085645657
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.93165978 27.48834585] [ 3.2306201  49.00790923] [3.46759641 1.78286134]
# (Manually) Weighted RMSE Train
# [ 1.71182201 28.10266482]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [8.391694402338816, 183.35974613644453] [0.9953003680436417, 28.129176601971594]
# Smiles Weight Mean and Std Dev
# 0.7059491183633838 0.10127896606503661
# Smiles Weight CI
# 0.49129469562462014 0.8595943736389624
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.70147453 29.46587479] [ 3.35941373 47.14229475] [4.78907444 1.59989463]
# (Manually) Weighted RMSE Train
# [ 0.99530037 28.1291766 ]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [5.571122871790307, 106.55253362499343] [0.6445043221470961, 18.080105148150256]
# Smiles Weight Mean and Std Dev
# 0.7121803483435695 0.08851477769900516
# Smiles Weight CI
# 0.5173647670194425 0.839171135286395
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0

#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.954118873826903] [1.0559649967212532, 24.694782053901868] [0.26704284542367146, 5.773419297228606]
# Smiles Weight Mean and Std Dev
# 0.7003005313344797 0.0825251245270061
# Smiles Weight CI
# 0.505569618117399 0.8225506489995154
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50809472 25.12546797] [ 2.76040311 37.99373286] [5.43285145 1.51216021]
# (Manually) Weighted RMSE Train
# [0.26704285 5.7734193 ]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.8164754953076121, 0.9551616266944735] [1.0288377276572016, 24.092706361034576] [0.2645699464711995, 5.737104150957879]
# Smiles Weight Mean and Std Dev
# 0.7063946982899804 0.08408574743061745
# Smiles Weight CI
# 0.5249363957877266 0.8378799618799692
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50815226 25.04094107] [ 2.75980769 38.24442719] [5.43106453 1.52727596]
# (Manually) Weighted RMSE Train
# [0.26456995 5.73710415]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.8143899895724713, 0.9520333680917622] [1.000279066474156, 22.981582001160522] [0.26591024644997174, 5.746846002724516]
# Smiles Weight Mean and Std Dev
# 0.7025641332231479 0.08130093022725308
# Smiles Weight CI
# 0.5218961696621969 0.8315762976843917
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50830797 25.12325023] [ 2.75844258 38.07788941] [5.42671516 1.51564344]
# (Manually) Weighted RMSE Train
# [0.26591025 5.746846  ]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.8175182481751825, 0.954118873826903] [1.0547625350050638, 25.094332750394944] [0.26489357985450784, 5.74018245285485]
# Smiles Weight Mean and Std Dev
# 0.7062191004846106 0.08460126230925606
# Smiles Weight CI
# 0.5139115521460895 0.8305019285369615
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50852652 25.10578858] [ 2.75768298 38.21640357] [5.42288918 1.52221483]
# (Manually) Weighted RMSE Train
# [0.26489358 5.74018245]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.9530761209593326] [0.965641878543073, 22.558304140065573] [0.26455959467502305, 5.733962411563374]
# Smiles Weight Mean and Std Dev
# 0.7061497046689709 0.08094140464532404
# Smiles Weight CI
# 0.5415227969274395 0.8230194147524197
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50852387 25.09920689] [ 2.75536055 38.19895434] [5.41835046 1.52191878]
# (Manually) Weighted RMSE Train
# [0.26455959 5.73396241]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.8008342022940563, 0.9478623566214807] [0.9821212684790183, 23.320955817952626] [0.2684848283144006, 5.805257333902593]
# Smiles Weight Mean and Std Dev
# 0.6966931104792148 0.08243197492139416
# Smiles Weight CI
# 0.5246964900051815 0.8148635885201447
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50831114 25.34353457] [ 2.75681318 37.83012537] [5.42347584 1.49269334]
# (Manually) Weighted RMSE Train
# [0.26848483 5.80525733]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.8091762252346194, 0.9457768508863399] [0.9785683833896779, 22.96813834588858] [0.2644804397500921, 5.735489621846855]
# Smiles Weight Mean and Std Dev
# 0.7085475009401865 0.08254874840607271
# Smiles Weight CI
# 0.5358191020979007 0.8292939058110326
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.509064   25.08949946] [ 2.7563123  38.27951383] [5.41447111 1.52571851]
# (Manually) Weighted RMSE Train
# [0.26448044 5.73548962]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.8112617309697602, 0.9603753910323254] [1.0756138056144608, 25.756325603464525] [0.27233653107857386, 5.851986799705691]
# Smiles Weight Mean and Std Dev
# 0.6927885958584434 0.08719387466988497
# Smiles Weight CI
# 0.500925785510547 0.8279134193571107
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50841494 25.4451488 ] [ 2.75731397 37.66120334] [5.42335357 1.48009366]
# (Manually) Weighted RMSE Train
# [0.27233653 5.8519868 ]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.7987486965589156, 0.9447340980187695] [0.9482093397826835, 22.166880750747705] [0.26827079721632935, 5.799156685202764]
# Smiles Weight Mean and Std Dev
# 0.6972961534782631 0.07983456563500885
# Smiles Weight CI
# 0.5367508048835464 0.8184070714365448
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50707971 25.36075058] [ 2.75547313 37.81823995] [5.43400392 1.49121138]
# (Manually) Weighted RMSE Train
# [0.2682708  5.79915669]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.8060479666319083, 0.948905109489051] [1.0005743786106827, 22.580504172523828] [0.26886130908454475, 5.804819984496614]
# Smiles Weight Mean and Std Dev
# 0.6965577747364652 0.082234716086127
# Smiles Weight CI
# 0.5317653797450291 0.8164224706811982
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50779656 25.38922057] [ 2.75542739 37.79486011] [5.42624273 1.48861837]
# (Manually) Weighted RMSE Train
# [0.26886131 5.80481998]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.794577685088634, 0.9509906152241918] [1.0211914598066087, 23.893449908940653] [0.2724735769363549, 5.855451780856622]
# Smiles Weight Mean and Std Dev
# 0.6923841256876797 0.08553735236881985
# Smiles Weight CI
# 0.5086609667451023 0.8143176362074129
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50729708 25.49242422] [ 2.75557853 37.64038215] [5.43188328 1.47653208]
# (Manually) Weighted RMSE Train
# [0.27247358 5.85545178]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.8070907194994786, 0.954118873826903] [0.981884858365829, 23.174044698997466] [0.2656495148061044, 5.769703877569959]
# Smiles Weight Mean and Std Dev
# 0.700901702590277 0.08076522518614021
# Smiles Weight CI
# 0.5343759829456192 0.8285101334199544
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50695306 25.29417815] [ 2.752586   37.95777524] [5.42966644 1.50065264]
# (Manually) Weighted RMSE Train
# [0.26564951 5.76970388]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.7966631908237748, 0.9457768508863399] [0.9565691086712712, 22.931405575726252] [0.26490870564908897, 5.74393692618869]
# Smiles Weight Mean and Std Dev
# 0.704323357531409 0.07965797017086267
# Smiles Weight CI
# 0.5291824896659058 0.8259852386974065
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50648456 25.21764874] [ 2.75235345 38.10469636] [5.43422977 1.51103288]
# (Manually) Weighted RMSE Train
# [0.26490871 5.74393693]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.954118873826903] [1.0159548433820569, 24.437001340833586] [0.264598043838375, 5.72506546143652]
# Smiles Weight Mean and Std Dev
# 0.7079498837552078 0.08476136642288257
# Smiles Weight CI
# 0.5185045856218488 0.8282905382986142
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50687787 25.11759405] [ 2.75211209 38.29378284] [5.42953685 1.52458005]
# (Manually) Weighted RMSE Train
# [0.26459804 5.72506546]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.808133472367049, 0.9551616266944735] [1.0171179405965798, 23.776552612295276] [0.26594571003625905, 5.757208260954146]
# Smiles Weight Mean and Std Dev
# 0.7009675803173679 0.08340848809205198
# Smiles Weight CI
# 0.5175713250461648 0.8211018064019519
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50609546 25.28236903] [ 2.75282734 37.99440085] [5.43934402 1.50280224]
# (Manually) Weighted RMSE Train
# [0.26594571 5.75720826]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.799791449426486, 0.954118873826903] [0.9853530383287786, 23.41690053499369] [0.2715104645282315, 5.826903230200123]
# Smiles Weight Mean and Std Dev
# 0.6935115784691482 0.08223905290577146
# Smiles Weight CI
# 0.5250993317396847 0.8265091919350662
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50662785 25.46174181] [ 2.7519594  37.72202485] [5.43191496 1.48151785]
# (Manually) Weighted RMSE Train
# [0.27151046 5.82690323]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.7893639207507821, 0.9478623566214807] [0.9854144077859638, 23.00362134426035] [0.2726843503603159, 5.839308434221506]
# Smiles Weight Mean and Std Dev
# 0.6923319342962919 0.08274612080045024
# Smiles Weight CI
# 0.523072086728259 0.8190377069653745
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50689107 25.49259221] [ 2.75095601 37.70410702] [5.42711471 1.47902209]
# (Manually) Weighted RMSE Train
# [0.27268435 5.83930843]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.8154327424400417, 0.9562043795620438] [1.0538488903436005, 24.774526486836354] [0.26703356864008077, 5.759159056124796]
# Smiles Weight Mean and Std Dev
# 0.699596041209383 0.09061131176187646
# Smiles Weight CI
# 0.5239264081487167 0.8305510024619542
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50541754 25.34845716] [ 2.75146295 37.94838148] [5.44394033 1.49706869]
# (Manually) Weighted RMSE Train
# [0.26703357 5.75915906]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.7904066736183525, 0.9322210636079249] [0.8983416036270736, 21.34998330429613] [0.26454256410796034, 5.733599574801047]
# Smiles Weight Mean and Std Dev
# 0.7081196004152065 0.07721075024812021
# Smiles Weight CI
# 0.5570836421352005 0.8282057923805595
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50494944 25.13758403] [ 2.75030437 38.27000418] [5.44669255 1.52242173]
# (Manually) Weighted RMSE Train
# [0.26454256 5.73359957]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.8008342022940563, 0.9520333680917622] [0.9977728926196325, 22.795232048327428] [0.2689280378571919, 5.768308584713251]
# Smiles Weight Mean and Std Dev
# 0.6974093275435915 0.08151734989935344
# Smiles Weight CI
# 0.542984180576073 0.8325560633319363
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50446432 25.39540569] [ 2.75160643 37.87748504] [5.45451146 1.49150935]
# (Manually) Weighted RMSE Train
# [0.26892804 5.76830858]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.7893639207507821, 0.9395203336809176] [0.9259959588463772, 21.944732855892223] [0.2648540392835397, 5.72492504218417]
# Smiles Weight Mean and Std Dev
# 0.7048192560603108 0.0761409992641917
# Smiles Weight CI
# 0.5460387577180527 0.8226480095341643
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50371892 25.21670223] [ 2.74703141 38.13924769] [5.45350055 1.51245977]
# (Manually) Weighted RMSE Train
# [0.26485404 5.72492504]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.7883211678832117, 0.9426485922836287] [0.9182534336888624, 22.002786401556676] [0.2668621506448843, 5.758477636526375]
# Smiles Weight Mean and Std Dev
# 0.699420973816127 0.07568955527265586
# Smiles Weight CI
# 0.5426365644015247 0.8173878727559701
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50437586 25.35782234] [ 2.74734592 37.93249339] [5.44702106 1.49588923]
# (Manually) Weighted RMSE Train
# [0.26686215 5.75847764]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.7987486965589156, 0.9530761209593326] [1.004140524169321, 24.392997540214022] [0.26716383715675296, 5.764259579180226]
# Smiles Weight Mean and Std Dev
# 0.6995338014230996 0.07846840345973236
# Smiles Weight CI
# 0.5297152980586621 0.8198317458956512
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50431744 25.33397235] [ 2.74974035 37.91010568] [5.45239992 1.49641379]
# (Manually) Weighted RMSE Train
# [0.26716384 5.76425958]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.794577685088634, 0.9499478623566214] [0.9711978459297741, 23.222251952930392] [0.26491934622295504, 5.727108518599028]
# Smiles Weight Mean and Std Dev
# 0.7036955392924565 0.08422916405879066
# Smiles Weight CI
# 0.5294381410554576 0.8209153822600694
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50397472 25.2362141 ] [ 2.74950741 38.07605722] [5.45564546 1.50878642]
# (Manually) Weighted RMSE Train
# [0.26491935 5.72710852]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.8050052137643379, 0.9562043795620438] [1.0081058449915663, 23.633654014452624] [0.2636025120729407, 5.720661163691746]
# Smiles Weight Mean and Std Dev
# 0.7085100927872506 0.08276445426594521
# Smiles Weight CI
# 0.5348867236425081 0.8271454912988517
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50447453 25.12199152] [ 2.74645732 38.28177585] [5.44419427 1.52383523]
# (Manually) Weighted RMSE Train
# [0.26360251 5.72066116]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.8039624608967675, 0.9530761209593326] [1.0347431513637289, 23.42896822268129] [0.26642183745949216, 5.770132108739066]
# Smiles Weight Mean and Std Dev
# 0.6994157323188049 0.08336757514066807
# Smiles Weight CI
# 0.5371769741861209 0.8407421188125178
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50460661 25.31012848] [ 2.74404815 37.88344074] [5.43799487 1.49676999]
# (Manually) Weighted RMSE Train
# [0.26642184 5.77013211]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.7893639207507821, 0.9551616266944735] [0.9719693327496, 24.008201325086066] [0.2660152733309776, 5.753504654224654]
# Smiles Weight Mean and Std Dev
# 0.70040717443197 0.08242725234898181
# Smiles Weight CI
# 0.5298019525358949 0.8243361853759706
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50484869 25.28939577] [ 2.74216296 37.91227186] [5.43165307 1.49913712]
# (Manually) Weighted RMSE Train
# [0.26601527 5.75350465]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.7935349322210636, 0.9551616266944735] [0.9772099357853018, 23.084230402185607] [0.26655024233220115, 5.754126984101607]
# Smiles Weight Mean and Std Dev
# 0.6994555678357492 0.08018107039820346
# Smiles Weight CI
# 0.5285817618573146 0.8320324576374558
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50525835 25.33411246] [ 2.74193228 37.87998028] [5.42679261 1.49521639]
# (Manually) Weighted RMSE Train
# [0.26655024 5.75412698]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.7924921793534933, 0.9572471324296142] [1.0103571038796464, 24.313410058506804] [0.26682520638205864, 5.75131432910743]
# Smiles Weight Mean and Std Dev
# 0.6995026273292116 0.08604688257123405
# Smiles Weight CI
# 0.5190275345485132 0.8274104188630198
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50478541 25.34111999] [ 2.74244431 37.88959663] [5.43289142 1.4951824 ]
# (Manually) Weighted RMSE Train
# [0.26682521 5.75131433]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.7914494264859229, 0.9520333680917622] [0.9883113860550216, 23.62244026683459] [0.2784967483903506, 5.922431212061343]
# Smiles Weight Mean and Std Dev
# 0.6875564843054138 0.08366649801620919
# Smiles Weight CI
# 0.511537841786293 0.8160927932013989
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50943332 25.65913034] [ 2.74061653 37.43367923] [5.37973556 1.4588834 ]
# (Manually) Weighted RMSE Train
# [0.27849675 5.92243121]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.7851929092805006, 0.9509906152241918] [0.9461604293683927, 22.98393992512401] [0.26876597305666744, 5.7877446737181995]
# Smiles Weight Mean and Std Dev
# 0.6958624663716577 0.08135309708591203
# Smiles Weight CI
# 0.5297955837324398 0.8256766335007317
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50545895 25.46298851] [ 2.73706023 37.7298549 ] [5.41500005 1.48175281]
# (Manually) Weighted RMSE Train
# [0.26876597 5.78774467]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.9499478623566214] [0.9539090257973593, 23.198708976214007] [0.2789787869465292, 5.9528143139313485]
# Smiles Weight Mean and Std Dev
# 0.6867778888180818 0.0818278210471089
# Smiles Weight CI
# 0.5294338508309798 0.8193775938954064
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50903182 25.63781263] [ 2.73814175 37.39552069] [5.37911709 1.45860808]
# (Manually) Weighted RMSE Train
# [0.27897879 5.95281431]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.8029197080291971, 0.959332638164755] [1.096867025332779, 26.15264164520768] [0.2722280466984854, 5.838875325226338]
# Smiles Weight Mean and Std Dev
# 0.6927719716003258 0.09035646189930063
# Smiles Weight CI
# 0.48863071649545503 0.832703419003914
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.5059841  25.47666192] [ 2.73812293 37.58909755] [5.41148015 1.4754326 ]
# (Manually) Weighted RMSE Train
# [0.27222805 5.83887533]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.8060479666319083, 0.9582898852971846] [1.0705990820205376, 25.13555885481012] [0.2643091853517769, 5.6981716360470385]
# Smiles Weight Mean and Std Dev
# 0.7048623956964731 0.0885137445991505
# Smiles Weight CI
# 0.5029473472511622 0.8312134735133727
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50318759 25.17909532] [ 2.73597896 38.11077028] [5.43729416 1.51358775]
# (Manually) Weighted RMSE Train
# [0.26430919 5.69817164]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.781021897810219, 0.9520333680917622] [0.9674914994419959, 23.751863219167504] [0.2639480974939928, 5.699688662126089]
# Smiles Weight Mean and Std Dev
# 0.7072432183927969 0.08043435156642824
# Smiles Weight CI
# 0.5212532556091687 0.8256656470008187
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50321112 25.11135002] [ 2.73495001 38.18456123] [5.43499514 1.52060965]
# (Manually) Weighted RMSE Train
# [0.2639481  5.69968866]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.7831074035453598, 0.9447340980187695] [0.9244148862456552, 22.059767823413946] [0.26395217909405067, 5.709716780244622]
# Smiles Weight Mean and Std Dev
# 0.7035723990980737 0.08065493737021072
# Smiles Weight CI
# 0.5409860558394299 0.8255822951710526
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.5024657  25.19020118] [ 2.73300199 38.04118709] [5.43918121 1.51015813]
# (Manually) Weighted RMSE Train
# [0.26395218 5.70971678]
#
#
# epoch number:  97
# Coverages, CI Widths, RMSEs
# [0.7820646506777894, 0.9447340980187695] [0.9732912032181216, 22.037320484625578] [0.2691033270945201, 5.783949372175087]
# Smiles Weight Mean and Std Dev
# 0.6954795229711203 0.08005966001524006
# Smiles Weight CI
# 0.5306210124960227 0.8145030955021554
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50428112 25.39106273] [ 2.7334734  37.73073725] [5.42053488 1.48598496]
# (Manually) Weighted RMSE Train
# [0.26910333 5.78394937]
#
#
# epoch number:  98
# Coverages, CI Widths, RMSEs
# [0.7518248175182481, 0.9280500521376434] [0.8465236047407084, 20.509811565496907] [0.2684717851522502, 5.798710207605371]
# Smiles Weight Mean and Std Dev
# 0.7215598286808698 0.07042351022592713
# Smiles Weight CI
# 0.5679474145295569 0.8362014906797901
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.50410288 24.79905167] [ 2.73178683 38.75967446] [5.41910574 1.56294986]
# (Manually) Weighted RMSE Train
# [0.26847179 5.79871021]
#
#
# done for fold0
# train_width[0.8983416036270736, 21.34998330429613]
# smiles_weight0.7081196004152065
# rmse_train[0.1401690111799539, 0.13285854163451682]
# smiles_weight_ci[0.5570836421352005, 0.8282057923805595]
# CPU times: user 55min, sys: 33min 34s, total: 1h 28min 34s
# Wall time: 18min 25s

# %%
with open("..//Data/returned_stuff_config4.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.65, epochs = 1000, fudging_var = 1e-6)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.7747653806047967, 0.9520333680917622] [1.0062678846627644, 24.436445665028824] [0.2904981169472849, 6.684947825156327]
# Smiles Weight Mean and Std Dev
# 0.7059672655813697 0.08461180694245073
# Smiles Weight CI
# 0.5080903266991359 0.8214694110007724
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.51916104 25.88531063] [ 2.7247846  37.80386374] [5.24843818 1.46043694]
# (Manually) Weighted RMSE Train
# [0.29049812 6.68494783]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.7695516162669447, 0.9478623566214807] [0.9738687582375382, 23.549073845803438] [0.2901173197472323, 6.565037688667886]
# Smiles Weight Mean and Std Dev
# 0.6978354514250069 0.0825443046629234
# Smiles Weight CI
# 0.5272074507426879 0.8248878237497693
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.51894337 26.22769647] [ 2.71215361 37.34932491] [5.22629975 1.42404137]
# (Manually) Weighted RMSE Train
# [0.29011732 6.56503769]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
#
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.71282556 33.9203996 ] [ 2.19215584 29.49551908] [3.07530475 0.86955105]
# (Manually) Weighted RMSE Train
# [0.22350608 4.90174208]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.6788321167883211, 0.9176225234619395] [0.47697286400811906, 22.517510768624074] [0.22415011343148622, 4.79216958199707]
# Smiles Weight Mean and Std Dev
# 0.6952586727186126 0.07799082442515075
# Smiles Weight CI
# 0.5272718678402183 0.8173712137573786
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.73058653 34.14542273] [ 2.17596061 29.07707482] [2.97837494 0.85156582]
# (Manually) Weighted RMSE Train
# [0.22415011 4.79216958]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.7069864442127216, 0.9197080291970803] [0.4929506459375721, 23.641379305430256] [0.22583638647436163, 4.7350874940114105]
# Smiles Weight Mean and Std Dev
# 0.6881816095833507 0.08292384624774878
# Smiles Weight CI
# 0.5245060332639847 0.8185586000721672
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.75348804 34.3959488 ] [ 2.15587748 28.51667735] [2.86119668 0.82907082]
# (Manually) Weighted RMSE Train
# [0.22583639 4.73508749]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.6903023983315955, 0.913451511991658] [0.4922881316799038, 22.870059897613075] [0.22414425275833966, 4.728800158741197]
# Smiles Weight Mean and Std Dev
# 0.6918078835488572 0.07475522302694403
# Smiles Weight CI
# 0.5310736141681515 0.8180058997984814
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.75086627 34.43719715] [ 2.15783071 28.60579449] [2.87378832 0.83066558]
# (Manually) Weighted RMSE Train
# [0.22414425 4.72880016]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.7153284671532847, 0.9228362877997914] [0.5089145797715019, 25.30446832882428] [0.22176634041400964, 4.796789467974045]
# Smiles Weight Mean and Std Dev
# 0.6983352464783467 0.082124203150223
# Smiles Weight CI
# 0.4953433027039628 0.8282611909354762
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.73964799 34.38160133] [ 2.16436303 28.9143318 ] [2.92620688 0.8409827 ]
# (Manually) Weighted RMSE Train
# [0.22176634 4.79678947]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.7028154327424401, 0.9228362877997914] [0.5163006005011559, 25.073108379659672] [0.22294375857103185, 4.703035023221246]
# Smiles Weight Mean and Std Dev
# 0.6927402302533081 0.08416596310738714
# Smiles Weight CI
# 0.4957757949682711 0.8198986480763392
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7586934  34.58434354] [ 2.14863471 28.49585023] [2.83201977 0.82395232]
# (Manually) Weighted RMSE Train
# [0.22294376 4.70303502]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.7101147028154328, 0.9197080291970803] [0.4933107705412838, 24.555866122495456] [0.22012200799622736, 4.902481394446595]
# Smiles Weight Mean and Std Dev
# 0.7041789332350102 0.08160573358201827
# Smiles Weight CI
# 0.5167561397782907 0.8288102456746086
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.73660127 34.45735533] [ 2.16214146 29.08205559] [2.93529423 0.84400138]
# (Manually) Weighted RMSE Train
# [0.22012201 4.90248139]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.6986444212721585, 0.9176225234619395] [0.48439361784689444, 23.099062782986245] [0.22151978461265898, 4.691435595233297]
# Smiles Weight Mean and Std Dev
# 0.6949634172591047 0.08271773377303136
# Smiles Weight CI
# 0.5267073211188691 0.821686918419259
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.76439085 34.76574186] [ 2.13897212 28.41771954] [2.79827017 0.81740581]
# (Manually) Weighted RMSE Train
# [0.22151978 4.6914356 ]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0

#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.7163712200208551, 0.908237747653806] [0.516036563030047, 26.288440988355386] [0.2199334626396007, 4.557561633347987]
# Smiles Weight Mean and Std Dev
# 0.6879275156320518 0.08775626363813409
# Smiles Weight CI
# 0.4856071681051222 0.8215805936307409
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81773471 35.84638698] [ 2.08669371 27.10290453] [2.55179789 0.75608469]
# (Manually) Weighted RMSE Train
# [0.21993346 4.55756163]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.6882168925964547, 0.8988529718456726] [0.4465259975511586, 22.545569042426383] [0.21634428182164622, 4.752638203559258]
# Smiles Weight Mean and Std Dev
# 0.7024050074929378 0.07363643718055116
# Smiles Weight CI
# 0.5460341090343255 0.8210201082383105
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.78696535 35.64173717] [ 2.1139261  27.90167358] [2.68617432 0.78283708]
# (Manually) Weighted RMSE Train
# [0.21634428 4.7526382 ]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.6913451511991658, 0.9061522419186653] [0.4658996625967119, 23.77379632125718] [0.21547712236194697, 4.987635236419255]
# Smiles Weight Mean and Std Dev
# 0.70954181857657 0.08145515660837907
# Smiles Weight CI
# 0.5259527451920726 0.8209237942527927
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.77316873 35.57733526] [ 2.12399819 28.26598894] [2.74713411 0.79449427]
# (Manually) Weighted RMSE Train
# [0.21547712 4.98763524]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.6788321167883211, 0.9040667361835245] [0.4593402662647132, 24.326206467845157] [0.2162818022124068, 4.60733434070753]
# Smiles Weight Mean and Std Dev
# 0.6975867125689226 0.08420296301145351
# Smiles Weight CI
# 0.5202218926711303 0.8229053334973757
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80440082 35.88874155] [ 2.09671868 27.41272154] [2.60655961 0.7638251 ]
# (Manually) Weighted RMSE Train
# [0.2162818  4.60733434]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.6663190823774765, 0.8978102189781022] [0.4463078234474041, 23.48796415485855] [0.21680436078010312, 4.535489677119474]
# Smiles Weight Mean and Std Dev
# 0.6935221774495058 0.07901585274395707
# Smiles Weight CI
# 0.5238446671600363 0.8239750296126156
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81815118 36.00726795] [ 2.08376565 27.07735487] [2.54692008 0.75199693]
# (Manually) Weighted RMSE Train
# [0.21680436 4.53548968]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.6809176225234619, 0.899895724713243] [0.45052002056539936, 23.394280122875028] [0.21557977213790833, 4.571328064575572]
# Smiles Weight Mean and Std Dev
# 0.6974075722296498 0.08000098295459206
# Smiles Weight CI
# 0.5326741032774175 0.8256926938967477
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81170237 35.9397792 ] [ 2.08819349 27.23852797] [2.57260982 0.75789358]
# (Manually) Weighted RMSE Train
# [0.21557977 4.57132806]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.6788321167883211, 0.8915537017726799] [0.44935949155341387, 24.14079989844588] [0.215185733074603, 4.56115306679371]
# Smiles Weight Mean and Std Dev
# 0.697142117995436 0.0772269365815086
# Smiles Weight CI
# 0.5066524294394807 0.8174053688523576
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81518808 36.0095947 ] [ 2.08258968 27.13655307] [2.55473519 0.75359229]
# (Manually) Weighted RMSE Train
# [0.21518573 4.56115307]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.6694473409801877, 0.8925964546402503] [0.439721349793294, 23.10602289259579] [0.21520070933266774, 4.522664546034077]
# Smiles Weight Mean and Std Dev
# 0.6956487064385307 0.07775812037470226
# Smiles Weight CI
# 0.5229598215777307 0.8230569843266466
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82250181 36.10494236] [ 2.07511745 26.98041359] [2.52293361 0.74727757]
# (Manually) Weighted RMSE Train
# [0.21520071 4.52266455]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.6642335766423357, 0.8925964546402503] [0.43219016775025104, 22.742469227470725] [0.21549569528386195, 4.503355778579468]
# Smiles Weight Mean and Std Dev
# 0.693552268880082 0.07612536828966593
# Smiles Weight CI
# 0.5324738896910329 0.8105059721433828
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83028054 36.24831425] [ 2.06795265 26.75651633] [2.49066737 0.73814512]
# (Manually) Weighted RMSE Train
# [0.2154957  4.50335578]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.7059436913451512, 0.9009384775808134] [0.4772310459173253, 24.44452263364998] [0.2136243360190417, 4.630240779485009]
# Smiles Weight Mean and Std Dev
# 0.7002114015597918 0.08382311203307014
# Smiles Weight CI
# 0.51453779991837 0.8325686335128555
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8168869  36.22341967] [ 2.07988179 27.12858528] [2.54610741 0.74892392]
# (Manually) Weighted RMSE Train
# [0.21362434 4.63024078]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.6663190823774765, 0.894681960375391] [0.448626032823599, 24.08652308599294] [0.21711798344121602, 4.483207619033902]
# Smiles Weight Mean and Std Dev
# 0.68646466943593 0.0807573430380244
# Smiles Weight CI
# 0.5140948810963021 0.8065592334214986
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85316418 36.5677903 ] [ 2.04535591 26.19110562] [2.39737667 0.7162343 ]
# (Manually) Weighted RMSE Train
# [0.21711798 4.48320762]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.6631908237747653, 0.8978102189781022] [0.4512934722774474, 25.061041181949165] [0.21368595582715696, 4.5650737429724995]
# Smiles Weight Mean and Std Dev
# 0.6976334969601353 0.0798208108873941
# Smiles Weight CI
# 0.5034098954399194 0.8128927500454973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82984102 36.43740316] [ 2.06641521 26.82500947] [2.49013383 0.73619433]
# (Manually) Weighted RMSE Train
# [0.21368596 4.56507374]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.662148070907195, 0.8852971845672576] [0.42044053434319084, 21.574827033878666] [0.2133709061591169, 4.542702991910405]
# Smiles Weight Mean and Std Dev
# 0.6965963228766288 0.07816691118867716
# Smiles Weight CI
# 0.5482506335733827 0.8141350103030166
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83590637 36.51251126] [ 2.06206163 26.67871932] [2.46685718 0.73067336]
# (Manually) Weighted RMSE Train
# [0.21337091 4.54270299]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.6840458811261731, 0.8957247132429614] [0.45754695310981525, 23.355339990115954] [0.21271612464424516, 4.611545618815461]
# Smiles Weight Mean and Std Dev
# 0.698826013469018 0.08011119080619448
# Smiles Weight CI
# 0.5298445477425398 0.8139065678023695
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83349335 36.5759664 ] [ 2.05944537 26.77466729] [2.47086    0.73202898]
# (Manually) Weighted RMSE Train
# [0.21271612 4.61154562]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.656934306569343, 0.8915537017726799] [0.4270913953319537, 22.468824548329216] [0.21478564012763277, 4.456795185502749]
# Smiles Weight Mean and Std Dev
# 0.6890561676342433 0.07628001100548383
# Smiles Weight CI
# 0.5308254906942258 0.8093609898000622
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86047933 36.84009244] [ 2.03570533 26.11102231] [2.36578063 0.70876647]
# (Manually) Weighted RMSE Train
# [0.21478564 4.45679519]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.7049009384775808, 0.8957247132429614] [0.45933413419461433, 23.70450303922155] [0.21462547616641853, 4.451637995456449]
# Smiles Weight Mean and Std Dev
# 0.6876806436575253 0.08358928525455098
# Smiles Weight CI
# 0.5217895060947816 0.8244824385019952
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86638493 36.95086291] [ 2.02643761 25.94786392] [2.3389576 0.7022262]
# (Manually) Weighted RMSE Train
# [0.21462548 4.451638  ]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.662148070907195, 0.8905109489051095] [0.43097048477735794, 23.428252787056167] [0.21244656003392243, 4.495174300673444]
# Smiles Weight Mean and Std Dev
# 0.6943227391253273 0.07815084292167007
# Smiles Weight CI
# 0.535879342825719 0.8155769343950833
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85405728 36.87068121] [ 2.03880966 26.31253298] [2.38720483 0.7136438 ]
# (Manually) Weighted RMSE Train
# [0.21244656 4.4951743 ]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.6767466110531803, 0.8957247132429614] [0.4547507063713123, 25.066184599656708] [0.2137109887607614, 4.443264292939521]
# Smiles Weight Mean and Std Dev
# 0.688378098907077 0.08565156962040987
# Smiles Weight CI
# 0.5080460997084364 0.8099047097002323
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87104893 37.03879885] [ 2.01855733 25.85404466] [2.31738684 0.698026  ]
# (Manually) Weighted RMSE Train
# [0.21371099 4.44326429]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.6684045881126173, 0.894681960375391] [0.4480765060944142, 24.02661264323622] [0.2113273916841939, 4.532544928800316]
# Smiles Weight Mean and Std Dev
# 0.6965834852458601 0.08299316790765525
# Smiles Weight CI
# 0.512621745872053 0.8132822612130621
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85584987 36.95021096] [ 2.03541217 26.30088604] [2.37823507 0.71179258]
# (Manually) Weighted RMSE Train
# [0.21132739 4.53254493]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.7257559958289885, 0.9040667361835245] [0.4915778576876459, 26.58447591352422] [0.21195903528354973, 4.467745924699028]
# Smiles Weight Mean and Std Dev
# 0.6930049223883665 0.0875300706047814
# Smiles Weight CI
# 0.5048370400619162 0.8365994521586323
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86742521 37.0651691 ] [ 2.02224279 26.01205326] [2.33131661 0.70179238]
# (Manually) Weighted RMSE Train
# [0.21195904 4.46774592]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.6590198123044838, 0.8957247132429614] [0.4380802105640485, 24.875349637544748] [0.2106110752095712, 4.545115644334434]
# Smiles Weight Mean and Std Dev
# 0.6977758689853273 0.07591053421912299
# Smiles Weight CI
# 0.510270484087793 0.8100971876337354
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85822792 37.02481227] [ 2.03032128 26.26091433] [2.3657134 0.7092788]
# (Manually) Weighted RMSE Train
# [0.21061108 4.54511564]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.6527632950990615, 0.8842544316996872] [0.4052364131167392, 21.855595697190235] [0.21033696191153248, 4.54284673082764]
# Smiles Weight Mean and Std Dev
# 0.6977045163707272 0.07370530309292433
# Smiles Weight CI
# 0.5451953854221748 0.8161311221277361
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86075019 37.0684781 ] [ 2.02713474 26.22422434] [2.35507905 0.70745349]
# (Manually) Weighted RMSE Train
# [0.21033696 4.54284673]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.6715328467153284, 0.8925964546402503] [0.4397492721750062, 24.232032391174364] [0.209979557784298, 4.544093959269971]
# Smiles Weight Mean and Std Dev
# 0.6981155795417288 0.07880488955488395
# Smiles Weight CI
# 0.5242605617959442 0.8178759387159222
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86351327 37.0955149 ] [ 2.02752868 26.22538686] [2.34799944 0.70696921]
# (Manually) Weighted RMSE Train
# [0.20997956 4.54409396]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.6934306569343066, 0.9019812304483837] [0.4661696268355136, 25.39574495391177] [0.2092450560104307, 4.640609902229368]
# Smiles Weight Mean and Std Dev
# 0.7006885521274838 0.08286196820195187
# Smiles Weight CI
# 0.5162322657273011 0.8244406574723
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85894226 37.10421566] [ 2.02728199 26.34294847] [2.36020752 0.70997185]
# (Manually) Weighted RMSE Train
# [0.20924506 4.6406099 ]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.6923879040667362, 0.9009384775808134] [0.4657746562652778, 25.24648657514453] [0.20951581866097738, 4.545628867077952]
# Smiles Weight Mean and Std Dev
# 0.6974283095145095 0.08382941525580717
# Smiles Weight CI
# 0.508995705994865 0.8261544790731523
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87030731 37.21383419] [ 2.01769614 26.09729825] [2.31837205 0.70127948]
# (Manually) Weighted RMSE Train
# [0.20951582 4.54562887]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.670490093847758, 0.8915537017726799] [0.45294325402529295, 25.852795505444373] [0.21454748152007075, 4.424013266407457]
# Smiles Weight Mean and Std Dev
# 0.6810947449715554 0.08364513150448934
# Smiles Weight CI
# 0.49378721634299794 0.8199098070238029
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.91287438 37.56730428] [ 1.97697395 25.01419124] [2.16565827 0.66585004]
# (Manually) Weighted RMSE Train
# [0.21454748 4.42401327]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.6673618352450469, 0.9019812304483837] [0.4596442181392387, 26.186259973956478] [0.21067686992549375, 4.397476280891589]
# Smiles Weight Mean and Std Dev
# 0.690029904770328 0.08447316075765694
# Smiles Weight CI
# 0.48824859608850935 0.8194216038784994
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89390589 37.43356374] [ 1.99207784 25.51818227] [2.22850957 0.68169257]
# (Manually) Weighted RMSE Train
# [0.21067687 4.39747628]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.6673618352450469, 0.886339937434828] [0.4330595188986577, 23.02982781155231] [0.21042141091166852, 4.401141976817972]
# Smiles Weight Mean and Std Dev
# 0.6903667394514257 0.08081234054798726
# Smiles Weight CI
# 0.5291583408110915 0.8152884945226296
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89514581 37.46566775] [ 1.99093348 25.48669694] [2.22414433 0.68026806]
# (Manually) Weighted RMSE Train
# [0.21042141 4.40114198]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.670490093847758, 0.8978102189781022] [0.4547523348072037, 24.46604586958699] [0.21029631133295762, 4.395834135895435]
# Smiles Weight Mean and Std Dev
# 0.6902676984898993 0.08156335720290273
# Smiles Weight CI
# 0.5090388508304899 0.8119476686900605
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89812394 37.5077942 ] [ 1.98672134 25.43106328] [2.21207926 0.67802076]
# (Manually) Weighted RMSE Train
# [0.21029631 4.39583414]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.6923879040667362, 0.886339937434828] [0.44892181253921964, 23.76370990036064] [0.20864380858649473, 4.4946679523976565]
# Smiles Weight Mean and Std Dev
# 0.6959652032085344 0.0806232262157071
# Smiles Weight CI
# 0.527037236764935 0.8160675288398735
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88635076 37.43632846] [ 1.99981313 25.77225137] [2.2562322  0.68842893]
# (Manually) Weighted RMSE Train
# [0.20864381 4.49466795]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.6715328467153284, 0.8957247132429614] [0.43028542198005015, 24.472883749622394] [0.20702930722140883, 4.864653670727901]
# Smiles Weight Mean and Std Dev
# 0.7060713016059903 0.07885891487642019
# Smiles Weight CI
# 0.5224028545844972 0.8328846238748607
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86534021 37.30217461] [ 2.02165947 26.41188847] [2.33625971 0.70805224]
# (Manually) Weighted RMSE Train
# [0.20702931 4.86465367]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.6777893639207507, 0.8905109489051095] [0.4405190429182506, 24.735905155279266] [0.2092301798146564, 4.417003387340047]
# Smiles Weight Mean and Std Dev
# 0.6932372336127485 0.08145167335835987
# Smiles Weight CI
# 0.5115125429018959 0.8197427127551216
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89887646 37.54365032] [ 1.98828605 25.4956599 ] [2.21196809 0.67909379]
# (Manually) Weighted RMSE Train
# [0.20923018 4.41700339]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.6652763295099061, 0.8821689259645464] [0.4132727080972158, 22.64166366545723] [0.2072969452186756, 4.60831357185782]
# Smiles Weight Mean and Std Dev
# 0.7002210719026801 0.07615906748183812
# Smiles Weight CI
# 0.5291445672486197 0.8199732386253425
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# ...
# Smiles Weight CI
# 0.5450807997247449 0.8241184713497716
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37044521 48.05567548] [ 1.56356783 25.50228276] [1.14091962 0.53068202]
# (Manually) Weighted RMSE Train
# [0.19387444 6.3829799 ]
#
#
# epoch number:  969
# Coverages, CI Widths, RMSEs
# [0.781021897810219, 0.881126173096976] [0.6591681049229693, 30.546683394314186] [0.188653279181756, 5.567883977051685]
# Smiles Weight Mean and Std Dev
# 0.6937021723265083 0.07678668366831119
# Smiles Weight CI
# 0.535406306634186 0.8143466111055233
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38563758 48.02926148] [ 1.52996527 25.28860126] [1.10415976 0.52652488]
# (Manually) Weighted RMSE Train
# [0.18865328 5.56788398]
#
#
# epoch number:  970
# Coverages, CI Widths, RMSEs
# [0.7883211678832117, 0.881126173096976] [0.6722845662926412, 31.297519854522143] [0.19198000632116613, 6.1001928199816415]
# Smiles Weight Mean and Std Dev
# 0.7004850478245321 0.07934010708891079
# Smiles Weight CI
# 0.5229633220174348 0.815209718223526
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37226866 47.98166435] [ 1.55545521 25.47047426] [1.13349175 0.53083766]
# (Manually) Weighted RMSE Train
# [0.19198001 6.10019282]
#
#
# epoch number:  971
# Coverages, CI Widths, RMSEs
# [0.7904066736183525, 0.881126173096976] [0.6764421109418227, 32.638134331849734] [0.18898597718586366, 5.525830146595167]
# Smiles Weight Mean and Std Dev
# 0.6938750835643892 0.08056968152842851
# Smiles Weight CI
# 0.5215862013617117 0.8190392166176604
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38511841 47.95174015] [ 1.53098612 25.3082402 ] [1.10531065 0.52778565]
# (Manually) Weighted RMSE Train
# [0.18898598 5.52583015]
#
#
# epoch number:  972
# Coverages, CI Widths, RMSEs
# [0.7935349322210636, 0.881126173096976] [0.6895536901174703, 33.31482179813422] [0.1881145606813768, 5.373796196314956]
# Smiles Weight Mean and Std Dev
# 0.6917837324076557 0.07991420066244406
# Smiles Weight CI
# 0.5245623910186101 0.8193829076664607
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38908149 47.95349014] [ 1.52273181 25.25985142] [1.09621488 0.52675731]
# (Manually) Weighted RMSE Train
# [0.18811456 5.3737962 ]
#
#
# epoch number:  973
# Coverages, CI Widths, RMSEs
# [0.786235662148071, 0.8800834202294057] [0.6677207922610314, 30.814755019241822] [0.18813510350846213, 5.335328641031115]
# Smiles Weight Mean and Std Dev
# 0.6912285138395866 0.07882847101529182
# Smiles Weight CI
# 0.5335726646376553 0.8172222234894299
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39150193 47.94807985] [ 1.52182073 25.27390659] [1.09365334 0.52710988]
# (Manually) Weighted RMSE Train
# [0.1881351  5.33532864]
#
#
# epoch number:  974
# Coverages, CI Widths, RMSEs
# [0.7820646506777894, 0.8717413972888426] [0.654340004268877, 30.701543561685696] [0.19135178988854742, 5.916926662161728]
# Smiles Weight Mean and Std Dev
# 0.698994718410436 0.07616807490848607
# Smiles Weight CI
# 0.5261597137960831 0.8100682916699877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37748786 47.95225643] [ 1.54933931 25.43900151] [1.12475714 0.53050687]
# (Manually) Weighted RMSE Train
# [0.19135179 5.91692666]
#
#
# epoch number:  975
# Coverages, CI Widths, RMSEs
# [0.7831074035453598, 0.881126173096976] [0.680518931490587, 31.119456999684427] [0.18985423901936352, 5.85375367606928]
# Smiles Weight Mean and Std Dev
# 0.6980209448051593 0.07915608827606396
# Smiles Weight CI
# 0.533701362487825 0.8191444809925232
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37850226 47.95648178] [ 1.54498108 25.39623915] [1.1207679  0.52956844]
# (Manually) Weighted RMSE Train
# [0.18985424 5.85375368]
#
#
# epoch number:  976
# Coverages, CI Widths, RMSEs
# [0.7883211678832117, 0.8800834202294057] [0.6864182407369092, 32.39651767537695] [0.18685998150700645, 5.162236972344703]
# Smiles Weight Mean and Std Dev
# 0.6879665174392124 0.07905077606895354
# Smiles Weight CI
# 0.5194511911824432 0.8177783212561662
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39871378 47.99625127] [ 1.50703528 25.19086234] [1.07744364 0.52485062]
# (Manually) Weighted RMSE Train
# [0.18685998 5.16223697]
#
#
# epoch number:  977
# Coverages, CI Widths, RMSEs
# [0.7977059436913452, 0.8832116788321168] [0.7043108176407943, 32.65572216180487] [0.1874645315659851, 5.3310247719491946]
# Smiles Weight Mean and Std Dev
# 0.6910792831450933 0.08746856451392293
# Smiles Weight CI
# 0.5192930620504884 0.8201373821323044
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39330169 47.97176681] [ 1.51886718 25.2559084 ] [1.09012082 0.52647443]
# (Manually) Weighted RMSE Train
# [0.18746453 5.33102477]
#
#
# epoch number:  978
# Coverages, CI Widths, RMSEs
# [0.7956204379562044, 0.8769551616266945] [0.692545530414148, 32.97604978807269] [0.18677837450737353, 5.073068019142371]
# Smiles Weight Mean and Std Dev
# 0.6860410077215033 0.08179987379783546
# Smiles Weight CI
# 0.5161308444284352 0.8105293881175784
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40267321 47.99363241] [ 1.50188607 25.17070545] [1.07073128 0.52445927]
# (Manually) Weighted RMSE Train
# [0.18677837 5.07306802]
#
#
# epoch number:  979
# Coverages, CI Widths, RMSEs
# [0.7695516162669447, 0.8748696558915537] [0.6312946218349985, 29.86888028631398] [0.1951869633323257, 6.513473022361758]
# Smiles Weight Mean and Std Dev
# 0.704488042208623 0.07176358593862806
# Smiles Weight CI
# 0.5507132058457661 0.8256756776158286
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36936388 47.98964679] [ 1.56924883 25.58234812] [1.1459692  0.53308057]
# (Manually) Weighted RMSE Train
# [0.19518696 6.51347302]
#
#
# epoch number:  980
# Coverages, CI Widths, RMSEs
# [0.786235662148071, 0.8790406673618353] [0.6863121759746991, 32.009147617223626] [0.19011250519130307, 5.908141520531637]
# Smiles Weight Mean and Std Dev
# 0.6978422386330382 0.08056504591069207
# Smiles Weight CI
# 0.5202750254227975 0.8169384890009944
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38127257 48.00675528] [ 1.54300223 25.40039683] [1.11708743 0.52910047]
# (Manually) Weighted RMSE Train
# [0.19011251 5.90814152]
#
#
# epoch number:  981
# Coverages, CI Widths, RMSEs
# [0.7966631908237748, 0.881126173096976] [0.7159530488728802, 34.42299708094559] [0.18702478761749863, 5.275367811440558]
# Smiles Weight Mean and Std Dev
# 0.6895557472081242 0.08178684762192064
# Smiles Weight CI
# 0.5126169501058303 0.8196956026845619
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39703911 48.01480148] [ 1.51066523 25.22602798] [1.08133353 0.52538024]
# (Manually) Weighted RMSE Train
# [0.18702479 5.27536781]
#
#
# epoch number:  982
# Coverages, CI Widths, RMSEs
# [0.7883211678832117, 0.8738269030239834] [0.6765597317801563, 33.087258576873566] [0.186606367608036, 4.977058790908257]
# Smiles Weight Mean and Std Dev
# 0.6838001139269857 0.08045427346660769
# Smiles Weight CI
# 0.5117053581554362 0.810951107685641
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40827369 48.02036009] [ 1.48779347 25.14358225] [1.05646614 0.52360253]
# (Manually) Weighted RMSE Train
# [0.18660637 4.97705879]
#
#
# epoch number:  983
# Coverages, CI Widths, RMSEs
# [0.7904066736183525, 0.8800834202294057] [0.695369373321913, 32.641085433096755] [0.1875831624919343, 5.393520870274072]
# Smiles Weight Mean and Std Dev
# 0.6913335713278689 0.07988099046624585
# Smiles Weight CI
# 0.5207812530111339 0.8199378560188617
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39590081 48.03189811] [ 1.51433329 25.23762204] [1.08484304 0.52543462]
# (Manually) Weighted RMSE Train
# [0.18758316 5.39352087]
#
#
# epoch number:  984
# Coverages, CI Widths, RMSEs
# [0.7778936392075079, 0.872784150156413] [0.6692955496997541, 31.570399254883256] [0.18941477512116606, 5.7044088646971725]
# Smiles Weight Mean and Std Dev
# 0.695719901645253 0.07811742272126855
# Smiles Weight CI
# 0.5330611268932686 0.8091794551277186
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38917462 48.01488441] [ 1.53241045 25.34207682] [1.10310859 0.52779627]
# (Manually) Weighted RMSE Train
# [0.18941478 5.70440886]
#
#
# epoch number:  985
# Coverages, CI Widths, RMSEs
# [0.786235662148071, 0.8790406673618353] [0.6956090346310587, 32.850742910292446] [0.18789056196980522, 5.434652400369004]
# Smiles Weight Mean and Std Dev
# 0.6924225976927575 0.07827949488961695
# Smiles Weight CI
# 0.5154533187905236 0.8129174773178595
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39582751 47.98203566] [ 1.5184365  25.25760571] [1.08783965 0.52639713]
# (Manually) Weighted RMSE Train
# [0.18789056 5.4346524 ]
#
#
# epoch number:  986
# Coverages, CI Widths, RMSEs
# [0.7987486965589156, 0.8873826903023984] [0.7154334930462737, 33.79874115410294] [0.18973020063145576, 5.768974295117201]
# Smiles Weight Mean and Std Dev
# 0.6967707655399382 0.08378492539262922
# Smiles Weight CI
# 0.5259488109358683 0.8298117358528815
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38912957 48.01034892] [ 1.53323346 25.37621081] [1.10373682 0.5285571 ]
# (Manually) Weighted RMSE Train
# [0.1897302 5.7689743]
#
#
# epoch number:  987
# Coverages, CI Widths, RMSEs
# [0.781021897810219, 0.8748696558915537] [0.6884882332452652, 33.33636344390321] [0.1869061384888956, 5.026318551543627]
# Smiles Weight Mean and Std Dev
# 0.6852347522802592 0.07692419793096883
# Smiles Weight CI
# 0.49887114779457536 0.8077322363406567
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41131611 47.98156024] [ 1.48884717 25.15702007] [1.05493529 0.524306  ]
# (Manually) Weighted RMSE Train
# [0.18690614 5.02631855]
#
#
# epoch number:  988
# Coverages, CI Widths, RMSEs
# [0.7778936392075079, 0.881126173096976] [0.672450984764794, 31.487718647372628] [0.1875817842002213, 5.253521168037399]
# Smiles Weight Mean and Std Dev
# 0.6895659071778465 0.08140054092228016
# Smiles Weight CI
# 0.5340864050656732 0.8171314864862032
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40383145 48.01484301] [ 1.50687577 25.22248615] [1.0734022  0.52530602]
# (Manually) Weighted RMSE Train
# [0.18758178 5.25352117]
#
#
# epoch number:  989
# Coverages, CI Widths, RMSEs
# [0.7966631908237748, 0.8842544316996872] [0.7167525807796705, 34.562117333869516] [0.18739475922398766, 5.271243465597497]
# Smiles Weight Mean and Std Dev
# 0.689686605268457 0.0847397288352746
# Smiles Weight CI
# 0.5133555189535743 0.8181035434183271
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4029941  48.03669573] [ 1.50643008 25.26155835] [1.07372517 0.52588043]
# (Manually) Weighted RMSE Train
# [0.18739476 5.27124347]
#
#
# epoch number:  990
# Coverages, CI Widths, RMSEs
# [0.7872784150156413, 0.8821689259645464] [0.68531099230086, 31.344200985477546] [0.18804084355377992, 5.398791958332179]
# Smiles Weight Mean and Std Dev
# 0.6916555969622129 0.08318552807815525
# Smiles Weight CI
# 0.5297073839924212 0.8226734573348982
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40097895 48.022766  ] [ 1.51369529 25.2938548 ] [1.08045541 0.5267055 ]
# (Manually) Weighted RMSE Train
# [0.18804084 5.39879196]
#
#
# epoch number:  991
# Coverages, CI Widths, RMSEs
# [0.7831074035453598, 0.881126173096976] [0.7080689555782318, 33.80910313966644] [0.19403087637095046, 6.305826338040141]
# Smiles Weight Mean and Std Dev
# 0.7025527513245977 0.07377491157334976
# Smiles Weight CI
# 0.5134050468565098 0.8234382724164099
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38138115 48.02777634] [ 1.55473835 25.54826845] [1.12549556 0.53194777]
# (Manually) Weighted RMSE Train
# [0.19403088 6.30582634]
#
#
# epoch number:  992
# Coverages, CI Widths, RMSEs
# [0.7799791449426486, 0.8717413972888426] [0.6642178004003454, 30.23118001435467] [0.19045502398107259, 5.855638461014685]
# Smiles Weight Mean and Std Dev
# 0.6974613378321319 0.07495419744638572
# Smiles Weight CI
# 0.528937408680317 0.8102090679815876
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38909833 48.01931861] [ 1.53482872 25.40182541] [1.10491006 0.52899179]
# (Manually) Weighted RMSE Train
# [0.19045502 5.85563846]
#
#
# epoch number:  993
# Coverages, CI Widths, RMSEs
# [0.8070907194994786, 0.8905109489051095] [0.7900684197606533, 38.412627740716964] [0.18770740849960316, 5.346272643234106]
# Smiles Weight Mean and Std Dev
# 0.6906477683896362 0.08600524635070997
# Smiles Weight CI
# 0.48083637750557634 0.8234600977888963
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40171645 48.03957396] [ 1.50883019 25.26773337] [1.07641613 0.52597747]
# (Manually) Weighted RMSE Train
# [0.18770741 5.34627264]
#
#
# epoch number:  994
# Coverages, CI Widths, RMSEs
# [0.7778936392075079, 0.8832116788321168] [0.6681569003024173, 32.56389208938439] [0.18922570720297732, 5.729778393146471]
# Smiles Weight Mean and Std Dev
# 0.6958870210008057 0.0789726266494469
# Smiles Weight CI
# 0.5317685741116017 0.8239326614108655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39147218 48.02625189] [ 1.52936922 25.39151159] [1.09910155 0.52870067]
# (Manually) Weighted RMSE Train
# [0.18922571 5.72977839]
#
#
# epoch number:  995
# Coverages, CI Widths, RMSEs
# [0.786235662148071, 0.8821689259645464] [0.7124788270792957, 34.329116686414736] [0.1894552241067842, 5.819708606419028]
# Smiles Weight Mean and Std Dev
# 0.6967740499492632 0.08154567839290619
# Smiles Weight CI
# 0.5075307124628802 0.8205309112010717
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39074121 48.01960079] [ 1.5316344  25.39708199] [1.10130799 0.5288899 ]
# (Manually) Weighted RMSE Train
# [0.18945522 5.81970861]
#
#
# epoch number:  996
# Coverages, CI Widths, RMSEs
# [0.7726798748696558, 0.8706986444212722] [0.6138759635641646, 28.575667838616734] [0.19269587064722454, 6.233543950647209]
# Smiles Weight Mean and Std Dev
# 0.7014465930745565 0.0765989477252375
# Smiles Weight CI
# 0.5641493785373101 0.8203792175709013
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38304789 48.01893153] [ 1.54880281 25.51334824] [1.11984756 0.53131853]
# (Manually) Weighted RMSE Train
# [0.19269587 6.23354395]
#
#
# epoch number:  997
# Coverages, CI Widths, RMSEs
# [0.7956204379562044, 0.8800834202294057] [0.6982430840063194, 32.661526831363005] [0.191924013149717, 6.047986153749251]
# Smiles Weight Mean and Std Dev
# 0.6998284915817663 0.08138742607438851
# Smiles Weight CI
# 0.5259997382678846 0.8150955894869825
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38672778 48.00601003] [ 1.54373119 25.48226746] [1.11321862 0.53081411]
# (Manually) Weighted RMSE Train
# [0.19192401 6.04798615]
#
#
# epoch number:  998
# Coverages, CI Widths, RMSEs
# [0.7851929092805006, 0.8800834202294057] [0.6874023926971449, 32.44055764797239] [0.1889250425933376, 5.447920174764356]
# Smiles Weight Mean and Std Dev
# 0.6924258628944062 0.08185407465383938
# Smiles Weight CI
# 0.5257362089784086 0.8173197759983647
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40232131 48.00506806] [ 1.51730283 25.30587163] [1.0819937 0.52715  ]
# (Manually) Weighted RMSE Train
# [0.18892504 5.44792017]
#
#
# epoch number:  999
# Coverages, CI Widths, RMSEs
# [0.7987486965589156, 0.881126173096976] [0.7328735304855458, 34.17256603408314] [0.18698851199043454, 5.196956652162667]
# Smiles Weight Mean and Std Dev
# 0.6886246404196388 0.08521789548216507
# Smiles Weight CI
# 0.5112108143051063 0.8301232940882158
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40900723 48.0015796 ] [ 1.49895249 25.23858711] [1.06383592 0.5257866 ]
# (Manually) Weighted RMSE Train
# [0.18698851 5.19695665]
#
#
# done for fold1
# train_width[0.3830035439149863, 20.920229670224142]
# smiles_weight0.6947259167495075
# rmse_train[0.10882680192923656, 0.10130937865124678]
# smiles_weight_ci[0.5499498092357573, 0.8132266580803411]
# CPU times: user 9h 1min 12s, sys: 5h 21min 28s, total: 14h 22min 40s
# Wall time: 2h 55min 42s

# %%
with open("..//Data/returned_stuff1_config4.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
# len(returned_stuff1[-2])

# %%
# with open("..//Data/returned_stuff_config4.pickle", "rb") as f: 
#     returned_stuff = pickle.load(f)

# %%
# import pickle

# %%
# with open("..//Data/returned_stuff_config3.pickle", "rb") as f: 
#     returned_stuff1 = pickle.load(f)

# %%
# returned_stuff1

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
