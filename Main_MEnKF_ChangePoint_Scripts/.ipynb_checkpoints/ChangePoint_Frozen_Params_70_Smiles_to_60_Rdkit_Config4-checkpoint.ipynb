# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-07-13 22:51:10.359894: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-07-13 22:51:10.406096: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 22:51:10.636326: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-07-13 22:51:10.637864: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-13 22:51:11.959313: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, fudging_var = 1.0):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_70_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_60_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200, fudging_var = 1.0):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
# returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 8.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-2)

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 100, fudging_var = 1e-5)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [47.65150128146758, 1065.3451576246282] [3.2102032775466918, 36.79470820950097]
# Smiles Weight Mean and Std Dev
# 0.5251325590082284 0.20690284904553263
# Smiles Weight CI
# 0.11906487034975784 0.8890514939860767
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.27611058 49.7652274 ] [ 3.7249335  41.39080739] [1.6365345  0.83172146]
# (Manually) Weighted RMSE Train
# [ 3.21020328 36.79470821]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [30.93881506585891, 717.0387192894759] [2.498133460532269, 47.8550849532023]
# Smiles Weight Mean and Std Dev
# 0.5338587011277066 0.20091165230433147
# Smiles Weight CI
# 0.1568949702857575 0.8682652877290538
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.57090663 50.63911208] [ 2.63676233 50.85640468] [1.02561575 1.004291  ]
# (Manually) Weighted RMSE Train
# [ 2.49813346 47.85508495]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [20.863647824505318, 480.6030286257794] [2.0640599370365615, 45.85897218523871]
# Smiles Weight Mean and Std Dev
# 0.5642386287845202 0.1735266871105004
# Smiles Weight CI
# 0.24924229756762784 0.8908239457884954
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.61638176 45.89534189] [ 2.22640113 52.37172442] [0.85094659 1.14111198]
# (Manually) Weighted RMSE Train
# [ 2.06405994 45.85897219]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [13.866014289665777, 322.49581886998783] [2.143173133447537, 33.14266484957453]
# Smiles Weight Mean and Std Dev
# 0.6188460511240185 0.1510027919494394
# Smiles Weight CI
# 0.33828380035481936 0.8894606400166815
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.40004239 42.5646321 ] [ 2.51490603 43.046387  ] [1.047859  1.0113182]
# (Manually) Weighted RMSE Train
# [ 2.14317313 33.14266485]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [10.594443420167094, 217.1682875221303] [1.8948687067130072, 32.846255883304835]
# Smiles Weight Mean and Std Dev
# 0.6901372370322384 0.11778010208797557
# Smiles Weight CI
# 0.4563919705412277 0.8881256084885649
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77752416 35.59858853] [ 2.90660483 50.5009848 ] [1.6351985  1.41862323]
# (Manually) Weighted RMSE Train
# [ 1.89486871 32.84625588]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [7.007907855985183, 151.65973321616661] [0.984744507321533, 25.536066111324523]
# Smiles Weight Mean and Std Dev
# 0.7199910494877719 0.11091251177078662
# Smiles Weight CI
# 0.5080723204844838 0.9156989459024542
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09316173 26.6617596 ] [ 2.67662618 52.94421462] [2.44851801 1.98577346]
# (Manually) Weighted RMSE Train
# [ 0.98474451 25.53606611]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.6152955455860845, 102.58549667053767] [0.7059458709727036, 17.811692502434976]
# Smiles Weight Mean and Std Dev
# 0.7456481162381228 0.09574210679350695
# Smiles Weight CI
# 0.5590278978194088 0.9250371254505318
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.66609818 21.47229014] [ 2.62889934 49.52010931] [3.94671449 2.30623324]
# (Manually) Weighted RMSE Train
# [ 0.70594587 17.8116925 ]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [3.5468859727755055, 78.4510084840446] [0.5550982504461301, 11.99809877870624]
# Smiles Weight Mean and Std Dev
# 0.735763863400239 0.09637598626701398
# Smiles Weight CI
# 0.5488718313018093 0.9090104866771077
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.63461559 15.68034184] [ 2.48889924 49.88822688] [3.92190058 3.18157776]
# (Manually) Weighted RMSE Train
# [ 0.55509825 11.99809878]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.556718078702538, 54.7070278395341] [0.34769905173777527, 8.143523274704844]
# Smiles Weight Mean and Std Dev
# 0.7539362715324789 0.09781669602388444
# Smiles Weight CI
# 0.5280508137107598 0.9125425962585365
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.62390361 13.98511967] [ 2.37191392 48.07250908] [3.80173134 3.4374042 ]
# (Manually) Weighted RMSE Train
# [0.34769905 8.14352327]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.1606061396949454, 44.965876627115804] [0.30831716199064674, 5.492758147056156]
# Smiles Weight Mean and Std Dev
# 0.7657973101029002 0.08654749063960897
# Smiles Weight CI
# 0.5979840127984158 0.9012220698441424
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.56383163 12.89145592] [ 2.37778257 46.23864885] [4.21718552 3.58676701]
# (Manually) Weighted RMSE Train
# [0.30831716 5.49275815]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 1.0] [1.8905545696944486, 35.188548530548644] [0.2642930766037302, 4.409040819764831]
# Smiles Weight Mean and Std Dev
# 0.7568932870708036 0.09762155822509314
# Smiles Weight CI
# 0.5570093077921439 0.8959275983864485
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.56898288 12.89457277] [ 2.44450767 44.11399542] [4.29627636 3.42112889]
# (Manually) Weighted RMSE Train
# [0.26429308 4.40904082]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 1.0] [1.6300453196143776, 31.799279485331535] [0.2671534438050213, 4.540914071708953]
# Smiles Weight Mean and Std Dev
# 0.7455312366006781 0.08661868054231042
# Smiles Weight CI
# 0.5870661813866648 0.8937412117529794
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.60986853 14.30507287] [ 2.37878393 43.04490399] [3.90048644 3.00906569]
# (Manually) Weighted RMSE Train
# [0.26715344 4.54091407]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9989572471324296] [1.395930079527502, 27.138270483858026] [0.2574697952895973, 4.337705085538978]
# Smiles Weight Mean and Std Dev
# 0.758828416122199 0.08320019149566132
# Smiles Weight CI
# 0.578743357837348 0.8831460112342061
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.60182672 13.57891828] [ 2.37300374 42.62438673] [3.94300163 3.13901195]
# (Manually) Weighted RMSE Train
# [0.2574698  4.33770509]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9801876955161627, 0.9968717413972888] [1.2766639099318737, 25.243851552364564] [0.2577687374328965, 4.43022149049613]
# Smiles Weight Mean and Std Dev
# 0.744214852612687 0.09106940444257372
# Smiles Weight CI
# 0.5505270712614846 0.8875771320829347
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.64202278 14.08140876] [ 2.3559465  41.51856024] [3.66956836 2.94846638]
# (Manually) Weighted RMSE Train
# [0.25776874 4.43022149]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9739311783107404, 0.9937434827945777] [1.21718320149766, 24.337253131132236] [0.2590688073076192, 4.496353473322853]
# Smiles Weight Mean and Std Dev
# 0.747078467607481 0.09156195283092955
# Smiles Weight CI
# 0.5672332100879758 0.8853223124533662
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.63612322 14.17365204] [ 2.36357954 41.19092466] [3.71560013 2.9061617 ]
# (Manually) Weighted RMSE Train
# [0.25906881 4.49635347]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9916579770594369] [1.1820613464902747, 21.91488966549604] [0.26155330855993486, 4.611603279053281]
# Smiles Weight Mean and Std Dev
# 0.7484151213194059 0.08612715630244216
# Smiles Weight CI
# 0.5486753970872035 0.8744352253391537
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.63820943 14.49694573] [ 2.35486227 41.11797679] [3.68979547 2.83631998]
# (Manually) Weighted RMSE Train
# [0.26155331 4.61160328]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9572471324296142, 0.9822732012513035] [1.1943436936101175, 21.02337275918829] [0.26311172766368957, 4.767226970914834]
# Smiles Weight Mean and Std Dev
# 0.7446426570808873 0.09732151149676452
# Smiles Weight CI
# 0.548781227332867 0.8893972875321627
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.65645471 14.62339301] [ 2.35663266 40.6743987 ] [3.58993943 2.78146109]
# (Manually) Weighted RMSE Train
# [0.26311173 4.76722697]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9582898852971846] [0.9841113506332648, 18.283901989291017] [0.2649666984819645, 4.77900040030274]
# Smiles Weight Mean and Std Dev
# 0.7517622131556748 0.08048068874416975
# Smiles Weight CI
# 0.5725486566875345 0.8697302981692997
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.65662444 14.55574795] [ 2.34634196 40.87258122] [3.57333939 2.80800282]
# (Manually) Weighted RMSE Train
# [0.2649667 4.7790004]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.959332638164755] [1.0048489056268763, 18.71647450240893] [0.2661278700312967, 4.87363913657838]
# Smiles Weight Mean and Std Dev
# 0.7442458862409942 0.09462118777772005
# Smiles Weight CI
# 0.5403739338164316 0.8767683793260092
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67559616 15.09969568] [ 2.33838495 40.2022376 ] [3.46121704 2.6624535 ]
# (Manually) Weighted RMSE Train
# [0.26612787 4.87363914]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9520333680917622] [0.9872761401032324, 18.470653824792695] [0.26751661653267045, 4.874167598521469]
# Smiles Weight Mean and Std Dev
# 0.7444058506631533 0.09189034964566774
# Smiles Weight CI
# 0.5412057764251818 0.8803439666511748
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67132901 15.33272498] [ 2.32926589 39.96019773] [3.4696339  2.60620325]
# (Manually) Weighted RMSE Train
# [0.26751662 4.8741676 ]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.9259645464025026] [0.8826209015059217, 17.26945047982141] [0.27067970405973485, 4.919272572346778]
# Smiles Weight Mean and Std Dev
# 0.7413017999525869 0.09020198233598256
# Smiles Weight CI
# 0.549326578272688 0.8806396807581977
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67977439 15.69807341] [ 2.32010118 39.68256   ] [3.41304586 2.52786179]
# (Manually) Weighted RMSE Train
# [0.2706797  4.91927257]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.867570385818561, 0.9124087591240876] [0.86936722619932, 15.60732389211125] [0.2745385948872414, 4.855448730916552]
# Smiles Weight Mean and Std Dev
# 0.7508552102517253 0.08167604169182764
# Smiles Weight CI
# 0.5621952210673199 0.8798003719690164
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.66022115 15.51580308] [ 2.34088212 40.00150601] [3.54560302 2.5781138 ]
# (Manually) Weighted RMSE Train
# [0.27453859 4.85544873]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.8456725755995829, 0.894681960375391] [0.7753802627993713, 14.490864280332882] [0.2718605198478753, 4.789443812788258]
# Smiles Weight Mean and Std Dev
# 0.7405829469993772 0.07797539267687444
# Smiles Weight CI
# 0.5734697601529978 0.8628230268761825
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67663853 16.18328604] [ 2.31647529 39.25206098] [3.42350484 2.42546915]
# (Manually) Weighted RMSE Train
# [0.27186052 4.78944381]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.8561001042752867, 0.908237747653806] [0.8389277209821885, 14.985934885635269] [0.26716174146346033, 4.805901896688416]
# Smiles Weight Mean and Std Dev
# 0.7389388430454086 0.08351049248484375
# Smiles Weight CI
# 0.5631535836833242 0.8675784940882971
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67461755 16.31356474] [ 2.32452657 38.9880235 ] [3.44569535 2.38991441]
# (Manually) Weighted RMSE Train
# [0.26716174 4.8059019 ]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.8331595411887383, 0.8519290928050052] [0.7447685512121383, 13.250843468574507] [0.27123243564261534, 4.851178707358402]
# Smiles Weight Mean and Std Dev
# 0.7478228930027746 0.07869376441061421
# Smiles Weight CI
# 0.5987903664640885 0.8664251149064279
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.65227681 15.99193259] [ 2.34684816 39.56763054] [3.59793286 2.47422445]
# (Manually) Weighted RMSE Train
# [0.27123244 4.85117871]
#
#
# done for fold0
# train_width[0.7753802627993713, 14.490864280332882]
# smiles_weight0.7405829469993772
# rmse_train[0.14404646152072725, 0.11098063612812496]
# smiles_weight_ci[0.5734697601529978, 0.8628230268761825]
# CPU times: user 13min 17s, sys: 8min 10s, total: 21min 27s
# Wall time: 4min 21s

# %%
with open("..//Data/returned_stuff_config5.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
with open("..//Data/returned_stuff_config5.pickle", "rb") as f: 
    returned_stuff = pickle.load(f)

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.65, epochs = 2000, fudging_var = 1e-4)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.886339937434828, 0.9207507820646507] [0.930635933012932, 16.80689710750855] [0.26742939361978774, 5.769775689826064]
# Smiles Weight Mean and Std Dev
# 0.742622720158187 0.08614019584629307
# Smiles Weight CI
# 0.5508156835161329 0.8801148270848491
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.6807652 18.0094815] [ 2.29942563 38.23570969] [3.37770739 2.12308776]
# (Manually) Weighted RMSE Train
# [0.26742939 5.76977569]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.954118873826903] [0.8963752162137969, 18.16310947273282] [0.2520141886551789, 5.429294185374322]
# Smiles Weight Mean and Std Dev
# 0.7422148662791563 0.0916148164378492
# Smiles Weight CI
# 0.5502070657988485 0.8924238052344666
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.705567  19.3437418] [ 2.25221462 37.26976092] [3.19206343 1.92670897]
# (Manually) Weighted RMSE Train
# [0.25201419 5.42929419]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.9603753910323254] [0.815761779716023, 17.602401532867695] [0.23864105147116282, 5.168544560342693]
# Smiles Weight Mean and Std Dev
# 0.7443538052176213 0.08244611327455383
# Smiles Weight CI
# 0.5449723938898046 0.8642191011137719
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7256943  20.03358823] [ 2.22498614 36.66104847] [3.06601024 1.82997914]
# (Manually) Weighted RMSE Train
# [0.23864105 5.16854456]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9687174139728885] [0.8329417790946041, 18.226357477556306] [0.23017791695514164, 5.044545425055174]
# Smiles Weight Mean and Std Dev
# 0.7462003296800266 0.08541250824835782
# Smiles Weight CI
# 0.560756159713202 0.8659876672886136
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.72665455 20.77731413] [ 2.20021024 35.99175786] [3.02786274 1.73226229]
# (Manually) Weighted RMSE Train
# [0.23017792 5.04454543]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9718456725755996] [0.825525987195267, 18.162382697026967] [0.22360880402982733, 4.904500795935283]
# Smiles Weight Mean and Std Dev
# 0.7385843211185468 0.08390349916230513
# Smiles Weight CI
# 0.5639712750308393 0.8677026578745278
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.74598599 22.46571931] [ 2.16864624 34.55867739] [2.9070871  1.53828493]
# (Manually) Weighted RMSE Train
# [0.2236088 4.9045008]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9708029197080292] [0.7877166516266443, 18.803599133419997] [0.21841313555752745, 4.700000556291118]
# Smiles Weight Mean and Std Dev
# 0.7310174090208436 0.08270159582930034
# Smiles Weight CI
# 0.5509306557862501 0.8585073825467382
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.77411071 23.61712608] [ 2.12864615 33.28735071] [2.74979551 1.40945815]
# (Manually) Weighted RMSE Train
# [0.21841314 4.70000056]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.9749739311783108] [0.8032266448441121, 21.237622995931357] [0.21489466537877536, 4.525608286394442]
# Smiles Weight Mean and Std Dev
# 0.7306159746805422 0.0907984388365441
# Smiles Weight CI
# 0.5402891863914531 0.8609083208110576
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.78634695 24.85301659] [ 2.10968434 32.34030114] [2.68289252 1.30126261]
# (Manually) Weighted RMSE Train
# [0.21489467 4.52560829]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9676746611053181] [0.7531942022776722, 19.549146740744025] [0.20953279658641177, 4.469481933237898]
# Smiles Weight Mean and Std Dev
# 0.7319906555803949 0.0734562528612118
# Smiles Weight CI
# 0.5778168823886648 0.8524044242561934
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80338237 26.14370038] [ 2.09680028 31.62272165] [2.60996553 1.20957329]
# (Manually) Weighted RMSE Train
# [0.2095328  4.46948193]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9801876955161627] [0.7891629629263143, 22.196314839838298] [0.20637740481460334, 4.573298421736621]
# Smiles Weight Mean and Std Dev
# 0.7355826340479299 0.08850836587316639
# Smiles Weight CI
# 0.5405341638865084 0.8624865619833436
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80442858 27.25924146] [ 2.08513829 31.33201701] [2.59207386 1.14940898]
# (Manually) Weighted RMSE Train
# [0.2063774  4.57329842]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9833159541188738] [0.7589942547876702, 22.519302689043066] [0.20223823932257723, 4.599052323092089]
# Smiles Weight Mean and Std Dev
# 0.7365340636920631 0.08488170254432205
# Smiles Weight CI
# 0.5452570338406946 0.862384233164051
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81962623 28.43044384] [ 2.07967165 30.61123173] [2.53734151 1.07670608]
# (Manually) Weighted RMSE Train
# [0.20223824 4.59905232]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9791449426485923] [0.7839151870908286, 24.92941836527455] [0.19558961261859656, 4.291222586842702]
# Smiles Weight Mean and Std Dev
# 0.7236398426247852 0.08303311776252804
# Smiles Weight CI
# 0.5393593095598684 0.8561425677876839
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87432321 29.84908214] [ 2.01940359 29.05523941] [2.3096763  0.97340479]
# (Manually) Weighted RMSE Train
# [0.19558961 4.29122259]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9770594369134515] [0.7610835041104349, 23.971664219362605] [0.1915478225748887, 4.194144056191132]
# Smiles Weight Mean and Std Dev
# 0.7125976679305864 0.08469987337608782
# Smiles Weight CI
# 0.5379658683650858 0.836956894048677
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.92392453 30.95038366] [ 1.97756167 27.95589793] [2.14039309 0.90324883]
# (Manually) Weighted RMSE Train
# [0.19154782 4.19414406]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9718456725755996] [0.7696528954414152, 23.550506164067386] [0.18886756869094937, 4.415939455309774]
# Smiles Weight Mean and Std Dev
# 0.7234550426218015 0.0832050463028084
# Smiles Weight CI
# 0.5504847724851755 0.8408380017552189
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.9063518 31.2405363] [ 1.9814424  28.49530259] [2.18617363 0.91212591]
# (Manually) Weighted RMSE Train
# [0.18886757 4.41593946]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9781021897810219] [0.7560769993814835, 26.57118578431559] [0.18659040317709197, 4.288330224121192]
# Smiles Weight Mean and Std Dev
# 0.7172254239139857 0.08493142405753928
# Smiles Weight CI
# 0.5221600806317562 0.8515019020847606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.93023216 31.86297228] [ 1.94003411 27.81297811] [2.08553756 0.8728934 ]
# (Manually) Weighted RMSE Train
# [0.1865904  4.28833022]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9760166840458812] [0.7340328007279892, 27.101841105298643] [0.18581167639047186, 4.3763874737568464]
# Smiles Weight Mean and Std Dev
# 0.7182693556721549 0.08484380106040283
# Smiles Weight CI
# 0.5224961331254739 0.8436483069183417
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.94059714 32.52180553] [ 1.94034611 27.65223214] [2.06288752 0.85026743]
# (Manually) Weighted RMSE Train
# [0.18581168 4.37638747]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9155370177267987, 0.9718456725755996] [0.7012858013127224, 23.42188548050186] [0.1852284654788013, 4.5979477699264075]
# Smiles Weight Mean and Std Dev
# 0.7168449211784022 0.08318029456761958
# Smiles Weight CI
# 0.5501717474307543 0.8401021521446453
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.95436324 33.16393285] [ 1.93323716 27.35754456] [2.02568276 0.82491858]
# (Manually) Weighted RMSE Train
# [0.18522847 4.59794777]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.9770594369134515] [0.759070390941999, 24.415734083814883] [0.18350437245547643, 4.594539667943668]
# Smiles Weight Mean and Std Dev
# 0.7145365601101795 0.08212121713641224
# Smiles Weight CI
# 0.5625872996844964 0.8320707640068442
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.96871058 33.74236343] [ 1.91431563 27.10120434] [1.97614816 0.80318038]
# (Manually) Weighted RMSE Train
# [0.18350437 4.59453967]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.927007299270073, 0.9739311783107404] [0.7334731378230525, 24.78432681625897] [0.18066802463530338, 4.478480309791892]
# Smiles Weight Mean and Std Dev
# 0.7102357248208586 0.08603261849752045
# Smiles Weight CI
# 0.5352850795202383 0.8433762392367975
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97999601 34.21324965] [ 1.89429916 26.58295571] [1.9329662  0.77697839]
# (Manually) Weighted RMSE Train
# [0.18066802 4.47848031]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.97288842544317] [0.7340870327250475, 24.580869148669358] [0.18004958683345873, 4.696220403475689]
# Smiles Weight Mean and Std Dev
# 0.7133268042685904 0.08271572801912531
# Smiles Weight CI
# 0.509587882731238 0.8416107956667309
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.98135987 34.59361572] [ 1.89512723 26.63865699] [1.93112363 0.77004547]
# (Manually) Weighted RMSE Train
# [0.18004959 4.6962204 ]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9718456725755996] [0.7510001745745736, 25.515001563062064] [0.17999546649699522, 4.357546925773815]
# Smiles Weight Mean and Std Dev
# 0.7063631830658677 0.0793450866710152
# Smiles Weight CI
# 0.5284554818636666 0.832646750795056
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00135072 34.96068687] [ 1.86450247 25.81921967] [1.86198744 0.73852152]
# (Manually) Weighted RMSE Train
# [0.17999547 4.35754693]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9708029197080292] [0.7165046148582136, 24.446318527185458] [0.179689269278782, 4.645533132142954]
# Smiles Weight Mean and Std Dev
# 0.7096808604218109 0.07649744097925379
# Smiles Weight CI
# 0.5553491265236055 0.8321478702095106
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.99585956 35.22571668] [ 1.87703525 25.95097619] [1.88483931 0.73670541]
# (Manually) Weighted RMSE Train
# [0.17968927 4.64553313]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9676746611053181] [0.7238015099030989, 23.518580541201846] [0.1784591533196817, 4.4322284196887844]
# Smiles Weight Mean and Std Dev
# 0.7020778897756259 0.0760161144709057
# Smiles Weight CI
# 0.5336345103116745 0.8237167534153833
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.01993094 35.66459663] [ 1.84718802 25.37924578] [1.81109127 0.71160894]
# (Manually) Weighted RMSE Train
# [0.17845915 4.43222842]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9635036496350365] [0.7161999733329912, 25.03090901566318] [0.17840025751859237, 5.111304305251396]
# Smiles Weight Mean and Std Dev
# 0.7136275958967467 0.0762370145429035
# Smiles Weight CI
# 0.5568023024160641 0.8334753926287332
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00753844 35.38004846] [ 1.87470928 26.29508868] [1.86068265 0.743218  ]
# (Manually) Weighted RMSE Train
# [0.17840026 5.11130431]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9666319082377477] [0.7588012832786514, 25.68421781925923] [0.17713932514799538, 4.253380677323721]
# Smiles Weight Mean and Std Dev
# 0.6964124105905996 0.08053833981376722
# Smiles Weight CI
# 0.5282341258101643 0.8203201403815475
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05245122 35.90961774] [ 1.81917716 24.75736273] [1.72851447 0.68943543]
# (Manually) Weighted RMSE Train
# [0.17713933 4.25338068]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9687174139728885] [0.7014949384818191, 25.51428345481163] [0.17550292781525773, 4.693935233717483]
# Smiles Weight Mean and Std Dev
# 0.7043754703592817 0.08365586209267482
# Smiles Weight CI
# 0.5036458429644403 0.825912974795704
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.04533164 36.02266972] [ 1.82722928 25.36373723] [1.74799003 0.70410487]
# (Manually) Weighted RMSE Train
# [0.17550293 4.69393523]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9655891553701773] [0.7203262266963576, 24.694949683297832] [0.17819660069383786, 5.0697766784596014]
# Smiles Weight Mean and Std Dev
# 0.7077299824383272 0.07835955660245231
# Smiles Weight CI
# 0.552904819702822 0.82422594852714
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.04574331 36.12546798] [ 1.83932991 25.55349585] [1.75887323 0.70735404]
# (Manually) Weighted RMSE Train
# [0.1781966  5.06977668]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9708029197080292] [0.7215292344628247, 25.200060065843648] [0.17727957684031612, 4.756513984309073]
# Smiles Weight Mean and Std Dev
# 0.7005966612427862 0.0796929054481971
# Smiles Weight CI
# 0.5423847760267585 0.8269817527850429
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.0710687  36.55309698] [ 1.80714177 24.96792144] [1.68723235 0.68305899]
# (Manually) Weighted RMSE Train
# [0.17727958 4.75651398]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9655891553701773] [0.7256948388848516, 25.487252647018714] [0.17600813097384685, 4.630355382388919]
# Smiles Weight Mean and Std Dev
# 0.6999271178885604 0.08049991988316173
# Smiles Weight CI
# 0.5345480275125778 0.8200857656376883
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.07650234 36.78328901] [ 1.80050083 24.78679492] [1.67254706 0.67386021]
# (Manually) Weighted RMSE Train
# [0.17600813 4.63035538]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9676746611053181] [0.7635508302160502, 26.607204118165786] [0.17514272730395194, 4.4471383434910035]
# Smiles Weight Mean and Std Dev
# 0.6949306941263804 0.0845698953057329
# Smiles Weight CI
# 0.5223046202937169 0.8234482056010981
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09625576 37.27134451] [ 1.77657116 24.31686251] [1.62058092 0.65242783]
# (Manually) Weighted RMSE Train
# [0.17514273 4.44713834]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9655891553701773] [0.7449490876504159, 26.08758644265046] [0.17766412280452787, 4.665105099052509]
# Smiles Weight Mean and Std Dev
# 0.6980767817196631 0.07840100716335698
# Smiles Weight CI
# 0.5288051239023398 0.8199883536288058
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09637194 37.27940938] [ 1.7783681  24.60811561] [1.62204818 0.6600994 ]
# (Manually) Weighted RMSE Train
# [0.17766412 4.6651051 ]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.9645464025026069] [0.6957892710904212, 23.384766447212254] [0.17779454356647462, 4.645515271684177]
# Smiles Weight Mean and Std Dev
# 0.6981152491879515 0.07744895336017764
# Smiles Weight CI
# 0.5343325875814924 0.8123512020879657
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.10036325 37.48896404] [ 1.77689931 24.54286324] [1.61482976 0.65466902]
# (Manually) Weighted RMSE Train
# [0.17779454 4.64551527]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9666319082377477] [0.7365240300102361, 26.239410476774356] [0.18231137821302562, 5.462676501398189]
# Smiles Weight Mean and Std Dev
# 0.7105716553397953 0.07783450558809897
# Smiles Weight CI
# 0.5141169559042614 0.8213249656814361
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08029174 37.45788767] [ 1.81154974 25.57353322] [1.6769079  0.68272759]
# (Manually) Weighted RMSE Train
# [0.18231138 5.4626765 ]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.927007299270073, 0.9801876955161627] [0.7406077178750181, 29.022572582146363] [0.17658653310296124, 4.142990109596714]
# Smiles Weight Mean and Std Dev
# 0.690210969282058 0.08439153227132754
# Smiles Weight CI
# 0.5228581528724048 0.8271272699047884
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1345852  38.05852179] [ 1.7376495  23.84901666] [1.53152844 0.62664065]
# (Manually) Weighted RMSE Train
# [0.17658653 4.14299011]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9718456725755996] [0.7615652608778887, 26.722723376987272] [0.17598006110988515, 4.010653838462187]
# Smiles Weight Mean and Std Dev
# 0.6820356790101546 0.08623749736920691
# Smiles Weight CI
# 0.5111749962005998 0.814970525635096
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.16089041 38.56878045] [ 1.70390203 23.27569592] [1.46775442 0.6034854 ]
# (Manually) Weighted RMSE Train
# [0.17598006 4.01065384]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9739311783107404] [0.7571954927590823, 26.183001044870927] [0.1784654793887635, 4.3307811265871905]
# Smiles Weight Mean and Std Dev
# 0.6913977410290836 0.08354087186880492
# Smiles Weight CI
# 0.5329306684937435 0.8187019888706255
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.14990314 38.60562625] [ 1.72920909 23.86635603] [1.50378673 0.61820927]
# (Manually) Weighted RMSE Train
# [0.17846548 4.33078113]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.97288842544317] [0.7417502195424354, 27.493047928824392] [0.17787544740702646, 4.5687340400749585]
# Smiles Weight Mean and Std Dev
# 0.6942188221223787 0.08497593625069878
# Smiles Weight CI
# 0.5055706515030136 0.8183000742088344
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.15698188 38.89449393] [ 1.72105949 23.96928201] [1.4875423  0.61626414]
# (Manually) Weighted RMSE Train
# [0.17787545 4.56873404]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9770594369134515] [0.7447712473306622, 27.784628927016627] [0.1768604206276769, 4.520927516584206]
# Smiles Weight Mean and Std Dev
# 0.6918149544598585 0.08618469685987759
# Smiles Weight CI
# 0.5115186862894068 0.8252276657494583
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17624263 39.09608262] [ 1.69802016 23.77875691] [1.44359686 0.60821329]
# (Manually) Weighted RMSE Train
# [0.17686042 4.52092752]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9708029197080292] [0.7786472346750282, 29.063668655161933] [0.18051989345610597, 5.153861968934114]
# Smiles Weight Mean and Std Dev
# 0.700305490698639 0.08347016876681351
# Smiles Weight CI
# 0.5095913199331022 0.8389078883025793
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.16991784 39.20014683] [ 1.71480463 24.44138217] [1.46574791 0.62350231]
# (Manually) Weighted RMSE Train
# [0.18051989 5.15386197]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.9676746611053181] [0.7646368373498292, 27.513385501895424] [0.1807493300690148, 5.143673815643386]
# Smiles Weight Mean and Std Dev
# 0.6990496567351211 0.08466244462408515
# Smiles Weight CI
# 0.5158590589402233 0.8338512180819885
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.183522   39.40605421] [ 1.70695261 24.39430845] [1.44226521 0.61904976]
# (Manually) Weighted RMSE Train
# [0.18074933 5.14367382]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.9718456725755996] [0.8036517211689519, 29.8871450044799] [0.17901373131253745, 5.14147207854492]
# Smiles Weight Mean and Std Dev
# 0.6970640633944937 0.08469033497455689
# Smiles Weight CI
# 0.49797679410736206 0.8195214770467645
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19589476 39.61712643] [ 1.6832267  24.25243477] [1.40750404 0.61217047]
# (Manually) Weighted RMSE Train
# [0.17901373 5.14147208]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9687174139728885] [0.7869037393431517, 28.325415038387103] [0.18102528536429527, 5.567887453942174]
# Smiles Weight Mean and Std Dev
# 0.7044731012523746 0.0824482283233172
# Smiles Weight CI
# 0.5404791603548725 0.8368440610154122
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18863949 39.63605935] [ 1.6977813 24.7741869] [1.42833997 0.62504162]
# (Manually) Weighted RMSE Train
# [0.18102529 5.56788745]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.9687174139728885] [0.7486993114315859, 27.03549876796153] [0.17899982049624538, 5.091516288033542]
# Smiles Weight Mean and Std Dev
# 0.6972567472284874 0.0761172465790121
# Smiles Weight CI
# 0.5301645303869863 0.8204524878576807
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20826903 39.92366735] [ 1.66792425 24.24153517] [1.38042456 0.6071971 ]
# (Manually) Weighted RMSE Train
# [0.17899982 5.09151629]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.9155370177267987, 0.9624608967674662] [0.7721395339441705, 27.8603749037911] [0.18105063239649408, 5.302681493696206]
# Smiles Weight Mean and Std Dev
# 0.6976992260334689 0.07694063312246482
# Smiles Weight CI
# 0.5248031852001299 0.8151960930640618
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.21474028 40.3852858 ] [ 1.66943776 24.34788965] [1.37431663 0.60289012]
# (Manually) Weighted RMSE Train
# [0.18105063 5.30268149]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9687174139728885] [0.7656023888780968, 29.24849308414968] [0.18174376105870926, 5.811195588598227]
# Smiles Weight Mean and Std Dev
# 0.702410518432278 0.08201118894790996
# Smiles Weight CI
# 0.5247457266079008 0.8229028160617496
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20099418 40.45549102] [ 1.68220899 24.77217592] [1.40068038 0.61233161]
# (Manually) Weighted RMSE Train
# [0.18174376 5.81119559]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9655891553701773] [0.7391246323448657, 26.417330879433433] [0.17985984694181628, 5.016688941019215]
# Smiles Weight Mean and Std Dev
# 0.6916448756459759 0.08164860516523295
# Smiles Weight CI
# 0.5223455333765455 0.8138155621115459
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23426157 40.78802132] [ 1.64729852 23.98157047] [1.33464296 0.58795621]
# (Manually) Weighted RMSE Train
# [0.17985985 5.01668894]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9655891553701773] [0.8220325327029849, 29.015610402054037] [0.17937094937876516, 5.16467530887741]
# Smiles Weight Mean and Std Dev
# 0.6958485326600573 0.08466856801804859
# Smiles Weight CI
# 0.5021107132538766 0.8186704787766869
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23112034 40.89477142] [ 1.64465662 24.18140607] [1.3359024  0.59130801]
# (Manually) Weighted RMSE Train
# [0.17937095 5.16467531]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.9697601668404588] [0.8227543022577777, 29.99442278328224] [0.1784026693501284, 4.962790676588149]
# Smiles Weight Mean and Std Dev
# 0.6932766850201243 0.08733517209999557
# Smiles Weight CI
# 0.5096517022015256 0.8269815273876079
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24425627 40.98177262] [ 1.63004957 24.05267228] [1.31005936 0.58691147]
# (Manually) Weighted RMSE Train
# [0.17840267 4.96279068]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.9666319082377477] [0.7519906256105289, 27.099128595188734] [0.18066283903030872, 5.121875914585591]
# Smiles Weight Mean and Std Dev
# 0.6955248408443662 0.07583081076919398
# Smiles Weight CI
# 0.5419829416492719 0.815456306048837
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24580289 41.10051866] [ 1.63785235 24.22679755] [1.31469622 0.58945236]
# (Manually) Weighted RMSE Train
# [0.18066284 5.12187591]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.97288842544317] [0.80059539399098, 29.140901331909486] [0.18316789928913266, 5.783414434499656]
# Smiles Weight Mean and Std Dev
# 0.7016479484405476 0.07970912770395913
# Smiles Weight CI
# 0.5278850540294991 0.8228085211365429
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24003059 41.26955961] [ 1.64799108 24.62674912] [1.32899228 0.59672915]
# (Manually) Weighted RMSE Train
# [0.1831679  5.78341443]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.9687174139728885] [0.7538821741523146, 29.20033105750925] [0.18365417866073505, 5.749873715635288]
# Smiles Weight Mean and Std Dev
# 0.697339640140394 0.07764219263113467
# Smiles Weight CI
# 0.5494576712561499 0.8277355141264148
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26132577 41.7249381 ] [ 1.62978732 24.44038386] [1.29212243 0.58575003]
# (Manually) Weighted RMSE Train
# [0.18365418 5.74987372]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9718456725755996] [0.8356886452891066, 31.71576477309216] [0.17853258370441055, 5.322848067895283]
# Smiles Weight Mean and Std Dev
# 0.6882811470742385 0.08184893384479533
# Smiles Weight CI
# 0.494857496342642 0.8233315591004923
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27816047 42.26784935] [ 1.59026257 23.89157149] [1.24418068 0.56524218]
# (Manually) Weighted RMSE Train
# [0.17853258 5.32284807]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9363920750782064, 0.9770594369134515] [0.9293434951903821, 33.85970201994452] [0.17808167019848373, 5.301791985022742]
# Smiles Weight Mean and Std Dev
# 0.6905768859978629 0.0879790130300079
# Smiles Weight CI
# 0.48986624377398535 0.8238097903434893
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27191785 42.34552781] [ 1.59301485 23.96618923] [1.25245105 0.56596742]
# (Manually) Weighted RMSE Train
# [0.17808167 5.30179199]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9749739311783108] [0.8248264513095542, 32.952158401533815] [0.17810651797020016, 5.17054135316798]
# Smiles Weight Mean and Std Dev
# 0.6895508718636003 0.09047533030338106
# Smiles Weight CI
# 0.48350350055236346 0.8169556416035678
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27750929 42.63291842] [ 1.59319488 23.87939025] [1.24711022 0.56011625]
# (Manually) Weighted RMSE Train
# [0.17810652 5.17054135]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9739311783107404] [0.7881694290066701, 30.38928349677568] [0.18351119271976263, 5.6261833716842435]
# Smiles Weight Mean and Std Dev
# 0.6944544915774833 0.08114637415788242
# Smiles Weight CI
# 0.5279616434617593 0.8100171265204836
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26905051 42.6795599 ] [ 1.6180056  24.20887146] [1.27497336 0.56722402]
# (Manually) Weighted RMSE Train
# [0.18351119 5.62618337]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.9426485922836287, 0.9739311783107404] [0.8509433547412902, 31.612859974146634] [0.17848319771829213, 4.83769540208456]
# Smiles Weight Mean and Std Dev
# 0.686471953832437 0.08554171596811563
# Smiles Weight CI
# 0.5111306951165336 0.8306399141660742
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29407066 42.84770223] [ 1.57919839 23.87400775] [1.22033398 0.55718292]
# (Manually) Weighted RMSE Train
# [0.1784832 4.8376954]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.9687174139728885] [0.7797902977200163, 29.38996108467195] [0.18272654033167057, 6.090548969758282]
# Smiles Weight Mean and Std Dev
# 0.6987893457581703 0.07901869630100604
# Smiles Weight CI
# 0.5342555221407869 0.8193953316812926
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26472856 42.91822661] [ 1.61971075 24.69845059] [1.28067856 0.57547696]
# (Manually) Weighted RMSE Train
# [0.18272654 6.09054897]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9697601668404588] [0.8304879321128797, 30.356023623865738] [0.18220204900012266, 5.456236268537236]
# Smiles Weight Mean and Std Dev
# 0.692612747630685 0.07728449239240638
# Smiles Weight CI
# 0.5423680359610541 0.8185417979598849
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28513293 43.00221212] [ 1.59442126 24.27685617] [1.24066641 0.56454901]
# (Manually) Weighted RMSE Train
# [0.18220205 5.45623627]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9718456725755996] [0.8250715224345222, 31.551879319734255] [0.19102915705721465, 6.511819204987119]
# Smiles Weight Mean and Std Dev
# 0.7005048860818923 0.08297671106450574
# Smiles Weight CI
# 0.5014652677774872 0.8233997422423567
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28325414 43.12144174] [ 1.62113572 24.84745255] [1.2633006  0.57622036]
# (Manually) Weighted RMSE Train
# [0.19102916 6.5118192 ]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.9332638164754953, 0.9687174139728885] [0.8209248911840434, 31.81680245698346] [0.18387960187365088, 5.3668959294508225]
# Smiles Weight Mean and Std Dev
# 0.6886667391408495 0.08340763626529223
# Smiles Weight CI
# 0.5120300503131227 0.8184347968524435
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32394713 43.40447485] [ 1.56396615 24.10057422] [1.18129049 0.55525552]
# (Manually) Weighted RMSE Train
# [0.1838796  5.36689593]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.97288842544317] [0.8952186641519649, 33.15624021301519] [0.18424420950728357, 5.520831219064983]
# Smiles Weight Mean and Std Dev
# 0.6871555694753986 0.08570635614336396
# Smiles Weight CI
# 0.505537218077177 0.8203514981759018
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32697659 43.66700964] [ 1.55567128 23.98131476] [1.17234267 0.5491861 ]
# (Manually) Weighted RMSE Train
# [0.18424421 5.52083122]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9791449426485923] [0.8322852526907819, 32.79347470552476] [0.1882860256513163, 6.086481280364082]
# Smiles Weight Mean and Std Dev
# 0.6932579639833799 0.08247548175834661
# Smiles Weight CI
# 0.5133205556451155 0.8340502160678428
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31649719 43.65755007] [ 1.5776384  24.44729997] [1.19836063 0.55997874]
# (Manually) Weighted RMSE Train
# [0.18828603 6.08648128]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9676746611053181] [0.8382631301189377, 30.10309357114307] [0.1835062186021905, 5.851912024508031]
# Smiles Weight Mean and Std Dev
# 0.6905296679252132 0.08008620693229726
# Smiles Weight CI
# 0.5322742064035098 0.8138479859884966
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31339284 43.93896957] [ 1.56010052 24.24482068] [1.18783998 0.55178401]
# (Manually) Weighted RMSE Train
# [0.18350622 5.85191202]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9760166840458812] [0.850930911361848, 33.094028073036974] [0.1804307188133408, 5.8436284400420515]
# Smiles Weight Mean and Std Dev
# 0.6901361136226593 0.0841403879160603
# Smiles Weight CI
# 0.5253488144340075 0.8149405289640798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31246414 44.03394609] [ 1.55908345 24.37340806] [1.18790556 0.55351406]
# (Manually) Weighted RMSE Train
# [0.18043072 5.84362844]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.9624608967674662] [0.8131487193046638, 30.75467268781004] [0.18200451170258858, 5.598262279663175]
# Smiles Weight Mean and Std Dev
# 0.687656533052433 0.07539031612628849
# Smiles Weight CI
# 0.5257111420032513 0.8152256111382575
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3237492  44.04183204] [ 1.55166737 24.12110892] [1.17217625 0.54768632]
# (Manually) Weighted RMSE Train
# [0.18200451 5.59826228]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.97288842544317] [0.8376284886544068, 31.82206717048342] [0.18548929353639163, 5.735780367438916]
# Smiles Weight Mean and Std Dev
# 0.6877439230109568 0.08493029721745736
# Smiles Weight CI
# 0.5092278832004125 0.8180655911037008
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33124952 44.26027072] [ 1.55556441 24.19557202] [1.16849951 0.5466657 ]
# (Manually) Weighted RMSE Train
# [0.18548929 5.73578037]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9718456725755996] [0.809847245036268, 30.415188086880594] [0.18360053037723878, 5.668452835046943]
# Smiles Weight Mean and Std Dev
# 0.6896200160061682 0.08013305307186118
# Smiles Weight CI
# 0.5401049254972161 0.8111714221111983
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33143644 44.26277775] [ 1.54984772 24.47973417] [1.16404184 0.55305463]
# (Manually) Weighted RMSE Train
# [0.18360053 5.66845284]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.9635036496350365] [0.7976655189141737, 30.184274256130806] [0.1834347005300332, 5.5658620969616015]
# Smiles Weight Mean and Std Dev
# 0.6892206532807016 0.07740162919760145
# Smiles Weight CI
# 0.5263786367263752 0.814284095930946
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34178778 44.36971891] [ 1.54020734 24.41406534] [1.147877  0.5502416]
# (Manually) Weighted RMSE Train
# [0.1834347 5.5658621]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9655891553701773] [0.8182627612272397, 30.8000540043405] [0.18020123934751753, 5.422536756180978]
# Smiles Weight Mean and Std Dev
# 0.689522320700686 0.07678424002470578
# Smiles Weight CI
# 0.5359369557501155 0.8168960312514981
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34136837 44.30168311] [ 1.53520203 24.28052904] [1.14450442 0.54807238]
# (Manually) Weighted RMSE Train
# [0.18020124 5.42253676]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.9718456725755996] [0.8579037921122376, 33.12422086383351] [0.18135634607095252, 5.201820929002758]
# Smiles Weight Mean and Std Dev
# 0.6846398383214332 0.08478177917384813
# Smiles Weight CI
# 0.5135299005561365 0.808008337755738
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36074506 44.61104242] [ 1.51772166 24.05949749] [1.11536077 0.53931709]
# (Manually) Weighted RMSE Train
# [0.18135635 5.20182093]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9718456725755996] [0.857492435171154, 34.44117712404044] [0.18293888474163836, 5.172005694969015]
# Smiles Weight Mean and Std Dev
# 0.6849116993575236 0.0836632885368958
# Smiles Weight CI
# 0.5196612939112633 0.8182181556627375
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36801266 44.82089345] [ 1.51511955 24.17846851] [1.10753328 0.53944638]
# (Manually) Weighted RMSE Train
# [0.18293888 5.17200569]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9655891553701773] [0.8281424664658001, 29.992230748832824] [0.18750993720437836, 6.048552396891601]
# Smiles Weight Mean and Std Dev
# 0.6934379554440114 0.07838594765427405
# Smiles Weight CI
# 0.5304453840344813 0.8168679476547493
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36638107 44.76647264] [ 1.53035618 24.51165457] [1.12000686 0.54754492]
# (Manually) Weighted RMSE Train
# [0.18750994 6.0485524 ]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.9384775808133472, 0.9676746611053181] [0.8359220850639014, 30.593092436309593] [0.18665302841462153, 5.756143779281335]
# Smiles Weight Mean and Std Dev
# 0.6891483593554242 0.0737798102718538
# Smiles Weight CI
# 0.5452378261028418 0.8004553278947639
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38662205 44.9349786 ] [ 1.50554234 24.43729884] [1.08576259 0.54383689]
# (Manually) Weighted RMSE Train
# [0.18665303 5.75614378]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.9363920750782064, 0.9676746611053181] [0.8514265881249156, 32.10302546238277] [0.1883599286303243, 5.891552261542659]
# Smiles Weight Mean and Std Dev
# 0.6893034325890343 0.07892705394089712
# Smiles Weight CI
# 0.5186023319495182 0.8042009521141792
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3993766  45.15831208] [ 1.49304101 24.43908613] [1.06693296 0.54118688]
# (Manually) Weighted RMSE Train
# [0.18835993 5.89155226]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9687174139728885] [0.9100887432616732, 33.79352510651212] [0.1848967460527997, 5.607226340785348]
# Smiles Weight Mean and Std Dev
# 0.6871141274726372 0.08167502933372164
# Smiles Weight CI
# 0.5243836882298499 0.8217207676582297
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40621424 45.42236835] [ 1.47803008 24.44546897] [1.05107034 0.53818129]
# (Manually) Weighted RMSE Train
# [0.18489675 5.60722634]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.9666319082377477] [0.8485645301343304, 32.466745749138234] [0.1900995845330311, 6.228964243347317]
# Smiles Weight Mean and Std Dev
# 0.6924852085591539 0.07673975349984735
# Smiles Weight CI
# 0.5369881764512424 0.810447798293302
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40545365 45.74939322] [ 1.49044998 24.7919151 ] [1.06047608 0.54190697]
# (Manually) Weighted RMSE Train
# [0.19009958 6.22896424]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.9655891553701773] [0.8989208621503291, 33.164310008544774] [0.1863613878592684, 5.781179808155064]
# Smiles Weight Mean and Std Dev
# 0.6871590462921954 0.0851028939551547
# Smiles Weight CI
# 0.5170159313913215 0.8128155349523914
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41490013 45.84046677] [ 1.4738971  24.55325427] [1.04169692 0.535624  ]
# (Manually) Weighted RMSE Train
# [0.18636139 5.78117981]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.9468196037539103, 0.9687174139728885] [0.9017172217322968, 34.58468465972801] [0.18068318011274004, 4.870977137842442]
# Smiles Weight Mean and Std Dev
# 0.6786313909254935 0.0820270382437663
# Smiles Weight CI
# 0.5249971011928375 0.817495830133532
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.43577166 45.72553872] [ 1.43813988 24.28942215] [1.00164944 0.53120035]
# (Manually) Weighted RMSE Train
# [0.18068318 4.87097714]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9645464025026069] [0.8547406705083157, 32.824465454607456] [0.18414048441923697, 5.931953061603275]
# Smiles Weight Mean and Std Dev
# 0.6903401110592811 0.07823043104657344
# Smiles Weight CI
# 0.5235812099370621 0.815829197231915
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42004168 45.73804768] [ 1.47076867 24.71396248] [1.03572218 0.54033707]
# (Manually) Weighted RMSE Train
# [0.18414048 5.93195306]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.9697601668404588] [0.9153448343556662, 33.701243331808044] [0.17817682905435855, 5.2479187663772215]
# Smiles Weight Mean and Std Dev
# 0.6814204107086995 0.08491416907318694
# Smiles Weight CI
# 0.49395129362377116 0.8107157497591472
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44789604 45.95825521] [ 1.42528012 24.50448335] [0.98438015 0.53319003]
# (Manually) Weighted RMSE Train
# [0.17817683 5.24791877]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.9447340980187695, 0.9676746611053181] [0.8905878707312974, 32.9634755959269] [0.18621340657393484, 6.547313185355092]
# Smiles Weight Mean and Std Dev
# 0.6937428011789556 0.07967323736261864
# Smiles Weight CI
# 0.5090761473406823 0.8041843803828208
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42528927 46.10809977] [ 1.46979581 25.04983529] [1.03122632 0.54328492]
# (Manually) Weighted RMSE Train
# [0.18621341 6.54731319]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.9426485922836287, 0.9687174139728885] [0.9066645404554364, 32.666448108041415] [0.17869918949961583, 5.694444238709927]
# Smiles Weight Mean and Std Dev
# 0.6847231565125363 0.07853459384314558
# Smiles Weight CI
# 0.5197826384603916 0.8118567107267987
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44886385 46.20264091] [ 1.43165468 24.76232521] [0.9881223  0.53595043]
# (Manually) Weighted RMSE Train
# [0.17869919 5.69444424]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.9624608967674662] [0.8881935579217152, 32.17479634355682] [0.18382365751394128, 5.867713999288864]
# Smiles Weight Mean and Std Dev
# 0.6875396300689773 0.07834284625867872
# Smiles Weight CI
# 0.5135435668777685 0.8175204553419952
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45140466 46.22760376] [ 1.44084125 24.97365122] [0.99272194 0.54023244]
# (Manually) Weighted RMSE Train
# [0.18382366 5.867714  ]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.9457768508863399, 0.9666319082377477] [0.9271507352732489, 34.788099380441096] [0.1792240463844412, 5.523787277328991]
# Smiles Weight Mean and Std Dev
# 0.6830924446907698 0.08302320085195575
# Smiles Weight CI
# 0.49623548006526574 0.8286748078520655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4599798 46.4138558] [ 1.41532417 24.66901603] [0.96941353 0.53150111]
# (Manually) Weighted RMSE Train
# [0.17922405 5.52378728]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.9697601668404588] [0.9296961962731641, 34.850804116608785] [0.1832357562576147, 6.050670951688571]
# Smiles Weight Mean and Std Dev
# 0.6893369115672024 0.07959890808774853
# Smiles Weight CI
# 0.5062574171008845 0.8129696063664295
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45415469 46.52727392] [ 1.43771331 24.8919365 ] [0.98869352 0.53499667]
# (Manually) Weighted RMSE Train
# [0.18323576 6.05067095]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.9457768508863399, 0.9760166840458812] [0.9492721330068535, 35.47778376324723] [0.17678661919931765, 5.252074750167333]
# Smiles Weight Mean and Std Dev
# 0.6823433974657305 0.08399723359629499
# Smiles Weight CI
# 0.49928667572256435 0.7999897286364829
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46786346 46.54951795] [ 1.40330108 24.86207732] [0.95601608 0.53409957]
# (Manually) Weighted RMSE Train
# [0.17678662 5.25207475]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.9468196037539103, 0.9708029197080292] [0.9002085018983397, 33.7256155131671] [0.17617314651955288, 5.362769789976793]
# Smiles Weight Mean and Std Dev
# 0.6822358408682568 0.08389770387784792
# Smiles Weight CI
# 0.5071592202149876 0.8112670931179743
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46954893 46.63976444] [ 1.40177225 24.75201718] [0.95387926 0.53070631]
# (Manually) Weighted RMSE Train
# [0.17617315 5.36276979]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.9447340980187695, 0.9676746611053181] [0.9433755107493897, 34.342345450813184] [0.18420407164873356, 6.379513199920892]
# Smiles Weight Mean and Std Dev
# 0.6915301625205174 0.08126122129102013
# Smiles Weight CI
# 0.5195496545890187 0.8173244649720954
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45202761 46.83027697] [ 1.4396521  25.07109312] [0.99147708 0.53536077]
# (Manually) Weighted RMSE Train
# [0.18420407 6.3795132 ]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.9676746611053181] [0.9175657553451783, 33.80301392538747] [0.1766486777982677, 5.097931820029956]
# Smiles Weight Mean and Std Dev
# 0.6778659969224704 0.08175801130455738
# Smiles Weight CI
# 0.5055920636427694 0.8127732523487987
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48530752 46.89697063] [ 1.3844883  24.62596555] [0.93212233 0.52510781]
# (Manually) Weighted RMSE Train
# [0.17664868 5.09793182]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.9520333680917622, 0.9666319082377477] [0.9823644716251251, 34.68588585683287] [0.1750882732790856, 4.968262343671766]
# Smiles Weight Mean and Std Dev
# 0.6800209699777504 0.08213778394508069
# Smiles Weight CI
# 0.4897500577822868 0.8102853331318989
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48029542 46.64925096] [ 1.38432455 24.79894826] [0.93516776 0.53160443]
# (Manually) Weighted RMSE Train
# [0.17508827 4.96826234]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.9509906152241918, 0.9655891553701773] [0.9796255951730354, 36.4355698959557] [0.17740326068914863, 5.191789975856223]
# Smiles Weight Mean and Std Dev
# 0.6816894150610083 0.08423149047033975
# Smiles Weight CI
# 0.49543658167460847 0.8122166236084346
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48300862 46.79101733] [ 1.39155264 24.6718199 ] [0.93833079 0.52727684]
# (Manually) Weighted RMSE Train
# [0.17740326 5.19178998]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9624608967674662] [0.9072805214116207, 33.667655397064074] [0.18415748937678356, 5.775852780406893]
# Smiles Weight Mean and Std Dev
# 0.6886587511440756 0.0794575917250741
# Smiles Weight CI
# 0.5102320424426 0.8178512120903083
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46785794 46.83480126] [ 1.4250906  24.88171734] [0.97086412 0.53126557]
# (Manually) Weighted RMSE Train
# [0.18415749 5.77585278]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.9426485922836287, 0.9614181438998958] [0.9325732493587003, 34.13082026262826] [0.18438297998739264, 5.644793734415454]
# Smiles Weight Mean and Std Dev
# 0.6896225236782927 0.07927655882827234
# Smiles Weight CI
# 0.5232964756830424 0.8092546892738078
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47433288 46.84815537] [ 1.42037654 24.92713724] [0.96340287 0.53208364]
# (Manually) Weighted RMSE Train
# [0.18438298 5.64479373]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.9457768508863399, 0.9645464025026069] [0.9248327186371161, 34.011812332912676] [0.17838148780992327, 5.30326518227092]
# Smiles Weight Mean and Std Dev
# 0.6844609674544567 0.08155464868444426
# Smiles Weight CI
# 0.509438755718475 0.8169555734424991
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47691334 46.9206379 ] [ 1.39979445 24.81458522] [0.94778374 0.52886291]
# (Manually) Weighted RMSE Train
# [0.17838149 5.30326518]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.9687174139728885] [0.9766800706884897, 38.48497613490485] [0.18399780961566123, 6.179129165483439]
# Smiles Weight Mean and Std Dev
# 0.6940747988384691 0.0808057736773427
# Smiles Weight CI
# 0.49700723418214343 0.8226064756437145
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47355026 47.08723086] [ 1.42411725 25.13882097] [0.96645312 0.53387767]
# (Manually) Weighted RMSE Train
# [0.18399781 6.17912917]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.9447340980187695, 0.9635036496350365] [0.9658271912521444, 35.24756012945096] [0.17477663328158713, 5.176018046414388]
# Smiles Weight Mean and Std Dev
# 0.6827913798498166 0.07959493421669685
# Smiles Weight CI
# 0.5200317158597466 0.8136658983024069
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.49301504 47.11392034] [ 1.37012539 24.62787361] [0.91769028 0.5227303 ]
# (Manually) Weighted RMSE Train
# [0.17477663 5.17601805]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.9655891553701773] [0.9756148620153294, 36.16923779773943] [0.18056017690714704, 5.645965206346464]
# Smiles Weight Mean and Std Dev
# 0.6865565479947285 0.08166704148645458
# Smiles Weight CI
# 0.510966490279013 0.8060383873868622
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4900059  47.09895899] [ 1.39620881 24.73489792] [0.93704918 0.52516868]
# (Manually) Weighted RMSE Train
# [0.18056018 5.64596521]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.9416058394160584, 0.9635036496350365] [0.9425120181982626, 33.97861022850195] [0.1773275772998543, 4.916687846650318]
# Smiles Weight Mean and Std Dev
# 0.680869414627125 0.08204695732156642
# Smiles Weight CI
# 0.5068670771496087 0.8024221062674333
# ...
# (Manually) Weighted RMSE Train
# [0.19639856 5.2920744 ]
#
#
# epoch number:  548
# Coverages, CI Widths, RMSEs
# [0.9436913451511991, 0.9551616266944735] [1.1779448694457755, 38.702821088660656] [0.1981515119472828, 5.2704981085779]
# Smiles Weight Mean and Std Dev
# 0.6713080285570303 0.07738004134025281
# Smiles Weight CI
# 0.5163555470819585 0.7994514345153714
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84059789 51.25839308] [ 1.0014454  27.11442853] [0.54408701 0.52897539]
# (Manually) Weighted RMSE Train
# [0.19815151 5.27049811]
#
#
# epoch number:  549
# Coverages, CI Widths, RMSEs
# [0.9572471324296142, 0.959332638164755] [1.2378767142546987, 39.45633874774913] [0.19644529804219588, 5.318117803992068]
# Smiles Weight Mean and Std Dev
# 0.6830813947230029 0.0800330432425563
# Smiles Weight CI
# 0.5199242015102975 0.8168227449578995
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81748828 51.39680128] [ 1.04782174 26.84735906] [0.57652187 0.52235467]
# (Manually) Weighted RMSE Train
# [0.1964453 5.3181178]
#
#
# epoch number:  550
# Coverages, CI Widths, RMSEs
# [0.954118873826903, 0.954118873826903] [1.257778003665627, 39.56301490114881] [0.1968262225480303, 5.438921942002643]
# Smiles Weight Mean and Std Dev
# 0.6865181026401781 0.07746288832952146
# Smiles Weight CI
# 0.5135870000183811 0.8102205322238643
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81306679 51.47576341] [ 1.06625959 26.77393603] [0.58809725 0.52012703]
# (Manually) Weighted RMSE Train
# [0.19682622 5.43892194]
#
#
# epoch number:  551
# Coverages, CI Widths, RMSEs
# [0.9457768508863399, 0.9572471324296142] [1.3026033116305857, 40.05426267806767] [0.2001574345909598, 5.291201502357522]
# Smiles Weight Mean and Std Dev
# 0.6702582190672218 0.08381686629086789
# Smiles Weight CI
# 0.49952826909536335 0.8079548913147369
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.84122723 51.29487649] [ 0.98983906 27.02836416] [0.53759745 0.52692132]
# (Manually) Weighted RMSE Train
# [0.20015743 5.2912015 ]
#
#
# epoch number:  552
# Coverages, CI Widths, RMSEs
# [0.9509906152241918, 0.9530761209593326] [1.2883518776190024, 40.81488021652457] [0.19975711397931145, 5.279133631401064]
# Smiles Weight Mean and Std Dev
# 0.6704738232193233 0.08552501752294911
# Smiles Weight CI
# 0.5051441914277418 0.8031488833243196
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83740766 51.16249686] [ 0.99018703 26.88363443] [0.53890437 0.52545587]
# (Manually) Weighted RMSE Train
# [0.19975711 5.27913363]
#
#
# epoch number:  553
# Coverages, CI Widths, RMSEs
# [0.9520333680917622, 0.954118873826903] [1.2604802676597924, 42.09342690495122] [0.19994669788218583, 5.305187568284233]
# Smiles Weight Mean and Std Dev
# 0.6846864097243961 0.08129078233997948
# Smiles Weight CI
# 0.490745698485327 0.8056010935048227
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83009121 51.04862104] [ 1.05185401 26.73837281] [0.57475497 0.52378247]
# (Manually) Weighted RMSE Train
# [0.1999467  5.30518757]
#
#
# epoch number:  554
# Coverages, CI Widths, RMSEs
# [0.9551616266944735, 0.9572471324296142] [1.2260349840021174, 39.22600463900539] [0.19934862676502624, 5.31425394173037]
# Smiles Weight Mean and Std Dev
# 0.6852569409046271 0.08021283441643504
# Smiles Weight CI
# 0.508238934272326 0.8101336089286927
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82149462 50.98512716] [ 1.05858972 26.70839155] [0.58116544 0.52384672]
# (Manually) Weighted RMSE Train
# [0.19934863 5.31425394]
#
#
# epoch number:  555
# Coverages, CI Widths, RMSEs
# [0.9530761209593326, 0.9551616266944735] [1.283135223925619, 42.91332300166752] [0.1963588935474063, 5.289239924737394]
# Smiles Weight Mean and Std Dev
# 0.6846499983576037 0.08234174408649664
# Smiles Weight CI
# 0.48794661178883875 0.8034971981655717
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82299497 51.02115378] [ 1.04761655 26.74502313] [0.57466782 0.52419479]
# (Manually) Weighted RMSE Train
# [0.19635889 5.28923992]
#
#
# epoch number:  556
# Coverages, CI Widths, RMSEs
# [0.954118873826903, 0.959332638164755] [1.2891228341361605, 42.01509503856835] [0.19557779198951292, 5.200877955301164]
# Smiles Weight Mean and Std Dev
# 0.6788156080379036 0.08394456846036259
# Smiles Weight CI
# 0.49429131023841016 0.8086585453659835
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82597636 50.93125024] [ 1.02102027 26.92840909] [0.55916401 0.52872076]
# (Manually) Weighted RMSE Train
# [0.19557779 5.20087796]
#
#
# epoch number:  557
# Coverages, CI Widths, RMSEs
# [0.9478623566214807, 0.9572471324296142] [1.226932542587036, 40.214254107126614] [0.19710175316353828, 5.279669535944296]
# Smiles Weight Mean and Std Dev
# 0.6737366164012057 0.07990932594879122
# Smiles Weight CI
# 0.49877128151411576 0.8038899655874312
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83885836 50.84928489] [ 0.98695844 26.98264325] [0.53672347 0.53063958]
# (Manually) Weighted RMSE Train
# [0.19710175 5.27966954]
#
#
# epoch number:  558
# Coverages, CI Widths, RMSEs
# [0.954118873826903, 0.9530761209593326] [1.2709153222270857, 39.59530803142361] [0.19518335799825132, 5.254162222565856]
# Smiles Weight Mean and Std Dev
# 0.6844235766933047 0.0780023154207865
# Smiles Weight CI
# 0.5200696373996622 0.8037885180065459
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81230542 50.92233856] [ 1.03635653 26.85893867] [0.5718443  0.52744904]
# (Manually) Weighted RMSE Train
# [0.19518336 5.25416222]
#
#
# epoch number:  559
# Coverages, CI Widths, RMSEs
# [0.9645464025026069, 0.959332638164755] [1.3154484151068133, 41.40416813327761] [0.1967099748249768, 5.652061321530425]
# Smiles Weight Mean and Std Dev
# 0.6900767134028497 0.08405819896467003
# Smiles Weight CI
# 0.5044925523577147 0.8170214488122977
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80380104 51.05004235] [ 1.07219268 26.60439314] [0.59440739 0.52114341]
# (Manually) Weighted RMSE Train
# [0.19670997 5.65206132]
#
#
# epoch number:  560
# Coverages, CI Widths, RMSEs
# [0.9582898852971846, 0.9551616266944735] [1.278485901609231, 39.72248239265648] [0.20251533231843383, 5.332125180927109]
# Smiles Weight Mean and Std Dev
# 0.6716322516186863 0.08083238753147885
# Smiles Weight CI
# 0.5002802809600218 0.7910921674731606
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8317849  50.99613348] [ 0.98111473 26.87732044] [0.53560586 0.52704624]
# (Manually) Weighted RMSE Train
# [0.20251533 5.33212518]
#
#
# epoch number:  561
# Coverages, CI Widths, RMSEs
# [0.9551616266944735, 0.9551616266944735] [1.3458017899448502, 41.31019787826683] [0.19623478162755, 5.232937106983835]
# Smiles Weight Mean and Std Dev
# 0.6797067348186978 0.08213048475852673
# Smiles Weight CI
# 0.47777591752833865 0.7943770070024495
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82036785 50.98359385] [ 1.02362908 26.88249689] [0.56231991 0.5272774 ]
# (Manually) Weighted RMSE Train
# [0.19623478 5.23293711]
#
#
# epoch number:  562
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9562043795620438] [1.2875321408583897, 38.93523636525522] [0.19512745853206576, 5.208860645609527]
# Smiles Weight Mean and Std Dev
# 0.6788662435266699 0.07825965150016642
# Smiles Weight CI
# 0.5134698568469022 0.8106458150186197
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82049337 51.08107516] [ 1.0242406  26.77563444] [0.56261704 0.52417915]
# (Manually) Weighted RMSE Train
# [0.19512746 5.20886065]
#
#
# epoch number:  563
# Coverages, CI Widths, RMSEs
# [0.9551616266944735, 0.948905109489051] [1.2534345874358028, 39.007225632395944] [0.19610971192365984, 5.222964555392069]
# Smiles Weight Mean and Std Dev
# 0.6782436616614552 0.08081530367170801
# Smiles Weight CI
# 0.5080517247406671 0.8102525283413029
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.83115719 51.05764472] [ 1.01271498 26.69982922] [0.55304645 0.522935  ]
# (Manually) Weighted RMSE Train
# [0.19610971 5.22296456]
#
#
# epoch number:  564
# Coverages, CI Widths, RMSEs
# [0.9478623566214807, 0.9582898852971846] [1.2558497808322364, 40.71505585566977] [0.19615861312122784, 5.244383256130325]
# Smiles Weight Mean and Std Dev
# 0.6806049703312086 0.0802620456590491
# Smiles Weight CI
# 0.5047779789937936 0.8001491110314808
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82471776 51.02608874] [ 1.02286248 26.66893691] [0.56055928 0.52265297]
# (Manually) Weighted RMSE Train
# [0.19615861 5.24438326]
#
#
# epoch number:  565
# Coverages, CI Widths, RMSEs
# [0.9468196037539103, 0.9520333680917622] [1.205004261198864, 40.16851721604183] [0.2002930433060155, 5.536457718074661]
# Smiles Weight Mean and Std Dev
# 0.6902176242766569 0.0758256548421977
# Smiles Weight CI
# 0.5161254989988414 0.8099520754948736
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80903238 50.99737235] [ 1.07496232 26.73440206] [0.5942195  0.52423097]
# (Manually) Weighted RMSE Train
# [0.20029304 5.53645772]
#
#
# epoch number:  566
# Coverages, CI Widths, RMSEs
# [0.959332638164755, 0.9614181438998958] [1.2881674163249814, 39.38953671012826] [0.19682835294808962, 5.198855174050381]
# Smiles Weight Mean and Std Dev
# 0.6812201782927246 0.08119752734068525
# Smiles Weight CI
# 0.5184498484472312 0.8058985952429846
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81195178 51.00445599] [ 1.03885397 26.88615761] [0.57333423 0.5271335 ]
# (Manually) Weighted RMSE Train
# [0.19682835 5.19885517]
#
#
# epoch number:  567
# Coverages, CI Widths, RMSEs
# [0.9478623566214807, 0.954118873826903] [1.2795645919658254, 39.83603185433147] [0.19965710217626023, 5.238916997296163]
# Smiles Weight Mean and Std Dev
# 0.6749379893175985 0.07897869514985052
# Smiles Weight CI
# 0.5095193329474408 0.8033356338291269
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81890671 51.06749322] [ 1.00784512 26.91881084] [0.55409391 0.52712223]
# (Manually) Weighted RMSE Train
# [0.1996571 5.238917 ]
#
#
# epoch number:  568
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9603753910323254] [1.3040884312044496, 41.605305530314205] [0.19621107220387596, 5.210717768338643]
# Smiles Weight Mean and Std Dev
# 0.6803926960722236 0.08310708548444386
# Smiles Weight CI
# 0.4988582477333878 0.8099512163107624
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81717109 51.05798414] [ 1.03676705 26.87333371] [0.57053904 0.5263297 ]
# (Manually) Weighted RMSE Train
# [0.19621107 5.21071777]
#
#
# epoch number:  569
# Coverages, CI Widths, RMSEs
# [0.9624608967674662, 0.9562043795620438] [1.3761310863800107, 43.30115485759836] [0.1988878617181315, 5.23448946008151]
# Smiles Weight Mean and Std Dev
# 0.6728634899336503 0.0851080307661685
# Smiles Weight CI
# 0.47678353588078354 0.8171644501352227
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82786206 51.03273273] [ 0.9943902  27.08063916] [0.54401818 0.53065234]
# (Manually) Weighted RMSE Train
# [0.19888786 5.23448946]
#
#
# epoch number:  570
# Coverages, CI Widths, RMSEs
# [0.9562043795620438, 0.959332638164755] [1.2559862275402558, 41.181674972316955] [0.19582552794230776, 5.208550442864356]
# Smiles Weight Mean and Std Dev
# 0.6798795713224495 0.07790485233363276
# Smiles Weight CI
# 0.5159528114166 0.8058562120372939
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8181018 51.0850031] [ 1.03058416 26.86742619] [0.56684624 0.52593569]
# (Manually) Weighted RMSE Train
# [0.19582553 5.20855044]
#
#
# epoch number:  571
# Coverages, CI Widths, RMSEs
# [0.9562043795620438, 0.9603753910323254] [1.3069589495716172, 41.41544665085474] [0.1966343174339628, 5.229474414858906]
# Smiles Weight Mean and Std Dev
# 0.6770412882231632 0.08080925597048923
# Smiles Weight CI
# 0.5178708452200822 0.8062523032716404
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82437846 51.19420054] [ 1.01400822 26.82001623] [0.55581024 0.52388778]
# (Manually) Weighted RMSE Train
# [0.19663432 5.22947441]
#
#
# epoch number:  572
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.9614181438998958] [1.3665876490632283, 42.55210718009764] [0.19573293460128452, 5.200308494133465]
# Smiles Weight Mean and Std Dev
# 0.6807387390238229 0.0891482226032014
# Smiles Weight CI
# 0.49584813470216293 0.8173485573765721
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.8218978  51.16902367] [ 1.03368675 26.97817174] [0.56736813 0.5272364 ]
# (Manually) Weighted RMSE Train
# [0.19573293 5.20030849]
#
#
# epoch number:  573
# Coverages, CI Widths, RMSEs
# [0.9572471324296142, 0.959332638164755] [1.2749576474296984, 41.72558498806122] [0.19615277246555052, 5.180495406324595]
# Smiles Weight Mean and Std Dev
# 0.6792817994018882 0.08540970779637118
# Smiles Weight CI
# 0.5028930319506938 0.8059642306510912
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82156678 51.23675735] [ 1.02232234 27.03616828] [0.56123243 0.52767134]
# (Manually) Weighted RMSE Train
# [0.19615277 5.18049541]
#
#
# epoch number:  574
# Coverages, CI Widths, RMSEs
# [0.954118873826903, 0.9551616266944735] [1.2290828506643734, 38.38278495508643] [0.19577959463409922, 5.241290930378174]
# Smiles Weight Mean and Std Dev
# 0.6796049401798379 0.08014097230007536
# Smiles Weight CI
# 0.519762018196987 0.8039709702830657
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81720001 51.40732375] [ 1.03301809 27.06471751] [0.56846692 0.52647591]
# (Manually) Weighted RMSE Train
# [0.19577959 5.24129093]
#
#
# epoch number:  575
# Coverages, CI Widths, RMSEs
# [0.9530761209593326, 0.9562043795620438] [1.2970099814730887, 40.35274036520581] [0.19590907649684836, 5.238374315975828]
# Smiles Weight Mean and Std Dev
# 0.6811522214018854 0.07713399818742749
# Smiles Weight CI
# 0.508018427941125 0.8019792362676883
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81557996 51.39699812] [ 1.03666164 27.03839694] [0.57098099 0.52606957]
# (Manually) Weighted RMSE Train
# [0.19590908 5.23837432]
#
#
# epoch number:  576
# Coverages, CI Widths, RMSEs
# [0.954118873826903, 0.9551616266944735] [1.310681453942677, 41.569851025961114] [0.19749761019555584, 5.196164121184781]
# Smiles Weight Mean and Std Dev
# 0.6791868163546938 0.08293895069687035
# Smiles Weight CI
# 0.5003896167321619 0.8104006076651671
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.82136639 51.26264859] [ 1.01954047 27.17290437] [0.55976682 0.53007219]
# (Manually) Weighted RMSE Train
# [0.19749761 5.19616412]
#
#
# epoch number:  577
# Coverages, CI Widths, RMSEs
# [0.9603753910323254, 0.9551616266944735] [1.2737430086333297, 39.775759136886634] [0.19635618094450438, 5.2203563028676125]
# Smiles Weight Mean and Std Dev
# 0.6820850892497775 0.08337267077671305
# Smiles Weight CI
# 0.5005497869268047 0.8142350147482744
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80713337 51.33509594] [ 1.03254845 27.02498191] [0.57137368 0.52644261]
# (Manually) Weighted RMSE Train
# [0.19635618 5.2203563 ]
#
#
# epoch number:  578
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.9614181438998958] [1.2442738054133113, 41.214061875051684] [0.19696434529921755, 5.193099643691565]
# Smiles Weight Mean and Std Dev
# 0.6786405103314928 0.07969730731636479
# Smiles Weight CI
# 0.5073131868849811 0.8125734325983651
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81507865 51.35889717] [ 1.01999758 27.14088314] [0.56195779 0.52845533]
# (Manually) Weighted RMSE Train
# [0.19696435 5.19309964]
#
#
# epoch number:  579
# Coverages, CI Widths, RMSEs
# [0.9582898852971846, 0.959332638164755] [1.2529391870453859, 38.56750156590308] [0.1973938508172973, 5.493172653096763]
# Smiles Weight Mean and Std Dev
# 0.6894343620896041 0.07732791424628704
# Smiles Weight CI
# 0.5318668129080133 0.7975590324856702
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80244803 51.49602159] [ 1.07006653 27.13320461] [0.593674   0.52689905]
# (Manually) Weighted RMSE Train
# [0.19739385 5.49317265]
#
#
# epoch number:  580

# %%
with open("..//Data/returned_stuff1_config5.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
# with open("..//Data/returned_stuff_config4.pickle", "rb") as f: 
#     returned_stuff = pickle.load(f)

# %%
# with open("..//Data/returned_stuff1_config3.pickle", "rb") as f: 
#     returned_stuff1 = pickle.load(f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
