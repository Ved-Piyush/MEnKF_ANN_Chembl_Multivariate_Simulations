# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-08-03 02:02:34.481309: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-03 02:02:34.632217: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 02:02:35.318139: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 02:02:35.320696: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 02:02:41.205703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_11 = final_output_1.copy()
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack, final_output_11

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1, data1_out11 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2, data1_out21 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1, data2_out11 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2, data2_out21 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out11, data1_out21, data2_out11, data2_out21

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta, fudging_var = 1.0):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    
    if fudging_var is not None: 
        mean_vec = np.zeros((updated_ensemble.shape[1],))
        cov_mat = np.identity(updated_ensemble.shape[1])*fudging_var
        fudging_for_updated_ensembles = mvn(mean_vec, cov_mat)
        fudging_for_updated_ensembles_vec = fudging_for_updated_ensembles.rvs(size_ens)
        updated_ensemble = updated_ensemble + fudging_for_updated_ensembles_vec
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_70_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_60_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200, fudging_var = 1.0):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta, fudging_var = fudging_var)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
# returned_stuff = get_results(0, var_weights = 3.0, var_weight_weights = 8.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.95, epochs = 500, fudging_var = 1e-2)

# %%
# %%time
returned_stuff = get_results(0, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 100, fudging_var = 1e-5)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [47.341237668826494, 1107.1992639022565] [4.181000205983791, 57.09033102518722]
# Smiles Weight Mean and Std Dev
# 0.51238502949114 0.20882854245552535
# Smiles Weight CI
# 0.14603835489481237 0.884038250152346
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 3.99501028 65.36809933] [ 3.74151546 58.90293524] [0.93654714 0.90109604]
# (Manually) Weighted RMSE Train
# [ 4.90734043 74.82149711]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [31.48003426059041, 736.8913829090437] [2.853451773454346, 69.89543183009351]
# Smiles Weight Mean and Std Dev
# 0.5183692890788426 0.17775455953808803
# Smiles Weight CI
# 0.21727786847467603 0.866445758937248
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.75418646 49.62195725] [ 2.72112078 90.84704452] [0.98799439 1.83078318]
# (Manually) Weighted RMSE Train
# [ 2.76152552 87.52176984]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [22.127977288297277, 495.9235817941167] [2.430688557937882, 48.39168205830935]
# Smiles Weight Mean and Std Dev
# 0.5396605600888085 0.1573647494550564
# Smiles Weight CI
# 0.2556601727484391 0.8363509197598235
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.12165457 41.82583497] [ 2.99220615 64.22976528] [1.4103173  1.53564813]
# (Manually) Weighted RMSE Train
# [ 3.01957939 53.18132509]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [13.355582437292195, 304.9859944074132] [1.3676715807106292, 48.526243055680055]
# Smiles Weight Mean and Std Dev
# 0.612470402528008 0.1365575219256235
# Smiles Weight CI
# 0.3215802160908463 0.8507478443818903
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.25529189 41.95461636] [ 2.48147291 75.50242706] [1.97680948 1.79962144]
# (Manually) Weighted RMSE Train
# [ 2.3074562  63.79911172]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [9.061757949855739, 218.2473552148431] [0.9449082839228397, 34.20349429647719]
# Smiles Weight Mean and Std Dev
# 0.6651301163710274 0.11000751665725593
# Smiles Weight CI
# 0.4257431477593151 0.8522470052140503
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83911855 22.50384409] [ 1.94529556 70.92232366] [2.31826071 3.15156483]
# (Manually) Weighted RMSE Train
# [ 3.19997134 53.80263127]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [5.655908691020824, 141.74189674095234] [0.9312301274860677, 18.71445717259158]
# Smiles Weight Mean and Std Dev
# 0.6967521058188613 0.09932590947707569
# Smiles Weight CI
# 0.4957031279800148 0.8604803081719312
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.8151711  9.00657538] [ 1.93283047 63.49975845] [2.37107334 7.05037773]
# (Manually) Weighted RMSE Train
# [ 3.45508862 50.3867861 ]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [4.037078193094509, 100.04674141180234] [0.6304119098073837, 12.31731133990647]
# Smiles Weight Mean and Std Dev
# 0.7027420733792183 0.0962531951282041
# Smiles Weight CI
# 0.4889826866142205 0.8576855694081548
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.42884051 8.05822288] [ 1.85223592 52.29060708] [4.31917201 6.48909913]
# (Manually) Weighted RMSE Train
# [ 3.69997084 50.22744696]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.950143222022956, 71.49781355335102] [0.46282261323522284, 10.533948197039138]
# Smiles Weight Mean and Std Dev
# 0.7065827665970178 0.08349713715691029
# Smiles Weight CI
# 0.5285387941145527 0.8502600734592447
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.58548844 9.2737886 ] [ 1.50221976 43.77295629] [2.56575479 4.72007269]
# (Manually) Weighted RMSE Train
# [ 3.01299864 43.12698201]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 1.0] [2.3320069703794957, 56.385448338000636] [0.33097764570727223, 6.9177351535014155]
# Smiles Weight Mean and Std Dev
# 0.7221238290812786 0.09092488541648473
# Smiles Weight CI
# 0.5312557827558921 0.8714532050845316
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.74351657 9.35793538] [ 1.72312281 36.06318407] [2.31753116 3.85375434]
# (Manually) Weighted RMSE Train
# [ 2.79367024 44.97543257]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9989572471324296, 0.9958289885297185] [1.8437421844562507, 42.44878112122224] [0.2954660208540463, 7.502902519546088]
# Smiles Weight Mean and Std Dev
# 0.7192615773048913 0.0813269846982673
# Smiles Weight CI
# 0.5521631681897897 0.8519096494977938
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.96857046 8.67331285] [ 2.07718371 35.52601568] [2.14458709 4.09601456]
# (Manually) Weighted RMSE Train
# [ 2.56444725 41.74651677]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9968717413972888, 0.9937434827945777] [1.5796188321114895, 34.91576058879873] [0.26970794925923314, 6.100695205847397]
# Smiles Weight Mean and Std Dev
# 0.7103423020667244 0.07882522296033123
# Smiles Weight CI
# 0.5374200889353649 0.848430656952822
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.98764703 11.93881098] [ 2.12112087 35.32242888] [2.14765073 2.95862201]
# (Manually) Weighted RMSE Train
# [ 2.43494203 43.72951124]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 0.9916579770594369] [1.6862478060806902, 31.53085159550569] [0.265046983012547, 5.780713091595523]
# Smiles Weight Mean and Std Dev
# 0.7049849794258569 0.08680070972365757
# Smiles Weight CI
# 0.5122570222034302 0.8550894794014626
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17320525 14.17166235] [ 2.47413931 35.0071429 ] [2.10887167 2.47022135]
# (Manually) Weighted RMSE Train
# [ 2.18614787 45.57004036]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9927007299270073, 0.9895724713242962] [1.5044484597190486, 29.434999188682312] [0.2706851532704141, 5.789584863082719]
# Smiles Weight Mean and Std Dev
# 0.6956709830134947 0.07932585140441406
# Smiles Weight CI
# 0.5344884907712116 0.8173922802374881
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.28175007 14.96764294] [ 2.62876725 33.48531643] [2.05092031 2.23718033]
# (Manually) Weighted RMSE Train
# [ 2.08065831 46.62040418]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9874869655891554, 0.9822732012513035] [1.3811091513341862, 26.508588995671808] [0.2665918994565969, 5.577121597672172]
# Smiles Weight Mean and Std Dev
# 0.6922479567541301 0.08447892720171231
# Smiles Weight CI
# 0.4981131720116541 0.8223674416139272
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33216827 15.70015851] [ 2.69814813 32.39931694] [2.02538087 2.06362993]
# (Manually) Weighted RMSE Train
# [ 2.02717185 48.67214811]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9770594369134515, 0.97288842544317] [1.3561768691389637, 24.867958458628486] [0.289386184366567, 5.8612831254710365]
# Smiles Weight Mean and Std Dev
# 0.6997560563616662 0.08385717105221838
# Smiles Weight CI
# 0.5168230767606072 0.8417904354885489
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38874929 16.59215411] [ 2.77976056 32.27437696] [2.00162879 1.94515894]
# (Manually) Weighted RMSE Train
# [ 1.98646868 50.34397755]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9718456725755996, 0.9781021897810219] [1.4533379126776234, 23.640276273513138] [0.27361630783909663, 5.8511890626583325]
# Smiles Weight Mean and Std Dev
# 0.6931711351442842 0.08522903642770166
# Smiles Weight CI
# 0.5127598848893683 0.8276282893260081
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41889424 16.39347345] [ 2.84822873 31.26858193] [2.00735803 1.90737991]
# (Manually) Weighted RMSE Train
# [ 1.92864943 51.53241026]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9655891553701773, 0.948905109489051] [1.3400744389048393, 22.6839316187806] [0.27768535327908045, 5.9762353988722525]
# Smiles Weight Mean and Std Dev
# 0.6937163239767524 0.08397695708359867
# Smiles Weight CI
# 0.5022466849973004 0.8192625812980329
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42284118 16.15377623] [ 2.85798434 30.0571278 ] [2.00864606 1.86068739]
# (Manually) Weighted RMSE Train
# [ 1.90481796 52.37019664]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9614181438998958, 0.9301355578727841] [1.2859819378512423, 21.63525045976171] [0.2765557022085508, 5.82545341885806]
# Smiles Weight Mean and Std Dev
# 0.6861309507043477 0.08207421332721973
# Smiles Weight CI
# 0.5170245168727655 0.8261216362078273
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44741421 15.90468163] [ 2.87082822 30.09224674] [1.98341857 1.89203704]
# (Manually) Weighted RMSE Train
# [ 1.91755328 52.28860389]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9530761209593326, 0.9478623566214807] [1.34723814281127, 20.36433147740787] [0.27776920748615425, 5.592232184930191]
# Smiles Weight Mean and Std Dev
# 0.6881293093451527 0.08298332054613963
# Smiles Weight CI
# 0.5137994482167774 0.8196345611738787
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47073563 15.70123808] [ 2.93256101 30.02241579] [1.99394163 1.912105  ]
# (Manually) Weighted RMSE Train
# [ 1.88393905 52.45671242]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9363920750782064, 0.9301355578727841] [1.2374007629657724, 19.31096764006221] [0.28270243027609876, 5.5813164785584055]
# Smiles Weight Mean and Std Dev
# 0.6907039224882048 0.07857082888098435
# Smiles Weight CI
# 0.5285009062204198 0.8109334566778649
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48434517 15.38866031] [ 2.94698536 29.627423  ] [1.9853774 1.9252763]
# (Manually) Weighted RMSE Train
# [ 1.88258444 52.45767779]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9384775808133472, 0.9384775808133472] [1.2448858752380216, 19.451566685381415] [0.2715506568623382, 5.4786042829999975]
# Smiles Weight Mean and Std Dev
# 0.6830651734335298 0.08557979261717283
# Smiles Weight CI
# 0.5272495201170387 0.8378144531306635
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4937219  15.02441842] [ 2.94220862 29.34723769] [1.96971647 1.95330274]
# (Manually) Weighted RMSE Train
# [ 1.90068412 52.49814963]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9447340980187695] [1.267272888975949, 19.180249585764397] [0.2780865863070063, 5.391909208375758]
# Smiles Weight Mean and Std Dev
# 0.6843602492803652 0.08619825040354163
# Smiles Weight CI
# 0.48122721941975294 0.8190327361663915
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51585306 14.98838502] [ 2.98983432 29.37166181] [1.9723774  1.95962819]
# (Manually) Weighted RMSE Train
# [ 1.88433984 52.32552916]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9343065693430657, 0.9311783107403545] [1.3167261270169384, 19.18258946841592] [0.27322911084314866, 5.4023248187407225]
# Smiles Weight Mean and Std Dev
# 0.6840562057469284 0.08415788790162644
# Smiles Weight CI
# 0.49926561587403395 0.8202166460068144
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.52422601 15.03196147] [ 2.999186   29.35118466] [1.967678   1.95258514]
# (Manually) Weighted RMSE Train
# [ 1.89190631 52.35744171]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.9103232533889468] [1.2297743382014947, 17.781892709429776] [0.2732640194641814, 5.382121753741683]
# Smiles Weight Mean and Std Dev
# 0.6832395211281247 0.08188442119669671
# Smiles Weight CI
# 0.524248801305171 0.8139591656666819
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53671604 15.0250921 ] [ 3.02622533 29.2187128 ] [1.96928076 1.94466114]
# (Manually) Weighted RMSE Train
# [ 1.88735817 52.54842   ]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9103232533889468] [1.1429496013755491, 17.05508229968355] [0.2676619195066868, 5.302359356376042]
# Smiles Weight Mean and Std Dev
# 0.6771820279992801 0.07619107644075193
# Smiles Weight CI
# 0.522340436845035 0.7904123501113265
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.54556082 14.8696428 ] [ 3.03203292 28.99741663] [1.96176875 1.95010849]
# (Manually) Weighted RMSE Train
# [ 1.89492325 52.56855791]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.9009384775808134] [1.1740616304690505, 16.540825377422287] [0.28739105526928405, 5.336974014904954]
# Smiles Weight Mean and Std Dev
# 0.6896841270196764 0.07880626625294516
# Smiles Weight CI
# 0.5177588790159001 0.8198547868977982
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55616568 14.79442601] [ 3.04292111 29.02697733] [1.95539663 1.96202119]
# (Manually) Weighted RMSE Train
# [ 1.89657556 52.49124504]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9155370177267987] [1.3280203071415968, 18.095564153807533] [0.26457813350937853, 5.263397866888235]
# Smiles Weight Mean and Std Dev
# 0.6708528637112563 0.08609067547510647
# Smiles Weight CI
# 0.48559291178513253 0.8118332829741478
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5664712  14.87390911] [ 3.0548304 29.0041741] [1.95013506 1.95000345]
# (Manually) Weighted RMSE Train
# [ 1.89615297 52.5700957 ]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9155370177267987, 0.9165797705943691] [1.23967983144184, 17.724112343605725] [0.2646963375254529, 5.250967387491575]
# Smiles Weight Mean and Std Dev
# 0.6734780960455686 0.0855783912279612
# Smiles Weight CI
# 0.4995289312369428 0.7967254363895243
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57702837 14.92862417] [ 3.08125297 29.12907275] [1.95383484 1.95122286]
# (Manually) Weighted RMSE Train
# [ 1.88660985 52.57516347]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9009384775808134] [1.289192677577355, 16.9184021214164] [0.2770816705777991, 5.282723601521266]
# Smiles Weight Mean and Std Dev
# 0.6834489864567662 0.08482294236312889
# Smiles Weight CI
# 0.49616075635230444 0.8107587206983309
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58951129 14.97543858] [ 3.10636066 29.15999744] [1.95428663 1.94718821]
# (Manually) Weighted RMSE Train
# [ 1.88012441 52.60148584]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9019812304483837] [1.2204061861736522, 16.265361848871898] [0.2638811913925732, 5.2123972834221455]
# Smiles Weight Mean and Std Dev
# 0.6678650401565026 0.08018323237504259
# Smiles Weight CI
# 0.4960225485496003 0.8031525814098978
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.608039   15.04764311] [ 3.13258583 29.1129729 ] [1.94807827 1.93471979]
# (Manually) Weighted RMSE Train
# [ 1.87069632 52.68827427]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.8978102189781022] [1.27877348386686, 16.95729551612786] [0.2724544766523153, 5.248385179009234]
# Smiles Weight Mean and Std Dev
# 0.6765766824574924 0.08219251816370948
# Smiles Weight CI
# 0.49293214790773254 0.7992074373958628
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62587629 15.20094089] [ 3.14965459 29.48015787] [1.93720433 1.93936402]
# (Manually) Weighted RMSE Train
# [ 1.86948687 52.6601833 ]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.8988529718456726] [1.2561355359929565, 16.59535217077515] [0.2789814137844094, 5.257970753253185]
# Smiles Weight Mean and Std Dev
# 0.6797132205877989 0.08163089571003733
# Smiles Weight CI
# 0.5027608303630726 0.811183619770828
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63457166 15.17836213] [ 3.15727111 29.40690345] [1.9315587  1.93742271]
# (Manually) Weighted RMSE Train
# [ 1.86546241 52.92703302]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.8852971845672576] [1.1026206645745016, 15.059551935957044] [0.2728821030816409, 5.261205428384345]
# Smiles Weight Mean and Std Dev
# 0.6751073228881355 0.07162140051303206
# Smiles Weight CI
# 0.5239674322642179 0.7785977475474612
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6426458  15.11330879] [ 3.17089517 29.47698067] [1.93035843 1.95039889]
# (Manually) Weighted RMSE Train
# [ 1.86073732 53.17937592]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9061522419186653, 0.8988529718456726] [1.2454369672471635, 16.675692272614167] [0.26813642979815083, 5.270743331919161]
# Smiles Weight Mean and Std Dev
# 0.6696629986935756 0.0832181615164983
# Smiles Weight CI
# 0.4940581621538286 0.8114576918813596
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6489863  15.19389986] [ 3.17534212 29.59025235] [1.9256328  1.94750871]
# (Manually) Weighted RMSE Train
# [ 1.8603661 53.2759406]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.8686131386861314] [1.1484146361907939, 15.310037616665127] [0.27097721125198737, 5.28190008820222]
# Smiles Weight Mean and Std Dev
# 0.6702214002851185 0.07454533842498794
# Smiles Weight CI
# 0.4973295276137502 0.7862678425769205
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6584024  15.16314394] [ 3.18428571 29.58484977] [1.92009232 1.95110261]
# (Manually) Weighted RMSE Train
# [ 1.8555206  53.40716193]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.8988529718456726] [1.2789302046743163, 16.194813743900628] [0.2708165896003775, 5.269223514439679]
# Smiles Weight Mean and Std Dev
# 0.6694276341687417 0.08373529639107324
# Smiles Weight CI
# 0.4861163315858749 0.8065603091266055
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.66593822 15.1195945 ] [ 3.19158915 29.39940684] [1.91579082 1.94445736]
# (Manually) Weighted RMSE Train
# [ 1.85508017 53.52144421]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.8905109489051095] [1.2203275496503607, 15.233624637194401] [0.2878388194289203, 5.283535037153103]
# Smiles Weight Mean and Std Dev
# 0.6800518353413268 0.07915571717136403
# Smiles Weight CI
# 0.49255603092754735 0.8033200962373037
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67572625 15.19878862] [ 3.20006141 29.47936759] [1.90965643 1.93958666]
# (Manually) Weighted RMSE Train
# [ 1.85614269 53.49884171]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.894681960375391] [1.182401541640405, 16.012371796825043] [0.27805548601604363, 5.252436070687809]
# Smiles Weight Mean and Std Dev
# 0.6733498541520486 0.07993273128268512
# Smiles Weight CI
# 0.5036647030735704 0.8009914744897676
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.68905682 15.29502387] [ 3.20658234 29.51479222] [1.89844551 1.929699  ]
# (Manually) Weighted RMSE Train
# [ 1.85727194 53.54573645]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9040667361835245, 0.9103232533889468] [1.2890700281599923, 16.46650419753518] [0.27302488596428653, 5.249271480128784]
# Smiles Weight Mean and Std Dev
# 0.6685581556361322 0.08506583657941709
# Smiles Weight CI
# 0.49874380507048144 0.8025843312785835
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70290529 15.32319795] [ 3.21207155 29.59913073] [1.8862303  1.93165492]
# (Manually) Weighted RMSE Train
# [ 1.86342568 53.65669907]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.9051094890510949] [1.3286457991849825, 16.17956097376857] [0.2830684896233616, 5.2204434049629835]
# Smiles Weight Mean and Std Dev
# 0.6738656874915656 0.08701247437544117
# Smiles Weight CI
# 0.5067597368592439 0.8074762413471284
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70646842 15.27260985] [ 3.21252563 29.5255124 ] [1.88255791 1.93323294]
# (Manually) Weighted RMSE Train
# [ 1.86308081 53.67549317]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.9051094890510949] [1.2146891650316072, 16.037919277657103] [0.28672895708012713, 5.215391204219701]
# Smiles Weight Mean and Std Dev
# 0.6759662276647325 0.07958994331436137
# Smiles Weight CI
# 0.5123077956883433 0.799259987298235
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7104348  15.30442025] [ 3.22049501 29.54345471] [1.88285167 1.93038705]
# (Manually) Weighted RMSE Train
# [ 1.85803466 53.60089867]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.8894681960375391] [1.178022013443054, 15.330447479131308] [0.27415644419702206, 5.169781651426157]
# Smiles Weight Mean and Std Dev
# 0.6675694991004498 0.07721845721378243
# Smiles Weight CI
# 0.5000142793191331 0.7934761050776286
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.71370801 15.35034902] [ 3.23552468 29.65359481] [1.88802565 1.93178636]
# (Manually) Weighted RMSE Train
# [ 1.84991632 53.31462912]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.9061522419186653, 0.9019812304483837] [1.2988235178200402, 16.545820314611497] [0.27868271797127486, 5.177528643318963]
# Smiles Weight Mean and Std Dev
# 0.6706161155741175 0.08396747697673382
# Smiles Weight CI
# 0.49546504547536613 0.8021741966725162
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.71619777 15.38865364] [ 3.23610982 29.59455727] [1.88562757 1.92314142]
# (Manually) Weighted RMSE Train
# [ 1.84779821 53.41274618]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.894681960375391] [1.2250198833438588, 15.479927717449495] [0.2784529440185634, 5.175257409542086]
# Smiles Weight Mean and Std Dev
# 0.6689121346721165 0.07749833490750731
# Smiles Weight CI
# 0.49037742151480096 0.7921987753566238
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72037008 15.44071594] [ 3.23527171 29.65320198] [1.88056729 1.92045512]
# (Manually) Weighted RMSE Train
# [ 1.85001144 53.43516411]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.9019812304483837] [1.1783467686568827, 15.412364442501563] [0.2721221623231727, 5.183686417235272]
# Smiles Weight Mean and Std Dev
# 0.6631953773730643 0.07506431103701751
# Smiles Weight CI
# 0.5053195253104902 0.7903673896280782
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.72873227 15.48335518] [ 3.24060901 29.73684402] [1.87455805 1.92056849]
# (Manually) Weighted RMSE Train
# [ 1.85473966 53.43185805]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.8884254431699687] [1.1409048300478972, 15.046303057017605] [0.27322040988785606, 5.16894307068145]
# Smiles Weight Mean and Std Dev
# 0.6634750720784154 0.07675567005284047
# Smiles Weight CI
# 0.501377192811673 0.7907191397954347
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73132154 15.48461168] [ 3.24369853 29.77272901] [1.87353906 1.9227301 ]
# (Manually) Weighted RMSE Train
# [ 1.85875391 53.49922771]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9030239833159541] [1.3267523851643208, 15.954171693806364] [0.2783851117141333, 5.1326749032820675]
# Smiles Weight Mean and Std Dev
# 0.6669894703223793 0.08026878037580262
# Smiles Weight CI
# 0.4941571354844691 0.805660832294816
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73660826 15.48177675] [ 3.24777792 29.78267277] [1.87018455 1.92372447]
# (Manually) Weighted RMSE Train
# [ 1.85805281 53.38089104]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.8915537017726799] [1.3516949143663228, 16.184578368521763] [0.27436729348936456, 5.123029712376834]
# Smiles Weight Mean and Std Dev
# 0.6625120554146268 0.0868579077272146
# Smiles Weight CI
# 0.47602539395977034 0.8003948430654922
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.74047327 15.54119145] [ 3.24961436 29.761469  ] [1.86708663 1.91500562]
# (Manually) Weighted RMSE Train
# [ 1.85714978 53.4755238 ]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.8957247132429614] [1.23375227932319, 15.77805518990571] [0.27177060046015444, 5.166647938296244]
# Smiles Weight Mean and Std Dev
# 0.6508568728260038 0.08215013766004646
# Smiles Weight CI
# 0.487486673027653 0.7846472665409706
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75127594 15.55795022] [ 3.26630705 29.80762144] [1.86510131 1.9159093 ]
# (Manually) Weighted RMSE Train
# [ 1.85023359 53.45406954]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.8915537017726799] [1.2383141744341815, 15.115364820631813] [0.2800577007423617, 5.129625802052151]
# Smiles Weight Mean and Std Dev
# 0.6664311502718137 0.07926332907360668
# Smiles Weight CI
# 0.49874732395457455 0.8023235181994434
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7533382  15.56286737] [ 3.25781129 29.9099262 ] [1.85806212 1.9218776 ]
# (Manually) Weighted RMSE Train
# [ 1.85701534 53.55063597]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.8884254431699687] [1.225861880383413, 15.083489222167] [0.2737056290819443, 5.141911237163239]
# Smiles Weight Mean and Std Dev
# 0.6582102806749639 0.0799931676272601
# Smiles Weight CI
# 0.49245788797340817 0.7904008833094714
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75836145 15.61622439] [ 3.25987415 29.99993266] [1.85392721 1.92107464]
# (Manually) Weighted RMSE Train
# [ 1.8606352  53.61672233]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.8978102189781022] [1.2996802198584747, 16.13878076657768] [0.2713909172490563, 5.138162343828585]
# Smiles Weight Mean and Std Dev
# 0.6545486398876046 0.08103113771110079
# Smiles Weight CI
# 0.4839801272991909 0.8010972016551384
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76215107 15.5974236 ] [ 3.2683279 30.148356 ] [1.85473764 1.93290615]
# (Manually) Weighted RMSE Train
# [ 1.85956839 53.55272416]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9051094890510949] [1.2845209485971065, 15.866631274890386] [0.2845912754709975, 5.1145606561804495]
# Smiles Weight Mean and Std Dev
# 0.668546168876428 0.08283002186618157
# Smiles Weight CI
# 0.49086734152879963 0.7988549878395402
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76311321 15.58376528] [ 3.26480431 30.19616846] [1.85172699 1.93766833]
# (Manually) Weighted RMSE Train
# [ 1.87004391 53.51689067]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.8852971845672576] [1.193207837995694, 14.771346380236135] [0.2798829064245416, 5.089018439211767]
# Smiles Weight Mean and Std Dev
# 0.6647238721940013 0.07736912240290585
# Smiles Weight CI
# 0.48327251688449646 0.7893780569995772
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76721416 15.64708665] [ 3.26271239 30.40080537] [1.84624617 1.94290516]
# (Manually) Weighted RMSE Train
# [ 1.8771106  53.41136726]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.8884254431699687] [1.2726919159025003, 15.23490994640897] [0.27855796904140645, 5.105404294374173]
# Smiles Weight Mean and Std Dev
# 0.6627378100092914 0.08202874684243336
# Smiles Weight CI
# 0.4938131071256682 0.7995711061761369
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76725246 15.71078802] [ 3.26195099 30.4993698 ] [1.84577533 1.94130108]
# (Manually) Weighted RMSE Train
# [ 1.87956475 53.4023728 ]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.8884254431699687] [1.2026267564459912, 15.163316873329318] [0.2721301186440956, 5.143328607759994]
# Smiles Weight Mean and Std Dev
# 0.6542477221418262 0.08184256146056083
# Smiles Weight CI
# 0.4981426194423056 0.7990920065953789
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76978274 15.72558128] [ 3.26642333 30.46339851] [1.84566345 1.93718744]
# (Manually) Weighted RMSE Train
# [ 1.87675525 53.44778792]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.8759124087591241, 0.8738269030239834] [1.1627790473387494, 14.304756615234725] [0.2805847779240547, 5.0887189304698826]
# Smiles Weight Mean and Std Dev
# 0.664679176586103 0.0717635709196193
# Smiles Weight CI
# 0.5013091543951215 0.7757094802180592
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77235018 15.80778419] [ 3.27476099 30.57271903] [1.84769411 1.93402938]
# (Manually) Weighted RMSE Train
# [ 1.86461652 53.47595167]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.8852971845672576, 0.8915537017726799] [1.2304449769677959, 14.603163291077308] [0.2769456875426301, 5.072687920489969]
# Smiles Weight Mean and Std Dev
# 0.6626329599786746 0.07786435610868173
# Smiles Weight CI
# 0.5093646349901171 0.788386625873155
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77338421 15.80405764] [ 3.27948223 30.59701676] [1.84927903 1.93602285]
# (Manually) Weighted RMSE Train
# [ 1.86371877 53.52908466]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.8936392075078207, 0.8884254431699687] [1.2161352451867216, 14.890734058646164] [0.2778837875016476, 5.076691193397316]
# Smiles Weight Mean and Std Dev
# 0.6622371792384033 0.07863883633590613
# Smiles Weight CI
# 0.5083896662567381 0.7835529322211238
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7714862  15.87176038] [ 3.2768261  30.61092024] [1.84976101 1.92864052]
# (Manually) Weighted RMSE Train
# [ 1.86129255 53.54158115]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.8759124087591241, 0.8884254431699687] [1.1316016740886887, 14.647301723129079] [0.2862294199459119, 5.082742577099324]
# Smiles Weight Mean and Std Dev
# 0.668518451872815 0.07260664081574061
# Smiles Weight CI
# 0.5148360166126328 0.7866786955016211
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77498177 15.89079558] [ 3.28017013 30.76384751] [1.84800215 1.93595389]
# (Manually) Weighted RMSE Train
# [ 1.85935807 53.47704581]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.881126173096976, 0.8842544316996872] [1.1870871419529356, 14.859893694298387] [0.2902182291943333, 5.074560361865285]
# Smiles Weight Mean and Std Dev
# 0.669037610837107 0.07499288731175709
# Smiles Weight CI
# 0.5206572838070448 0.7901692768628669
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78002801 15.89115207] [ 3.27358209 30.95739204] [1.83906213 1.94808985]
# (Manually) Weighted RMSE Train
# [ 1.86850716 53.42993689]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.8852971845672576] [1.156562703407715, 14.995319066932382] [0.29596076378562725, 5.076544230550422]
# Smiles Weight Mean and Std Dev
# 0.6730367019426126 0.0760887305382178
# Smiles Weight CI
# 0.5104535839521421 0.7983708462798154
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77903075 15.95387204] [ 3.27655328 30.92741886] [1.84176315 1.93855252]
# (Manually) Weighted RMSE Train
# [ 1.86831862 53.5026986 ]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.8769551616266945, 0.8779979144942649] [1.125206929006125, 14.354148734278743] [0.27568156516545117, 5.086094202845995]
# Smiles Weight Mean and Std Dev
# 0.6579819443107494 0.07543572484008017
# Smiles Weight CI
# 0.5057139573907862 0.7774394946470745
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77881281 16.03370349] [ 3.27864931 30.9498716 ] [1.84316714 1.93030086]
# (Manually) Weighted RMSE Train
# [ 1.86806799 53.55786727]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.881126173096976, 0.8832116788321168] [1.2077011602171728, 14.86697255155624] [0.2996669321491223, 5.136085546716549]
# Smiles Weight Mean and Std Dev
# 0.6748592735088019 0.07643055974693702
# Smiles Weight CI
# 0.500899004775904 0.7861493786551025
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78288483 16.16756176] [ 3.28755607 31.06872973] [1.84395314 1.9216707 ]
# (Manually) Weighted RMSE Train
# [ 1.86530458 53.68390382]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.8978102189781022] [1.226971122701146, 15.086977981737384] [0.28090004629103477, 5.105779599006834]
# Smiles Weight Mean and Std Dev
# 0.663351024208409 0.07350138525943718
# Smiles Weight CI
# 0.5132658073242943 0.7925426631003567
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78130433 16.15606333] [ 3.28655751 31.10049003] [1.84502864 1.92500422]
# (Manually) Weighted RMSE Train
# [ 1.86448763 53.66378559]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.8967674661105318] [1.2541510468537094, 15.359876155913037] [0.27603701473623893, 5.099867877540047]
# Smiles Weight Mean and Std Dev
# 0.6586275690964741 0.07712668194680013
# Smiles Weight CI
# 0.4953102419663704 0.7892744011504522
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78511827 16.17324933] [ 3.2872683  31.16376645] [1.84148487 1.92687108]
# (Manually) Weighted RMSE Train
# [ 1.86896762 53.59721358]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9009384775808134] [1.2388487623549354, 15.701387755407065] [0.2759446042587387, 5.109970735683739]
# Smiles Weight Mean and Std Dev
# 0.6585924440962727 0.080416950363226
# Smiles Weight CI
# 0.4972255139753623 0.7932388383098627
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78714401 16.20375996] [ 3.29103372 31.19540091] [1.84150449 1.9251952 ]
# (Manually) Weighted RMSE Train
# [ 1.86929441 53.64785269]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.9113660062565172] [1.3644999761385719, 16.05984885546175] [0.2797739567712632, 5.095588281506145]
# Smiles Weight Mean and Std Dev
# 0.6616905092581633 0.08160273814272437
# Smiles Weight CI
# 0.4815904036839361 0.8038808640372073
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78996992 16.23223842] [ 3.2854494 31.3044951] [1.83547743 1.9285384 ]
# (Manually) Weighted RMSE Train
# [ 1.87733636 53.64734939]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.9009384775808134] [1.2955704912764872, 15.803162393563682] [0.2729617777651992, 5.174228018359942]
# Smiles Weight Mean and Std Dev
# 0.647125726971723 0.08405127444606003
# Smiles Weight CI
# 0.4822267351296831 0.7920464156967489
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78854608 16.2329659 ] [ 3.28896784 31.33160849] [1.83890584 1.93012224]
# (Manually) Weighted RMSE Train
# [ 1.87784325 53.77759062]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.8779979144942649, 0.8925964546402503] [1.1858532965133235, 14.909603780552471] [0.2951723308039106, 5.120162537916453]
# Smiles Weight Mean and Std Dev
# 0.6725651298486822 0.07794073416903481
# Smiles Weight CI
# 0.5074937666272296 0.7933328140475933
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78603214 16.31540368] [ 3.29049985 31.4472165 ] [1.84235198 1.92745562]
# (Manually) Weighted RMSE Train
# [ 1.87886477 53.8028149 ]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.899895724713243] [1.3069390817408035, 16.176552217475727] [0.2780537314377662, 5.127491791328205]
# Smiles Weight Mean and Std Dev
# 0.6617431060912708 0.08147893373193837
# Smiles Weight CI
# 0.49055189352563744 0.7902184487735666
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78803823 16.32568056] [ 3.29068297 31.57623132] [1.84038736 1.93414487]
# (Manually) Weighted RMSE Train
# [ 1.87550299 53.66811088]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.8915537017726799] [1.3241860015458138, 15.621334032937861] [0.2780543507204918, 5.082621995169176]
# Smiles Weight Mean and Std Dev
# 0.6614681161923531 0.07884633569893396
# Smiles Weight CI
# 0.4805562275994028 0.7865888752823971
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78406334 16.31282616] [ 3.29161113 31.58303666] [1.845008   1.93608614]
# (Manually) Weighted RMSE Train
# [ 1.86778654 53.51755244]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.8800834202294057] [1.289573150425675, 15.346466601190645] [0.27287249631138155, 5.127628020659706]
# Smiles Weight Mean and Std Dev
# 0.6514832756884438 0.08035607352861447
# Smiles Weight CI
# 0.48519425208838723 0.780442193552189
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78231862 16.29364751] [ 3.28321493 31.64479523] [1.84210326 1.94215538]
# (Manually) Weighted RMSE Train
# [ 1.87467229 53.49182634]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.8915537017726799] [1.255701542333526, 15.52607956190519] [0.27766435800199585, 5.110658375167904]
# Smiles Weight Mean and Std Dev
# 0.6603437566632425 0.08302802621936364
# Smiles Weight CI
# 0.4880557671476865 0.7958816832549276
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78109399 16.28562732] [ 3.2733025  31.60812981] [1.83780447 1.94086044]
# (Manually) Weighted RMSE Train
# [ 1.88077866 53.54489989]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.8769551616266945, 0.8988529718456726] [1.2628070731443433, 16.310882806039114] [0.276694564281226, 5.122108774670146]
# Smiles Weight Mean and Std Dev
# 0.6602887005787863 0.0818602236190817
# Smiles Weight CI
# 0.4827470046470781 0.7918636006428877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77900695 16.39419825] [ 3.28330196 31.81322731] [1.8455813  1.94051742]
# (Manually) Weighted RMSE Train
# [ 1.87468655 53.47126374]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.8748696558915537, 0.872784150156413] [1.2042634744031753, 14.506700887914663] [0.2755756800445971, 5.094467808847323]
# Smiles Weight Mean and Std Dev
# 0.6606805239222203 0.07499644401487351
# Smiles Weight CI
# 0.5089101416179399 0.7885507300980941
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77424709 16.44304709] [ 3.29130728 31.79539677] [1.85504449 1.93366817]
# (Manually) Weighted RMSE Train
# [ 1.86482352 53.54386971]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.8832116788321168, 0.8842544316996872] [1.2462596936756798, 15.410944419028786] [0.27379988002980726, 5.109522437753818]
# Smiles Weight Mean and Std Dev
# 0.6591813526467892 0.0776354326827263
# Smiles Weight CI
# 0.4901252946941384 0.7839563031577028
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77397569 16.44120365] [ 3.29872279 31.93575421] [1.85950845 1.94242191]
# (Manually) Weighted RMSE Train
# [ 1.85884756 53.43143648]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.8988529718456726] [1.3193488134348759, 16.592531821298596] [0.2727510161680845, 5.133789264229811]
# Smiles Weight Mean and Std Dev
# 0.6582845811574223 0.08373746480749558
# Smiles Weight CI
# 0.47833526244050545 0.7903772491996947
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77578293 16.49564764] [ 3.29809532 31.89078664] [1.85726265 1.93328491]
# (Manually) Weighted RMSE Train
# [ 1.86498062 53.64005917]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.8832116788321168, 0.9040667361835245] [1.3149846077127665, 16.539087411189712] [0.2734577945228392, 5.130063746741971]
# Smiles Weight Mean and Std Dev
# 0.657826861181602 0.0838619564408148
# Smiles Weight CI
# 0.49669837793438987 0.79482116164347
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77743279 16.51211976] [ 3.30572209 31.876919  ] [1.85982958 1.93051646]
# (Manually) Weighted RMSE Train
# [ 1.85862205 53.62482748]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9113660062565172] [1.3318435996695657, 16.65705011939116] [0.272141388787772, 5.133960886065043]
# Smiles Weight Mean and Std Dev
# 0.6519095325338826 0.0833520047669622
# Smiles Weight CI
# 0.4851372629210831 0.8020112342087939
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77867511 16.59204984] [ 3.31363538 31.92790296] [1.86297956 1.92428924]
# (Manually) Weighted RMSE Train
# [ 1.84869612 53.57170314]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.8905109489051095] [1.2630424258206299, 15.630963627552829] [0.27291532615140635, 5.129324507691629]
# Smiles Weight Mean and Std Dev
# 0.6564697369316588 0.07977107107734364
# Smiles Weight CI
# 0.4991474282646218 0.7862133841684936
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77948538 16.65760761] [ 3.31130045 32.00534823] [1.86081914 1.92136524]
# (Manually) Weighted RMSE Train
# [ 1.84925068 53.61999801]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.8738269030239834, 0.8905109489051095] [1.1938062187127065, 15.148273454740965] [0.2730228194198561, 5.106167315290436]
# Smiles Weight Mean and Std Dev
# 0.6558840507315286 0.07882748918563241
# Smiles Weight CI
# 0.4948591300163664 0.7901101186337647
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77912394 16.68041216] [ 3.30422276 32.05769707] [1.85721898 1.9218768 ]
# (Manually) Weighted RMSE Train
# [ 1.8607854  53.51458782]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.881126173096976, 0.9040667361835245] [1.2952171539957222, 16.00070854607437] [0.2750157377056323, 5.113270055684484]
# Smiles Weight Mean and Std Dev
# 0.6583164602180951 0.08067521491346999
# Smiles Weight CI
# 0.4882613534623785 0.7909281984225115
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78307031 16.67567982] [ 3.31104164 32.11181303] [1.85693274 1.9256674 ]
# (Manually) Weighted RMSE Train
# [ 1.85610622 53.53575661]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.8988529718456726] [1.2826062159805725, 15.908756635768125] [0.2774066622537957, 5.104430521609502]
# Smiles Weight Mean and Std Dev
# 0.6618101364760928 0.08061879011352877
# Smiles Weight CI
# 0.4936988165331465 0.7872704608608521
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7842588  16.63492597] [ 3.30399764 32.08824002] [1.85174799 1.92896801]
# (Manually) Weighted RMSE Train
# [ 1.86280516 53.58549835]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.8790406673618353, 0.8988529718456726] [1.2381612915761493, 15.783805264977055] [0.27322876967207743, 5.151349420978031]
# Smiles Weight Mean and Std Dev
# 0.6547818111848454 0.07834959345935767
# Smiles Weight CI
# 0.49102691002832355 0.7949916789596106
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7863598  16.70761145] [ 3.30318136 32.17403866] [1.84911313 1.92571145]
# (Manually) Weighted RMSE Train
# [ 1.86495057 53.60857688]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.8873826903023984, 0.899895724713243] [1.272368249826298, 15.740135642690436] [0.2837577304899003, 5.127332651784818]
# Smiles Weight Mean and Std Dev
# 0.6661783248841706 0.08059528998547333
# Smiles Weight CI
# 0.4946365952130166 0.7906231629732522
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78992653 16.6983659 ] [ 3.29733262 32.19869586] [1.84216088 1.9282543 ]
# (Manually) Weighted RMSE Train
# [ 1.87019206 53.60464845]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.8936392075078207] [1.2858029103051543, 15.698988583823807] [0.27885872100754305, 5.130755530625041]
# Smiles Weight Mean and Std Dev
# 0.6608184033118534 0.08185238129661897
# Smiles Weight CI
# 0.4802870667856712 0.785955668754679
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79245979 16.75819026] [ 3.29614654 32.18285221] [1.83889567 1.92042528]
# (Manually) Weighted RMSE Train
# [ 1.87547434 53.62742519]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.872784150156413, 0.8925964546402503] [1.1839609775592446, 15.297730316482948] [0.2768529585524772, 5.141474737552917]
# Smiles Weight Mean and Std Dev
# 0.6579794664382133 0.07620418682649491
# Smiles Weight CI
# 0.5121892378148574 0.7897719535887145
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79497157 16.72739977] [ 3.29427744 32.239361  ] [1.83528113 1.92733847]
# (Manually) Weighted RMSE Train
# [ 1.87833424 53.62635233]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.8790406673618353, 0.8967674661105318] [1.2387470344484555, 15.542293501748134] [0.2831788630504106, 5.123457543662477]
# Smiles Weight Mean and Std Dev
# 0.664519229751645 0.07734502719886102
# Smiles Weight CI
# 0.5049364797921374 0.8082731682966459
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79712147 16.82208882] [ 3.29965377 32.27885689] [1.83607721 1.91883762]
# (Manually) Weighted RMSE Train
# [ 1.87304325 53.64897463]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.8852971845672576] [1.2348025967578213, 15.324951824851922] [0.27960507065341306, 5.146438382928276]
# Smiles Weight Mean and Std Dev
# 0.6602434796135701 0.07418740639206761
# Smiles Weight CI
# 0.4973824411483057 0.7838146774851973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80219692 16.90544394] [ 3.30686811 32.39980614] [1.83490942 1.91653093]
# (Manually) Weighted RMSE Train
# [ 1.87114121 53.58260027]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.8769551616266945, 0.8884254431699687] [1.1896475124797408, 15.556061968034657] [0.2791730154824912, 5.1246086252749485]
# Smiles Weight Mean and Std Dev
# 0.6589425316042332 0.07781232322524541
# Smiles Weight CI
# 0.49064327547195385 0.7839949829556542
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80302694 16.89930324] [ 3.29808687 32.52858394] [1.82919445 1.92484764]
# (Manually) Weighted RMSE Train
# [ 1.88185032 53.45382658]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.8696558915537018, 0.8779979144942649] [1.1988504842319971, 14.503282134568952] [0.27857543087773295, 5.112073994168496]
# Smiles Weight Mean and Std Dev
# 0.6573350726963866 0.07228804888535946
# Smiles Weight CI
# 0.5121577374614571 0.7760855310509877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80488185 16.95836658] [ 3.3052745 32.5491268] [1.83129688 1.91935507]
# (Manually) Weighted RMSE Train
# [ 1.87353729 53.45778792]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.8800834202294057, 0.8915537017726799] [1.2153995286064998, 15.886096303751788] [0.28215459236807766, 5.119122927336231]
# Smiles Weight Mean and Std Dev
# 0.6609959015787926 0.07736631045792518
# Smiles Weight CI
# 0.49235833279968527 0.7928967335695614
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.80786405 17.03412099] [ 3.3128267  32.57653271] [1.83245344 1.91242816]
# (Manually) Weighted RMSE Train
# [ 1.87209655 53.48564409]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.8706986444212722, 0.8884254431699687] [1.2417539270074978, 15.795574240898437] [0.28082410194387053, 5.126551775081236]
# Smiles Weight Mean and Std Dev
# 0.6604734814218632 0.07542642305331189
# Smiles Weight CI
# 0.49017034593246606 0.77775182947973
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81015845 17.09271771] [ 3.3170006  32.63579206] [1.8324366  1.90933897]
# (Manually) Weighted RMSE Train
# [ 1.86939048 53.54757568]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.872784150156413, 0.8978102189781022] [1.2058942950954135, 16.017768142436317] [0.2747493151818749, 5.133470188892419]
# Smiles Weight Mean and Std Dev
# 0.6522212150838483 0.07779913379766912
# Smiles Weight CI
# 0.49750400874156275 0.7796827885537885
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81260595 17.05033557] [ 3.30573988 32.61098388] [1.82374988 1.91263003]
# (Manually) Weighted RMSE Train
# [ 1.88189781 53.45444636]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.8967674661105318] [1.2943956068288358, 16.20560752581729] [0.2747337231114589, 5.17431752346808]
# Smiles Weight Mean and Std Dev
# 0.6500649490969358 0.08559279892105505
# Smiles Weight CI
# 0.4777869363299928 0.7947308070089445
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81200174 17.13964251] [ 3.30630479 32.6383621 ] [1.82466977 1.90426154]
# (Manually) Weighted RMSE Train
# [ 1.88198029 53.54466525]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.8873826903023984, 0.899895724713243] [1.2900084420691447, 16.213192802558645] [0.286427594248565, 5.149038092960815]
# Smiles Weight Mean and Std Dev
# 0.6634263755954698 0.07958723462662352
# Smiles Weight CI
# 0.4904722536154608 0.7982663098573676
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81555835 17.13852497] [ 3.30999436 32.68671895] [1.82312751 1.90720724]
# (Manually) Weighted RMSE Train
# [ 1.87427336 53.56131195]
#
#
# epoch number:  97
# Coverages, CI Widths, RMSEs
# [0.8936392075078207, 0.899895724713243] [1.2950298652398948, 16.757635120440355] [0.2777504158014146, 5.161698745607883]
# Smiles Weight Mean and Std Dev
# 0.6570779050765602 0.08448810265985424
# Smiles Weight CI
# 0.4884689458369835 0.7894061520841462
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81492022 17.09558634] [ 3.32048411 32.69481398] [1.82954824 1.91247105]
# (Manually) Weighted RMSE Train
# [ 1.86620601 53.57692318]
#
#
# epoch number:  98
# Coverages, CI Widths, RMSEs
# [0.8759124087591241, 0.8832116788321168] [1.2471092565972446, 15.417312817939882] [0.2788766402070383, 5.18991008952314]
# Smiles Weight Mean and Std Dev
# 0.6568755025794 0.07602465636579595
# Smiles Weight CI
# 0.4892170321370784 0.7789202296465824
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81757057 17.21567741] [ 3.31883544 32.68180477] [1.82597337 1.8983746 ]
# (Manually) Weighted RMSE Train
# [ 1.87016771 53.66593684]
#
#
# epoch number:  99
# Coverages, CI Widths, RMSEs
# [0.8800834202294057, 0.8800834202294057] [1.2466331037346692, 15.466214786896584] [0.279716626828889, 5.185941611386131]
# Smiles Weight Mean and Std Dev
# 0.6579560071264084 0.07777681977924678
# Smiles Weight CI
# 0.48866146268091115 0.7940963915372743
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.81755313 17.29790091] [ 3.31700305 32.65481408] [1.82498271 1.88779056]
# (Manually) Weighted RMSE Train
# [ 1.87515521 53.75175784]
#
#
# done for fold0
# train_width[1.1627790473387494, 14.304756615234725]
# smiles_weight0.664679176586103
# rmse_train[0.9879750361881883, 1.2391406799152258]
# smiles_weight_ci[0.5013091543951215, 0.7757094802180592]
# CPU times: user 54min 33s, sys: 32min 57s, total: 1h 27min 31s
# Wall time: 17min 58s

# %%
with open("..//Data/returned_stuff_config3_prop_ratio.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.65, epochs = 1500, fudging_var = 1e-5)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.8832116788321168, 0.862356621480709] [1.2928625400406861, 15.548297329568467] [0.30037229944095944, 6.165447688692434]
# Smiles Weight Mean and Std Dev
# 0.6610841934924394 0.08500818214958356
# Smiles Weight CI
# 0.4725385869361076 0.7971138238490908
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.756559   16.15225274] [ 3.14209042 28.95767494] [1.78877591 1.79279481]
# (Manually) Weighted RMSE Train
# [ 1.95784666 53.87972535]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.8779979144942649] [1.2477255641522502, 14.879922591708697] [0.3014216599353383, 5.958407073714335]
# Smiles Weight Mean and Std Dev
# 0.663826316998467 0.08112135901546601
# Smiles Weight CI
# 0.4877685123624711 0.8000412656353407
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73027821 15.59148732] [ 3.06060984 27.92630739] [1.76885417 1.7911253 ]
# (Manually) Weighted RMSE Train
# [ 2.00028112 54.12143374]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.8832116788321168, 0.8759124087591241] [1.1525008490990325, 14.54947915014405] [0.28511301066926653, 5.7776258813623675]
# Smiles Weight Mean and Std Dev
# 0.6544004352291697 0.07986980881367098
# Smiles Weight CI
# 0.48059163144202505 0.7809528747769763
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.70522882 15.37413441] [ 2.98163987 27.21216972] [1.74852773 1.76999687]
# (Manually) Weighted RMSE Train
# [ 2.0416739  54.64179997]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.8696558915537018] [1.1871640751101706, 14.406430616455783] [0.29614354401252596, 5.680685152157965]
# Smiles Weight Mean and Std Dev
# 0.6633972291054626 0.08041725187989042
# Smiles Weight CI
# 0.48074186212551195 0.7934943424719009
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.67590478 15.16633762] [ 2.90657925 26.55867748] [1.73433436 1.75115958]
# (Manually) Weighted RMSE Train
# [ 2.08169227 55.08149565]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.8842544316996872] [1.1853122714074704, 14.589203416979823] [0.2976493799111383, 5.512542625932277]
# Smiles Weight Mean and Std Dev
# 0.6641444401155653 0.08056423178970654
# Smiles Weight CI
# 0.48344131670726753 0.792537419938435
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.65410318 14.76920302] [ 2.83058563 25.96770602] [1.71125094 1.7582334 ]
# (Manually) Weighted RMSE Train
# [ 2.1356596  55.14098563]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.8738269030239834] [1.1132952464936758, 14.250997859024665] [0.28902144212835107, 5.409920952907987]
# Smiles Weight Mean and Std Dev
# 0.6622403239074547 0.07999721744112692
# Smiles Weight CI
# 0.487672647901855 0.7992595651821462
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62877996 14.69906184] [ 2.78126277 25.5933923 ] [1.70757428 1.74115822]
# (Manually) Weighted RMSE Train
# [ 2.14981516 55.53751427]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.8706986444212722] [1.125949548636207, 13.818200623950124] [0.27303094875711953, 5.274675618657953]
# Smiles Weight Mean and Std Dev
# 0.655242172734552 0.07973438597919709
# Smiles Weight CI
# 0.4899422093833425 0.7764708173931661
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60505114 14.43893014] [ 2.74240405 25.03599766] [1.70860852 1.73392332]
# (Manually) Weighted RMSE Train
# [ 2.1606488  55.60128819]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.8644421272158499] [1.0772711632338636, 13.420779435081483] [0.2792122321074051, 5.201456144012443]
# Smiles Weight Mean and Std Dev
# 0.6612297806003162 0.07645690173939793
# Smiles Weight CI
# 0.4855133015424815 0.7892134709133359
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57251844 14.13981205] [ 2.68358016 24.55986982] [1.70654924 1.73693043]
# (Manually) Weighted RMSE Train
# [ 2.18449312 55.76854855]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.9040667361835245, 0.8925964546402503] [1.1086118121690764, 14.07398599544459] [0.2767152497355929, 5.09837571641565]
# Smiles Weight Mean and Std Dev
# 0.661756831197072 0.0811985594756848
# Smiles Weight CI
# 0.474240381012853 0.7898801001657325
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.54893829 13.83657009] [ 2.63832121 24.13483066] [1.70330944 1.74427842]
# (Manually) Weighted RMSE Train
# [ 2.20902308 56.00222113]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.9040667361835245, 0.8602711157455682] [1.0063638606381526, 12.938212470954088] [0.26867603178948307, 5.000143718372159]
# Smiles Weight Mean and Std Dev
# 0.6576863977647786 0.07334797728273285
# Smiles Weight CI
# 0.49992649367925546 0.7808888258772847
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.52435211 13.55886412] [ 2.58702874 23.63094299] [1.69713331 1.7428409 ]
# (Manually) Weighted RMSE Train
# [ 2.23135939 56.18440827]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.8832116788321168] [1.099420667563369, 13.777384407850558] [0.27240579122651465, 4.961095703968171]
# Smiles Weight Mean and Std Dev
# 0.6616349972017149 0.08393893690406616
# Smiles Weight CI
# 0.4818029548307815 0.7954628405013388
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50477598 13.40944206] [ 2.55228589 23.45631636] [1.69612349 1.7492388 ]
# (Manually) Weighted RMSE Train
# [ 2.24683649 56.38908422]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.8633993743482794] [1.0237650811840782, 13.117250308263564] [0.2664180010810836, 4.921463694116525]
# Smiles Weight Mean and Std Dev
# 0.6601057226299912 0.07523818969550403
# Smiles Weight CI
# 0.4894132975371281 0.7735290187613192
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47912903 13.40392398] [ 2.51660568 23.2215627 ] [1.70141051 1.73244512]
# (Manually) Weighted RMSE Train
# [ 2.26107696 56.52516954]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.8821689259645464] [1.0726376709029681, 13.858750833791227] [0.24850761951821973, 4.852732565813538]
# Smiles Weight Mean and Std Dev
# 0.6489447362185058 0.08466590528108825
# Smiles Weight CI
# 0.4807095324501138 0.781412958273503
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46559529 13.39346619] [ 2.48800796 23.04670745] [1.69760914 1.72074257]
# (Manually) Weighted RMSE Train
# [ 2.27399329 56.70695562]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9197080291970803, 0.8884254431699687] [1.0391781694791828, 13.619786802501455] [0.2655662690048749, 4.823636658769492]
# Smiles Weight Mean and Std Dev
# 0.6628064249019602 0.07939723200221328
# Smiles Weight CI
# 0.49626881696955305 0.79620697533319
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44773333 13.31991036] [ 2.45016345 22.94575106] [1.69241351 1.72266558]
# (Manually) Weighted RMSE Train
# [ 2.29223975 56.92659686]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.867570385818561] [0.9985456116266587, 13.109813087100733] [0.2583745114707401, 4.773661412925298]
# Smiles Weight Mean and Std Dev
# 0.6604231263406829 0.07828656518706452
# Smiles Weight CI
# 0.4895793077058559 0.7868062255883421
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.43123795 13.33018709] [ 2.42592914 22.81587092] [1.6949866 1.7115942]
# (Manually) Weighted RMSE Train
# [ 2.29187591 57.2687362 ]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.8769551616266945] [1.0024822866879086, 13.023753299282827] [0.251220777337616, 4.718518089767992]
# Smiles Weight Mean and Std Dev
# 0.6573037700450859 0.07972264737823921
# Smiles Weight CI
# 0.4867527045606762 0.7841585660877162
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41423169 13.352127  ] [ 2.40833793 22.79971741] [1.70293025 1.70757194]
# (Manually) Weighted RMSE Train
# [ 2.29319303 57.49790264]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.886339937434828] [1.0311842557764606, 13.71913137426577] [0.2461709414541134, 4.65148652548665]
# Smiles Weight Mean and Std Dev
# 0.6548962877304825 0.08515475786655612
# Smiles Weight CI
# 0.4737102368226777 0.7836655164092761
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.40331354 13.39756186] [ 2.37905713 22.82859455] [1.69531403 1.70393649]
# (Manually) Weighted RMSE Train
# [ 2.3065412  57.90367448]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.8925964546402503] [0.9666689229352009, 13.387198736749777] [0.24333276499877712, 4.616937031508169]
# Smiles Weight Mean and Std Dev
# 0.6533475973543014 0.08108809487269447
# Smiles Weight CI
# 0.49052677929001653 0.7828319656665508
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39175818 13.43522834] [ 2.35209387 22.9260061 ] [1.6900162  1.70640986]
# (Manually) Weighted RMSE Train
# [ 2.31983459 58.26944098]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9363920750782064, 0.8925964546402503] [1.0217480142377844, 13.628172553653373] [0.23970671665730905, 4.601862879087549]
# Smiles Weight Mean and Std Dev
# 0.6509463257481792 0.08546903159454207
# Smiles Weight CI
# 0.47988389574652895 0.7884338510185469
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38052   13.5218176] [ 2.31422346 23.03118716] [1.67634186 1.70326119]
# (Manually) Weighted RMSE Train
# [ 2.33852148 58.43283479]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.886339937434828] [0.9721894290859202, 12.812035453440606] [0.24451523051334834, 4.575306603946798]
# Smiles Weight Mean and Std Dev
# 0.6536173478689442 0.07498445878138521
# Smiles Weight CI
# 0.5048788470414992 0.7733605660665822
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36775544 13.77969658] [ 2.27899885 23.2551881 ] [1.66623271 1.68764152]
# (Manually) Weighted RMSE Train
# [ 2.35231649 58.59296051]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.935349322210636, 0.881126173096976] [0.9836802164704934, 13.181410251341093] [0.2516802372201146, 4.603860756311991]
# Smiles Weight Mean and Std Dev
# 0.658571183978773 0.07986539725652099
# Smiles Weight CI
# 0.4771524688344247 0.7888043547760203
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35829986 13.92575775] [ 2.25416217 23.43000544] [1.65954678 1.68249411]
# (Manually) Weighted RMSE Train
# [ 2.36738853 58.68801815]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9311783107403545, 0.8873826903023984] [0.9640530228947907, 13.462255650024062] [0.25165927402035837, 4.571721279712987]
# Smiles Weight Mean and Std Dev
# 0.6594437332364607 0.08006319245509541
# Smiles Weight CI
# 0.4777636253914462 0.7871025458779426
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.34813509 14.1294763 ] [ 2.22857469 23.66989714] [1.65307966 1.67521404]
# (Manually) Weighted RMSE Train
# [ 2.3787096  58.96321977]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.8748696558915537] [0.9347283404873626, 12.966227465815937] [0.24810907223664813, 4.530781350527039]
# Smiles Weight Mean and Std Dev
# 0.6573675456179726 0.07429358123066204
# Smiles Weight CI
# 0.5076656111333511 0.782738005283695
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32726506 14.33372709] [ 2.18978717 23.92887226] [1.64984918 1.66941034]
# (Manually) Weighted RMSE Train
# [ 2.39859655 59.0944493 ]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.921793534932221, 0.8581856100104275] [0.8849060500744587, 12.54553296305571] [0.26053312688504443, 4.608939899774675]
# Smiles Weight Mean and Std Dev
# 0.6654431056812955 0.07309475376439095
# Smiles Weight CI
# 0.5054880662230589 0.7834408841926216
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3175263  14.52737491] [ 2.16151661 24.153866  ] [1.64058708 1.66264491]
# (Manually) Weighted RMSE Train
# [ 2.42030143 59.18062949]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.8821689259645464] [0.9200119255830885, 13.686861323457533] [0.24680242573663913, 4.5254779093099495]
# Smiles Weight Mean and Std Dev
# 0.6584592085745139 0.08009514523459325
# Smiles Weight CI
# 0.4882242319764556 0.7884181657643367
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.3030526  14.75298564] [ 2.13723825 24.55873627] [1.64017803 1.66466211]
# (Manually) Weighted RMSE Train
# [ 2.42984282 59.37307651]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9363920750782064, 0.886339937434828] [0.9447131330404197, 13.625816191505733] [0.24439106485481485, 4.485914799690413]
# Smiles Weight Mean and Std Dev
# 0.6584831705597274 0.08063361671826887
# Smiles Weight CI
# 0.4980908860259198 0.7857396036643952
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29049194 15.01030525] [ 2.1185363 24.8715432] [1.64165016 1.65696452]
# (Manually) Weighted RMSE Train
# [ 2.43921998 59.69772941]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.8821689259645464] [0.8791156505438856, 13.535043705397722] [0.23700209570063044, 4.482500987745158]
# Smiles Weight Mean and Std Dev
# 0.6555342515956561 0.07625825382872833
# Smiles Weight CI
# 0.4947483828268891 0.7861553656895716
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27645425 15.24439133] [ 2.09945761 25.12070207] [1.64475743 1.64786521]
# (Manually) Weighted RMSE Train
# [ 2.44054035 59.86253463]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.8769551616266945] [0.8902526241941483, 13.656745050132633] [0.23461042448690103, 4.45989325888619]
# Smiles Weight Mean and Std Dev
# 0.6546054768208961 0.07977718680272136
# Smiles Weight CI
# 0.4832259674831434 0.77662383742828
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26838242 15.40566252] [ 2.08419576 25.3254657 ] [1.64319193 1.6439063 ]
# (Manually) Weighted RMSE Train
# [ 2.44439047 60.02382328]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9499478623566214, 0.8832116788321168] [0.9569841947545117, 13.741441291165664] [0.21454085101953643, 4.362924111843637]
# Smiles Weight Mean and Std Dev
# 0.6354157370699024 0.07717145931564082
# Smiles Weight CI
# 0.46886922403878223 0.7754078585563917
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26022663 15.67190048] [ 2.06482624 25.68881998] [1.63845628 1.63916431]
# (Manually) Weighted RMSE Train
# [ 2.45659201 60.31296831]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.8748696558915537] [0.8778209083432987, 13.006782433330372] [0.22216844872954536, 4.392172661224693]
# Smiles Weight Mean and Std Dev
# 0.6455499084362328 0.07684348289346885
# Smiles Weight CI
# 0.4905992425216547 0.7696119705030258
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2487678  15.82201523] [ 2.03776815 25.89955205] [1.6318231  1.63693131]
# (Manually) Weighted RMSE Train
# [ 2.47002352 60.51886193]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9436913451511991, 0.8957247132429614] [0.9165162216789629, 14.635820743312038] [0.22197605602975964, 4.370656085818401]
# Smiles Weight Mean and Std Dev
# 0.6470422542405233 0.08400045212455948
# Smiles Weight CI
# 0.4713607028836689 0.7752320998964419
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22598594 15.96525051] [ 1.99975025 26.1584566 ] [1.63113637 1.63846202]
# (Manually) Weighted RMSE Train
# [ 2.48627933 60.78688929]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9436913451511991, 0.8894681960375391] [0.9209987826634815, 14.029846765380539] [0.2113741824246927, 4.301189308444654]
# Smiles Weight Mean and Std Dev
# 0.636721930524299 0.07737147378390181
# Smiles Weight CI
# 0.47462736691545016 0.7702454475099719
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.20985163 16.07713279] [ 1.97713052 26.40861299] [1.63419255 1.64261957]
# (Manually) Weighted RMSE Train
# [ 2.50018393 60.99710512]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.8738269030239834] [0.9267348433234057, 13.683394994952538] [0.21858299614193494, 4.322392487127428]
# Smiles Weight Mean and Std Dev
# 0.6464391949691601 0.07871510032838105
# Smiles Weight CI
# 0.4688026241025124 0.7707872405388576
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.19998046 16.2766947 ] [ 1.94956312 26.80958378] [1.62466239 1.64711474]
# (Manually) Weighted RMSE Train
# [ 2.5174563  61.30235331]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9322210636079249, 0.899895724713243] [0.9073117205726632, 14.713083891194763] [0.21554792979406534, 4.247081808787524]
# Smiles Weight Mean and Std Dev
# 0.6432885603262678 0.08241560430281138
# Smiles Weight CI
# 0.4767723788712967 0.783568983593186
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18455404 16.51675727] [ 1.92627907 27.22430527] [1.62616394 1.64828391]
# (Manually) Weighted RMSE Train
# [ 2.52625021 61.51745905]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.8842544316996872] [0.8747887153153202, 14.072683235463606] [0.2132986254936081, 4.280567316619158]
# Smiles Weight Mean and Std Dev
# 0.6435438146935307 0.08121404511218874
# Smiles Weight CI
# 0.48029346761921304 0.7708231790667043
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17263009 16.64204871] [ 1.90729007 27.31314524] [1.62650616 1.64121291]
# (Manually) Weighted RMSE Train
# [ 2.53883196 61.49468612]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.948905109489051, 0.8894681960375391] [0.9131419489119267, 14.345977695351486] [0.21621953169331337, 4.285267682899138]
# Smiles Weight Mean and Std Dev
# 0.6480705212082085 0.08232477176626023
# Smiles Weight CI
# 0.4749081485166525 0.7809321820304012
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.16082922 16.82991371] [ 1.88342066 27.66307404] [1.62247868 1.64368484]
# (Manually) Weighted RMSE Train
# [ 2.55268772 61.68383246]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.8936392075078207] [0.8789862671415344, 14.280617928794024] [0.21027317112450336, 4.2002996565328905]
# Smiles Weight Mean and Std Dev
# 0.6414537512740682 0.08090730211833108
# Smiles Weight CI
# 0.4829007186240634 0.7775764435448028
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1445606  17.03553491] [ 1.85616033 28.06725663] [1.62172307 1.6475712 ]
# (Manually) Weighted RMSE Train
# [ 2.56399672 61.86845806]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.9395203336809176, 0.8915537017726799] [0.8236207135505238, 13.78144095577154] [0.21193227575245588, 4.245608389710234]
# Smiles Weight Mean and Std Dev
# 0.645151395426772 0.07868588809697874
# Smiles Weight CI
# 0.48231545800466313 0.7723649370356896
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.12999668 17.19364883] [ 1.83320304 28.34936332] [1.62230834 1.64882763]
# (Manually) Weighted RMSE Train
# [ 2.56875429 62.05030665]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.8717413972888426] [0.7327684099112409, 12.852223639555863] [0.20658902129389484, 4.16275282898495]
# Smiles Weight Mean and Std Dev
# 0.6407048954669479 0.0705292931499591
# Smiles Weight CI
# 0.5069746339429135 0.765571256421225
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.11556211 17.21697378] [ 1.8188082 28.7278892] [1.63039618 1.66857948]
# (Manually) Weighted RMSE Train
# [ 2.57649922 62.45380522]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.9019812304483837] [0.8459954046344581, 14.545773457370965] [0.20491868982103353, 4.168675603799998]
# Smiles Weight Mean and Std Dev
# 0.6410026067830921 0.07679227426557829
# Smiles Weight CI
# 0.46869404663690056 0.7574408865671122
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.10908598 17.30619073] [ 1.80929378 28.95233611] [1.63133771 1.67294678]
# (Manually) Weighted RMSE Train
# [ 2.57090666 62.75481921]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9447340980187695, 0.9051094890510949] [0.886105511613966, 15.203007912266946] [0.20644341837801286, 4.152697059330383]
# Smiles Weight Mean and Std Dev
# 0.6433477413674216 0.08382289040045109
# Smiles Weight CI
# 0.4595660172734799 0.7763028630234231
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.10357453 17.52969952] [ 1.79616577 29.3443926 ] [1.627589   1.67398149]
# (Manually) Weighted RMSE Train
# [ 2.58311736 62.87941929]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.8936392075078207] [0.8193252889067529, 14.292242525131142] [0.21005082712987894, 4.17016092778404]
# Smiles Weight Mean and Std Dev
# 0.6491465297367204 0.07958027822269172
# Smiles Weight CI
# 0.48200964511675365 0.7838309647419954
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.09071093 17.63125402] [ 1.78481161 29.56700504] [1.63637456 1.67696552]
# (Manually) Weighted RMSE Train
# [ 2.58273752 62.83484883]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.894681960375391] [0.8052358028951557, 14.310668832283886] [0.2039700902940563, 4.124953384709956]
# Smiles Weight Mean and Std Dev
# 0.6425284405755772 0.08019780424106471
# Smiles Weight CI
# 0.4738683442891748 0.7603967748132341
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08037686 17.75155656] [ 1.77227337 29.72332805] [1.64042144 1.67440686]
# (Manually) Weighted RMSE Train
# [ 2.58489602 62.9203526 ]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.9249217935349322, 0.9019812304483837] [0.8253333312823076, 15.062508798814676] [0.21049035779263572, 4.175708417073926]
# Smiles Weight Mean and Std Dev
# 0.6509693358501581 0.08012217031109481
# Smiles Weight CI
# 0.47171632996987267 0.7824628767691851
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.07189257 17.919227  ] [ 1.75703644 29.87695149] [1.63919079 1.66731252]
# (Manually) Weighted RMSE Train
# [ 2.58540521 62.86711952]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.9061522419186653, 0.8769551616266945] [0.7585848373154954, 13.670856648203765] [0.20564127638029664, 4.18389141748928]
# Smiles Weight Mean and Std Dev
# 0.649828375037066 0.07567893234376304
# Smiles Weight CI
# 0.49808452612967175 0.7803847963480297
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.05384924 17.94389411] [ 1.74386873 29.90123541] [1.65476109 1.66637382]
# (Manually) Weighted RMSE Train
# [ 2.57904824 62.72479059]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.894681960375391] [0.7571920783489935, 13.848827385164885] [0.20060344070947614, 4.092787857873644]
# Smiles Weight Mean and Std Dev
# 0.64204614486876 0.07992255360200512
# Smiles Weight CI
# 0.48739899124414704 0.7592167336640506
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.04270718 18.14615867] [ 1.72302796 30.09891109] [1.65245621 1.65869326]
# (Manually) Weighted RMSE Train
# [ 2.59078935 62.64232966]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.8988529718456726] [0.7658505528783747, 14.926529297586788] [0.1991521250387407, 4.103556958410489]
# Smiles Weight Mean and Std Dev
# 0.6405876063132031 0.07871487759108087
# Smiles Weight CI
# 0.48659376038121915 0.7763937815525995
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.0368043  18.25762082] [ 1.71291741 30.23581471] [1.65211257 1.65606543]
# (Manually) Weighted RMSE Train
# [ 2.59311396 62.7415906 ]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.881126173096976] [0.6842479573157448, 13.553142728150704] [0.2017050931562817, 4.135295317032878]
# Smiles Weight Mean and Std Dev
# 0.6466638137383571 0.07224979390491891
# Smiles Weight CI
# 0.5060293690942856 0.7601817667846001
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.02950465 18.32846366] [ 1.70697823 30.3773443 ] [1.65805782 1.65738629]
# (Manually) Weighted RMSE Train
# [ 2.5960181  62.88634719]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.8832116788321168] [0.764091437546858, 14.287377634185837] [0.2002322266424725, 4.1168837151050255]
# Smiles Weight Mean and Std Dev
# 0.6454174925886663 0.07519882165037625
# Smiles Weight CI
# 0.48877433732350445 0.7846592695893528
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.02140841 18.34649211] [ 1.69970189 30.40003208] [1.66407666 1.65699426]
# (Manually) Weighted RMSE Train
# [ 2.59698489 62.87626907]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.8852971845672576] [0.7300871391636092, 13.96037906207171] [0.19980573395054943, 4.088836282315083]
# Smiles Weight Mean and Std Dev
# 0.6450511287010068 0.07207214315518337
# Smiles Weight CI
# 0.4974380791201699 0.7739385989828091
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.01424184 18.37232407] [ 1.68405793 30.43996386] [1.66041062 1.65683796]
# (Manually) Weighted RMSE Train
# [ 2.60737812 62.94675638]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.8988529718456726] [0.7078372158666528, 14.346430228261246] [0.19760131717584523, 4.070242020651355]
# Smiles Weight Mean and Std Dev
# 0.6416157406988913 0.07404265580078159
# Smiles Weight CI
# 0.4973439563058756 0.7742194488737543
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00631885 18.54190134] [ 1.66810798 30.70986274] [1.65763364 1.6562413 ]
# (Manually) Weighted RMSE Train
# [ 2.61799888 63.0642768 ]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.9092805005213764, 0.8978102189781022] [0.7359245723895419, 14.962769255055843] [0.19760154415136605, 4.04121716956709]
# Smiles Weight Mean and Std Dev
# 0.6411355151423476 0.07870197466191632
# Smiles Weight CI
# 0.47911922093035697 0.7728473862722137
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00462386 18.61546962] [ 1.66342047 30.81644172] [1.65576445 1.65542113]
# (Manually) Weighted RMSE Train
# [ 2.62340852 63.12054118]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.9259645464025026, 0.8967674661105318] [0.7883150027273917, 14.927073582204143] [0.19471173707335454, 3.987383826003089]
# Smiles Weight Mean and Std Dev
# 0.6367346679094761 0.08211763503554147
# Smiles Weight CI
# 0.46621493739899955 0.770052690039873
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.99850813 18.64533282] [ 1.65498085 31.02882092] [1.65745357 1.66416021]
# (Manually) Weighted RMSE Train
# [ 2.63089975 63.36658603]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.8978102189781022] [0.7618505491577641, 14.44864153444299] [0.19929722943780678, 4.04700630434955]
# Smiles Weight Mean and Std Dev
# 0.6482745226295263 0.0814106549501731
# Smiles Weight CI
# 0.48465139613530656 0.7751668926093256
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.99174173 18.61968702] [ 1.64789931 31.31723316] [1.66162142 1.68194198]
# (Manually) Weighted RMSE Train
# [ 2.62933789 63.72471307]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.9207507820646507, 0.899895724713243] [0.7882215490484357, 15.332551160503876] [0.19602025346312582, 3.9871089142003275]
# Smiles Weight Mean and Std Dev
# 0.6408730264072029 0.07987578505085502
# Smiles Weight CI
# 0.4661823433680166 0.7726898370038694
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.98628594 18.79299842] [ 1.63465307 31.46269589] [1.65738251 1.67417116]
# (Manually) Weighted RMSE Train
# [ 2.6366796  63.71195545]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.8988529718456726] [0.7541002847196954, 15.093699769762011] [0.1922794812679954, 3.964346520148804]
# Smiles Weight Mean and Std Dev
# 0.6342270296778512 0.0817094154453152
# Smiles Weight CI
# 0.4818866668474095 0.769672233890307
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.98161515 18.91355867] [ 1.62716112 31.57035525] [1.65763651 1.66919171]
# (Manually) Weighted RMSE Train
# [ 2.6410524  63.79768658]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.9051094890510949, 0.9009384775808134] [0.7462440034969915, 14.927610651245603] [0.1981861903777553, 4.06905924921542]
# Smiles Weight Mean and Std Dev
# 0.6500104388354141 0.07803475800801764
# Smiles Weight CI
# 0.49995967847085193 0.7781824354814784
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97174951 18.95681001] [ 1.62110942 31.72606047] [1.66823795 1.67359701]
# (Manually) Weighted RMSE Train
# [ 2.64883644 63.96992983]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9071949947862357] [0.7368900998776013, 15.30910971611132] [0.1934898484539522, 4.010664951613639]
# Smiles Weight Mean and Std Dev
# 0.6447661579145012 0.0820656452387579
# Smiles Weight CI
# 0.4735777771989652 0.7741346445322109
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.96365583 18.91598586] [ 1.61896963 31.64840023] [1.68002888 1.6731034 ]
# (Manually) Weighted RMSE Train
# [ 2.64584285 63.95679138]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.9113660062565172, 0.8978102189781022] [0.7285546192421324, 14.975688773537257] [0.19597211621581176, 4.049353087131873]
# Smiles Weight Mean and Std Dev
# 0.6492101343715618 0.0762458264188963
# Smiles Weight CI
# 0.4707588801971913 0.766692904098864
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.96068095 19.0018104 ] [ 1.60930098 31.77054904] [1.67516696 1.67197485]
# (Manually) Weighted RMSE Train
# [ 2.65256896 63.89860878]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.9186652763295099, 0.9071949947862357] [0.7843977443407896, 15.97422153520203] [0.19609139073278134, 4.071390377656471]
# Smiles Weight Mean and Std Dev
# 0.6499308114033044 0.08623385308260277
# Smiles Weight CI
# 0.4698865354617164 0.7914469703373933
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.95398889 19.03978798] [ 1.60216961 31.73814011] [1.67944262 1.66693769]
# (Manually) Weighted RMSE Train
# [ 2.66029206 63.82836059]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.9113660062565172, 0.908237747653806] [0.7581019283317696, 15.517078409970258] [0.19148529905241, 3.939395525378778]
# Smiles Weight Mean and Std Dev
# 0.6410438995353869 0.07888638011922211
# Smiles Weight CI
# 0.47103385476746445 0.7640716805438672
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.95257177 18.99210037] [ 1.59690387 31.78234976] [1.67641317 1.67345102]
# (Manually) Weighted RMSE Train
# [ 2.66716439 63.95951273]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.9040667361835245, 0.9019812304483837] [0.7071032724244013, 15.138825248716502] [0.190954030174689, 3.9545318854483322]
# Smiles Weight Mean and Std Dev
# 0.6399777147858304 0.08096504653869593
# Smiles Weight CI
# 0.48419539438647224 0.7647267437012691
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.94907385 19.12676519] [ 1.58702921 31.82699307] [1.67218727 1.66400292]
# (Manually) Weighted RMSE Train
# [ 2.67831356 63.88182362]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9040667361835245] [0.7471821566259211, 15.210423341467333] [0.19616853649764318, 4.0636766563093945]
# Smiles Weight Mean and Std Dev
# 0.650861453972495 0.07918605497890023
# Smiles Weight CI
# 0.4830069332160847 0.7788219662247786
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.94623185 19.1352901 ] [ 1.58266146 31.90645522] [1.67259372 1.66741424]
# (Manually) Weighted RMSE Train
# [ 2.68125332 63.92554748]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.8925964546402503] [0.7461304344920612, 15.352582578844048] [0.18897671075599856, 3.9234765982144912]
# Smiles Weight Mean and Std Dev
# 0.6337207976977698 0.08165150752085892
# Smiles Weight CI
# 0.4831068204755022 0.772508216398784
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.94033148 19.19251163] [ 1.57949768 31.81788116] [1.67972434 1.6578279 ]
# (Manually) Weighted RMSE Train
# [ 2.671357   63.72912687]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.9103232533889468, 0.9019812304483837] [0.7514260165536313, 15.852823034238284] [0.19081422276757007, 3.94196299204844]
# Smiles Weight Mean and Std Dev
# 0.6416082306656868 0.080432399089176
# Smiles Weight CI
# 0.4548156451201849 0.7634196533590374
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.93733655 19.3034936 ] [ 1.5722067 32.1854711] [1.67731291 1.66733918]
# (Manually) Weighted RMSE Train
# [ 2.67457126 64.01213746]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.894681960375391] [0.6467825930034248, 14.325514738157676] [0.18857017049203506, 3.901327070930206]
# Smiles Weight Mean and Std Dev
# 0.635792787896036 0.07172321820916265
# Smiles Weight CI
# 0.5009442058717016 0.756661152805643
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.9328364  19.34900646] [ 1.56409393 32.22231157] [1.67670766 1.66532125]
# (Manually) Weighted RMSE Train
# [ 2.67285879 63.97413652]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9051094890510949] [0.697734487505096, 15.632137509105489] [0.19069309211079163, 3.9284841997297444]
# Smiles Weight Mean and Std Dev
# 0.6429032526867197 0.08195798315576014
# Smiles Weight CI
# 0.47793984841974024 0.7833745561114377
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.92690269 19.3562597 ] [ 1.55143195 32.43244389] [1.67378083 1.67555325]
# (Manually) Weighted RMSE Train
# [ 2.67845485 64.15166967]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.8967674661105318] [0.6901959426841758, 14.679117258834449] [0.19028801425105477, 3.9113284356627607]
# Smiles Weight Mean and Std Dev
# 0.6419279037659382 0.0759034960047639
# Smiles Weight CI
# 0.4948574401301972 0.7619946603642148
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.92065091 19.39650639] [ 1.5383304  32.59799862] [1.67091607 1.68061186]
# (Manually) Weighted RMSE Train
# [ 2.69247702 64.27540615]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.9165797705943691, 0.9030239833159541] [0.7623785497421693, 15.504507630408316] [0.18866610307980597, 3.8815619387556297]
# Smiles Weight Mean and Std Dev
# 0.6377662487957446 0.08505016369152256
# Smiles Weight CI
# 0.468317046605216 0.7850754749455653
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.91767256 19.49483903] [ 1.53014432 32.68266419] [1.66741863 1.67647777]
# (Manually) Weighted RMSE Train
# [ 2.69612124 64.26331911]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.8978102189781022] [0.7270915217498882, 15.343275312623852] [0.18735529600808737, 3.8351952574389316]
# Smiles Weight Mean and Std Dev
# 0.6328675124235554 0.08054639500187372
# Smiles Weight CI
# 0.46686277879197696 0.7678509855303168
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.91120748 19.60858532] [ 1.52135183 32.8788735 ] [1.66959979 1.67675908]
# (Manually) Weighted RMSE Train
# [ 2.69710848 64.27009213]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.9040667361835245] [0.6775134700422529, 14.89031636707058] [0.19160824874102597, 3.955705917663059]
# Smiles Weight Mean and Std Dev
# 0.6466057864010459 0.07868495781297823
# Smiles Weight CI
# 0.48854523044503306 0.7792366428658595
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90612552 19.63912365] [ 1.51229904 32.72164075] [1.668973   1.66614567]
# (Manually) Weighted RMSE Train
# [ 2.70596183 64.08137529]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.8832116788321168, 0.8894681960375391] [0.6445165804201385, 14.102686151717549] [0.18914213691416457, 3.897067111652942]
# Smiles Weight Mean and Std Dev
# 0.6418226210648058 0.0709255556806009
# Smiles Weight CI
# 0.4911069442625083 0.7594319717675109
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90020575 19.78536565] [ 1.50170562 32.90545564] [1.66818043 1.66312093]
# (Manually) Weighted RMSE Train
# [ 2.70662374 64.11137117]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.9051094890510949] [0.6692838666029942, 14.940435535028223] [0.18987666112397253, 3.97248917672832]
# Smiles Weight Mean and Std Dev
# 0.6461169339875009 0.07711400780347173
# Smiles Weight CI
# 0.49213895994068774 0.7749981593076013
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89519509 19.90072493] [ 1.49918855 33.08708826] [1.67470595 1.66260719]
# (Manually) Weighted RMSE Train
# [ 2.71069216 64.15185525]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.8957247132429614] [0.6966410920944289, 15.59622843339061] [0.1878768522077805, 3.9556859300235137]
# Smiles Weight Mean and Std Dev
# 0.6432095624958197 0.07902230849769548
# Smiles Weight CI
# 0.4664563492315451 0.7686764863542399
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88929451 20.02071479] [ 1.4942047  33.26978588] [1.68021356 1.66176813]
# (Manually) Weighted RMSE Train
# [ 2.71561935 64.32281912]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9019812304483837] [0.7158616773418186, 15.10425837830645] [0.18655513072768126, 3.8793116982046256]
# Smiles Weight Mean and Std Dev
# 0.6383960482630306 0.08211063379997788
# Smiles Weight CI
# 0.4587894897817558 0.7644875078438111
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89128058 20.07917243] [ 1.4900289  33.41823259] [1.67178433 1.6643232 ]
# (Manually) Weighted RMSE Train
# [ 2.72348914 64.46978975]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.9061522419186653, 0.9124087591240876] [0.702652587388283, 15.935309495378096] [0.18591287979334495, 3.8414737797943035]
# Smiles Weight Mean and Std Dev
# 0.629200412553847 0.08013859078861703
# Smiles Weight CI
# 0.45891965989249994 0.753659438841659
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88873962 20.16443604] [ 1.48875746 33.52097895] [1.67513345 1.66238118]
# (Manually) Weighted RMSE Train
# [ 2.72390256 64.4846978 ]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.8686131386861314, 0.899895724713243] [0.6218687971160117, 14.680630784556673] [0.18879288396152835, 3.911465353820897]
# Smiles Weight Mean and Std Dev
# 0.6442723831577319 0.0736541465323135
# Smiles Weight CI
# 0.4934248904223716 0.765230585300226
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88480471 20.20305315] [ 1.48658235 33.76090027] [1.68012482 1.67107912]
# (Manually) Weighted RMSE Train
# [ 2.72099681 64.68479974]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9144942648592284] [0.6882669240529194, 15.728030720769299] [0.18537635410638215, 3.8188482763953258]
# Smiles Weight Mean and Std Dev
# 0.629602357016553 0.07754848106920564
# Smiles Weight CI
# 0.4756554237509154 0.7529021637784065
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8850445  20.24227546] [ 1.47803439 33.80596595] [1.67001139 1.67006748]
# (Manually) Weighted RMSE Train
# [ 2.73086842 64.75783198]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.9197080291970803] [0.6961447568328875, 16.116939563106985] [0.18544743718176646, 3.8204291452837658]
# Smiles Weight Mean and Std Dev
# 0.6295005515165915 0.08182119947665205
# Smiles Weight CI
# 0.4728604470356673 0.7673445668513617
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88249336 20.31233897] [ 1.47008938 33.86344029] [1.6658362  1.66713643]
# (Manually) Weighted RMSE Train
# [ 2.73758766 64.73804399]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.8800834202294057, 0.9040667361835245] [0.6535127853130286, 14.959648998515657] [0.18776976987754038, 3.837818993897028]
# Smiles Weight Mean and Std Dev
# 0.6377425184154052 0.07599363222309478
# Smiles Weight CI
# 0.48561791925834796 0.7630190865786963
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.88074674 20.20920347] [ 1.4579558  33.85885692] [1.65536326 1.67541769]
# (Manually) Weighted RMSE Train
# [ 2.75068311 64.74111433]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.9071949947862357] [0.6756609564957913, 15.401969965688304] [0.18693908437674708, 3.845089522596025]
# Smiles Weight Mean and Std Dev
# 0.6349479068736166 0.07807272127479485
# Smiles Weight CI
# 0.47748966484502325 0.7724015759754528
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87812414 20.26317306] [ 1.45422318 33.88698213] [1.65605649 1.67234332]
# (Manually) Weighted RMSE Train
# [ 2.74745141 64.62929419]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.8905109489051095] [0.6422431439582286, 14.932882237107133] [0.18631656736403757, 3.8451158156212757]
# Smiles Weight Mean and Std Dev
# 0.6323611689877459 0.07604430527790589
# Smiles Weight CI
# 0.4676280803982941 0.7539839095016588
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.87674623 20.1758146 ] [ 1.44342291 33.88136789] [1.6463406  1.67930607]
# (Manually) Weighted RMSE Train
# [ 2.75206706 64.74639678]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.908237747653806] [0.693051378743157, 15.368195221460626] [0.18562467906651514, 3.8575332384328074]
# Smiles Weight Mean and Std Dev
# 0.6341694204473722 0.07810426837505628
# Smiles Weight CI
# 0.4669064049136074 0.7614510540972975
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86634745 20.38735791] [ 1.43623456 33.97945116] [1.65780434 1.66669224]
# (Manually) Weighted RMSE Train
# [ 2.74924886 64.75396158]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.908237747653806] [0.6554351841563499, 14.902534039462871] [0.18629446897373514, 3.8658502180842973]
# Smiles Weight Mean and Std Dev
# 0.6366558235551266 0.07694854206162066
# Smiles Weight CI
# 0.47787924025202094 0.7621313310591464
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86143135 20.49789475] [ 1.43049475 34.0231107 ] [1.66060216 1.65983439]
# (Manually) Weighted RMSE Train
# [ 2.75039604 64.71775892]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9228362877997914] [0.7099371386362261, 16.50850990744442] [0.18590049940624792, 3.86054654519007]
# Smiles Weight Mean and Std Dev
# 0.6365765232530187 0.08502616152459638
# Smiles Weight CI
# 0.4635036504902367 0.7837470010897732
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85762289 20.50892994] [ 1.42123426 33.96863222] [1.65717856 1.65628496]
# (Manually) Weighted RMSE Train
# [ 2.75725223 64.72969045]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9103232533889468] [0.6871247541857393, 15.741288797476871] [0.1845643200221338, 3.8010267882510917]
# Smiles Weight Mean and Std Dev
# 0.6306341263272258 0.0824043557703798
# Smiles Weight CI
# 0.4618493188602881 0.7705268205277691
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85134088 20.58080395] [ 1.4159663  34.15275846] [1.66321897 1.65944725]
# (Manually) Weighted RMSE Train
# [ 2.76032101 64.81642486]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9165797705943691] [0.6781868489450059, 15.45551668787057] [0.1855770071234518, 3.884535738263159]
# Smiles Weight Mean and Std Dev
# 0.6406280639559097 0.07934636471399907
# Smiles Weight CI
# 0.4644200629101805 0.7725222085356112
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84725342 20.77473124] [ 1.4077025  34.22835366] [1.66148931 1.6475955 ]
# (Manually) Weighted RMSE Train
# [ 2.76594702 64.68879796]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.8852971845672576, 0.9061522419186653] [0.6398671947548038, 15.089271028036908] [0.18711651624613965, 3.9571830736466427]
# Smiles Weight Mean and Std Dev
# 0.642319083750808 0.07700510895550558
# Smiles Weight CI
# 0.48135581885193995 0.7623544126054502
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84772976 20.86369496] [ 1.40645934 34.27005498] [1.65908925 1.64256883]
# (Manually) Weighted RMSE Train
# [ 2.76449232 64.72269035]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.9009384775808134, 0.9155370177267987] [0.6854243859716929, 16.00904169204042] [0.1843941784793129, 3.84087383111346]
# Smiles Weight Mean and Std Dev
# 0.6339047750132816 0.08291170496567948
# Smiles Weight CI
# 0.4624324882578844 0.7766751806337288
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84562313 21.06002091] [ 1.40068588 34.50395711] [1.65639495 1.63836291]
# (Manually) Weighted RMSE Train
# [ 2.78450833 64.70002698]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.9051094890510949, 0.9228362877997914] [0.6900428419561102, 16.467466674635233] [0.18318804406594966, 3.769885615182237]
# Smiles Weight Mean and Std Dev
# 0.6298073051876166 0.08420933910937603
# Smiles Weight CI
# 0.4589858898271644 0.7748670633386376
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84210094 21.15009302] [ 1.39211867 34.76175113] [1.65314941 1.64357438]
# (Manually) Weighted RMSE Train
# [ 2.79304399 64.83972866]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.881126173096976, 0.9071949947862357] [0.635459008710761, 15.025378194006302] [0.18331911978003165, 3.778888272656407]
# Smiles Weight Mean and Std Dev
# 0.6317273434251084 0.07394971220488887
# Smiles Weight CI
# 0.4747769511031171 0.7715512333346563
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84439042 21.17355481] [ 1.39050543 34.93713704] [1.64675651 1.65003644]
# (Manually) Weighted RMSE Train
# [ 2.80055828 64.96280379]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.8873826903023984, 0.9071949947862357] [0.6401046467296212, 15.366320943657554] [0.18383883094486272, 3.7972029299416916]
# Smiles Weight Mean and Std Dev
# 0.6345538135170504 0.07637220101186726
# Smiles Weight CI
# 0.4690858441991319 0.7558249450095054
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.84015178 21.27431887] [ 1.38521078 35.00083039] [1.64876253 1.64521509]
# (Manually) Weighted RMSE Train
# [ 2.8071728  64.86024994]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.8759124087591241, 0.8978102189781022] [0.6276853722452369, 14.905370826395128] [0.1880770860056934, 3.964816214717497]
# Smiles Weight Mean and Std Dev
# 0.6472208185582798 0.07432907191631992
# Smiles Weight CI
# 0.4947803669585788 0.7701338132041085
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83580246 21.3788624 ] [ 1.38422881 35.23318632] [1.65616742 1.64803841]
# (Manually) Weighted RMSE Train
# [ 2.80625709 64.93983577]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9040667361835245] [0.6621701805904365, 15.016866319637906] [0.18360090428598794, 3.8078142600052116]
# Smiles Weight Mean and Std Dev
# 0.6354147492957648 0.07575071153125769
# Smiles Weight CI
# 0.474425579730458 0.7618713307379129
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83397323 21.49664378] [ 1.38082123 35.22686394] [1.65571408 1.6387146 ]
# (Manually) Weighted RMSE Train
# [ 2.807191   64.82011951]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.886339937434828, 0.9144942648592284] [0.6346263139881387, 15.85462801724649] [0.1824692435549489, 3.774073095944176]
# Smiles Weight Mean and Std Dev
# 0.631911228405885 0.07935090804272063
# Smiles Weight CI
# 0.4580263799110672 0.7650409650199792
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83029795 21.66784754] [ 1.37569891 35.44484714] [1.65687378 1.63582687]
# (Manually) Weighted RMSE Train
# [ 2.81347764 64.84073707]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.913451511991658] [0.6498339406168514, 15.348152533122432] [0.18240551774080235, 3.781533821097346]
# Smiles Weight Mean and Std Dev
# 0.628539401826237 0.07562337920794268
# Smiles Weight CI
# 0.4639886539152595 0.7562258149763353
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83168214 21.76919569] [ 1.37279218 35.57298315] [1.65062121 1.63409727]
# (Manually) Weighted RMSE Train
# [ 2.82175754 64.85620762]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# ...
# [ 1.26594714 46.41543137] [ 2.18004918 79.02501073] [1.72206967 1.70255901]
# (Manually) Weighted RMSE Train
# [ 3.45937805 81.28877599]
#
#
# epoch number:  1469
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.9155370177267987] [0.840529915292417, 26.78250557310121] [0.19010658132946734, 4.872742499773426]
# Smiles Weight Mean and Std Dev
# 0.6373607220175969 0.07624076697057472
# Smiles Weight CI
# 0.48884253266815725 0.7684040141839438
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26856725 46.35649458] [ 2.17902915 79.08243707] [1.71770882 1.70596241]
# (Manually) Weighted RMSE Train
# [ 3.45414774 81.41548345]
#
#
# epoch number:  1470
# Coverages, CI Widths, RMSEs
# [0.8873826903023984, 0.9155370177267987] [0.8907053131349503, 28.759563550648156] [0.19616879024609904, 5.065769594611995]
# Smiles Weight Mean and Std Dev
# 0.6188007446134204 0.07732248437862685
# Smiles Weight CI
# 0.4590038691894585 0.7496736330875923
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27095742 46.39515808] [ 2.18266137 79.15985743] [1.71733634 1.70620946]
# (Manually) Weighted RMSE Train
# [ 3.45832868 81.42833482]
#
#
# epoch number:  1471
# Coverages, CI Widths, RMSEs
# [0.908237747653806, 0.9280500521376434] [0.9656022972519768, 30.64620366904227] [0.1939769177661143, 4.956015712093531]
# Smiles Weight Mean and Std Dev
# 0.6224329855369075 0.08547110079003595
# Smiles Weight CI
# 0.449543728021735 0.7663688839421361
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27084491 46.3492161 ] [ 2.18536222 79.38594753] [1.71961363 1.71277864]
# (Manually) Weighted RMSE Train
# [ 3.46356636 81.68195734]
#
#
# epoch number:  1472
# Coverages, CI Widths, RMSEs
# [0.8978102189781022, 0.921793534932221] [0.9131038392388844, 27.961380261025187] [0.1907998758910424, 4.837334196666018]
# Smiles Weight Mean and Std Dev
# 0.6287255090629552 0.07928665057492962
# Smiles Weight CI
# 0.4700192578490103 0.7707491593856763
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2693702  46.44750234] [ 2.18314897 79.2927961 ] [1.71986784 1.70714876]
# (Manually) Weighted RMSE Train
# [ 3.46396283 81.52594881]
#
#
# epoch number:  1473
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9176225234619395] [0.8902543972481627, 28.77820358446477] [0.19005617005028072, 4.80762626626144]
# Smiles Weight Mean and Std Dev
# 0.6318089167147517 0.07725314479034644
# Smiles Weight CI
# 0.4793471928472668 0.7570975075118104
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26854273 46.49116393] [ 2.17902846 79.42569169] [1.71774147 1.70840403]
# (Manually) Weighted RMSE Train
# [ 3.46209817 81.4937382 ]
#
#
# epoch number:  1474
# Coverages, CI Widths, RMSEs
# [0.8936392075078207, 0.9197080291970803] [0.8667603899742045, 28.30239586259608] [0.19037561643307901, 4.82537307996628]
# Smiles Weight Mean and Std Dev
# 0.6352319757624353 0.07113444047504737
# Smiles Weight CI
# 0.47379875208770145 0.7617629378025838
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26959961 46.5578999 ] [ 2.17588198 79.64610131] [1.71383321 1.7106893 ]
# (Manually) Weighted RMSE Train
# [ 3.45719958 81.5957575 ]
#
#
# epoch number:  1475
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.9144942648592284] [0.8663480442977824, 27.47416243455574] [0.19069479830895966, 4.823840578777393]
# Smiles Weight Mean and Std Dev
# 0.6292306813141824 0.07605285897221412
# Smiles Weight CI
# 0.4755162371715543 0.7548499555110858
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26871586 46.51005838] [ 2.17483984 79.54040126] [1.71420561 1.71017634]
# (Manually) Weighted RMSE Train
# [ 3.45218143 81.55014614]
#
#
# epoch number:  1476
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9228362877997914] [0.9628580946321272, 29.354660170713917] [0.1910658643126527, 4.835200950261849]
# Smiles Weight Mean and Std Dev
# 0.6276178475337112 0.07985675587151626
# Smiles Weight CI
# 0.4494638645364981 0.7487128067912318
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26981034 46.50842435] [ 2.17662759 79.5646096 ] [1.71413598 1.71075694]
# (Manually) Weighted RMSE Train
# [ 3.4561523  81.66073952]
#
#
# epoch number:  1477
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9228362877997914] [0.9406468231397191, 30.079628181660752] [0.20115926280873261, 5.230880293508652]
# Smiles Weight Mean and Std Dev
# 0.6154166294687624 0.08054149331573096
# Smiles Weight CI
# 0.44377982996996573 0.7509532965893588
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26848349 46.53087073] [ 2.18206986 79.57086142] [1.72021937 1.71006603]
# (Manually) Weighted RMSE Train
# [ 3.46440035 81.65251071]
#
#
# epoch number:  1478
# Coverages, CI Widths, RMSEs
# [0.8905109489051095, 0.9124087591240876] [0.8698189875449882, 28.20366252387005] [0.19227868039267748, 4.857222006981403]
# Smiles Weight Mean and Std Dev
# 0.6263169112837182 0.07374189193468554
# Smiles Weight CI
# 0.47813375486728543 0.7605485632071071
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26865858 46.54417788] [ 2.18024812 79.51803993] [1.718546   1.70844225]
# (Manually) Weighted RMSE Train
# [ 3.45975148 81.57607963]
#
#
# epoch number:  1479
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.9290928050052137] [0.9309757964467584, 30.263545041797478] [0.19173735962020344, 4.824315631374826]
# Smiles Weight Mean and Std Dev
# 0.6272706622910996 0.08303300293904005
# Smiles Weight CI
# 0.4640875983867501 0.7686906173703999
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26909023 46.56393901] [ 2.17846084 79.50983657] [1.71655316 1.70754103]
# (Manually) Weighted RMSE Train
# [ 3.45809862 81.55737305]
#
#
# epoch number:  1480
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9238790406673618] [0.9251697846774217, 29.990779952590838] [0.19144033980207553, 4.816595753077721]
# Smiles Weight Mean and Std Dev
# 0.6286062615297061 0.0823261525232355
# Smiles Weight CI
# 0.4592724812216777 0.7577105854707353
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2688589  46.61140717] [ 2.17889481 79.554866  ] [1.71720812 1.70676817]
# (Manually) Weighted RMSE Train
# [ 3.45856005 81.61558102]
#
#
# epoch number:  1481
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.9207507820646507] [0.8582672611679072, 28.457432156974303] [0.19238117140743005, 4.852105507037552]
# Smiles Weight Mean and Std Dev
# 0.6258524294325772 0.07495640855693546
# Smiles Weight CI
# 0.47142913136699505 0.7584310080403508
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27048794 46.62262488] [ 2.17528623 79.51882393] [1.71216598 1.70558445]
# (Manually) Weighted RMSE Train
# [ 3.45004034 81.6257101 ]
#
#
# epoch number:  1482
# Coverages, CI Widths, RMSEs
# [0.894681960375391, 0.921793534932221] [0.9016638573841924, 29.10781702161177] [0.19231912149657981, 4.824767895755981]
# Smiles Weight Mean and Std Dev
# 0.6268856061134217 0.07709125943383892
# Smiles Weight CI
# 0.45575957281517254 0.7579773289450656
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27079324 46.76879966] [ 2.17796735 79.3717553 ] [1.71386445 1.6971091 ]
# (Manually) Weighted RMSE Train
# [ 3.45332763 81.30922206]
#
#
# epoch number:  1483
# Coverages, CI Widths, RMSEs
# [0.8873826903023984, 0.913451511991658] [0.8497195598492159, 26.996341238728213] [0.191406245466962, 4.805980648573315]
# Smiles Weight Mean and Std Dev
# 0.6286507950125831 0.07263574401827134
# Smiles Weight CI
# 0.48895873618153723 0.7568273035971832
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27087662 46.80126493] [ 2.17602166 79.39836819] [1.71222101 1.69650048]
# (Manually) Weighted RMSE Train
# [ 3.44554476 81.34320246]
#
#
# epoch number:  1484
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.921793534932221] [0.8980968639540584, 28.076011069063775] [0.19478380976527268, 4.9118693420102515]
# Smiles Weight Mean and Std Dev
# 0.6217709204357963 0.07452798827642394
# Smiles Weight CI
# 0.4737142045870987 0.7579318957084964
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26987592 46.80751064] [ 2.17321228 79.37453326] [1.71135798 1.69576489]
# (Manually) Weighted RMSE Train
# [ 3.44095543 81.30892276]
#
#
# epoch number:  1485
# Coverages, CI Widths, RMSEs
# [0.9019812304483837, 0.921793534932221] [0.8726205005901907, 27.923424806094147] [0.19084911830186785, 4.822181420004116]
# Smiles Weight Mean and Std Dev
# 0.6315741532330152 0.07495976749714874
# Smiles Weight CI
# 0.47618091355350045 0.7585976416923482
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27065987 46.84451318] [ 2.17473041 79.21718119] [1.71149689 1.69106638]
# (Manually) Weighted RMSE Train
# [ 3.44323151 81.02379641]
#
#
# epoch number:  1486
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.9186652763295099] [0.8826660421418966, 28.529741106323357] [0.19138180970379853, 4.8102957512874855]
# Smiles Weight Mean and Std Dev
# 0.6312251353748618 0.07510128943698571
# Smiles Weight CI
# 0.46561918909212496 0.7563523694866418
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27038321 46.8679917 ] [ 2.16620933 79.35443846] [1.70516213 1.69314783]
# (Manually) Weighted RMSE Train
# [ 3.43253864 81.17183526]
#
#
# epoch number:  1487
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.9238790406673618] [0.9154395781713253, 30.174805861352496] [0.19169149707069696, 4.807898507324743]
# Smiles Weight Mean and Std Dev
# 0.6290354874951796 0.07998561767726048
# Smiles Weight CI
# 0.4569348068528349 0.7625014327548859
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26847123 46.81232802] [ 2.16211864 79.36725285] [1.70450743 1.69543486]
# (Manually) Weighted RMSE Train
# [ 3.42587417 81.22025279]
#
#
# epoch number:  1488
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.9186652763295099] [0.9005289378264036, 28.41650588388679] [0.1912348901090977, 4.797124701216825]
# Smiles Weight Mean and Std Dev
# 0.6305453269079734 0.07652254669669595
# Smiles Weight CI
# 0.46662284137889165 0.760475206510886
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26919716 46.81037868] [ 2.16695287 79.26085228] [1.70734142 1.69323245]
# (Manually) Weighted RMSE Train
# [ 3.4325619  81.13335386]
#
#
# epoch number:  1489
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9249217935349322] [0.9271949586820171, 29.829684488426057] [0.19221471171688378, 4.805281405778545]
# Smiles Weight Mean and Std Dev
# 0.6268628688740321 0.07886145781167604
# Smiles Weight CI
# 0.47009130710422287 0.7630899061241756
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26919202 46.80811525] [ 2.17219323 79.30290954] [1.71147722 1.69421283]
# (Manually) Weighted RMSE Train
# [ 3.44404252 81.1667424 ]
#
#
# epoch number:  1490
# Coverages, CI Widths, RMSEs
# [0.8957247132429614, 0.9176225234619395] [0.8534140346013694, 27.36876696433867] [0.1928216377164553, 4.814611296101833]
# Smiles Weight Mean and Std Dev
# 0.6252880248787772 0.07603076915765451
# Smiles Weight CI
# 0.48626055142636976 0.7547134438205002
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27076513 46.82363836] [ 2.1721516  79.25329361] [1.70932578 1.69259153]
# (Manually) Weighted RMSE Train
# [ 3.44110741 81.13876813]
#
#
# epoch number:  1491
# Coverages, CI Widths, RMSEs
# [0.8978102189781022, 0.9238790406673618] [0.9097908772167468, 29.49073384238296] [0.19660688079751928, 4.968622225503181]
# Smiles Weight Mean and Std Dev
# 0.6199750165648444 0.07536095770605733
# Smiles Weight CI
# 0.4572337078711254 0.7465151621690082
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27152893 46.80850469] [ 2.17540404 79.34463471] [1.71085689 1.69509014]
# (Manually) Weighted RMSE Train
# [ 3.44488545 81.2458765 ]
#
#
# epoch number:  1492
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.927007299270073] [0.9502945105618731, 30.57124578595756] [0.19154399587945473, 4.803562085282426]
# Smiles Weight Mean and Std Dev
# 0.6305542387509252 0.0849155769325201
# Smiles Weight CI
# 0.45476594017774397 0.7556939374787877
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27246069 46.75029964] [ 2.17804891 79.37762591] [1.71168267 1.69790625]
# (Manually) Weighted RMSE Train
# [ 3.44777429 81.43753888]
#
#
# epoch number:  1493
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9207507820646507] [0.8695673424386279, 28.204537925473794] [0.1918073329936149, 4.798182419299204]
# Smiles Weight Mean and Std Dev
# 0.6306991596299455 0.07560740143616426
# Smiles Weight CI
# 0.4671175133179472 0.7549138044418165
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27061136 46.8071057 ] [ 2.17750793 79.36832345] [1.71374821 1.6956469 ]
# (Manually) Weighted RMSE Train
# [ 3.44508876 81.32999105]
#
#
# epoch number:  1494
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9228362877997914] [0.9203163301215326, 29.56410986277155] [0.1912245924766292, 4.795540451156868]
# Smiles Weight Mean and Std Dev
# 0.6315439625993187 0.0751395434052888
# Smiles Weight CI
# 0.4698417228005815 0.763474367736839
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27109739 46.78118647] [ 2.17986442 79.38938202] [1.71494682 1.69703652]
# (Manually) Weighted RMSE Train
# [ 3.44553298 81.44893208]
#
#
# epoch number:  1495
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.9207507820646507] [0.858656006830321, 27.183337663208256] [0.19112236218683148, 4.830460614557235]
# Smiles Weight Mean and Std Dev
# 0.6349776482392362 0.07556928659326043
# Smiles Weight CI
# 0.4760446582798517 0.7548648986048941
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27084995 46.73716633] [ 2.18252096 79.53154085] [1.71737109 1.70167657]
# (Manually) Weighted RMSE Train
# [ 3.44692276 81.56845451]
#
#
# epoch number:  1496
# Coverages, CI Widths, RMSEs
# [0.8884254431699687, 0.927007299270073] [0.8832923810392217, 29.34885694611475] [0.195443470387998, 4.920861637133167]
# Smiles Weight Mean and Std Dev
# 0.6212923784626366 0.07856384090672332
# Smiles Weight CI
# 0.4617513293417805 0.7566519273268937
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26882263 46.72571083] [ 2.17919827 79.38873908] [1.71749638 1.69903759]
# (Manually) Weighted RMSE Train
# [ 3.44630395 81.46356281]
#
#
# epoch number:  1497
# Coverages, CI Widths, RMSEs
# [0.9071949947862357, 0.9290928050052137] [0.8944951404130259, 28.297724576863484] [0.19117576171385917, 4.786393852008938]
# Smiles Weight Mean and Std Dev
# 0.632110056165054 0.08122500987331416
# Smiles Weight CI
# 0.4681087178376027 0.7623689660824537
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26879674 46.70390166] [ 2.17592633 79.51303751] [1.71495266 1.7024924 ]
# (Manually) Weighted RMSE Train
# [ 3.44333055 81.51851072]
#
#
# epoch number:  1498
# Coverages, CI Widths, RMSEs
# [0.8925964546402503, 0.9249217935349322] [0.8927893658961786, 28.977788240583745] [0.19421701203139746, 4.8819972207851645]
# Smiles Weight Mean and Std Dev
# 0.6232667819844574 0.08065970948950643
# Smiles Weight CI
# 0.4590576448789026 0.7432374517026681
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.26985656 46.74386843] [ 2.17815762 79.3710818 ] [1.71527847 1.69799985]
# (Manually) Weighted RMSE Train
# [ 3.44346373 81.34414034]
#
#
# epoch number:  1499
# Coverages, CI Widths, RMSEs
# [0.9051094890510949, 0.9322210636079249] [0.9857504513842782, 32.05130871733574] [0.19244275934653512, 4.805373940761344]
# Smiles Weight Mean and Std Dev
# 0.6270781922090267 0.08533746328391353
# Smiles Weight CI
# 0.4314646003889738 0.7620590580647538
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.27129466 46.82483345] [ 2.18447639 79.53266144] [1.71830847 1.69851456]
# (Manually) Weighted RMSE Train
# [ 3.45185419 81.43264873]
#
#
# done for fold1
# train_width[0.8849060500744587, 12.54553296305571]
# smiles_weight0.6654431056812955
# rmse_train[1.282407065558226, 1.371329039117223]
# smiles_weight_ci[0.5054880662230589, 0.7834408841926216]
# CPU times: user 13h 23min 7s, sys: 8h 3min 3s, total: 21h 26min 11s
# Wall time: 4h 23min 42s

# %%
with open("..//Data/returned_stuff1_config3_prop_ratio.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
# with open("..//Data/returned_stuff_config4.pickle", "rb") as f: 
#     returned_stuff = pickle.load(f)

# %%
# with open("..//Data/returned_stuff1_config3.pickle", "rb") as f: 
#     returned_stuff1 = pickle.load(f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
# plt.xlim(0,100)
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
