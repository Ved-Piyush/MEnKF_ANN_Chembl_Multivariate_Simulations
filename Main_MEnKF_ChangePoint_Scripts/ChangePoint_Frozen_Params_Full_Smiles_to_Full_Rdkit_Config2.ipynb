# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
import warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-06-27 01:08:08.345914: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-27 01:08:08.348488: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 01:08:08.386705: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 01:08:08.387487: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 01:08:09.518890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
warnings.filterwarnings('ignore')

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens): 
    
    target_dim = 1
    
    # weights_ann_1 = ann.get_weights()
    
    # h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
samp_ann =  ann(hidden = 16, input_shape = 32, output_shape = 1)
# Out:
# 2023-06-27 01:08:11.436610: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-06-27 01:08:11.436663: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: c3101.swan.hcc.unl.edu
# 2023-06-27 01:08:11.436670: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: c3101.swan.hcc.unl.edu
# 2023-06-27 01:08:11.436774: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 525.116.4
# 2023-06-27 01:08:11.436791: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 525.116.4
# 2023-06-27 01:08:11.436797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 525.116.4

# %%
weights_ann_1 = samp_ann.get_weights()

# %%
h1  = samp_ann.layers[1].output.shape[-1]

# %%
samp_ann.count_params()
# Out:
# 545

# %%
hidden_neurons = h1

# %%
samp_ann_params = samp_ann.count_params()

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann_params, var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weight_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_L, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_D, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, weights): 
    
    target_dim = 1
    

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))

# %%
from scipy.stats import beta

# %%
fudging_beta = beta(1,9)

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens, fudging_beta):
    # samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann_params
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:, :2].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    # model_1 = np.min(model_1 -fudging_factor)
    
    model_2 = softmax_weights[:, 2:].sum(1).reshape(-1,1) +  fudging_beta.rvs(size_ens).reshape(-1,1)
    
    
    model_1_plus_model_2 = model_1 + model_2
    
    model_1 = model_1/model_1_plus_model_2
    
    model_2 = model_2/model_1_plus_model_2
    
    
    # print(np.mean(model_1 + model_2))
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                  weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                  weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2, data1_out1, data1_out2, data2_out1, data2_out2

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
reduction = 10

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 219

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
def get_predictions(data1, data2, initial_ensembles, fudging_beta  =fudging_beta): 
    _,_, weighted_alogp, weighted_psa, w1, w2, data1_out1, data1_out2, data2_out1, data2_out2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    
    weighted_smiles_alogp = np.expand_dims(data1_out1,-1)
    weighted_smiles_psa = np.expand_dims(data1_out2,-1)
    weighted_smiles_preds = np.concatenate((weighted_smiles_alogp, weighted_smiles_psa),-1)

    weighted_rdkit_alogp = np.expand_dims(data2_out1,-1)
    weighted_rdkit_psa = np.expand_dims(data2_out2,-1)
    weighted_rdkit_preds = np.concatenate((weighted_rdkit_alogp, weighted_rdkit_psa),-1)
    
    return preds, w1, w2, weighted_smiles_preds, weighted_rdkit_preds

# %%
def get_predictions_test(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation_test(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann_params + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens, fudging_beta = fudging_beta)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, y_train, size_ens = size_ens, inflation_factor = 1.0, fudging_beta = fudging_beta):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles, fudging_beta)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    inflation = np.identity(R_t.shape[0])*inflation_factor
    D_plus_cov = D + (R_t *inflation_factor)
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    return updated_ensemble

# %%
target_dim = 2

# %%
lambda_D = 1

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
with open("..//Data/smiles_heavy_catch.pickle", "rb") as f: 
    smiles_heavy_catch = pickle.load(f)

# %%
with open("..//Data/rdkit_heavy_catch.pickle", "rb") as f: 
    rdkit_heavy_catch = pickle.load(f)

# %%
catch = [ smiles_heavy_catch, rdkit_heavy_catch]

# %%
def prepare_data(idx, var_weights = 1.0, var_weight_weights = 4.0, var_L = 1.0, var_D = 1.0): 
    catch_idx = catch[idx]

    y_train_actual, y_train = catch_idx[2], catch_idx[3]

    smiles_feats_train = catch_idx[0]
    rdkit_feats_train = catch_idx[1]


    X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens, var_weights = var_weights, var_weight_weights = var_weight_weights, var_L = var_L, var_D = var_D)
    initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    return smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles

# %%
# catch_covs

# %%
from scipy.linalg import norm

# %%
def get_results(idx, var_weights = 1.0, var_weight_weights = 1.0, var_L = 1, var_D = 0.01, inflation_factor = 1.6, fudging_beta = beta(1,19), initial = False, previous_initial_ensembles = None, threshold = 0.98, epochs = 200):
    # print('var_weights' + str(var_weights))
    # print('inflation_factor' + str(inflation_factor))
    # print('var_weight_weights' + str(var_weight_weights))
    weight_catch = []
    ratio_catch = []
    smiles_feats_train, rdkit_feats_train, y_train, y_train_actual, initial_ensembles  = prepare_data(idx, var_weights = var_weights, var_weight_weights =var_weight_weights, var_L = var_L, var_D = var_D)
    # print(R_t.shape)
    if initial == True: 
        initial_ensembles = previous_initial_ensembles
    best_train_width_mean = 100000
    # print(catch_covs[idx])
    for i in range(0,epochs):
        print("epoch number: ", str(i))
        # print("\n")
    
        # c = np.zeros((2,2))
        initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles, y_train, size_ens, inflation_factor = inflation_factor, fudging_beta = fudging_beta)
        # print(inflation_factor)
        G_u_train, w1, w2, weighted_smiles_preds, weighted_rdkit_preds = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)
        
        rmse_train = np.sqrt(((y_train_actual -G_u_train.mean(0))**2).mean(0))
        
        # print("std targets rmse")
        # print(rmse_train)
        
        
        # G_u_train, w1, w2 = get_predictions_test(smiles_feats_train, rdkit_feats_train, initial_ensembles, fudging_beta)

        catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
        G_u_train = np.array(catch)
    
        y_train_cur = std_targets.inverse_transform(y_train_actual)
    
        li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
        ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
        width_train = ui_train - li_train
        avg_width_train = width_train.mean(0)
    
        ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
        coverage_train= ind_train.mean(0)
    
        averaged_targets_train = G_u_train.mean(0)
        rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))

        cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

        # est_r =  correlation_from_covariance(cov_mat_final)

        
        li_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[0][0]
        
        # print(np.percentile(w1, axis = 0, q = (2.5, 97.5)))
        
        ui_smiles_weight = np.percentile(w1, axis = 0, q = (2.5, 97.5))[1][0]      
        
        print("Coverages, CI Widths, RMSEs")
        print(coverage_train.tolist(), avg_width_train.tolist(), rmse_train.tolist())
        # print("\n")
        # # print(coverage_test.tolist(), avg_width_test.tolist(), rmse_test.tolist())
        print("Smiles Weight Mean and Std Dev")
        print(w1.mean(), w1.std())
        # print("\n")
        print("Smiles Weight CI")
        print(li_smiles_weight, ui_smiles_weight)
        # print("\n")
        # print(avg_width_train.tolist(), coverage_train.tolist(), rmse_train.tolist(), avg_width_test.tolist(), coverage_test.tolist(), rmse_test.tolist(), w1.mean())
        
        weight_catch.append(w1.mean())
        
        rmse_train = np.sqrt(((y_train_actual -weighted_smiles_preds.mean(0))**2).mean(0))
        
        # print("smiles std targets rmse")
        # print(rmse_train)
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_smiles_preds, i)  for i in range(weighted_smiles_preds.shape[0]))
        
        catch_smiles = np.array(catch_smiles)

        rmse_train = np.sqrt(((y_train_actual -weighted_rdkit_preds.mean(0))**2).mean(0))
        
        # print("rdkit std targets rmse")
        # print(rmse_train)
        
        catch_rdkit = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(weighted_rdkit_preds, i)  for i in range(weighted_rdkit_preds.shape[0]))
        
        catch_rdkit = np.array(catch_rdkit)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        averaged_rdkit_preds_train = catch_rdkit.mean(0)
        
        rmse_rdkit_train_weighted = np.sqrt(((y_train_cur -averaged_rdkit_preds_train)**2).mean(0))
    
        print("(WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE")
        print(rmse_smiles_train_weighted, rmse_rdkit_train_weighted, rmse_rdkit_train_weighted/rmse_smiles_train_weighted)
        # print("\n")
        
        ratio = rmse_rdkit_train_weighted/rmse_smiles_train_weighted
        
        ratio_catch.append(ratio)
        
        just_added = weighted_smiles_preds + weighted_rdkit_preds
        
        rmse_train = np.sqrt(((y_train_actual -just_added.mean(0))**2).mean(0))
        
        # print("(MANUALLY) std Weighted RMSE Train")
        # print(rmse_train)
        
        catch_smiles = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(just_added, i)  for i in range(just_added.shape[0]))
        
        catch_smiles = np.array(catch_smiles)
        
        averaged_smiles_preds_train = catch_smiles.mean(0)
        
        rmse_smiles_train_weighted = np.sqrt(((y_train_cur -averaged_smiles_preds_train)**2).mean(0))

        print("(Manually) Weighted RMSE Train")
        print(rmse_smiles_train_weighted)
        print("\n")
        
        if (avg_width_train.mean() < best_train_width_mean) & (coverage_train.mean() >  threshold): 
            # print("went here")
            best_train_width_mean = avg_width_train.mean()
            best_train_width = avg_width_train
            best_smiles_weight = w1.mean()
            best_coverage_train = coverage_train
            best_rmse_train = rmse_train
        
            # best_test_width = avg_width_test

            # best_coverage_test = coverage_test    
            # best_rmse_test = rmse_test
            
            best_li_smiles_weight = li_smiles_weight
            
            best_ui_smiles_weight = ui_smiles_weight
            
            best_initial_ensembles = initial_ensembles
            
            
            # best_cmd = cmd
    
        if (coverage_train.mean() < threshold) | (i == (epochs-1)):
            
            # print()
            # print(best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_test_width.tolist(), best_coverage_test.tolist(), best_rmse_test.tolist(), best_smiles_weight, flush = True)
            print("done for fold" + str(idx), flush = True)
            print("train_width" + str(best_train_width.tolist()), flush = True)
            # print("test_width" + str(best_test_width.tolist()), flush = True)
            print("smiles_weight" + str(best_smiles_weight), flush = True)
            print("rmse_train" + str(best_rmse_train.tolist()), flush = True)
            # print("rmse_test" + str(best_rmse_test.tolist()), flush = True)
            print("smiles_weight_ci" + str([best_li_smiles_weight, best_ui_smiles_weight]), flush = True)
            
            return [best_train_width.tolist(), best_coverage_train.tolist(), best_rmse_train.tolist(), best_smiles_weight, best_li_smiles_weight, best_ui_smiles_weight, best_initial_ensembles, weight_catch, ratio_catch]

# %%
# results_df[results_df["indicator"] == False]

# %%
# %%time
returned_stuff = get_results(0, var_weights = 2.0, var_weight_weights = 5.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = False, previous_initial_ensembles = None, threshold = 0.85, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [96.21390526053833, 2120.9826156189492] [2.1746530228736267, 94.22876910248127]
# Smiles Weight Mean and Std Dev
# 0.45671379533008893 0.24000339725166178
# Smiles Weight CI
# 0.06531459118204878 0.8919440662875827
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 3.55201135 45.4079087 ] [ 1.4608564  95.02682136] [0.41127582 2.09273724]
# (Manually) Weighted RMSE Train
# [ 2.17465302 94.2287691 ]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [57.56871214582109, 1287.5716240359586] [1.332500834483589, 147.47677699414186]
# Smiles Weight Mean and Std Dev
# 0.4897433764222034 0.20095104551580784
# Smiles Weight CI
# 0.13695786880466634 0.8753096395117969
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.89009157 60.93767546] [  1.19153571 133.59932346] [0.41228303 2.19239284]
# (Manually) Weighted RMSE Train
# [  1.33250083 147.47677699]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [32.478533078962215, 821.6556991237734] [1.1595323486257605, 94.62072606877372]
# Smiles Weight Mean and Std Dev
# 0.5346105141290959 0.17520064787465403
# Smiles Weight CI
# 0.1833777469504592 0.8539406066719841
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 2.16491526 52.29931707] [ 1.35368302 92.60477487] [0.62528222 1.77066891]
# (Manually) Weighted RMSE Train
# [ 1.15953235 94.62072607]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [21.49301748587639, 483.9133170332546] [1.449569332450795, 43.27681138062375]
# Smiles Weight Mean and Std Dev
# 0.5664555548851979 0.15111075098135396
# Smiles Weight CI
# 0.2298609431339595 0.8389302638127751
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.73127042 41.22975317] [ 1.49914427 53.66111304] [0.8659215  1.30151429]
# (Manually) Weighted RMSE Train
# [ 1.44956933 43.27681138]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [13.587461920873093, 306.6865646974013] [1.3899830165896265, 38.209101915630626]
# Smiles Weight Mean and Std Dev
# 0.6204347392731729 0.12360140604031755
# Smiles Weight CI
# 0.3942684247823699 0.8598259145024078
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.30576734 34.96870697] [ 2.38353371 61.06575223] [1.82538929 1.74629712]
# (Manually) Weighted RMSE Train
# [ 1.38998302 38.20910192]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [9.005189437120002, 202.9840348957807] [1.1485043286595464, 25.066277608650292]
# Smiles Weight Mean and Std Dev
# 0.637769921259846 0.09576171115038874
# Smiles Weight CI
# 0.47040887272479315 0.8114415113758734
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97606512 26.40624493] [ 2.54397225 56.56185371] [2.60635505 2.14198777]
# (Manually) Weighted RMSE Train
# [ 1.14850433 25.06627761]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [5.718310429214073, 125.7204398177237] [0.7935017574574144, 20.475920802136375]
# Smiles Weight Mean and Std Dev
# 0.6668117814949334 0.08545505170638414
# Smiles Weight CI
# 0.506256464451096 0.8445151585738184
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.74335717 20.78818641] [ 2.62524389 59.79109611] [3.531605  2.8762055]
# (Manually) Weighted RMSE Train
# [ 0.79350176 20.4759208 ]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [3.7973773920690874, 86.7495444379761] [0.4232337363334356, 9.605845435736418]
# Smiles Weight Mean and Std Dev
# 0.6787969397829549 0.07291057564006928
# Smiles Weight CI
# 0.5312173087563384 0.8165458326030427
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.63066715 17.36858523] [ 2.64573674 52.63135281] [4.1951396  3.03026137]
# (Manually) Weighted RMSE Train
# [0.42323374 9.60584544]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.8527293844490766, 59.502556171653374] [0.22610722036618155, 6.703391400996886]
# Smiles Weight Mean and Std Dev
# 0.7042048825718783 0.06864956814567921
# Smiles Weight CI
# 0.5647813340719425 0.8241666148718184
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.70165078 12.80499849] [ 2.62212005 53.01479159] [3.73707279 4.14016383]
# (Manually) Weighted RMSE Train
# [0.22610722 6.7033914 ]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [2.0606112081700076, 46.825704049259215] [0.18543534860064642, 4.719728111843575]
# Smiles Weight Mean and Std Dev
# 0.7064052836942302 0.06595837519047734
# Smiles Weight CI
# 0.5719146936980922 0.8201171946136225
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.71272221 11.15620107] [ 2.61628049 52.06115952] [3.67082776 4.66656698]
# (Manually) Weighted RMSE Train
# [0.18543535 4.71972811]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.813580229409597, 38.76555194653069] [0.17687557371749613, 4.242297116911391]
# Smiles Weight Mean and Std Dev
# 0.7046963745141289 0.06564150158261507
# Smiles Weight CI
# 0.5671676290953943 0.8171624613975343
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.61920331 11.39371141] [ 2.61813663 51.93500458] [4.22823421 4.55821661]
# (Manually) Weighted RMSE Train
# [0.17687557 4.24229712]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.4874152303717882, 31.959268406632948] [0.1729826475736495, 3.67730597871497]
# Smiles Weight Mean and Std Dev
# 0.7050050469636379 0.059892421902808746
# Smiles Weight CI
# 0.5886289689877687 0.8125688854164125
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.64490368 10.84140634] [ 2.6423378  51.77861842] [4.0972596  4.77600569]
# (Manually) Weighted RMSE Train
# [0.17298265 3.67730598]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [1.0, 1.0] [1.3214153177879957, 28.03108751999086] [0.15734748774599183, 3.202744910317005]
# Smiles Weight Mean and Std Dev
# 0.7160253375642347 0.05650559360634056
# Smiles Weight CI
# 0.5914688549319752 0.8140594676464478
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.6557402  10.18464237] [ 2.65534785 52.03191072] [4.04939008 5.10885987]
# (Manually) Weighted RMSE Train
# [0.15734749 3.20274491]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.9979144942648592, 1.0] [1.2314634933881456, 25.10937335288927] [0.1680153647400415, 3.294537980636597]
# Smiles Weight Mean and Std Dev
# 0.7044198079565414 0.0616320695237904
# Smiles Weight CI
# 0.5714399857774579 0.8157465742282608
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.67013961 10.15469903] [ 2.64398608 52.0445251 ] [3.94542576 5.12516668]
# (Manually) Weighted RMSE Train
# [0.16801536 3.29453798]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.9895724713242962, 1.0] [1.1232639255440002, 22.309012549808365] [0.1566597419938782, 2.927148868209063]
# Smiles Weight Mean and Std Dev
# 0.7159928503231785 0.06003059627658423
# Smiles Weight CI
# 0.582103393593798 0.8067942519348389
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.66870909 9.69940138] [ 2.64807384 52.18477359] [3.95997883 5.3802056 ]
# (Manually) Weighted RMSE Train
# [0.15665974 2.92714887]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.9937434827945777, 1.0] [1.1715611416380725, 21.78562121052711] [0.16023175543432522, 2.9753302716118806]
# Smiles Weight Mean and Std Dev
# 0.7114857930500369 0.062415323030669774
# Smiles Weight CI
# 0.5570031503029785 0.8055396847510371
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67699295 9.62886224] [ 2.65134572 52.27359373] [3.91635647 5.42884428]
# (Manually) Weighted RMSE Train
# [0.16023176 2.97533027]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.9843587069864442, 0.9979144942648592] [1.0205299479620218, 20.429972491518097] [0.1594804811888992, 2.9663664633399267]
# Smiles Weight Mean and Std Dev
# 0.7125046654095794 0.056199920179048575
# Smiles Weight CI
# 0.5910552355669797 0.8083797252262459
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68006793 9.58041461] [ 2.66435574 52.60438316] [3.91777881 5.49082532]
# (Manually) Weighted RMSE Train
# [0.15948048 2.96636646]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.9885297184567258, 0.9958289885297185] [1.049656075783599, 19.66206304356161] [0.15843436349657888, 2.871188472100785]
# Smiles Weight Mean and Std Dev
# 0.7141990854239615 0.05720576274539439
# Smiles Weight CI
# 0.5872359734923425 0.8049788091902799
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68189562 9.42206321] [ 2.66603214 52.63577974] [3.90973643 5.58643882]
# (Manually) Weighted RMSE Train
# [0.15843436 2.87118847]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.9822732012513035, 0.9947862356621481] [1.0309200684275228, 19.192582295418617] [0.16201368065030797, 2.9101717364960096]
# Smiles Weight Mean and Std Dev
# 0.7141378093097844 0.05774009240734654
# Smiles Weight CI
# 0.5673288555771064 0.8082725172203499
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68185706 9.51874669] [ 2.67383451 52.82400033] [3.92140035 5.54947012]
# (Manually) Weighted RMSE Train
# [0.16201368 2.91017174]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.9781021897810219, 0.9937434827945777] [0.997830558486856, 18.790856849022457] [0.16232750235803187, 2.92425755647345]
# Smiles Weight Mean and Std Dev
# 0.7124429854825258 0.0592824846404761
# Smiles Weight CI
# 0.5712206346650769 0.8023307090671767
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67646837 9.50140989] [ 2.67544869 52.90015368] [3.95502407 5.56761095]
# (Manually) Weighted RMSE Train
# [0.1623275  2.92425756]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.9749739311783108, 0.9947862356621481] [1.033894327350742, 19.58569967751378] [0.16344977723111423, 2.9720830561301987]
# Smiles Weight Mean and Std Dev
# 0.7091067754044479 0.06189188654066965
# Smiles Weight CI
# 0.5681106321561268 0.8022419689531668
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67473744 9.4797701 ] [ 2.68425637 52.92062281] [3.97822354 5.58247956]
# (Manually) Weighted RMSE Train
# [0.16344978 2.97208306]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.9708029197080292, 0.9895724713242962] [0.9514683496765381, 17.748876556488813] [0.1618875543514243, 2.964462157824819]
# Smiles Weight Mean and Std Dev
# 0.7096114315380045 0.05450896532021441
# Smiles Weight CI
# 0.5893929493670794 0.7879451442644083
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67931155 9.40541864] [ 2.68436827 52.99400454] [3.95160108 5.63441209]
# (Manually) Weighted RMSE Train
# [0.16188755 2.96446216]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.9624608967674662, 0.986444212721585] [0.9246763154604453, 17.50614690593894] [0.16020863961752094, 2.952563427221563]
# Smiles Weight Mean and Std Dev
# 0.7128523151593963 0.06079309304264336
# Smiles Weight CI
# 0.5927374903667649 0.8080115175466827
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68090806 9.46630418] [ 2.68368077 52.92947249] [3.94132621 5.59135556]
# (Manually) Weighted RMSE Train
# [0.16020864 2.95256343]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.9603753910323254, 0.9854014598540146] [0.9595881153977059, 17.34618895176247] [0.16241248457826415, 2.9386491684706657]
# Smiles Weight Mean and Std Dev
# 0.7101955493249116 0.0590442539570767
# Smiles Weight CI
# 0.5872560276337536 0.8015003803457842
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68487443 9.41546552] [ 2.68822734 53.05314546] [3.925139   5.63468108]
# (Manually) Weighted RMSE Train
# [0.16241248 2.93864917]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.9478623566214807, 0.9812304483837331] [0.9409210729651273, 17.432273237441233] [0.1609768069513507, 2.9047450111713458]
# Smiles Weight Mean and Std Dev
# 0.7111737788851658 0.06037872941753068
# Smiles Weight CI
# 0.5560031802099537 0.7953429488662186
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67901177 9.32001881] [ 2.68446462 53.10147636] [3.95348763 5.6975718 ]
# (Manually) Weighted RMSE Train
# [0.16097681 2.90474501]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.9520333680917622, 0.9791449426485923] [0.9317293158863076, 17.18606159654948] [0.16240749145926994, 2.951060193410911]
# Smiles Weight Mean and Std Dev
# 0.7104042741407202 0.05651235757092511
# Smiles Weight CI
# 0.5852841060487223 0.7982975119090843
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67956486 9.29864501] [ 2.68398845 53.18124145] [3.94956922 5.71924634]
# (Manually) Weighted RMSE Train
# [0.16240749 2.95106019]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.9478623566214807, 0.9781021897810219] [0.9219254602697559, 17.089395140922882] [0.16669858039177496, 3.015091190905238]
# Smiles Weight Mean and Std Dev
# 0.704353920800279 0.059412680603717974
# Smiles Weight CI
# 0.5757360230830938 0.7915750743440286
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.67890537 9.46706792] [ 2.68548327 53.21489398] [3.95560762 5.62105337]
# (Manually) Weighted RMSE Train
# [0.16669858 3.01509119]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.940563086548488, 0.9655891553701773] [0.8513143404391736, 15.166327664717816] [0.16302479620624322, 2.9349615659084054]
# Smiles Weight Mean and Std Dev
# 0.7107547089649958 0.05653354046395814
# Smiles Weight CI
# 0.5772252898794358 0.8067560810267566
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68288263 9.34456384] [ 2.688825   53.33499268] [3.93746287 5.70759573]
# (Manually) Weighted RMSE Train
# [0.1630248  2.93496157]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.9457768508863399, 0.9676746611053181] [0.9224206386051534, 16.645903753524834] [0.1700216316975678, 3.0543181546799874]
# Smiles Weight Mean and Std Dev
# 0.7021061980851894 0.055754839900839515
# Smiles Weight CI
# 0.5835831486355902 0.79135907254124
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68754383 9.47472631] [ 2.68715822 53.37466006] [3.9083446  5.63337223]
# (Manually) Weighted RMSE Train
# [0.17002163 3.05431815]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.9416058394160584, 0.9708029197080292] [0.8819523421841252, 16.342587577006213] [0.1624255602049612, 2.968763093901262]
# Smiles Weight Mean and Std Dev
# 0.7141621372983631 0.05707522055745373
# Smiles Weight CI
# 0.5785215912528809 0.8047123039438016
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.68787584 9.31480729] [ 2.68839682 53.42455336] [3.9082588  5.73544376]
# (Manually) Weighted RMSE Train
# [0.16242556 2.96876309]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.9447340980187695, 0.9645464025026069] [0.9270631697921219, 16.60029298471439] [0.16600122714722695, 3.0283555218180607]
# Smiles Weight Mean and Std Dev
# 0.70653350405883 0.05876436950476544
# Smiles Weight CI
# 0.5569416883067951 0.8040960659927583
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.69345253 9.39042642] [ 2.68593941 53.46415637] [3.87328521 5.69347482]
# (Manually) Weighted RMSE Train
# [0.16600123 3.02835552]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.9290928050052137, 0.9614181438998958] [0.8412868424538599, 15.423032130294759] [0.16357207028032542, 3.050483486593835]
# Smiles Weight Mean and Std Dev
# 0.713815802633346 0.05627960983331614
# Smiles Weight CI
# 0.5752191949943022 0.8017394803869394
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.69326598 9.43183754] [ 2.68286948 53.50456527] [3.8698992  5.67276154]
# (Manually) Weighted RMSE Train
# [0.16357207 3.05048349]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.9374348279457768, 0.9551616266944735] [0.8719352839949254, 15.248221158314067] [0.1633246749739645, 3.0069173317806337]
# Smiles Weight Mean and Std Dev
# 0.7100274875680711 0.058784017510101205
# Smiles Weight CI
# 0.583720905051442 0.8126693900541191
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.69317526 9.47521507] [ 2.6800353  53.53999607] [3.866317   5.65053096]
# (Manually) Weighted RMSE Train
# [0.16332467 3.00691733]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.9238790406673618, 0.9572471324296142] [0.8213747871779855, 15.199602076193344] [0.16358769950689186, 3.0306812145234963]
# Smiles Weight Mean and Std Dev
# 0.7110335136659504 0.054410777568825196
# Smiles Weight CI
# 0.5934897528504861 0.7944620070280568
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.69599121 9.4119007 ] [ 2.6814626  53.57428547] [3.85272478 5.69218559]
# (Manually) Weighted RMSE Train
# [0.1635877  3.03068121]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.9301355578727841, 0.959332638164755] [0.8594069021353082, 15.675020212756102] [0.16377482591087555, 3.05688197955353]
# Smiles Weight Mean and Std Dev
# 0.7125373572344692 0.056229586171173976
# Smiles Weight CI
# 0.589828679445979 0.7988916854232795
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.69791658 9.40675313] [ 2.68199016 53.59749035] [3.84285202 5.69776729]
# (Manually) Weighted RMSE Train
# [0.16377483 3.05688198]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.9280500521376434, 0.948905109489051] [0.9376396140363206, 16.54426735424897] [0.1674074955734147, 3.080100166747275]
# Smiles Weight Mean and Std Dev
# 0.7036305551552117 0.05818313594844104
# Smiles Weight CI
# 0.5573363143224461 0.7889835374031949
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70094662 9.37145944] [ 2.68445843 53.53069761] [3.82976155 5.71209831]
# (Manually) Weighted RMSE Train
# [0.1674075  3.08010017]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.9228362877997914, 0.9447340980187695] [0.9071929262916767, 15.728263721547924] [0.16486931508569078, 3.058596964062411]
# Smiles Weight Mean and Std Dev
# 0.7113031767633928 0.05904407806191076
# Smiles Weight CI
# 0.5610431700793761 0.798078716298418
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70071835 9.28885366] [ 2.6846413 53.5676273] [3.83127018 5.7668717 ]
# (Manually) Weighted RMSE Train
# [0.16486932 3.05859696]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.9124087591240876, 0.940563086548488] [0.8065737430997358, 14.33693508039158] [0.1660490331628549, 3.0690472784291636]
# Smiles Weight Mean and Std Dev
# 0.70592991903214 0.055177845350507335
# Smiles Weight CI
# 0.5714909253520769 0.7880157569662949
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70440145 9.34496042] [ 2.68494681 53.53296072] [3.81167131 5.72853798]
# (Manually) Weighted RMSE Train
# [0.16604903 3.06904728]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.9176225234619395, 0.9384775808133472] [0.8170447682634975, 14.46998449279476] [0.16560616468574124, 3.075033440866599]
# Smiles Weight Mean and Std Dev
# 0.7071229788039104 0.05520553650851605
# Smiles Weight CI
# 0.5946054682042248 0.7983386306652243
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.705747  9.2652055] [ 2.68548441 53.56402801] [3.80516589 5.78120237]
# (Manually) Weighted RMSE Train
# [0.16560616 3.07503344]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.913451511991658, 0.935349322210636] [0.8276447503819832, 14.406565403687177] [0.16598224125256586, 3.0699341562236477]
# Smiles Weight Mean and Std Dev
# 0.7086594485511902 0.05481839921425498
# Smiles Weight CI
# 0.5919869585542625 0.787024038749255
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70713524 9.26356176] [ 2.68511644 53.59258745] [3.79717525 5.78531118]
# (Manually) Weighted RMSE Train
# [0.16598224 3.06993416]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.9144942648592284, 0.9280500521376434] [0.8584243464509153, 14.900231421262575] [0.16749296411963177, 3.063128795768593]
# Smiles Weight Mean and Std Dev
# 0.7115276178488104 0.05660275020906508
# Smiles Weight CI
# 0.5755799872187246 0.7994440605400192
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70773641 9.24227456] [ 2.68498663 53.67811005] [3.79376643 5.80788957]
# (Manually) Weighted RMSE Train
# [0.16749296 3.0631288 ]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.8978102189781022, 0.9176225234619395] [0.7440348369534494, 13.271627453302814] [0.16785544752365042, 3.1115891824424735]
# Smiles Weight Mean and Std Dev
# 0.7115879556241693 0.04800788958244903
# Smiles Weight CI
# 0.6007579387571438 0.7855645090161935
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70728332 9.23000424] [ 2.68327927 53.66974694] [3.79378276 5.81470447]
# (Manually) Weighted RMSE Train
# [0.16785545 3.11158918]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.8967674661105318, 0.9124087591240876] [0.7148215473944004, 12.652745609119123] [0.1720963917592266, 3.196860902575302]
# Smiles Weight Mean and Std Dev
# 0.7158100532970183 0.04803340693789443
# Smiles Weight CI
# 0.6211838635479091 0.7848830982742798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70821181 9.23246927] [ 2.68437749 53.69932615] [3.79035968 5.81635579]
# (Manually) Weighted RMSE Train
# [0.17209639 3.1968609 ]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.9176225234619395] [0.7577109949749158, 13.359490020500175] [0.1666089176736376, 3.101595656757977]
# Smiles Weight Mean and Std Dev
# 0.706142139810372 0.054377808026663574
# Smiles Weight CI
# 0.5792822046049098 0.7869889190717237
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70925571 9.30310942] [ 2.68172146 53.72092204] [3.78103612 5.77451254]
# (Manually) Weighted RMSE Train
# [0.16660892 3.10159566]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.8978102189781022, 0.921793534932221] [0.8083509798356049, 14.401107685054626] [0.16754215323595287, 3.1054077053359608]
# Smiles Weight Mean and Std Dev
# 0.7061733955091024 0.05372482008589897
# Smiles Weight CI
# 0.5800989848429043 0.7873370109839772
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.70990239 9.34233133] [ 2.68008866 53.73433706] [3.77529177 5.75170535]
# (Manually) Weighted RMSE Train
# [0.16754215 3.10540771]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.899895724713243, 0.9249217935349322] [0.8028049797351501, 14.189525798291726] [0.1685094933812767, 3.116725961716474]
# Smiles Weight Mean and Std Dev
# 0.7022490985480476 0.056446991472932015
# Smiles Weight CI
# 0.5784307188216271 0.7892562780633469
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71041104 9.40766641] [ 2.68107048 53.69964358] [3.77397075 5.70807267]
# (Manually) Weighted RMSE Train
# [0.16850949 3.11672596]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.9030239833159541, 0.9197080291970803] [0.8510695362677108, 14.634709341467264] [0.16834709899884476, 3.1005975194545026]
# Smiles Weight Mean and Std Dev
# 0.7037484510713555 0.055234444031882726
# Smiles Weight CI
# 0.5689188428131502 0.7842248068502248
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71124333 9.42453499] [ 2.68263812 53.66934817] [3.77175857 5.69464151]
# (Manually) Weighted RMSE Train
# [0.1683471  3.10059752]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.8988529718456726, 0.9259645464025026] [0.8841750176126278, 16.023631557471457] [0.16927193547212802, 3.138854004578319]
# Smiles Weight Mean and Std Dev
# 0.7000016303949563 0.05800491657557937
# Smiles Weight CI
# 0.5566952858050184 0.7853203004983793
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71297454 9.50326907] [ 2.68338205 53.66122083] [3.76364359 5.64660649]
# (Manually) Weighted RMSE Train
# [0.16927194 3.138854  ]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.8717413972888426, 0.8967674661105318] [0.7081392994688601, 12.656580858042208] [0.16964698045664708, 3.1473825779521527]
# Smiles Weight Mean and Std Dev
# 0.7054043712931948 0.04781114824731067
# Smiles Weight CI
# 0.5953737613699047 0.779324989529775
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.7128567  9.50168337] [ 2.68222298 53.65431339] [3.76263977 5.64682187]
# (Manually) Weighted RMSE Train
# [0.16964698 3.14738258]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.8915537017726799, 0.9071949947862357] [0.774994670612848, 13.665644945752438] [0.17025473917847758, 3.1418001418624804]
# Smiles Weight Mean and Std Dev
# 0.7058779605105656 0.05263254050062466
# Smiles Weight CI
# 0.5944343576337755 0.7899217334252525
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71401815 9.48398694] [ 2.68438816 53.610226  ] [3.7595517  5.65270981]
# (Manually) Weighted RMSE Train
# [0.17025474 3.14180014]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.9019812304483837] [0.7684649030767765, 13.494332028789424] [0.16994675946121848, 3.140891554065659]
# Smiles Weight Mean and Std Dev
# 0.7052261939742084 0.05202871039699079
# Smiles Weight CI
# 0.5877382393395675 0.7920591090021303
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71443112 9.51519678] [ 2.68315263 53.59870797] [3.75564916 5.63295844]
# (Manually) Weighted RMSE Train
# [0.16994676 3.14089155]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.8894681960375391, 0.9019812304483837] [0.7645423027519159, 13.33626348334929] [0.1741208027859891, 3.2041613626052117]
# Smiles Weight Mean and Std Dev
# 0.7106223848067829 0.05480070736111659
# Smiles Weight CI
# 0.5963335458771387 0.7871906377069605
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71570551 9.50303661] [ 2.68568038 53.59380693] [3.75249367 5.63965068]
# (Manually) Weighted RMSE Train
# [0.1741208  3.20416136]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.8821689259645464, 0.9019812304483837] [0.8221272983412098, 13.753477206449912] [0.17491536301201313, 3.214850544398223]
# Smiles Weight Mean and Std Dev
# 0.7108547430559574 0.05393727487044462
# Smiles Weight CI
# 0.5733364973825466 0.7946580271717739
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71773405 9.47845991] [ 2.6900624  53.59868045] [3.74799329 5.65478791]
# (Manually) Weighted RMSE Train
# [0.17491536 3.21485054]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.8686131386861314, 0.8957247132429614] [0.7474594871835382, 13.489432234606301] [0.17339864104669142, 3.218653051751325]
# Smiles Weight Mean and Std Dev
# 0.6934679917650336 0.05241015585897549
# Smiles Weight CI
# 0.5712753347535805 0.7746569643472564
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71725752 9.57087823] [ 2.68951501 53.53920774] [3.74972019 5.59397022]
# (Manually) Weighted RMSE Train
# [0.17339864 3.21865305]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.8769551616266945, 0.9019812304483837] [0.7837150769415774, 13.577472047300672] [0.17051852016346636, 3.186266945301812]
# Smiles Weight Mean and Std Dev
# 0.7043619269870264 0.05288286169837985
# Smiles Weight CI
# 0.5795164672380788 0.7819582622967416
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71601295 9.50553163] [ 2.69100588 53.55905441] [3.75832012 5.63451435]
# (Manually) Weighted RMSE Train
# [0.17051852 3.18626695]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.8842544316996872, 0.908237747653806] [0.8155211938385358, 14.366232049677865] [0.17035283807126292, 3.1604658112027075]
# Smiles Weight Mean and Std Dev
# 0.6983358970372957 0.05805209455812208
# Smiles Weight CI
# 0.5702345574848511 0.7852996906038994
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71741323 9.51194142] [ 2.69080352 53.53921525] [3.75070238 5.62863173]
# (Manually) Weighted RMSE Train
# [0.17035284 3.16046581]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.8633993743482794, 0.8852971845672576] [0.7296802777282914, 12.9060705025283] [0.17007174356231683, 3.1625594044704797]
# Smiles Weight Mean and Std Dev
# 0.7012948679988099 0.050035683236438845
# Smiles Weight CI
# 0.5884699415299715 0.7797892321646559
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71894828 9.49552891] [ 2.69259941 53.5240421 ] [3.74519206 5.63676259]
# (Manually) Weighted RMSE Train
# [0.17007174 3.1625594 ]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.881126173096976, 0.9061522419186653] [0.8175291329638951, 14.73333910587923] [0.16999664733743286, 3.1744170292905207]
# Smiles Weight Mean and Std Dev
# 0.7008962849060658 0.05847029028155073
# Smiles Weight CI
# 0.5729974645691038 0.7859441366250943
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.7186771  9.53733716] [ 2.69464244 53.52124579] [3.74944807 5.61175985]
# (Manually) Weighted RMSE Train
# [0.16999665 3.17441703]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.8748696558915537, 0.8873826903023984] [0.7957566765529845, 13.694074999740204] [0.17305010512818414, 3.2025184082017324]
# Smiles Weight Mean and Std Dev
# 0.7065289963217087 0.05272692911235686
# Smiles Weight CI
# 0.5800360949973129 0.7811342060503098
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71980895 9.51405088] [ 2.69501179 53.55314263] [3.7440654  5.62884762]
# (Manually) Weighted RMSE Train
# [0.17305011 3.20251841]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.8717413972888426, 0.8832116788321168] [0.7407518586769345, 12.749460654447454] [0.1705116463889289, 3.1765428273990204]
# Smiles Weight Mean and Std Dev
# 0.7020331779403307 0.05249622349646746
# Smiles Weight CI
# 0.5875695307119413 0.7881029051019842
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.71975892 9.54718807] [ 2.6962428  53.54814824] [3.74603596 5.60878741]
# (Manually) Weighted RMSE Train
# [0.17051165 3.17654283]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.8540145985401459, 0.867570385818561] [0.7217006565796737, 12.556301332817377] [0.17275705606318276, 3.2111483890747854]
# Smiles Weight Mean and Std Dev
# 0.70591347688605 0.049468760757823194
# Smiles Weight CI
# 0.5939617076601156 0.7856624017721783
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72206681 9.5371805 ] [ 2.69756388 53.55980249] [3.73589234 5.61589481]
# (Manually) Weighted RMSE Train
# [0.17275706 3.21114839]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.8613138686131386, 0.872784150156413] [0.6954423762006965, 12.211657963940294] [0.17355073681611058, 3.219090122897943]
# Smiles Weight Mean and Std Dev
# 0.7059403541784067 0.04743289346187662
# Smiles Weight CI
# 0.5928391740030389 0.7830764061361555
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72239846 9.59277055] [ 2.694441   53.54938156] [3.72985432 5.5822644 ]
# (Manually) Weighted RMSE Train
# [0.17355074 3.21909012]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.8571428571428571, 0.886339937434828] [0.7256125995348162, 13.001386526550588] [0.17156733463494298, 3.1926614594089737]
# Smiles Weight Mean and Std Dev
# 0.7031783077139043 0.05304670954932587
# Smiles Weight CI
# 0.5942160911404858 0.792987593714714
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72162059 9.63640644] [ 2.69814403 53.55551131] [3.73900643 5.55762271]
# (Manually) Weighted RMSE Train
# [0.17156733 3.19266146]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.8748696558915537, 0.8748696558915537] [0.7548220401590899, 13.181235518034851] [0.17184615262772593, 3.196138745539297]
# Smiles Weight Mean and Std Dev
# 0.7030650360522519 0.052072372061714604
# Smiles Weight CI
# 0.5842660917168034 0.7851367377948091
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72171654 9.63551766] [ 2.69930328 53.5489605 ] [3.7401156  5.55745549]
# (Manually) Weighted RMSE Train
# [0.17184615 3.19613875]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.8717413972888426, 0.8759124087591241] [0.7644856214869027, 13.057963270409864] [0.17372527343545852, 3.2271725478626445]
# Smiles Weight Mean and Std Dev
# 0.7067009536770039 0.05385287931296119
# Smiles Weight CI
# 0.581498435137664 0.7893246524152703
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72153974 9.59171386] [ 2.70006378 53.5801425 ] [3.74208603 5.58608642]
# (Manually) Weighted RMSE Train
# [0.17372527 3.22717255]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.8633993743482794, 0.8738269030239834] [0.7703850299711309, 13.717835496320786] [0.17185135112948743, 3.210697178224862]
# Smiles Weight Mean and Std Dev
# 0.7026067534896226 0.05332595558498649
# Smiles Weight CI
# 0.5770405392751277 0.7838835893404829
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72005862 9.61519409] [ 2.7003792  53.58808068] [3.75022134 5.57327083]
# (Manually) Weighted RMSE Train
# [0.17185135 3.21069718]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.867570385818561, 0.8779979144942649] [0.7750774554389005, 13.2799437372642] [0.17177195625117586, 3.1965518312535597]
# Smiles Weight Mean and Std Dev
# 0.6982643908304851 0.053647840198152615
# Smiles Weight CI
# 0.5868606746217956 0.7965138413395889
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72169596 9.63433259] [ 2.69887271 53.58812016] [3.73962566 5.56220368]
# (Manually) Weighted RMSE Train
# [0.17177196 3.19655183]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.8592283628779979, 0.8498435870698644] [0.7010214303189264, 12.315445523975276] [0.17221792712535508, 3.204988150335097]
# Smiles Weight Mean and Std Dev
# 0.7022125598891381 0.050600070892696844
# Smiles Weight CI
# 0.60627141407661 0.7819518148936979
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72100317 9.64887861] [ 2.69777605 53.60221562] [3.74169789 5.5552793 ]
# (Manually) Weighted RMSE Train
# [0.17221793 3.20498815]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.872784150156413, 0.8925964546402503] [0.8976574696402292, 15.378289504801524] [0.171796731616267, 3.20102681390559]
# Smiles Weight Mean and Std Dev
# 0.6987800308864677 0.06286011432488656
# Smiles Weight CI
# 0.5452630584521524 0.802293789196589
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72276189 9.6445142 ] [ 2.69868866 53.58388153] [3.73385576 5.55589223]
# (Manually) Weighted RMSE Train
# [0.17179673 3.20102681]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.8529718456725756, 0.8665276329509907] [0.7415425556018311, 13.446228502826004] [0.17223188795043526, 3.2089557576681207]
# Smiles Weight Mean and Std Dev
# 0.7023872989223561 0.052261426657206136
# Smiles Weight CI
# 0.5893287780047236 0.7811414177097837
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72347843 9.65324919] [ 2.69975954 53.60946644] [3.73163792 5.55351524]
# (Manually) Weighted RMSE Train
# [0.17223189 3.20895576]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.8613138686131386, 0.8821689259645464] [0.8313113831934807, 14.188220657733279] [0.17244995111365105, 3.206655339419275]
# Smiles Weight Mean and Std Dev
# 0.7017123249492758 0.055572552313403675
# Smiles Weight CI
# 0.5693661335934895 0.7892644201465012
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72529883 9.63799828] [ 2.69619232 53.58982842] [3.71735372 5.56026541]
# (Manually) Weighted RMSE Train
# [0.17244995 3.20665534]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.8602711157455682, 0.8633993743482794] [0.7668101149133263, 13.325767895576048] [0.17376316594732139, 3.237812298034604]
# Smiles Weight Mean and Std Dev
# 0.7048766352488436 0.051465717149249315
# Smiles Weight CI
# 0.5796860985140668 0.7861558878400646
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72645982 9.61994926] [ 2.69707738 53.6315233 ] [3.71263117 5.57503183]
# (Manually) Weighted RMSE Train
# [0.17376317 3.2378123 ]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.8529718456725756, 0.8665276329509907] [0.7263478730314794, 12.786470275688881] [0.1723086579181524, 3.1891645404418876]
# Smiles Weight Mean and Std Dev
# 0.70073682132328 0.052446146834310495
# Smiles Weight CI
# 0.5912557413707553 0.7820519436452218
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.72803587 9.59090602] [ 2.69770926 53.63909585] [3.705462   5.59270372]
# (Manually) Weighted RMSE Train
# [0.17230866 3.18916454]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.8519290928050052, 0.8550573514077163] [0.7349072612861598, 12.76706189479267] [0.17789836386435057, 3.3031034223842854]
# Smiles Weight Mean and Std Dev
# 0.7089645961248521 0.04854493085349006
# Smiles Weight CI
# 0.5916570525195315 0.7853251154360419
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.73022302 9.60288677] [ 2.69706381 53.63150584] [3.69347956 5.58493577]
# (Manually) Weighted RMSE Train
# [0.17789836 3.30310342]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.8373305526590198, 0.8456725755995829] [0.728916888479546, 12.299586028966463] [0.17421717578895154, 3.241052885314768]
# Smiles Weight Mean and Std Dev
# 0.7045203209180466 0.04817722725577805
# Smiles Weight CI
# 0.5832519116343325 0.7716452836052377
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [0.73023536 9.58799707] [ 2.69821052 53.61409679] [3.69498751 5.5917932 ]
# (Manually) Weighted RMSE Train
# [0.17421718 3.24105289]
#
#
# done for fold0
# train_width[0.6954423762006965, 12.211657963940294]
# smiles_weight0.7059403541784067
# rmse_train[0.09195660190008831, 0.0745925071724438]
# smiles_weight_ci[0.5928391740030389, 0.7830764061361555]
# CPU times: user 22min 52s, sys: 14min 17s, total: 37min 9s
# Wall time: 12min 14s

# %%
with open("..//Data/returned_stuff_config1.pickle", "wb") as f: 
    pickle.dump(returned_stuff, f)

# %%
# %%time
# returned_stuff2 = get_results(2, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,4), initial = True, previous_initial_ensembles = returned_stuff[-2], threshold = 0.75)

# %%
len(returned_stuff)
# Out:
# 9

# %%
# %%time
returned_stuff1 = get_results(1, var_weights = 1.0, var_weight_weights = 3.0, var_L = 1, var_D = 1,inflation_factor =1.0, fudging_beta = beta(1,9), initial = True, previous_initial_ensembles = returned_stuff[-3], threshold = 0.40, epochs = 200)
# Out:
# epoch number:  0
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.7382690302398331] [0.8439382481427986, 14.665097680575006] [0.3449605723889284, 10.877621656133398]
# Smiles Weight Mean and Std Dev
# 0.698202441104077 0.058110366186366044
# Smiles Weight CI
# 0.5696984626293404 0.788159421605487
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.7855321  14.29175637] [ 2.64599791 52.95995481] [3.36841477 3.70562956]
# (Manually) Weighted RMSE Train
# [ 0.34496057 10.87762166]
#
#
# epoch number:  1
# Coverages, CI Widths, RMSEs
# [0.7685088633993743, 0.7049009384775808] [0.751609451764885, 12.958312772043964] [0.3409009736358215, 10.7286009557517]
# Smiles Weight Mean and Std Dev
# 0.696497602050333 0.05193489972931877
# Smiles Weight CI
# 0.5717840098717069 0.7754631616856547
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.79391602 14.49037125] [ 2.61114287 52.35013805] [3.2889409 3.6127534]
# (Manually) Weighted RMSE Train
# [ 0.34090097 10.72860096]
#
#
# epoch number:  2
# Coverages, CI Widths, RMSEs
# [0.7924921793534933, 0.7434827945776851] [0.8654835165907873, 15.014264199017658] [0.33887030501951865, 10.635776208117141]
# Smiles Weight Mean and Std Dev
# 0.7002383887787337 0.05986778097857816
# Smiles Weight CI
# 0.5357894084492194 0.792337944455315
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.80079674 14.61467558] [ 2.58146045 51.84628134] [3.22361507 3.54754925]
# (Manually) Weighted RMSE Train
# [ 0.33887031 10.63577621]
#
#
# epoch number:  3
# Coverages, CI Widths, RMSEs
# [0.7632950990615224, 0.7111574556830031] [0.7228105655624174, 12.835069832373556] [0.33534524171929075, 10.52097362151746]
# Smiles Weight Mean and Std Dev
# 0.6997064054780707 0.05200208455349104
# Smiles Weight CI
# 0.5748485537057225 0.7760331972152423
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.8053664  14.80958107] [ 2.55352955 51.32356199] [3.17064327 3.46556474]
# (Manually) Weighted RMSE Train
# [ 0.33534524 10.52097362]
#
#
# epoch number:  4
# Coverages, CI Widths, RMSEs
# [0.7580813347236705, 0.7247132429614181] [0.6823214053296135, 12.67524007927636] [0.33045129317463784, 10.3679204903041]
# Smiles Weight Mean and Std Dev
# 0.6957413591683047 0.05281154776497946
# Smiles Weight CI
# 0.5815526628735005 0.7731119194529655
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.81470623 15.01858192] [ 2.52281674 50.796174  ] [3.09659683 3.38222172]
# (Manually) Weighted RMSE Train
# [ 0.33045129 10.36792049]
#
#
# epoch number:  5
# Coverages, CI Widths, RMSEs
# [0.781021897810219, 0.7090719499478624] [0.7072626565757194, 12.21027580254178] [0.3285431262966629, 10.267345435658584]
# Smiles Weight Mean and Std Dev
# 0.6977865639043849 0.05259964414984075
# Smiles Weight CI
# 0.5836680288367118 0.7818115353621149
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82108907 15.16439198] [ 2.49647789 50.33073024] [3.0404471  3.31900747]
# (Manually) Weighted RMSE Train
# [ 0.32854313 10.26734544]
#
#
# epoch number:  6
# Coverages, CI Widths, RMSEs
# [0.7601668404588112, 0.6955161626694474] [0.64155804215225, 11.605719252603452] [0.32488688025879797, 10.143157418701263]
# Smiles Weight Mean and Std Dev
# 0.6959754107258569 0.04811757018048431
# Smiles Weight CI
# 0.5793743729112861 0.7717468689822613
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.82826361 15.30242151] [ 2.4717851  49.82392764] [2.98429758 3.25595054]
# (Manually) Weighted RMSE Train
# [ 0.32488688 10.14315742]
#
#
# epoch number:  7
# Coverages, CI Widths, RMSEs
# [0.7674661105318039, 0.7038581856100105] [0.6605162402937469, 11.482464236713394] [0.323022213935082, 10.044689926135757]
# Smiles Weight Mean and Std Dev
# 0.6987445868109715 0.051469311379490915
# Smiles Weight CI
# 0.5780720013123883 0.7777440844711184
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.83641026 15.46359642] [ 2.45116749 49.45252624] [2.93058036 3.19799644]
# (Manually) Weighted RMSE Train
# [ 0.32302221 10.04468993]
#
#
# epoch number:  8
# Coverages, CI Widths, RMSEs
# [0.7664233576642335, 0.7194994786235662] [0.6571429088373142, 11.797618291356242] [0.32064662550840123, 9.918324299868914]
# Smiles Weight Mean and Std Dev
# 0.6969676853947929 0.05032719368542242
# Smiles Weight CI
# 0.5811251803454477 0.7703653891754019
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.85136546 15.65945599] [ 2.42662387 48.98525332] [2.85027288 3.12815805]
# (Manually) Weighted RMSE Train
# [0.32064663 9.9183243 ]
#
#
# epoch number:  9
# Coverages, CI Widths, RMSEs
# [0.7768508863399375, 0.7101147028154328] [0.6557869723773063, 11.332590176732495] [0.31695248290198114, 9.784429994530724]
# Smiles Weight Mean and Std Dev
# 0.693999039705206 0.05057239985605825
# Smiles Weight CI
# 0.5873252308503485 0.7678012804470913
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.86874168 15.96078125] [ 2.39739649 48.50774598] [2.7596195  3.03918369]
# (Manually) Weighted RMSE Train
# [0.31695248 9.78442999]
#
#
# epoch number:  10
# Coverages, CI Widths, RMSEs
# [0.799791449426486, 0.7424400417101147] [0.7166304576816579, 12.223848457232524] [0.3125063799096374, 9.635174874534393]
# Smiles Weight Mean and Std Dev
# 0.6860358423868727 0.05419135569729045
# Smiles Weight CI
# 0.5544501473675498 0.7689136491195491
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.89334769 16.29460963] [ 2.36206319 47.88292028] [2.6440581  2.93857425]
# (Manually) Weighted RMSE Train
# [0.31250638 9.63517487]
#
#
# epoch number:  11
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.7288842544316997] [0.6651618857812385, 11.597540976395782] [0.31418307877855045, 9.587777163248118]
# Smiles Weight Mean and Std Dev
# 0.6946497856801928 0.05231076154341345
# Smiles Weight CI
# 0.5726299386503534 0.7759501084838103
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.90788671 16.30185299] [ 2.34499077 47.56883567] [2.58291121 2.91800176]
# (Manually) Weighted RMSE Train
# [0.31418308 9.58777716]
#
#
# epoch number:  12
# Coverages, CI Widths, RMSEs
# [0.7987486965589156, 0.7288842544316997] [0.699029708551172, 11.92870401456558] [0.31167753008691024, 9.477784769034233]
# Smiles Weight Mean and Std Dev
# 0.69248735772139 0.05549555561449819
# Smiles Weight CI
# 0.5694403911023066 0.7745153534889035
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.9280801  16.57908855] [ 2.31849829 47.08245812] [2.49816615 2.83987012]
# (Manually) Weighted RMSE Train
# [0.31167753 9.47778477]
#
#
# epoch number:  13
# Coverages, CI Widths, RMSEs
# [0.799791449426486, 0.735140771637122] [0.7117152194364752, 11.634373563026296] [0.30822094967998953, 9.34420907029424]
# Smiles Weight Mean and Std Dev
# 0.6874050830007954 0.05434872356985846
# Smiles Weight CI
# 0.5509281504692959 0.7696860173293005
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.95582705 16.96080593] [ 2.28872531 46.4588444 ] [2.39449733 2.73918849]
# (Manually) Weighted RMSE Train
# [0.30822095 9.34420907]
#
#
# epoch number:  14
# Coverages, CI Widths, RMSEs
# [0.7778936392075079, 0.7247132429614181] [0.6664690338709338, 11.56240608840317] [0.3111991915944158, 9.26429987416232]
# Smiles Weight Mean and Std Dev
# 0.6905666738933722 0.05207659012029645
# Smiles Weight CI
# 0.5648964997341791 0.7738270071819623
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 0.97474654 17.09959846] [ 2.26960235 46.01380792] [2.32840257 2.69092915]
# (Manually) Weighted RMSE Train
# [0.31119919 9.26429987]
#
#
# epoch number:  15
# Coverages, CI Widths, RMSEs
# [0.8018769551616267, 0.7434827945776851] [0.7056693331840868, 11.686720176633937] [0.3087480776424082, 9.147401159446893]
# Smiles Weight Mean and Std Dev
# 0.6870922921359203 0.05826497706390503
# Smiles Weight CI
# 0.5471075736592338 0.7697447018764076
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.00198578 17.38743551] [ 2.23902624 45.41051661] [2.23458884 2.6116857 ]
# (Manually) Weighted RMSE Train
# [0.30874808 9.14740116]
#
#
# epoch number:  16
# Coverages, CI Widths, RMSEs
# [0.7904066736183525, 0.7320125130344108] [0.6802449724122179, 11.206813167602897] [0.30914831982850677, 9.056419345072467]
# Smiles Weight Mean and Std Dev
# 0.6872882585094816 0.05736945620180043
# Smiles Weight CI
# 0.5532401023912282 0.7810577431532878
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.02295867 17.66052002] [ 2.21754506 44.80666793] [2.1677758  2.53710921]
# (Manually) Weighted RMSE Train
# [0.30914832 9.05641935]
#
#
# epoch number:  17
# Coverages, CI Widths, RMSEs
# [0.7434827945776851, 0.6934306569343066] [0.6016680508922184, 9.79629384904739] [0.3106123121635893, 8.97480439754947]
# Smiles Weight Mean and Std Dev
# 0.6871646211679944 0.04922832161646809
# Smiles Weight CI
# 0.5601093297651019 0.764447419622496
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.04550348 17.94373272] [ 2.19890409 44.27310679] [2.10320112 2.46732982]
# (Manually) Weighted RMSE Train
# [0.31061231 8.9748044 ]
#
#
# epoch number:  18
# Coverages, CI Widths, RMSEs
# [0.7872784150156413, 0.7069864442127216] [0.6802553859759808, 10.234548075374429] [0.3060454326811075, 8.843650789665746]
# Smiles Weight Mean and Std Dev
# 0.6801136343846274 0.05212145324736968
# Smiles Weight CI
# 0.5467942209162894 0.7626723366736775
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.07548284 18.36634357] [ 2.1686326  43.57644842] [2.01642697 2.37262514]
# (Manually) Weighted RMSE Train
# [0.30604543 8.84365079]
#
#
# epoch number:  19
# Coverages, CI Widths, RMSEs
# [0.7716371220020855, 0.7174139728884255] [0.6687591266830101, 10.451674075812216] [0.3186185995112323, 8.880835319372528]
# Smiles Weight Mean and Std Dev
# 0.6904629307829796 0.05316315535201221
# Smiles Weight CI
# 0.5563458545933831 0.7853309976069225
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.08724629 18.2512367 ] [ 2.16412779 43.46033718] [1.99046693 2.38122698]
# (Manually) Weighted RMSE Train
# [0.3186186  8.88083532]
#
#
# epoch number:  20
# Coverages, CI Widths, RMSEs
# [0.7789363920750783, 0.7184567257559958] [0.6585189252211106, 10.191235988286785] [0.3107558108887231, 8.741683723927734]
# Smiles Weight Mean and Std Dev
# 0.6839273912080984 0.054731894779176817
# Smiles Weight CI
# 0.5593448399184516 0.7708747181449005
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.1102261  18.66549449] [ 2.13126828 42.85304127] [1.91967049 2.29584281]
# (Manually) Weighted RMSE Train
# [0.31075581 8.74168372]
#
#
# epoch number:  21
# Coverages, CI Widths, RMSEs
# [0.7789363920750783, 0.7017726798748697] [0.6298971173581176, 9.595295005819928] [0.3063843729970974, 8.646991768756225]
# Smiles Weight Mean and Std Dev
# 0.6802023181155512 0.05239327294886462
# Smiles Weight CI
# 0.5592620682797906 0.7585054551168942
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.13241069 19.04695438] [ 2.10058198 42.2598199 ] [1.85496481 2.21871797]
# (Manually) Weighted RMSE Train
# [0.30638437 8.64699177]
#
#
# epoch number:  22
# Coverages, CI Widths, RMSEs
# [0.786235662148071, 0.7111574556830031] [0.6397080104860152, 9.924532217358971] [0.3044921846373103, 8.575592153079475]
# Smiles Weight Mean and Std Dev
# 0.6786214828523492 0.05646324610178622
# Smiles Weight CI
# 0.5570774069678958 0.7652624686726716
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.16127687 19.34932293] [ 2.07030005 41.78315992] [1.78277904 2.15941199]
# (Manually) Weighted RMSE Train
# [0.30449218 8.57559215]
#
#
# epoch number:  23
# Coverages, CI Widths, RMSEs
# [0.7497393117831074, 0.6767466110531803] [0.5988869458523982, 9.077317923960573] [0.3093341126457759, 8.563650878840402]
# Smiles Weight Mean and Std Dev
# 0.6819551329343819 0.05046146713222451
# Smiles Weight CI
# 0.5644878650340401 0.7622076346842913
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.17449457 19.42332561] [ 2.06323896 41.55301192] [1.75670371 2.1393356 ]
# (Manually) Weighted RMSE Train
# [0.30933411 8.56365088]
#
#
# epoch number:  24
# Coverages, CI Widths, RMSEs
# [0.7914494264859229, 0.6850886339937435] [0.6309420887027412, 9.535414048275884] [0.3055287942694689, 8.488500743062488]
# Smiles Weight Mean and Std Dev
# 0.6809133931433674 0.04960360180412838
# Smiles Weight CI
# 0.566347027883443 0.7579198056174403
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.18778494 19.72685578] [ 2.0458646  41.12500954] [1.72242006 2.08472196]
# (Manually) Weighted RMSE Train
# [0.30552879 8.48850074]
#
#
# epoch number:  25
# Coverages, CI Widths, RMSEs
# [0.794577685088634, 0.7132429614181439] [0.6625438114689011, 9.496792420152186] [0.2976904853977823, 8.352093752526377]
# Smiles Weight Mean and Std Dev
# 0.6724412526420385 0.05552067413278289
# Smiles Weight CI
# 0.5466864715284683 0.7554655127657242
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2175703  20.27413137] [ 2.01868903 40.55283502] [1.65796507 2.00022552]
# (Manually) Weighted RMSE Train
# [0.29769049 8.35209375]
#
#
# epoch number:  26
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.7132429614181439] [0.6646275302849803, 9.994677342753516] [0.29805926209146194, 8.332824735223483]
# Smiles Weight Mean and Std Dev
# 0.6738691180354456 0.055603814798411616
# Smiles Weight CI
# 0.5489079509932047 0.7542676630040083
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.22224815 20.39075376] [ 2.01328621 40.37204203] [1.64719923 1.97991906]
# (Manually) Weighted RMSE Train
# [0.29805926 8.33282474]
#
#
# epoch number:  27
# Coverages, CI Widths, RMSEs
# [0.7643378519290928, 0.6788321167883211] [0.6058526684552643, 9.04406709099407] [0.3025530873405906, 8.308309126953095]
# Smiles Weight Mean and Std Dev
# 0.6773889378704354 0.050156105694237035
# Smiles Weight CI
# 0.5582792524243293 0.7528706602499773
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.23926359 20.53170431] [ 2.0015944  40.09811234] [1.61514824 1.95298509]
# (Manually) Weighted RMSE Train
# [0.30255309 8.30830913]
#
#
# epoch number:  28
# Coverages, CI Widths, RMSEs
# [0.7799791449426486, 0.6840458811261731] [0.6227123053726161, 9.192865801180478] [0.3049614257684548, 8.270761309753938]
# Smiles Weight Mean and Std Dev
# 0.6785599187551792 0.050861667389141746
# Smiles Weight CI
# 0.5608336642347385 0.7613443428410649
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.24909668 20.7694815 ] [ 1.99161942 39.76841275] [1.59444777 1.91475231]
# (Manually) Weighted RMSE Train
# [0.30496143 8.27076131]
#
#
# epoch number:  29
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.7090719499478624] [0.680644758857113, 9.941544455404298] [0.29477648613256924, 8.128260253839453]
# Smiles Weight Mean and Std Dev
# 0.669387644556067 0.054469442387699206
# Smiles Weight CI
# 0.5426486612909246 0.7604862496692569
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2751672  21.38885011] [ 1.96196603 38.96625214] [1.53859512 1.8218021 ]
# (Manually) Weighted RMSE Train
# [0.29477649 8.12826025]
#
#
# epoch number:  30
# Coverages, CI Widths, RMSEs
# [0.7539103232533889, 0.6767466110531803] [0.6129225651025141, 9.152863206250807] [0.3027680185590051, 8.148125387654837]
# Smiles Weight Mean and Std Dev
# 0.6763538692944976 0.05085925320317824
# Smiles Weight CI
# 0.5601380089905583 0.7553258424615575
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.2768909  21.35726305] [ 1.96242713 38.94826636] [1.53687925 1.82365438]
# (Manually) Weighted RMSE Train
# [0.30276802 8.14812539]
#
#
# epoch number:  31
# Coverages, CI Widths, RMSEs
# [0.7935349322210636, 0.6903023983315955] [0.6487424156066426, 9.265727992008427] [0.29194746731334076, 8.006271018930574]
# Smiles Weight Mean and Std Dev
# 0.6674116125653405 0.05653341956514613
# Smiles Weight CI
# 0.5419303607460186 0.7470512099948085
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29887058 21.97241643] [ 1.93560679 38.22773871] [1.49022298 1.73980585]
# (Manually) Weighted RMSE Train
# [0.29194747 8.00627102]
#
#
# epoch number:  32
# Coverages, CI Widths, RMSEs
# [0.8029197080291971, 0.6798748696558915] [0.6814215628090683, 9.360188128899548] [0.2983249865561395, 8.01318033564759]
# Smiles Weight Mean and Std Dev
# 0.6723258890136286 0.05324024958674538
# Smiles Weight CI
# 0.5413609976254757 0.7632557775581014
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.29946701 22.01615138] [ 1.93704096 38.1750374 ] [1.49064267 1.73395598]
# (Manually) Weighted RMSE Train
# [0.29832499 8.01318034]
#
#
# epoch number:  33
# Coverages, CI Widths, RMSEs
# [0.7320125130344108, 0.6558915537017727] [0.6010962615174424, 8.53717330278771] [0.29761117560178185, 7.961571118967486]
# Smiles Weight Mean and Std Dev
# 0.6717494036833984 0.04851869334985952
# Smiles Weight CI
# 0.5687424776736385 0.7604490032175353
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31089098 22.23053246] [ 1.92496697 37.92098287] [1.46844169 1.70580632]
# (Manually) Weighted RMSE Train
# [0.29761118 7.96157112]
#
#
# epoch number:  34
# Coverages, CI Widths, RMSEs
# [0.7872784150156413, 0.6777893639207507] [0.6478930302037816, 9.030633272510713] [0.29885547020417774, 7.935330237634031]
# Smiles Weight Mean and Std Dev
# 0.6732394384126333 0.051520701099679087
# Smiles Weight CI
# 0.5503839306500272 0.7513535247736349
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.31611152 22.46812337] [ 1.91898295 37.72078063] [1.45807017 1.67885764]
# (Manually) Weighted RMSE Train
# [0.29885547 7.93533024]
#
#
# epoch number:  35
# Coverages, CI Widths, RMSEs
# [0.7403545359749739, 0.6590198123044838] [0.6092220672330778, 8.673714933976138] [0.29399418694703133, 7.8505882886217275]
# Smiles Weight Mean and Std Dev
# 0.6706697749880975 0.049659672976082356
# Smiles Weight CI
# 0.5648026116950253 0.7617940575269281
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.32927971 22.83102766] [ 1.90369053 37.2967673 ] [1.43212186 1.63360002]
# (Manually) Weighted RMSE Train
# [0.29399419 7.85058829]
#
#
# epoch number:  36
# Coverages, CI Widths, RMSEs
# [0.7726798748696558, 0.67570385818561] [0.6190699107913897, 8.954080766555645] [0.29138863411493937, 7.7972832104596055]
# Smiles Weight Mean and Std Dev
# 0.6698270906782464 0.05181785176333265
# Smiles Weight CI
# 0.546578734341819 0.7472269499376808
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33739945 23.23094312] [ 1.89098101 36.9437184 ] [1.41392388 1.59028061]
# (Manually) Weighted RMSE Train
# [0.29138863 7.79728321]
#
#
# epoch number:  37
# Coverages, CI Widths, RMSEs
# [0.748696558915537, 0.6611053180396246] [0.6133910724704719, 8.679680089445833] [0.2972933653630934, 7.806808806316227]
# Smiles Weight Mean and Std Dev
# 0.6754460980131869 0.052087250605662994
# Smiles Weight CI
# 0.5705497150383367 0.7574035373578615
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.33652329 23.35300163] [ 1.89278787 36.93469432] [1.41620268 1.58158231]
# (Manually) Weighted RMSE Train
# [0.29729337 7.80680881]
#
#
# epoch number:  38
# Coverages, CI Widths, RMSEs
# [0.7507820646506778, 0.6725755995828988] [0.6077107247972435, 9.03236644425326] [0.29239391896256006, 7.716725096638885]
# Smiles Weight Mean and Std Dev
# 0.6716787346156883 0.050632834914191335
# Smiles Weight CI
# 0.5551126212543159 0.7613575374688822
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.35190283 23.78248715] [ 1.8737147 36.4444979] [1.38598326 1.53240902]
# (Manually) Weighted RMSE Train
# [0.29239392 7.7167251 ]
#
#
# epoch number:  39
# Coverages, CI Widths, RMSEs
# [0.7559958289885297, 0.6652763295099061] [0.6086435305451916, 8.872671877749823] [0.28999027531477856, 7.666379069870346]
# Smiles Weight Mean and Std Dev
# 0.6704842272924133 0.05329511235523571
# Smiles Weight CI
# 0.5602917468687267 0.750021217111726
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.36008697 24.1709966 ] [ 1.86406985 36.11741782] [1.37055195 1.49424612]
# (Manually) Weighted RMSE Train
# [0.28999028 7.66637907]
#
#
# epoch number:  40
# Coverages, CI Widths, RMSEs
# [0.8091762252346194, 0.7038581856100105] [0.6918268214890653, 9.938214625481967] [0.2863688363234329, 7.599924448187054]
# Smiles Weight Mean and Std Dev
# 0.6693599264109666 0.055569037543177366
# Smiles Weight CI
# 0.5381208344933573 0.7541196906395469
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37008288 24.57885223] [ 1.84805057 35.67215804] [1.34886042 1.45133539]
# (Manually) Weighted RMSE Train
# [0.28636884 7.59992445]
#
#
# epoch number:  41
# Coverages, CI Widths, RMSEs
# [0.7841501564129302, 0.694473409801877] [0.6371071485012807, 9.698742100012947] [0.2827283646888775, 7.533917264779408]
# Smiles Weight Mean and Std Dev
# 0.6665502665455975 0.053438111001880936
# Smiles Weight CI
# 0.5474744515184393 0.7519342646763905
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.37432332 24.99686993] [ 1.83855539 35.22627135] [1.33778956 1.40922729]
# (Manually) Weighted RMSE Train
# [0.28272836 7.53391726]
#
#
# epoch number:  42
# Coverages, CI Widths, RMSEs
# [0.6850886339937435, 0.64859228362878] [0.5407612142890313, 8.438417583861812] [0.2857759574780179, 7.528101829071922]
# Smiles Weight Mean and Std Dev
# 0.6699049363053301 0.046865382690538866
# Smiles Weight CI
# 0.5680088097789933 0.7536773915211935
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38048437 25.17854551] [ 1.83637028 35.16172286] [1.3302362  1.39649539]
# (Manually) Weighted RMSE Train
# [0.28577596 7.52810183]
#
#
# epoch number:  43
# Coverages, CI Widths, RMSEs
# [0.799791449426486, 0.6830031282586028] [0.6496576927297013, 9.619895938485865] [0.2845340059259225, 7.4778761296483225]
# Smiles Weight Mean and Std Dev
# 0.6694429553102837 0.05215515784441175
# Smiles Weight CI
# 0.5349942700604273 0.739630758920525
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38715439 25.5176468 ] [ 1.82666307 34.81144543] [1.31684193 1.36421065]
# (Manually) Weighted RMSE Train
# [0.28453401 7.47787613]
#
#
# epoch number:  44
# Coverages, CI Widths, RMSEs
# [0.748696558915537, 0.6684045881126173] [0.627384318896344, 9.158993387200429] [0.28971231139279824, 7.503841846691358]
# Smiles Weight Mean and Std Dev
# 0.6736793759705035 0.05262382722195444
# Smiles Weight CI
# 0.5549985128960182 0.7620099445261462
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.38653832 25.68420233] [ 1.8325041  34.80385101] [1.3216397 1.3550684]
# (Manually) Weighted RMSE Train
# [0.28971231 7.50384185]
#
#
# epoch number:  45
# Coverages, CI Widths, RMSEs
# [0.762252346193952, 0.6882168925964547] [0.6357714072927034, 9.762029590427533] [0.2863708944656685, 7.444590755986398]
# Smiles Weight Mean and Std Dev
# 0.6707867029371857 0.05542857528619483
# Smiles Weight CI
# 0.5577178041973228 0.761736842946993
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.39917671 26.0614157 ] [ 1.82059151 34.3885019 ] [1.30118769 1.3195178 ]
# (Manually) Weighted RMSE Train
# [0.28637089 7.44459076]
#
#
# epoch number:  46
# Coverages, CI Widths, RMSEs
# [0.7643378519290928, 0.6736183524504692] [0.6169505027638442, 9.641719736915864] [0.2793799448270207, 7.3456258814555335]
# Smiles Weight Mean and Std Dev
# 0.6649415768408812 0.05427092948098249
# Smiles Weight CI
# 0.5466032406765483 0.7455230026385123
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.41503703 26.61685768] [ 1.79883288 33.72256485] [1.27122672 1.26696266]
# (Manually) Weighted RMSE Train
# [0.27937994 7.34562588]
#
#
# epoch number:  47
# Coverages, CI Widths, RMSEs
# [0.7601668404588112, 0.6548488008342023] [0.6186721861264088, 9.490929048030509] [0.27536177224450364, 7.269898640652545]
# Smiles Weight Mean and Std Dev
# 0.6613770609222998 0.05372043685363367
# Smiles Weight CI
# 0.5433893527961297 0.7453935821662954
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42899354 27.07385821] [ 1.78499311 33.17511879] [1.24912609 1.22535615]
# (Manually) Weighted RMSE Train
# [0.27536177 7.26989864]
#
#
# epoch number:  48
# Coverages, CI Widths, RMSEs
# [0.7466110531803962, 0.67570385818561] [0.6181348969495852, 9.746322665465714] [0.2817085428948509, 7.301208108347471]
# Smiles Weight Mean and Std Dev
# 0.6674329422920373 0.05152517960938122
# Smiles Weight CI
# 0.5393951909403248 0.7443082897110094
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.42704531 27.0933778 ] [ 1.7926853  33.28436883] [1.25622171 1.22850569]
# (Manually) Weighted RMSE Train
# [0.28170854 7.30120811]
#
#
# epoch number:  49
# Coverages, CI Widths, RMSEs
# [0.7716371220020855, 0.67570385818561] [0.6459782869262168, 10.149090185492389] [0.276270507980016, 7.222087576294503]
# Smiles Weight Mean and Std Dev
# 0.6632723493795873 0.05268749011385452
# Smiles Weight CI
# 0.540175717628286 0.7546227571643912
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4355344  27.57788357] [ 1.7793451  32.71198579] [1.23950015 1.18616738]
# (Manually) Weighted RMSE Train
# [0.27627051 7.22208758]
#
#
# epoch number:  50
# Coverages, CI Widths, RMSEs
# [0.7653806047966631, 0.6850886339937435] [0.6388315477509425, 10.352245890314057] [0.2809828226118013, 7.223960868228467]
# Smiles Weight Mean and Std Dev
# 0.6673367715250403 0.055417549698207495
# Smiles Weight CI
# 0.5408887688730919 0.7459959375899792
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.43496324 27.67241607] [ 1.78320886 32.70642048] [1.24268609 1.18191416]
# (Manually) Weighted RMSE Train
# [0.28098282 7.22396087]
#
#
# epoch number:  51
# Coverages, CI Widths, RMSEs
# [0.8102189781021898, 0.7101147028154328] [0.7013446421479143, 11.205984348043913] [0.27370460941960584, 7.128633884610103]
# Smiles Weight Mean and Std Dev
# 0.661462723646405 0.05744731042443463
# Smiles Weight CI
# 0.5301750965627661 0.7529091578377972
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44894199 28.18811421] [ 1.76353319 32.04559012] [1.21711787 1.1368476 ]
# (Manually) Weighted RMSE Train
# [0.27370461 7.12863388]
#
#
# epoch number:  52
# Coverages, CI Widths, RMSEs
# [0.7142857142857143, 0.6517205422314911] [0.5812097029207803, 9.423216781832359] [0.2783696775863535, 7.1467720818938965]
# Smiles Weight Mean and Std Dev
# 0.6664289461139791 0.05016897753678708
# Smiles Weight CI
# 0.556560811782141 0.7466081316393798
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.44763787 28.29884901] [ 1.76877417 32.07959721] [1.22183469 1.13360078]
# (Manually) Weighted RMSE Train
# [0.27836968 7.14677208]
#
#
# epoch number:  53
# Coverages, CI Widths, RMSEs
# [0.7309697601668405, 0.6642335766423357] [0.5931732198917975, 9.700998761574473] [0.27468637146054464, 7.083721046333429]
# Smiles Weight Mean and Std Dev
# 0.6630091937001495 0.050034627063914774
# Smiles Weight CI
# 0.547995460503268 0.747250051924978
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45888038 28.6877885 ] [ 1.75500133 31.59744645] [1.20297822 1.10142497]
# (Manually) Weighted RMSE Train
# [0.27468637 7.08372105]
#
#
# epoch number:  54
# Coverages, CI Widths, RMSEs
# [0.7153284671532847, 0.6642335766423357] [0.5995717556803857, 9.788434074039408] [0.2796859044537434, 7.112361596717075]
# Smiles Weight Mean and Std Dev
# 0.6679054446126577 0.04903520604081712
# Smiles Weight CI
# 0.548581590967435 0.7442497442513593
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.45644699 28.78679447] [ 1.76136199 31.67909024] [1.20935537 1.10047301]
# (Manually) Weighted RMSE Train
# [0.2796859 7.1123616]
#
#
# epoch number:  55
# Coverages, CI Widths, RMSEs
# [0.6965589155370178, 0.629822732012513] [0.5523415691687239, 9.013002122594385] [0.2755965530841234, 7.055550601328866]
# Smiles Weight Mean and Std Dev
# 0.6652196016647334 0.044734435574175994
# Smiles Weight CI
# 0.5798170496729124 0.7402294257876239
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.46536932 29.18252168] [ 1.74764649 31.23545727] [1.1926321  1.07034812]
# (Manually) Weighted RMSE Train
# [0.27559655 7.0555506 ]
#
#
# epoch number:  56
# Coverages, CI Widths, RMSEs
# [0.7038581856100105, 0.6579770594369134] [0.5737303345298717, 9.67144827065958] [0.274495206457711, 7.0215499420502905]
# Smiles Weight Mean and Std Dev
# 0.6640009851118416 0.04880379105343865
# Smiles Weight CI
# 0.5514224436187398 0.7411015053331823
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47346483 29.48537962] [ 1.74022596 30.9261986 ] [1.18104343 1.04886554]
# (Manually) Weighted RMSE Train
# [0.27449521 7.02154994]
#
#
# epoch number:  57
# Coverages, CI Widths, RMSEs
# [0.662148070907195, 0.6256517205422315] [0.5374113203949213, 8.94278611297377] [0.2741512999232249, 7.003764189893157]
# Smiles Weight Mean and Std Dev
# 0.6647809171358513 0.045893921028485905
# Smiles Weight CI
# 0.5676166187389722 0.7435040256114296
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.47696664 29.72419675] [ 1.73548673 30.73827877] [1.17503448 1.03411638]
# (Manually) Weighted RMSE Train
# [0.2741513  7.00376419]
#
#
# epoch number:  58
# Coverages, CI Widths, RMSEs
# [0.7382690302398331, 0.670490093847758] [0.6144827926206463, 10.432094273917329] [0.27095890075311474, 6.940089176812924]
# Smiles Weight Mean and Std Dev
# 0.6612643174818899 0.05122352234442377
# Smiles Weight CI
# 0.5481494255003815 0.744620684001012
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.48968573 30.0891175 ] [ 1.72125503 30.28859679] [1.15544842 1.00662962]
# (Manually) Weighted RMSE Train
# [0.2709589  6.94008918]
#
#
# epoch number:  59
# Coverages, CI Widths, RMSEs
# [0.6830031282586028, 0.6402502606882169] [0.5527512374779588, 9.549249925750553] [0.275863228873785, 6.980415316101578]
# Smiles Weight Mean and Std Dev
# 0.6661281833916672 0.046495728714480655
# Smiles Weight CI
# 0.5533168909287467 0.7365531817730046
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.4908834  30.18470498] [ 1.72569817 30.39553633] [1.15750043 1.00698471]
# (Manually) Weighted RMSE Train
# [0.27586323 6.98041532]
#
#
# epoch number:  60
# Coverages, CI Widths, RMSEs
# [0.7069864442127216, 0.662148070907195] [0.5906481975756243, 10.163807759791078] [0.27455959265197205, 6.943755437796637]
# Smiles Weight Mean and Std Dev
# 0.6646586241597966 0.05071147483163102
# Smiles Weight CI
# 0.5492688776160538 0.7436982176180134
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.49688888 30.46979885] [ 1.71960353 30.09643478] [1.14878502 0.98774642]
# (Manually) Weighted RMSE Train
# [0.27455959 6.94375544]
#
#
# epoch number:  61
# Coverages, CI Widths, RMSEs
# [0.7257559958289885, 0.6913451511991658] [0.6194002583760823, 10.951813801209653] [0.2716600533017456, 6.893946678811226]
# Smiles Weight Mean and Std Dev
# 0.6622380690839546 0.05281391433368905
# Smiles Weight CI
# 0.5474860791867501 0.7540037694816064
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.50450099 30.69941467] [ 1.70864648 29.7518099 ] [1.13568983 0.96913281]
# (Manually) Weighted RMSE Train
# [0.27166005 6.89394668]
#
#
# epoch number:  62
# Coverages, CI Widths, RMSEs
# [0.7716371220020855, 0.7038581856100105] [0.6728586576593425, 11.71706041164947] [0.2675021625583415, 6.8370880152763895]
# Smiles Weight Mean and Std Dev
# 0.6589808186968652 0.05663832827872039
# Smiles Weight CI
# 0.5256354718618759 0.7409326859083342
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51392791 31.03105515] [ 1.69413849 29.30298551] [1.11903512 0.94431161]
# (Manually) Weighted RMSE Train
# [0.26750216 6.83708802]
#
#
# epoch number:  63
# Coverages, CI Widths, RMSEs
# [0.7069864442127216, 0.6558915537017727] [0.5810058085631348, 9.888421797897475] [0.26785565088814206, 6.832669326502176]
# Smiles Weight Mean and Std Dev
# 0.6598701371599501 0.046572991257646086
# Smiles Weight CI
# 0.5558420511609511 0.7328256022420295
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51708135 31.20476475] [ 1.69084625 29.19499962] [1.11453894 0.93559429]
# (Manually) Weighted RMSE Train
# [0.26785565 6.83266933]
#
#
# epoch number:  64
# Coverages, CI Widths, RMSEs
# [0.735140771637122, 0.6788321167883211] [0.6098024631865152, 10.796522490837718] [0.27150931641928316, 6.838977291963561]
# Smiles Weight Mean and Std Dev
# 0.6622012279557518 0.050415686696001924
# Smiles Weight CI
# 0.5397942950515628 0.7310437592665897
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.51794402 31.39799405] [ 1.69637295 29.14006834] [1.11754645 0.92808694]
# (Manually) Weighted RMSE Train
# [0.27150932 6.83897729]
#
#
# epoch number:  65
# Coverages, CI Widths, RMSEs
# [0.7267987486965589, 0.662148070907195] [0.6118986425114791, 10.34958815027022] [0.2718877668273096, 6.821506264194602]
# Smiles Weight Mean and Std Dev
# 0.6621773679620586 0.050418588454079684
# Smiles Weight CI
# 0.542021280254607 0.7414574961550575
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.52244587 31.60784013] [ 1.69165258 28.9636838 ] [1.11114137 0.91634492]
# (Manually) Weighted RMSE Train
# [0.27188777 6.82150626]
#
#
# epoch number:  66
# Coverages, CI Widths, RMSEs
# [0.7340980187695516, 0.6631908237747653] [0.6020559677032378, 10.502843894095204] [0.2671289801418423, 6.761473329917505]
# Smiles Weight Mean and Std Dev
# 0.6578741647237458 0.05085821114694106
# Smiles Weight CI
# 0.540704485486636 0.7282298967713623
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53403027 31.91905943] [ 1.67524633 28.54974172] [1.09205558 0.89444182]
# (Manually) Weighted RMSE Train
# [0.26712898 6.76147333]
#
#
# epoch number:  67
# Coverages, CI Widths, RMSEs
# [0.7570385818561001, 0.6903023983315955] [0.6564947051047927, 11.756014239548058] [0.2655754965904784, 6.730372025978184]
# Smiles Weight Mean and Std Dev
# 0.6567178259811587 0.05599399126419953
# Smiles Weight CI
# 0.5348454879491954 0.7417108108265766
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.53884614 32.14548989] [ 1.66933222 28.31557614] [1.08479476 0.88085689]
# (Manually) Weighted RMSE Train
# [0.2655755  6.73037203]
#
#
# epoch number:  68
# Coverages, CI Widths, RMSEs
# [0.7434827945776851, 0.6673618352450469] [0.5967608220153583, 10.88864316124576] [0.26327306843022014, 6.684066423986732]
# Smiles Weight Mean and Std Dev
# 0.6542496941216507 0.051119039592914514
# Smiles Weight CI
# 0.5320392157713706 0.7262800758941379
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5475388  32.37283093] [ 1.65856154 27.93799597] [1.07174149 0.8630075 ]
# (Manually) Weighted RMSE Train
# [0.26327307 6.68406642]
#
#
# epoch number:  69
# Coverages, CI Widths, RMSEs
# [0.7028154327424401, 0.6725755995828988] [0.5913315321251343, 11.243562960566875] [0.26714758505102215, 6.705977629296768]
# Smiles Weight Mean and Std Dev
# 0.6573124803367648 0.050914760917412115
# Smiles Weight CI
# 0.5351335809702897 0.7372112539059658
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5449614  32.44704167] [ 1.66507289 28.0375648 ] [1.07774401 0.86410235]
# (Manually) Weighted RMSE Train
# [0.26714759 6.70597763]
#
#
# epoch number:  70
# Coverages, CI Widths, RMSEs
# [0.721584984358707, 0.6725755995828988] [0.5971881312055982, 10.940365563811259] [0.26393240200067075, 6.662423754402812]
# Smiles Weight Mean and Std Dev
# 0.6549008807986264 0.051531923522482155
# Smiles Weight CI
# 0.5405413674724264 0.737465907806224
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55039641 32.61540599] [ 1.65568906 27.73901715] [1.06791337 0.85048818]
# (Manually) Weighted RMSE Train
# [0.2639324  6.66242375]
#
#
# epoch number:  71
# Coverages, CI Widths, RMSEs
# [0.7340980187695516, 0.6767466110531803] [0.6324870749790846, 11.355129573698306] [0.2683154590464369, 6.6920629046805535]
# Smiles Weight Mean and Std Dev
# 0.6588698845530608 0.05280154949420509
# Smiles Weight CI
# 0.5366378141187594 0.7451361475285727
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.54882243 32.64905271] [ 1.66217074 27.89557734] [1.07318354 0.85440694]
# (Manually) Weighted RMSE Train
# [0.26831546 6.6920629 ]
#
#
# epoch number:  72
# Coverages, CI Widths, RMSEs
# [0.7142857142857143, 0.6579770594369134] [0.5881947253620586, 10.732452942663347] [0.2642098094709255, 6.638338727788771]
# Smiles Weight Mean and Std Dev
# 0.6552503765229315 0.051449446377727644
# Smiles Weight CI
# 0.5431687538445822 0.7316079963342018
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.5552825  32.87177123] [ 1.65071595 27.51544025] [1.06136085 0.83705378]
# (Manually) Weighted RMSE Train
# [0.26420981 6.63833873]
#
#
# epoch number:  73
# Coverages, CI Widths, RMSEs
# [0.7163712200208551, 0.6663190823774765] [0.5920613823430614, 11.083156138807235] [0.2656378199408658, 6.635747897153151]
# Smiles Weight Mean and Std Dev
# 0.6567143994944756 0.049772167710082825
# Smiles Weight CI
# 0.5446159371061188 0.7429322459675687
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.55562717 33.07166919] [ 1.65186712 27.40911298] [1.06186569 0.82877924]
# (Manually) Weighted RMSE Train
# [0.26563782 6.6357479 ]
#
#
# epoch number:  74
# Coverages, CI Widths, RMSEs
# [0.7643378519290928, 0.7049009384775808] [0.6841874240140402, 12.45711856420508] [0.2599782485046715, 6.565186321455555]
# Smiles Weight Mean and Std Dev
# 0.6512450086584692 0.05659448279685356
# Smiles Weight CI
# 0.5209585737507747 0.7422486714959332
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56410117 33.39513829] [ 1.63647307 26.85695232] [1.0462706  0.80421743]
# (Manually) Weighted RMSE Train
# [0.25997825 6.56518632]
#
#
# epoch number:  75
# Coverages, CI Widths, RMSEs
# [0.7267987486965589, 0.6871741397288843] [0.6275999571629509, 11.731552146617299] [0.26366894447057426, 6.589875231421632]
# Smiles Weight Mean and Std Dev
# 0.6547634648872447 0.05302951860136532
# Smiles Weight CI
# 0.5247789213345758 0.7361733298869573
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56423449 33.45533704] [ 1.64173194 26.9777038 ] [1.04954337 0.80637967]
# (Manually) Weighted RMSE Train
# [0.26366894 6.58987523]
#
#
# epoch number:  76
# Coverages, CI Widths, RMSEs
# [0.7247132429614181, 0.6809176225234619] [0.6255364927310004, 12.042269819524849] [0.26219674608315474, 6.567300081345784]
# Smiles Weight Mean and Std Dev
# 0.6533823250520466 0.05074149401838305
# Smiles Weight CI
# 0.5219600148814694 0.7289462426955396
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56918541 33.6161652 ] [ 1.63475537 26.75035494] [1.04178598 0.79575867]
# (Manually) Weighted RMSE Train
# [0.26219675 6.56730008]
#
#
# epoch number:  77
# Coverages, CI Widths, RMSEs
# [0.6986444212721585, 0.67570385818561] [0.5903513372237799, 11.320281006584498] [0.268629303768563, 6.6183006315704755]
# Smiles Weight Mean and Std Dev
# 0.6591343460339998 0.049609381140402954
# Smiles Weight CI
# 0.5550198529585294 0.7448686250805683
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.56550091 33.59608192] [ 1.64585363 27.02256439] [1.05132716 0.80433678]
# (Manually) Weighted RMSE Train
# [0.2686293  6.61830063]
#
#
# epoch number:  78
# Coverages, CI Widths, RMSEs
# [0.7559958289885297, 0.6955161626694474] [0.65677211255655, 12.386931820821562] [0.2646300338311936, 6.561961214214482]
# Smiles Weight Mean and Std Dev
# 0.6553114292472019 0.057823564473682955
# Smiles Weight CI
# 0.5240751129469439 0.7397750624222114
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57436356 33.86532402] [ 1.63355658 26.63099373] [1.03759806 0.78637942]
# (Manually) Weighted RMSE Train
# [0.26463003 6.56196121]
#
#
# epoch number:  79
# Coverages, CI Widths, RMSEs
# [0.6955161626694474, 0.6673618352450469] [0.5767343947408945, 11.152565728465197] [0.2610982565314791, 6.519328923721535]
# Smiles Weight Mean and Std Dev
# 0.6524370648773734 0.051290504392310095
# Smiles Weight CI
# 0.5443144837604665 0.7320838791119179
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57953341 34.04061212] [ 1.62257277 26.29473749] [1.02724815 0.77245196]
# (Manually) Weighted RMSE Train
# [0.26109826 6.51932892]
#
#
# epoch number:  80
# Coverages, CI Widths, RMSEs
# [0.6892596454640251, 0.6746611053180396] [0.5777256755392173, 11.216745163744022] [0.26947622384449116, 6.589073596966266]
# Smiles Weight Mean and Std Dev
# 0.6598482945283044 0.049546998135497664
# Smiles Weight CI
# 0.5503536583425231 0.7375696779499361
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.57293323 34.04497035] [ 1.63899217 26.65974839] [1.04199729 0.78307451]
# (Manually) Weighted RMSE Train
# [0.26947622 6.5890736 ]
#
#
# epoch number:  81
# Coverages, CI Widths, RMSEs
# [0.7038581856100105, 0.6715328467153284] [0.6005611415533189, 11.417462134632855] [0.2620255728840856, 6.497932302072523]
# Smiles Weight Mean and Std Dev
# 0.6532873490466655 0.05250787763438257
# Smiles Weight CI
# 0.5375031919051836 0.740609133671156
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58677059 34.30781615] [ 1.61775398 26.08019801] [1.01952607 0.7601824 ]
# (Manually) Weighted RMSE Train
# [0.26202557 6.4979323 ]
#
#
# epoch number:  82
# Coverages, CI Widths, RMSEs
# [0.7090719499478624, 0.6819603753910324] [0.6085461990941993, 12.173771186565277] [0.2668649083678809, 6.552675051851337]
# Smiles Weight Mean and Std Dev
# 0.6581049660610797 0.052705356210852365
# Smiles Weight CI
# 0.5341216544622348 0.7419061640529659
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.58451166 34.27842502] [ 1.6260936  26.35026467] [1.02624275 0.76871282]
# (Manually) Weighted RMSE Train
# [0.26686491 6.55267505]
#
#
# epoch number:  83
# Coverages, CI Widths, RMSEs
# [0.6913451511991658, 0.6955161626694474] [0.6176497394083165, 12.357203923954074] [0.26892461825542124, 6.553317006930039]
# Smiles Weight Mean and Std Dev
# 0.6592709359660734 0.050053486009900436
# Smiles Weight CI
# 0.5523688795097759 0.7602401008404147
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.59124764 34.34303858] [ 1.62291064 26.33061531] [1.01989822 0.7666944 ]
# (Manually) Weighted RMSE Train
# [0.26892462 6.55331701]
#
#
# epoch number:  84
# Coverages, CI Widths, RMSEs
# [0.7059436913451512, 0.6736183524504692] [0.5920631015816229, 11.734800633771535] [0.26172870508698076, 6.480462014970441]
# Smiles Weight Mean and Std Dev
# 0.6532512616068628 0.05283073419477875
# Smiles Weight CI
# 0.5377125602895005 0.7361089433417101
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60243052 34.63964592] [ 1.60398736 25.79992527] [1.00097155 0.74480915]
# (Manually) Weighted RMSE Train
# [0.26172871 6.48046201]
#
#
# epoch number:  85
# Coverages, CI Widths, RMSEs
# [0.7236704900938478, 0.6798748696558915] [0.6184684992792694, 12.074082792801327] [0.26157756994731163, 6.4725414493120494]
# Smiles Weight Mean and Std Dev
# 0.6533402647685453 0.051926869665328584
# Smiles Weight CI
# 0.5308520826569991 0.7350284851757236
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60563867 34.74171524] [ 1.60063677 25.71350927] [0.99688479 0.74013356]
# (Manually) Weighted RMSE Train
# [0.26157757 6.47254145]
#
#
# epoch number:  86
# Coverages, CI Widths, RMSEs
# [0.7361835245046924, 0.6913451511991658] [0.6359140067528677, 12.594793170237743] [0.2636607057272894, 6.485208454939838]
# Smiles Weight Mean and Std Dev
# 0.6549922496867008 0.05424754544245163
# Smiles Weight CI
# 0.5261671595242192 0.7411524539940569
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60626797 34.84752747] [ 1.60370496 25.70560312] [0.99840437 0.73765931]
# (Manually) Weighted RMSE Train
# [0.26366071 6.48520845]
#
#
# epoch number:  87
# Coverages, CI Widths, RMSEs
# [0.6819603753910324, 0.6423357664233577] [0.5345130813593579, 10.644852346975197] [0.26060689840490064, 6.446246404346272]
# Smiles Weight Mean and Std Dev
# 0.6518535898169138 0.04744900025122039
# Smiles Weight CI
# 0.5533101819509589 0.7284868245510128
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6123094  35.06276438] [ 1.59415704 25.34123929] [0.98874139 0.72273934]
# (Manually) Weighted RMSE Train
# [0.2606069 6.4462464]
#
#
# epoch number:  88
# Coverages, CI Widths, RMSEs
# [0.67570385818561, 0.6611053180396246] [0.5500906787403244, 11.0919028476356] [0.26520000429485713, 6.4906087771957175]
# Smiles Weight Mean and Std Dev
# 0.656652515223986 0.04695230465709333
# Smiles Weight CI
# 0.5506301569597151 0.7329936883359219
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.60968913 35.01357426] [ 1.60189796 25.60168075] [0.99515983 0.73119301]
# (Manually) Weighted RMSE Train
# [0.2652     6.49060878]
#
#
# epoch number:  89
# Coverages, CI Widths, RMSEs
# [0.7184567257559958, 0.6652763295099061] [0.6146426486288893, 11.90900674983375] [0.2637833041683502, 6.466038177139409]
# Smiles Weight Mean and Std Dev
# 0.6549923863364677 0.050330990132678236
# Smiles Weight CI
# 0.525416326791513 0.7278408431737254
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6149351  35.14280634] [ 1.59575271 25.41434232] [0.98812188 0.72317339]
# (Manually) Weighted RMSE Train
# [0.2637833  6.46603818]
#
#
# epoch number:  90
# Coverages, CI Widths, RMSEs
# [0.7518248175182481, 0.6871741397288843] [0.6702435910164645, 13.137484127335624] [0.257189510200855, 6.404551348207705]
# Smiles Weight Mean and Std Dev
# 0.6490839229060396 0.05564243740917918
# Smiles Weight CI
# 0.5230261341105291 0.7338818769690985
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6253659  35.38982314] [ 1.57645081 24.88046029] [0.96990518 0.70303997]
# (Manually) Weighted RMSE Train
# [0.25718951 6.40455135]
#
#
# epoch number:  91
# Coverages, CI Widths, RMSEs
# [0.6819603753910324, 0.6412930135557873] [0.5529273952284759, 11.042301839558222] [0.25992492222031316, 6.419407203969738]
# Smiles Weight Mean and Std Dev
# 0.6519478224579746 0.04595827651367215
# Smiles Weight CI
# 0.5443418786037542 0.7228551572765619
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62377619 35.41151933] [ 1.58107388 25.01428021] [0.97370185 0.70638822]
# (Manually) Weighted RMSE Train
# [0.25992492 6.4194072 ]
#
#
# epoch number:  92
# Coverages, CI Widths, RMSEs
# [0.6923879040667362, 0.6558915537017727] [0.5705202248821342, 11.299986215158187] [0.2615372320420393, 6.430518764084794]
# Smiles Weight Mean and Std Dev
# 0.6537368474669626 0.0483446797992248
# Smiles Weight CI
# 0.5360727743481738 0.7252949722782481
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62254372 35.46235823] [ 1.58385426 25.0328261 ] [0.97615506 0.70589852]
# (Manually) Weighted RMSE Train
# [0.26153723 6.43051876]
#
#
# epoch number:  93
# Coverages, CI Widths, RMSEs
# [0.7142857142857143, 0.6840458811261731] [0.6261308313808327, 12.622290920626698] [0.2589786261340477, 6.403627517064267]
# Smiles Weight Mean and Std Dev
# 0.6518193350501726 0.054615265120167844
# Smiles Weight CI
# 0.5393864880572505 0.7363473909376437
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.62854971 35.62530061] [ 1.57550788 24.79449508] [0.96743002 0.69597995]
# (Manually) Weighted RMSE Train
# [0.25897863 6.40362752]
#
#
# epoch number:  94
# Coverages, CI Widths, RMSEs
# [0.7090719499478624, 0.6965589155370178] [0.6273939727325046, 12.92994676463626] [0.25713138214934333, 6.379967022900648]
# Smiles Weight Mean and Std Dev
# 0.650044122859403 0.052561051288902164
# Smiles Weight CI
# 0.5368246498679966 0.7415560383533625
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.63310817 35.75725573] [ 1.56904185 24.56046551] [0.96077032 0.68686662]
# (Manually) Weighted RMSE Train
# [0.25713138 6.37996702]
#
#
# epoch number:  95
# Coverages, CI Widths, RMSEs
# [0.67570385818561, 0.6287799791449427] [0.5284077946648529, 10.630039178143731] [0.25608608735606275, 6.370012431008947]
# Smiles Weight Mean and Std Dev
# 0.6488072215325409 0.049107080491808196
# Smiles Weight CI
# 0.5485957088121332 0.7169908308731627
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.6378138 35.8599384] [ 1.56369804 24.41863593] [0.95474714 0.68094473]
# (Manually) Weighted RMSE Train
# [0.25608609 6.37001243]
#
#
# epoch number:  96
# Coverages, CI Widths, RMSEs
# [0.6861313868613139, 0.656934306569343] [0.5609699304191121, 10.981260029745432] [0.26131536892203444, 6.414239630005286]
# Smiles Weight Mean and Std Dev
# 0.6543540595024978 0.04815662064416463
# Smiles Weight CI
# 0.5458548293127645 0.7328087979187485
# ...
# 0.643473136964453 0.046843562943671944
# Smiles Weight CI
# 0.5295119032502414 0.7109129083988528
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76333162 39.5842193 ] [ 1.43279803 20.87107918] [0.81255165 0.52725757]
# (Manually) Weighted RMSE Train
# [0.2463674  6.18190005]
#
#
# epoch number:  169
# Coverages, CI Widths, RMSEs
# [0.6809176225234619, 0.6538060479666319] [0.5979818253995306, 13.22691657811041] [0.24707057853359782, 6.179227314839062]
# Smiles Weight Mean and Std Dev
# 0.6440570796329091 0.04819928443353268
# Smiles Weight CI
# 0.5338222084162161 0.729561931556392
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76371278 39.61062554] [ 1.43407936 20.89013356] [0.81310255 0.52738712]
# (Manually) Weighted RMSE Train
# [0.24707058 6.17922731]
#
#
# epoch number:  170
# Coverages, CI Widths, RMSEs
# [0.6809176225234619, 0.6788321167883211] [0.6092571904265052, 13.73348650010753] [0.2529078968394226, 6.207631417095721]
# Smiles Weight Mean and Std Dev
# 0.6493048687682619 0.05216060173045595
# Smiles Weight CI
# 0.5403416721828711 0.74419406649772
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.75840418 39.52257642] [ 1.44725769 21.2639332 ] [0.82305178 0.53801991]
# (Manually) Weighted RMSE Train
# [0.2529079  6.20763142]
#
#
# epoch number:  171
# Coverages, CI Widths, RMSEs
# [0.6506777893639207, 0.6266944734098019] [0.5369931096915332, 11.982637758434159] [0.24761984538592652, 6.17892949756245]
# Smiles Weight Mean and Std Dev
# 0.644603183274564 0.045715443075540096
# Smiles Weight CI
# 0.54125944966052 0.7170901679730887
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76501279 39.65538897] [ 1.43337491 20.9035398 ] [0.81210454 0.52712986]
# (Manually) Weighted RMSE Train
# [0.24761985 6.1789295 ]
#
#
# epoch number:  172
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.656934306569343] [0.5958792472157828, 13.429176863590925] [0.24400923266485933, 6.176810136888599]
# Smiles Weight Mean and Std Dev
# 0.6406087199886207 0.05149189699642752
# Smiles Weight CI
# 0.5340391218246642 0.7227932543292752
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77045941 39.76851629] [ 1.42101383 20.57096758] [0.80262435 0.51726767]
# (Manually) Weighted RMSE Train
# [0.24400923 6.17681014]
#
#
# epoch number:  173
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.6694473409801877] [0.6057872325429706, 13.568089397518888] [0.2480131583030161, 6.17656048212434]
# Smiles Weight Mean and Std Dev
# 0.6450615240941134 0.05089556010578617
# Smiles Weight CI
# 0.5322514584285535 0.7326822493867513
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76657607 39.7067356 ] [ 1.4319822  20.87749129] [0.81059753 0.52579219]
# (Manually) Weighted RMSE Train
# [0.24801316 6.17656048]
#
#
# epoch number:  174
# Coverages, CI Widths, RMSEs
# [0.6965589155370178, 0.6652763295099061] [0.6190811598601552, 14.044829461844838] [0.24247648048154577, 6.1809874320998]
# Smiles Weight Mean and Std Dev
# 0.6385295057484186 0.05181067527633023
# Smiles Weight CI
# 0.5159168339728423 0.720102638483006
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77501955 39.87675297] [ 1.41353116 20.38397562] [0.79634682 0.51117441]
# (Manually) Weighted RMSE Train
# [0.24247648 6.18098743]
#
#
# epoch number:  175
# Coverages, CI Widths, RMSEs
# [0.6767466110531803, 0.6579770594369134] [0.5910274430187608, 13.1977552397145] [0.2483249974606742, 6.1739353089797]
# Smiles Weight Mean and Std Dev
# 0.6454634706078866 0.04883140527956053
# Smiles Weight CI
# 0.5364159452052779 0.7246140745072923
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.76789106 39.75263152] [ 1.43095615 20.863629  ] [0.80941421 0.52483642]
# (Manually) Weighted RMSE Train
# [0.248325   6.17393531]
#
#
# epoch number:  176
# Coverages, CI Widths, RMSEs
# [0.6736183524504692, 0.6611053180396246] [0.5792164867349513, 13.216495330626051] [0.24341647016649814, 6.171373543463323]
# Smiles Weight Mean and Std Dev
# 0.6402312113945682 0.05149627667160389
# Smiles Weight CI
# 0.539598681679636 0.730726843671536
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7741611  39.89573586] [ 1.41605256 20.45087612] [0.79815331 0.51260807]
# (Manually) Weighted RMSE Train
# [0.24341647 6.17137354]
#
#
# epoch number:  177
# Coverages, CI Widths, RMSEs
# [0.6819603753910324, 0.6423357664233577] [0.6071645847885904, 13.60518932862259] [0.24238406400810228, 6.175912667095782]
# Smiles Weight Mean and Std Dev
# 0.6386000039318612 0.052978674101531786
# Smiles Weight CI
# 0.5161307771307266 0.7174003521504232
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77688374 39.96191111] [ 1.41119022 20.32014703] [0.79419389 0.50848787]
# (Manually) Weighted RMSE Train
# [0.24238406 6.17591267]
#
#
# epoch number:  178
# Coverages, CI Widths, RMSEs
# [0.6965589155370178, 0.6496350364963503] [0.6213584485185614, 13.654335147605098] [0.2455145857020115, 6.161866010676488]
# Smiles Weight Mean and Std Dev
# 0.6427872419731382 0.05083259881743585
# Smiles Weight CI
# 0.5235944993394019 0.7235854207059983
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77300254 39.90176661] [ 1.42138549 20.59051448] [0.80168271 0.51603015]
# (Manually) Weighted RMSE Train
# [0.24551459 6.16186601]
#
#
# epoch number:  179
# Coverages, CI Widths, RMSEs
# [0.7007299270072993, 0.6788321167883211] [0.6383913619265023, 14.23785747206139] [0.24811989496938, 6.166943071698498]
# Smiles Weight Mean and Std Dev
# 0.6452744970282354 0.054912842665190295
# Smiles Weight CI
# 0.5277858869490138 0.7341456237527854
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77094486 39.88184841] [ 1.4275559  20.76344251] [0.80609845 0.52062388]
# (Manually) Weighted RMSE Train
# [0.24811989 6.16694307]
#
#
# epoch number:  180
# Coverages, CI Widths, RMSEs
# [0.6819603753910324, 0.6496350364963503] [0.597368196349978, 13.266416085150132] [0.2464435759561243, 6.158553946924627]
# Smiles Weight Mean and Std Dev
# 0.6434458291061731 0.049492774588932996
# Smiles Weight CI
# 0.5301975652229387 0.7233148957026256
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77458641 39.94041078] [ 1.42224237 20.59886007] [0.80145005 0.51573982]
# (Manually) Weighted RMSE Train
# [0.24644358 6.15855395]
#
#
# epoch number:  181
# Coverages, CI Widths, RMSEs
# [0.6903023983315955, 0.6538060479666319] [0.6244713021837517, 14.064906941919228] [0.24470582832145443, 6.15708138756571]
# Smiles Weight Mean and Std Dev
# 0.6416423777147217 0.051602825152046505
# Smiles Weight CI
# 0.514745675450087 0.7193816480254742
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77757761 40.003756  ] [ 1.41629306 20.46470492] [0.79675455 0.51156959]
# (Manually) Weighted RMSE Train
# [0.24470583 6.15708139]
#
#
# epoch number:  182
# Coverages, CI Widths, RMSEs
# [0.6882168925964547, 0.6715328467153284] [0.6211386434796304, 13.892860679175243] [0.2456770793685484, 6.156088781650604]
# Smiles Weight Mean and Std Dev
# 0.6427925324982909 0.05181843316785152
# Smiles Weight CI
# 0.526171421929534 0.7289056489889192
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77715485 40.00366792] [ 1.41817559 20.53130734] [0.79800338 0.51323562]
# (Manually) Weighted RMSE Train
# [0.24567708 6.15608878]
#
#
# epoch number:  183
# Coverages, CI Widths, RMSEs
# [0.6903023983315955, 0.6715328467153284] [0.6107293948170152, 14.010596977989014] [0.2413672476621979, 6.17650838670477]
# Smiles Weight Mean and Std Dev
# 0.6366980302837362 0.05458035102486264
# Smiles Weight CI
# 0.5263320554758989 0.7252760292557167
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7856192  40.15380695] [ 1.40162778 20.08155149] [0.78495335 0.50011576]
# (Manually) Weighted RMSE Train
# [0.24136725 6.17650839]
#
#
# epoch number:  184
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.6746611053180396] [0.6130822711612748, 13.638652749119576] [0.25269130013706115, 6.180316404867315]
# Smiles Weight Mean and Std Dev
# 0.6488640477291904 0.05062433963220305
# Smiles Weight CI
# 0.5379575405262335 0.7306543406169939
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7731331  39.92875781] [ 1.43341158 20.94329327] [0.80840608 0.52451652]
# (Manually) Weighted RMSE Train
# [0.2526913 6.1803164]
#
#
# epoch number:  185
# Coverages, CI Widths, RMSEs
# [0.6871741397288843, 0.6590198123044838] [0.6202270336634444, 13.949394043563483] [0.2498188959090642, 6.162757495490683]
# Smiles Weight Mean and Std Dev
# 0.6466517542712316 0.05026157765128022
# Smiles Weight CI
# 0.5246413908505025 0.7249740386810704
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.77618036 40.00813536] [ 1.42609175 20.76569063] [0.80289805 0.5190367 ]
# (Manually) Weighted RMSE Train
# [0.2498189 6.1627575]
#
#
# epoch number:  186
# Coverages, CI Widths, RMSEs
# [0.6850886339937435, 0.6642335766423357] [0.6071376756448867, 13.989202166109749] [0.24464114294811992, 6.148239322376052]
# Smiles Weight Mean and Std Dev
# 0.6416154479638657 0.05091143755423918
# Smiles Weight CI
# 0.5287618388957965 0.7221266985546039
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78325979 40.14172368] [ 1.41115847 20.37886409] [0.79133645 0.50767287]
# (Manually) Weighted RMSE Train
# [0.24464114 6.14823932]
#
#
# epoch number:  187
# Coverages, CI Widths, RMSEs
# [0.656934306569343, 0.64859228362878] [0.5504271681539159, 12.59244490489938] [0.2508419051129439, 6.161952147550582]
# Smiles Weight Mean and Std Dev
# 0.6473738344806119 0.04656229944333095
# Smiles Weight CI
# 0.5521997207021664 0.7293256775497801
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7774981  40.03965432] [ 1.42699373 20.7748915 ] [0.80281027 0.51885791]
# (Manually) Weighted RMSE Train
# [0.25084191 6.16195215]
#
#
# epoch number:  188
# Coverages, CI Widths, RMSEs
# [0.6777893639207507, 0.6423357664233577] [0.5959612111738539, 13.460562697349511] [0.2475244010652427, 6.146763499410047]
# Smiles Weight Mean and Std Dev
# 0.6447030238673163 0.049042434765984445
# Smiles Weight CI
# 0.5190336315089499 0.7134202006825001
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78096801 40.11698688] [ 1.41820627 20.56837639] [0.79631204 0.5127099 ]
# (Manually) Weighted RMSE Train
# [0.2475244 6.1467635]
#
#
# epoch number:  189
# Coverages, CI Widths, RMSEs
# [0.7194994786235662, 0.6986444212721585] [0.6824998073676023, 15.471461406312724] [0.24643438113215665, 6.14068924951244]
# Smiles Weight Mean and Std Dev
# 0.6434078047917179 0.057370053529711924
# Smiles Weight CI
# 0.5193433081580118 0.7387559825152342
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78302424 40.16200816] [ 1.41504888 20.46263589] [0.79362291 0.50950231]
# (Manually) Weighted RMSE Train
# [0.24643438 6.14068925]
#
#
# epoch number:  190
# Coverages, CI Widths, RMSEs
# [0.6913451511991658, 0.662148070907195] [0.6070840580435088, 13.536530378496916] [0.24203810106709572, 6.150764830048868]
# Smiles Weight Mean and Std Dev
# 0.6379912926742142 0.053162495771083194
# Smiles Weight CI
# 0.5285036892308174 0.7220551359495834
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78982142 40.29707262] [ 1.39955565 20.06311411] [0.78195268 0.49788019]
# (Manually) Weighted RMSE Train
# [0.2420381  6.15076483]
#
#
# epoch number:  191
# Coverages, CI Widths, RMSEs
# [0.6642335766423357, 0.6517205422314911] [0.566208215014866, 13.04417743017891] [0.2492537220308552, 6.146580304983063]
# Smiles Weight Mean and Std Dev
# 0.645962469627065 0.05067106847369036
# Smiles Weight CI
# 0.5400608752818806 0.723252531065092
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78120679 40.16001978] [ 1.42083789 20.61239555] [0.79768273 0.51325661]
# (Manually) Weighted RMSE Train
# [0.24925372 6.1465803 ]
#
#
# epoch number:  192
# Coverages, CI Widths, RMSEs
# [0.7059436913451512, 0.6830031282586028] [0.6510044884117051, 14.80669076377872] [0.243348561378199, 6.138522196576226]
# Smiles Weight Mean and Std Dev
# 0.6398781785878435 0.05407348510492255
# Smiles Weight CI
# 0.5179397509363463 0.7333884509262926
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7890339  40.31274577] [ 1.40351057 20.17065221] [0.78450753 0.50035421]
# (Manually) Weighted RMSE Train
# [0.24334856 6.1385222 ]
#
#
# epoch number:  193
# Coverages, CI Widths, RMSEs
# [0.6892596454640251, 0.6663190823774765] [0.629243142613145, 14.297056261292493] [0.24047043122960543, 6.166180580518889]
# Smiles Weight Mean and Std Dev
# 0.6352943564995792 0.05344921725651492
# Smiles Weight CI
# 0.5181320077468244 0.7243352570893928
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79519548 40.42573596] [ 1.39021497 19.83379225] [0.77440868 0.49062291]
# (Manually) Weighted RMSE Train
# [0.24047043 6.16618058]
#
#
# epoch number:  194
# Coverages, CI Widths, RMSEs
# [0.6746611053180396, 0.656934306569343] [0.5876835082030165, 13.200237743108378] [0.24768995424110613, 6.137865747798712]
# Smiles Weight Mean and Std Dev
# 0.6445987852831397 0.048611994861055434
# Smiles Weight CI
# 0.5316805889396438 0.7235222504587545
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78577331 40.24724992] [ 1.41432334 20.47949191] [0.7919949  0.50884202]
# (Manually) Weighted RMSE Train
# [0.24768995 6.13786575]
#
#
# epoch number:  195
# Coverages, CI Widths, RMSEs
# [0.6475495307612096, 0.629822732012513] [0.5345210147217497, 12.087416247003036] [0.2504321907692966, 6.15165865362373]
# Smiles Weight Mean and Std Dev
# 0.64697627912266 0.04617434707645358
# Smiles Weight CI
# 0.5463046849835271 0.7204502678248336
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.78428938 40.22260698] [ 1.41995824 20.65850874] [0.79581163 0.51360442]
# (Manually) Weighted RMSE Train
# [0.25043219 6.15165865]
#
#
# epoch number:  196
# Coverages, CI Widths, RMSEs
# [0.6903023983315955, 0.6631908237747653] [0.6247406603774824, 14.020043325190514] [0.24414585590425475, 6.13346376477255]
# Smiles Weight Mean and Std Dev
# 0.6409399952826622 0.04845174786449133
# Smiles Weight CI
# 0.5235528857673889 0.7250215288007869
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7921883 40.3621188] [ 1.4026841  20.20335139] [0.78266558 0.5005523 ]
# (Manually) Weighted RMSE Train
# [0.24414586 6.13346376]
#
#
# epoch number:  197
# Coverages, CI Widths, RMSEs
# [0.7153284671532847, 0.6955161626694474] [0.6855707860582166, 15.288275954585014] [0.24380864161758517, 6.1335914564442575]
# Smiles Weight Mean and Std Dev
# 0.6406815057707824 0.04949034945091776
# Smiles Weight CI
# 0.514659220176448 0.7383354363426118
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79342405 40.38647211] [ 1.40067762 20.18582804] [0.7810075  0.49981657]
# (Manually) Weighted RMSE Train
# [0.24380864 6.13359146]
#
#
# epoch number:  198
# Coverages, CI Widths, RMSEs
# [0.7007299270072993, 0.6694473409801877] [0.6432275103232158, 14.492185274574018] [0.24309936013230815, 6.135811347356148]
# Smiles Weight Mean and Std Dev
# 0.6396259933179703 0.05385863007877358
# Smiles Weight CI
# 0.5193989663318477 0.7252438278676455
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.79520748 40.42940519] [ 1.39770731 20.09568152] [0.77857703 0.49705608]
# (Manually) Weighted RMSE Train
# [0.24309936 6.13581135]
#
#
# epoch number:  199
# Coverages, CI Widths, RMSEs
# [0.6736183524504692, 0.6590198123044838] [0.5825851858343288, 13.143191670715895] [0.2508299046279591, 6.15145701439404]
# Smiles Weight Mean and Std Dev
# 0.6469715373116469 0.04925416814000004
# Smiles Weight CI
# 0.5388362461919466 0.7246814033241938
# (WEIGHTED) Smiles Model RMSE, RDKIT Model RMSE, RDKIT_RMSE/SMILES_RMSE
# [ 1.7888784  40.30426601] [ 1.41781211 20.61981527] [0.79257042 0.51160379]
# (Manually) Weighted RMSE Train
# [0.2508299  6.15145701]
#
#
# done for fold1
# train_width[0.5407612142890313, 8.438417583861812]
# smiles_weight0.6699049363053301
# rmse_train[0.15141961459412345, 0.17444060201806894]
# smiles_weight_ci[0.5680088097789933, 0.7536773915211935]
# CPU times: user 1h 45s, sys: 37min 56s, total: 1h 38min 42s
# Wall time: 32min 30s

# %%
with open("..//Data/returned_stuff1_config1.pickle", "wb") as f: 
    pickle.dump(returned_stuff1, f)

# %%
plt.plot(range(0, len(returned_stuff[-2])),returned_stuff[-2])
plt.plot(range(len(returned_stuff[-2]), len(returned_stuff[-2]) + len(returned_stuff1[-2])), returned_stuff1[-2])
plt.xlabel("Update Index")
plt.ylabel("Average Smiles Weight")
plt.show()

# %%
returned_stuff_1_unr = np.array(returned_stuff[-1])
returned_stuff_2_unr = np.array(returned_stuff1[-1])

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,0])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,0])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT AlogP RMSE/ Smiles AlogP RMSE)")
plt.show()

# %%
plt.plot(range(0, len(returned_stuff_1_unr)),returned_stuff_1_unr[:,1])
plt.plot(range(len(returned_stuff_1_unr), len(returned_stuff_1_unr) + len(returned_stuff_2_unr)), returned_stuff_2_unr[:,1])
plt.xlabel("Update Index")
plt.ylabel("Ratio (RDKIT PSA RMSE/ Smiles PSA RMSE)")
plt.show()

# %%
# returned_stuff1
